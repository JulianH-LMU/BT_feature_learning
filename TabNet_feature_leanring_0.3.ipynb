# %% [markdown]
# ## Change Log
# - Use KL divergence in custom loss function
# - determin number of bins for distributions using Freedman-Diaconis rule
# - added test_size to config
# - now using CUDA (GPU) instead of CPU (if NVIDIA Cuda available)
# - save output data and models for multiple runs

# %%
# %%javascript
# IPython.notebook.kernel.execute('nb_name = "' + IPython.notebook.notebook_name + '"')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import random
import math

import sys
import os
sys.path.append(os.getcwd() + "/pytorch_tabnet/")

from sklearn.cluster import DBSCAN
from scipy.special import rel_entr

# %% [markdown]
# ## 0. Experiment Setup

# %%
# should an output folder be created to save the experiment data?
save_output = True

# %%
# read config file
import toml
config = toml.load("config.toml")

# rnd seed to support reproducable results
seed_value =  config["general"]["random_seed"] if config["general"]["random_seed"] else random.randrange(sys.maxsize)
random.seed(seed_value)

# TabNet hyperparameters
regressor_param = {"optimizer_fn" : torch.optim.Adam,
                   "optimizer_params" : {"lr":0.05},
                   "scheduler_params" : {"step_size": 2, "gamma": 0.9},
                   "scheduler_fn" : torch.optim.lr_scheduler.StepLR,
                   "mask_type" : 'entmax',
                   "device_name" : 'cuda', # only working on NVIDIA GPUs
                  }

if save_output:
    # create experiment folder
    from datetime import datetime
    
    experiment_name = config["general"]["experiment_name"]
    experiment_folder = f"{experiment_name} {datetime.now().strftime('%Y_%m_%d %H-%M-%S')}" if experiment_name else f"Exp {datetime.now().strftime('%Y_%m_%d %H-%M-%S')}"
    
    experiment_path = os.path.join("Experiments", experiment_folder)
    os.mkdir(experiment_path)
    
    plots_path = os.path.join(experiment_path, "plots")
    os.mkdir(plots_path)
    
    models_path = os.path.join(experiment_path, "models")
    os.mkdir(models_path)
    
    # save config file
    import shutil
    shutil.copy2("config.toml", experiment_path)
    
    # save random seed
    if not config["general"]["random_seed"]:
        config["general"]["random_seed"] = seed_value
        config_path = os.path.join(experiment_path, "config.toml")
        with open(config_path, "w") as f:
            toml.dump(config, f)
    
    # save model hyperparameters
    with open(os.path.join(experiment_path, 'config.toml'), 'a') as config_file:
        config_file.write("\n#[regressor_param]\n")
        for key, value in regressor_param.items(): 
            config_file.write('#%s = %s\n' % (key, str(value)))
    
    # save notebook
    shutil.copy2(nb_name, experiment_path)#
    
    # create output file
    output_path = os.path.join(experiment_path, "output.toml")
    output_file = open(output_path, "w")
    output = {}

# %% [markdown]
# ## 1. Datasets
#
# Different datasets are to be used for the experiments.
# - toy dataset using make_blobs from sklearn mainly to setup and test the notebook
# - DAMI Benchmark datasets with the respective best practice hyperparameters (https://www.dbs.ifi.lmu.de/research/outlier-evaluation/DAMI/)
#
# ### 1.0. Create toy dataset
# As of now, only a toy dataset is used (n_features features with clusters centered around different points).

# %%
from sklearn.datasets import make_blobs

features_arr, clusters_arr = make_blobs(**config["toy_data"])

# name feature and cluster (ground truth) columns
features = pd.DataFrame(features_arr, columns=[f"F{x + 1}" for x in range(features_arr.shape[1])])
clusters = pd.DataFrame(clusters_arr, columns=["C"])

# %% [markdown]
# ### 1.1. plot data

# %%
# plot dataset
# %matplotlib notebook
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(projection='3d')
ax.scatter(features_arr[:, 0], features_arr[:, 1], features_arr[:, 2], c=clusters_arr)
plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "0_ground_truth_clusters.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### 1.2. Create missing data
# Create a specified amount of missing values in the given feature columns (for complete datasets).

# %%
# create missing values in feature column(s)
mv_config = {feature:mv_ratio for feature,mv_ratio in zip(list(features.columns), config["general"]["missing_percent"])}
features_mv = features.copy()

for f, mv in mv_config.items():
    features_mv[f] = features_mv[f].mask(np.random.random(features.shape[0]) < mv)

# %%
import missingno as msno
# %matplotlib inline

# plot missing values
fig = msno.matrix(features_mv)
plt.show()
if save_output:
    #plt.savefig(os.path.join(plots_path, "missing_values.png"), **config["plots"])
    fig_copy = fig.get_figure()
    fig_copy.savefig(os.path.join(plots_path, "missing_values.png"), **config["plots"], bbox_inches = 'tight')

# %% [markdown]
# ### 1.3. Initial Clustering (without missing values)
# Use the cluster algorithm on dataset without missing values.\
# Get cluster means for loss function input.

# %%
# run DBSCAN on original data
dbscan_orig = DBSCAN(**config["DBSCAN"]).fit(features)
clusters_orig = dbscan_orig.labels_

# %%
# plot clustering
# %matplotlib notebook
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(projection='3d')
ax.scatter(features.iloc[:, 0], features.iloc[:, 1], features.iloc[:, 2], c=clusters_orig)
plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "1_DBSCAN_original_data.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# get cluster means (used to calculate the cluster mean loss)
complete_data = features.copy()
complete_data["C"] = clusters_orig
cluster_means = complete_data.groupby("C").agg("mean")
cluster_means = cluster_means if -1 not in cluster_means.index else cluster_means.drop(-1)

# %% [markdown]
# ## 2. Filling Strategies
#
#
# ### 2.1. Define custom-loss
# The loss function for the model fitting shall be customized to improve cluster perforamnce. The custom loss is divided into 2 separate losses
#
# 1. **Reconstruction Loss**\
# Classic loss function, such as RMSE.
# 2. **Cluster-Mean Loss**\
# The distance to the nearest cluster mean shall be minimized.
# 3. **KL Divergence Loss**\
# Deviation of original distribution shall be minimized \
# (prob distribution based on https://stackoverflow.com/questions/57687458/how-to-calculate-probabilities-using-numpy-histogram-and-then-use-it-for-calcula \
# number of bins: D. Freedman & P. Diaconis (1981) “On the histogram as a density estimator: L2 theory”. Probability Theory and Related Fields 57 (4): 453-476)
#
# The chosen approach to implement the cluster-mean loss is as follows:\
# **Adapt the loss function** to calculate a distance to each cluster. The minimum distance (to the nearest cluster) will be used as a cluster-mean-loss. Minimizing this loss should result in the data point moving closer to the nearest cluster mean.\
# Potential Problem: loss functions currently work with y_true (true values) and y_score (predicted values). Calculating the distance would require all features. Calculating only the 1 dimensional distance will result in missing values being put into wrong clusters - depending on the first estimate.

# %%
# define custom loss function: extend L2-loss by cluster-mean-loss

from pytorch_tabnet.metrics import Metric
from sklearn.metrics import mean_squared_error
import astropy.stats

class custom_loss(Metric):

    def __init__(self):
        self._name = "custom_loss"
        self._maximize = False

    def __call__(self, y_true, y_score, cluster_means, target_feature, x_val, y_val):
        # reconstruction loss
        rmse = np.sqrt(mean_squared_error(y_true, y_score))
        
        # cluster mean loss
        cml = self.cluster_mean_loss(cluster_means, y_score, target_feature, x_val, y_val)
        
        # KL divergence loss
        bins = len(astropy.stats.freedman_bin_width(y_true.reshape(1,-1)[0], return_bins=True)[1])
        distr1, distr2 = self.probability_dist(y_score, y_true, bins)
        KLdl = torch.nn.functional.kl_div(torch.tensor(distr1).log(), torch.tensor(distr2), log_target=False, reduction='sum').item()
        
        # total loss
        custom_loss = rmse + KLdl + cml
        return custom_loss
    
    # calculate sum of distances to the closest cluster mean
    def cluster_mean_loss(self, cluster_means, y_score, target_feature, x_val, y_val):
        
        # reorder cluster_means to match x_val columns (predicted feature is last column)
        cols = cluster_means.columns.tolist()
        feature_col = features.columns.get_loc(target_feature)
        cols = cols[:feature_col] + cols[feature_col+1:] + [target_feature]
        
        # x values extended by predicted values
        x_extended = pd.DataFrame(np.hstack((x_val, y_score)), columns=cols)


        # calculate distances to each cluster and select the closest one
        dist = []
        for cluster in range(cluster_means.shape[0]):
            dist.append(np.linalg.norm((x_extended - cluster_means.iloc[cluster]), axis=1))
            
        dist = pd.DataFrame(dist).T
        min_dist = dist.assign(min_dist=lambda d: d.min(1))["min_dist"]
        
        return sum(min_dist)
    
    # calculate probabilities
    def probability_dist(self, x, y, bins):
        # transforms 2 series into their probability distributions
        # histogram
        hist_xy = np.histogram2d(np.asarray(x)[:,0], np.asarray(y)[:,0], bins=bins)[0]

        # compute marginals
        hist_xy = hist_xy + sys.float_info.min # prevent division with 0
        hist_xy = hist_xy / np.sum(hist_xy)
        hist_x = np.sum(hist_xy, axis=1)
        hist_y = np.sum(hist_xy, axis=0)
        return(hist_x, hist_y)

# %% [markdown]
# ### 2.2. Fill missing values (TabNet).
#
# **Approach 1:**\
# For each feature that contains missing values, use all rows with complete other features as train set and predict missing values of the feature.\
# &rarr; Problem: lots of models, especially for high-dimensional datasets.
# Also problem, if more than one feature is missing values. &rarr; see Approach 2
#
# **Approach 2:**\
# Mask missing values as -1 (or some other value) and fit a model predicting each feature just like in approach 1.\
# &rarr; one model for each feature containing missing values.\
# Possible adaption: use predicted values to predict subsequent values (instead of using -1)

# %%
import time

from pytorch_tabnet.tab_model import TabNetRegressor
from sklearn.model_selection import train_test_split

features_to_predict = features_mv.columns[features_mv.isnull().any()]
features_reconstr = []
costs = {}
output["runtimes"] = {}

for run in range(config["RQ2"]["runs"]):
    time_start = time.time()
    features_reconstr.append(features_mv.copy())
    costs[run] = []
    for feature in features_to_predict:
        print(f"Run {run+1}, predicting {feature}")

        # select % of features for prediction based on pred_features (e.g. 10% of randomly selected features)
        number_of_features = math.ceil(config["RQ2"]["pred_features"] * (len(features_mv.columns)) - 1)
        features_mv_masked = features_mv.copy().drop(feature, axis=1).sample(n=number_of_features, axis='columns')
        selected_features = features_mv_masked.columns
        
        print(f"Predictions based on features {list(selected_features)}")
        
        # mask other columns' missing values as defined in config (missing_value_mask)
        features_mv_masked[feature] = features_mv[feature]
        features_mv_masked[selected_features] = features_mv_masked[(selected_features)].fillna(config["general"]["missing_value_mask"])
        
        # separate complete rows as train data
        # separate column with missing values as target
        test_data = features_mv_masked[features_mv_masked[feature].isna()].drop(feature, axis=1).to_numpy()
        train_data = features_mv_masked[features_mv_masked[feature].notna()]
        train_features = train_data.drop(columns=feature).to_numpy()
        train_target = train_data[feature].to_numpy().reshape(-1,1)

        x_train, x_val, y_train, y_val = train_test_split(train_features, train_target, test_size=config["training"]["test_size"])

        # create & train model
        model = TabNetRegressor(**regressor_param)
        model.fit(
            x_train, y_train,
            eval_set=[(x_val, y_val)],
            eval_metric=['custom_loss'],
            **config["model_param"],
            cluster_means=cluster_means,
            target_feature=feature,
            x_val=x_val,
            y_val=y_val,
        )

        #track runtime
        time_end = time.time()
        
        # add costs to dict
        costs[run].append(model.best_cost)
        

        # fill missing values with model predictions
        features_reconstr[run].loc[features_reconstr[run][feature].isna(), feature] = [x[0] for x in model.predict(test_data)]

        # save outputs
        if save_output:
            
            # save model
            torch.save(model, os.path.join(models_path, f"Model_run{run}_{feature}.pt"))
            
            # save runtimes
            output["runtimes"][f"run{run}_{feature}"] = time_end - time_start
# Out:
# Run 1, predicting F2
# Predictions based on features ['F1', 'F3']
# Device used : cpu
# epoch 0  | loss: 52.66152| val_0_custom_loss: 1550.21984|  0:00:00s
# epoch 1  | loss: 29.18482| val_0_custom_loss: 2295.50395|  0:00:00s
# epoch 2  | loss: 16.28622| val_0_custom_loss: 2462.28925|  0:00:00s
# epoch 3  | loss: 12.17543| val_0_custom_loss: 1935.82159|  0:00:00s
# epoch 4  | loss: 10.8615 | val_0_custom_loss: 1665.53277|  0:00:00s
# epoch 5  | loss: 8.86721 | val_0_custom_loss: 1303.3718|  0:00:00s
# epoch 6  | loss: 8.28565 | val_0_custom_loss: 1078.8862|  0:00:00s
# epoch 7  | loss: 10.30868| val_0_custom_loss: 970.72222|  0:00:00s
# epoch 8  | loss: 7.33122 | val_0_custom_loss: 937.77657|  0:00:00s
# epoch 9  | loss: 7.68244 | val_0_custom_loss: 899.14138|  0:00:00s
# epoch 10 | loss: 9.27489 | val_0_custom_loss: 829.8843|  0:00:00s
# epoch 11 | loss: 7.37224 | val_0_custom_loss: 730.52733|  0:00:00s
# epoch 12 | loss: 7.49177 | val_0_custom_loss: 644.0482|  0:00:00s
# epoch 13 | loss: 7.36    | val_0_custom_loss: 606.78468|  0:00:00s
# epoch 14 | loss: 8.32073 | val_0_custom_loss: 595.42397|  0:00:00s
# epoch 15 | loss: 8.37462 | val_0_custom_loss: 580.46501|  0:00:00s
# epoch 16 | loss: 7.51712 | val_0_custom_loss: 562.56439|  0:00:00s
# epoch 17 | loss: 7.58131 | val_0_custom_loss: 523.14722|  0:00:00s
# epoch 18 | loss: 7.48487 | val_0_custom_loss: 464.80169|  0:00:00s
# epoch 19 | loss: 6.74588 | val_0_custom_loss: 393.53574|  0:00:00s
# epoch 20 | loss: 6.96802 | val_0_custom_loss: 307.54822|  0:00:00s
# epoch 21 | loss: 7.53605 | val_0_custom_loss: 266.93655|  0:00:01s
# epoch 22 | loss: 8.35692 | val_0_custom_loss: 271.76355|  0:00:01s
# epoch 23 | loss: 6.80037 | val_0_custom_loss: 306.43334|  0:00:01s
# epoch 24 | loss: 6.68486 | val_0_custom_loss: 332.10457|  0:00:01s
# epoch 25 | loss: 9.16796 | val_0_custom_loss: 334.99739|  0:00:01s
# epoch 26 | loss: 6.99803 | val_0_custom_loss: 332.38286|  0:00:01s
# epoch 27 | loss: 6.32554 | val_0_custom_loss: 309.47148|  0:00:01s
# epoch 28 | loss: 7.13605 | val_0_custom_loss: 303.05386|  0:00:01s
# epoch 29 | loss: 7.59586 | val_0_custom_loss: 293.09146|  0:00:01s
# epoch 30 | loss: 6.48898 | val_0_custom_loss: 269.62708|  0:00:01s
# epoch 31 | loss: 7.90668 | val_0_custom_loss: 262.38345|  0:00:01s
# epoch 32 | loss: 6.40523 | val_0_custom_loss: 258.1501|  0:00:01s
# epoch 33 | loss: 6.46125 | val_0_custom_loss: 245.68891|  0:00:01s
# epoch 34 | loss: 6.56665 | val_0_custom_loss: 234.45689|  0:00:01s
# epoch 35 | loss: 6.45611 | val_0_custom_loss: 230.46154|  0:00:01s
# epoch 36 | loss: 6.24386 | val_0_custom_loss: 220.53989|  0:00:01s
# epoch 37 | loss: 6.15258 | val_0_custom_loss: 211.62952|  0:00:01s
# epoch 38 | loss: 6.54195 | val_0_custom_loss: 200.63877|  0:00:01s
# epoch 39 | loss: 6.08726 | val_0_custom_loss: 194.22593|  0:00:01s
# epoch 40 | loss: 6.58112 | val_0_custom_loss: 192.34718|  0:00:01s
# epoch 41 | loss: 6.70091 | val_0_custom_loss: 189.92492|  0:00:01s
# epoch 42 | loss: 6.00108 | val_0_custom_loss: 187.47974|  0:00:01s
# epoch 43 | loss: 6.83554 | val_0_custom_loss: 184.29944|  0:00:01s
# epoch 44 | loss: 6.22237 | val_0_custom_loss: 182.02177|  0:00:01s
# epoch 45 | loss: 6.27164 | val_0_custom_loss: 179.87805|  0:00:02s
# epoch 46 | loss: 6.38164 | val_0_custom_loss: 178.72483|  0:00:02s
# epoch 47 | loss: 5.79892 | val_0_custom_loss: 177.36359|  0:00:02s
# epoch 48 | loss: 6.15959 | val_0_custom_loss: 172.24245|  0:00:02s
# epoch 49 | loss: 6.10102 | val_0_custom_loss: 169.98248|  0:00:02s
# epoch 50 | loss: 5.97586 | val_0_custom_loss: 170.49246|  0:00:02s
# epoch 51 | loss: 6.32879 | val_0_custom_loss: 170.20718|  0:00:02s
# epoch 52 | loss: 6.5127  | val_0_custom_loss: 171.44856|  0:00:02s
# epoch 53 | loss: 6.74275 | val_0_custom_loss: 170.72377|  0:00:02s
# epoch 54 | loss: 6.40132 | val_0_custom_loss: 168.99346|  0:00:02s
# epoch 55 | loss: 6.23437 | val_0_custom_loss: 168.49818|  0:00:02s
# epoch 56 | loss: 6.84689 | val_0_custom_loss: 167.70489|  0:00:02s
# epoch 57 | loss: 6.17463 | val_0_custom_loss: 166.01786|  0:00:02s
# epoch 58 | loss: 5.58982 | val_0_custom_loss: 161.7611|  0:00:02s
# epoch 59 | loss: 6.03278 | val_0_custom_loss: 159.15813|  0:00:02s
# epoch 60 | loss: 5.68786 | val_0_custom_loss: 157.89999|  0:00:02s
# epoch 61 | loss: 7.73647 | val_0_custom_loss: 157.03272|  0:00:02s
# epoch 62 | loss: 6.71486 | val_0_custom_loss: 155.51738|  0:00:02s
# epoch 63 | loss: 5.90061 | val_0_custom_loss: 153.9562|  0:00:02s
# epoch 64 | loss: 6.56688 | val_0_custom_loss: 152.6908|  0:00:02s
# epoch 65 | loss: 6.10645 | val_0_custom_loss: 151.20337|  0:00:02s
# epoch 66 | loss: 5.68171 | val_0_custom_loss: 149.63533|  0:00:02s
# epoch 67 | loss: 6.51383 | val_0_custom_loss: 148.46175|  0:00:02s
# epoch 68 | loss: 6.06748 | val_0_custom_loss: 147.65958|  0:00:02s
# epoch 69 | loss: 6.17956 | val_0_custom_loss: 146.88466|  0:00:03s
# epoch 70 | loss: 5.74819 | val_0_custom_loss: 146.12033|  0:00:03s
# epoch 71 | loss: 6.6184  | val_0_custom_loss: 145.22013|  0:00:03s
# epoch 72 | loss: 5.4109  | val_0_custom_loss: 144.32411|  0:00:03s
# epoch 73 | loss: 7.85835 | val_0_custom_loss: 143.52295|  0:00:03s
# epoch 74 | loss: 6.44119 | val_0_custom_loss: 142.64062|  0:00:03s
# epoch 75 | loss: 5.87967 | val_0_custom_loss: 141.82349|  0:00:03s
# epoch 76 | loss: 5.49279 | val_0_custom_loss: 141.1613|  0:00:03s
# epoch 77 | loss: 6.19461 | val_0_custom_loss: 140.48327|  0:00:03s
# epoch 78 | loss: 7.25557 | val_0_custom_loss: 139.9206|  0:00:03s
# epoch 79 | loss: 6.0709  | val_0_custom_loss: 139.32351|  0:00:03s
# epoch 80 | loss: 6.57939 | val_0_custom_loss: 138.70417|  0:00:03s
# epoch 81 | loss: 7.80331 | val_0_custom_loss: 138.22747|  0:00:03s
# epoch 82 | loss: 5.40999 | val_0_custom_loss: 137.71154|  0:00:03s
# epoch 83 | loss: 5.90164 | val_0_custom_loss: 137.16365|  0:00:03s
# epoch 84 | loss: 6.21762 | val_0_custom_loss: 136.62338|  0:00:03s
# epoch 85 | loss: 5.8045  | val_0_custom_loss: 136.11011|  0:00:03s
# epoch 86 | loss: 5.32421 | val_0_custom_loss: 135.58643|  0:00:03s
# epoch 87 | loss: 7.19977 | val_0_custom_loss: 135.14166|  0:00:03s
# epoch 88 | loss: 6.09153 | val_0_custom_loss: 134.76296|  0:00:03s
# epoch 89 | loss: 6.52773 | val_0_custom_loss: 134.41274|  0:00:03s
# epoch 90 | loss: 5.70692 | val_0_custom_loss: 134.08842|  0:00:03s
# epoch 91 | loss: 6.32077 | val_0_custom_loss: 133.77552|  0:00:04s
# epoch 92 | loss: 5.88558 | val_0_custom_loss: 133.54014|  0:00:04s
# epoch 93 | loss: 6.604   | val_0_custom_loss: 133.24721|  0:00:04s
# epoch 94 | loss: 6.30062 | val_0_custom_loss: 132.9724|  0:00:04s
# epoch 95 | loss: 6.12319 | val_0_custom_loss: 196.92516|  0:00:04s
# epoch 96 | loss: 5.92431 | val_0_custom_loss: 196.70911|  0:00:04s
# epoch 97 | loss: 6.38604 | val_0_custom_loss: 196.4646|  0:00:04s
# epoch 98 | loss: 6.27184 | val_0_custom_loss: 196.20705|  0:00:04s
# epoch 99 | loss: 6.00798 | val_0_custom_loss: 195.94785|  0:00:04s
# epoch 100| loss: 7.97236 | val_0_custom_loss: 195.74531|  0:00:04s
# epoch 101| loss: 6.1593  | val_0_custom_loss: 195.58497|  0:00:04s
# epoch 102| loss: 5.99736 | val_0_custom_loss: 131.21861|  0:00:04s
# epoch 103| loss: 6.01756 | val_0_custom_loss: 131.04519|  0:00:04s
# epoch 104| loss: 6.22195 | val_0_custom_loss: 130.86206|  0:00:04s
# epoch 105| loss: 6.99983 | val_0_custom_loss: 130.71637|  0:00:04s
# epoch 106| loss: 5.58329 | val_0_custom_loss: 130.55843|  0:00:04s
# epoch 107| loss: 6.3447  | val_0_custom_loss: 130.3839|  0:00:04s
# epoch 108| loss: 5.63746 | val_0_custom_loss: 130.17586|  0:00:04s
# epoch 109| loss: 5.96979 | val_0_custom_loss: 130.02091|  0:00:04s
# epoch 110| loss: 5.3638  | val_0_custom_loss: 129.87967|  0:00:04s
# epoch 111| loss: 6.279   | val_0_custom_loss: 129.73577|  0:00:04s
# epoch 112| loss: 6.11051 | val_0_custom_loss: 129.64547|  0:00:04s
# epoch 113| loss: 6.43601 | val_0_custom_loss: 129.54033|  0:00:04s
# epoch 114| loss: 7.36914 | val_0_custom_loss: 129.44856|  0:00:04s
# epoch 115| loss: 5.07148 | val_0_custom_loss: 129.2997|  0:00:05s
# epoch 116| loss: 5.82903 | val_0_custom_loss: 129.20311|  0:00:05s
# epoch 117| loss: 6.27143 | val_0_custom_loss: 129.15534|  0:00:05s
# epoch 118| loss: 5.48218 | val_0_custom_loss: 129.04137|  0:00:05s
# epoch 119| loss: 5.66036 | val_0_custom_loss: 128.94666|  0:00:05s
# epoch 120| loss: 6.48688 | val_0_custom_loss: 128.85513|  0:00:05s
# epoch 121| loss: 6.25439 | val_0_custom_loss: 128.75874|  0:00:05s
# epoch 122| loss: 5.2588  | val_0_custom_loss: 128.70272|  0:00:05s
# epoch 123| loss: 5.5114  | val_0_custom_loss: 128.63465|  0:00:05s
# epoch 124| loss: 5.76257 | val_0_custom_loss: 128.57501|  0:00:05s
# epoch 125| loss: 6.61748 | val_0_custom_loss: 128.56143|  0:00:05s
# epoch 126| loss: 6.79884 | val_0_custom_loss: 128.52486|  0:00:05s
# epoch 127| loss: 6.30568 | val_0_custom_loss: 128.56773|  0:00:05s
# epoch 128| loss: 5.78932 | val_0_custom_loss: 128.54374|  0:00:05s
# epoch 129| loss: 6.19318 | val_0_custom_loss: 128.51549|  0:00:05s
# epoch 130| loss: 6.35109 | val_0_custom_loss: 128.38676|  0:00:05s
# epoch 131| loss: 6.65838 | val_0_custom_loss: 128.34907|  0:00:05s
# epoch 132| loss: 5.93906 | val_0_custom_loss: 128.34218|  0:00:05s
# epoch 133| loss: 5.73798 | val_0_custom_loss: 128.34803|  0:00:05s
# epoch 134| loss: 6.18837 | val_0_custom_loss: 128.35343|  0:00:05s
# epoch 135| loss: 5.3661  | val_0_custom_loss: 128.37854|  0:00:05s
# epoch 136| loss: 6.74637 | val_0_custom_loss: 128.46695|  0:00:05s
# epoch 137| loss: 5.97596 | val_0_custom_loss: 128.47802|  0:00:05s
# epoch 138| loss: 5.6624  | val_0_custom_loss: 128.53045|  0:00:05s
# epoch 139| loss: 6.43463 | val_0_custom_loss: 128.61764|  0:00:06s
# epoch 140| loss: 5.79894 | val_0_custom_loss: 128.60969|  0:00:06s
# epoch 141| loss: 5.28165 | val_0_custom_loss: 128.61336|  0:00:06s
# epoch 142| loss: 6.06387 | val_0_custom_loss: 128.65855|  0:00:06s
# epoch 143| loss: 5.39401 | val_0_custom_loss: 128.71073|  0:00:06s
# epoch 144| loss: 6.32299 | val_0_custom_loss: 128.80506|  0:00:06s
# epoch 145| loss: 5.77678 | val_0_custom_loss: 128.88769|  0:00:06s
# epoch 146| loss: 5.81982 | val_0_custom_loss: 128.98061|  0:00:06s
# epoch 147| loss: 6.23297 | val_0_custom_loss: 129.10682|  0:00:06s
# epoch 148| loss: 6.32357 | val_0_custom_loss: 129.24738|  0:00:06s
# epoch 149| loss: 6.00328 | val_0_custom_loss: 129.40637|  0:00:06s
# epoch 150| loss: 5.51492 | val_0_custom_loss: 129.56375|  0:00:06s
# epoch 151| loss: 5.72543 | val_0_custom_loss: 129.71658|  0:00:06s
# epoch 152| loss: 5.32173 | val_0_custom_loss: 129.82115|  0:00:06s
# epoch 153| loss: 5.88629 | val_0_custom_loss: 129.90859|  0:00:06s
# epoch 154| loss: 6.49472 | val_0_custom_loss: 129.84519|  0:00:06s
# epoch 155| loss: 5.20957 | val_0_custom_loss: 129.81691|  0:00:06s
# epoch 156| loss: 6.21929 | val_0_custom_loss: 129.71152|  0:00:06s
# epoch 157| loss: 5.61465 | val_0_custom_loss: 129.66528|  0:00:06s
# epoch 158| loss: 6.53672 | val_0_custom_loss: 129.61861|  0:00:06s
# epoch 159| loss: 5.74833 | val_0_custom_loss: 129.57753|  0:00:06s
# epoch 160| loss: 5.82584 | val_0_custom_loss: 129.54491|  0:00:06s
# epoch 161| loss: 5.29892 | val_0_custom_loss: 129.50999|  0:00:07s
# epoch 162| loss: 5.59405 | val_0_custom_loss: 129.47257|  0:00:07s
# epoch 163| loss: 5.75108 | val_0_custom_loss: 129.44213|  0:00:07s
# epoch 164| loss: 5.98323 | val_0_custom_loss: 129.42887|  0:00:07s
# epoch 165| loss: 6.23261 | val_0_custom_loss: 129.34309|  0:00:07s
# epoch 166| loss: 5.96364 | val_0_custom_loss: 129.34355|  0:00:07s
# epoch 167| loss: 6.10522 | val_0_custom_loss: 129.33024|  0:00:07s
# epoch 168| loss: 6.75157 | val_0_custom_loss: 129.26966|  0:00:07s
# epoch 169| loss: 6.43181 | val_0_custom_loss: 129.24619|  0:00:07s
# epoch 170| loss: 6.52011 | val_0_custom_loss: 129.15722|  0:00:07s
# epoch 171| loss: 5.60467 | val_0_custom_loss: 129.06817|  0:00:07s
# epoch 172| loss: 5.32591 | val_0_custom_loss: 129.02602|  0:00:07s
# epoch 173| loss: 7.70787 | val_0_custom_loss: 128.98697|  0:00:07s
# epoch 174| loss: 5.60344 | val_0_custom_loss: 128.911 |  0:00:07s
# epoch 175| loss: 5.57109 | val_0_custom_loss: 128.90803|  0:00:07s
# epoch 176| loss: 6.02709 | val_0_custom_loss: 128.94434|  0:00:07s
# epoch 177| loss: 6.08544 | val_0_custom_loss: 128.89457|  0:00:07s
# epoch 178| loss: 7.86647 | val_0_custom_loss: 128.85024|  0:00:07s
# epoch 179| loss: 5.55297 | val_0_custom_loss: 128.83985|  0:00:07s
# epoch 180| loss: 6.42469 | val_0_custom_loss: 128.80566|  0:00:07s
# epoch 181| loss: 5.74787 | val_0_custom_loss: 128.80084|  0:00:07s
# epoch 182| loss: 6.47936 | val_0_custom_loss: 128.75699|  0:00:07s
#
# Early stopping occurred at epoch 182 with best_epoch = 132 and best_val_0_custom_loss = 128.34218
# Best weights from best epoch are automatically used!
# Run 1, predicting F3
# Predictions based on features ['F1', 'F2']
# Device used : cpu
# epoch 0  | loss: 32.73735| val_0_custom_loss: 4439.20102|  0:00:00s
# epoch 1  | loss: 17.27455| val_0_custom_loss: 4114.6277|  0:00:00s
# epoch 2  | loss: 13.0635 | val_0_custom_loss: 2816.2875|  0:00:00s
# epoch 3  | loss: 6.81651 | val_0_custom_loss: 2338.36602|  0:00:00s
# epoch 4  | loss: 5.11425 | val_0_custom_loss: 1140.6208|  0:00:00s
# epoch 5  | loss: 3.31198 | val_0_custom_loss: 901.47466|  0:00:00s
# epoch 6  | loss: 2.75867 | val_0_custom_loss: 717.61251|  0:00:00s
# epoch 7  | loss: 2.35394 | val_0_custom_loss: 614.93774|  0:00:00s
# epoch 8  | loss: 2.66636 | val_0_custom_loss: 532.54346|  0:00:00s
# epoch 9  | loss: 2.50182 | val_0_custom_loss: 523.20614|  0:00:00s
# epoch 10 | loss: 2.45687 | val_0_custom_loss: 541.31  |  0:00:00s
# epoch 11 | loss: 2.3162  | val_0_custom_loss: 559.89938|  0:00:00s
# epoch 12 | loss: 2.31278 | val_0_custom_loss: 511.35647|  0:00:00s
# epoch 13 | loss: 2.07807 | val_0_custom_loss: 449.26359|  0:00:00s
# epoch 14 | loss: 2.64086 | val_0_custom_loss: 397.7975|  0:00:00s
# epoch 15 | loss: 2.07819 | val_0_custom_loss: 373.47069|  0:00:00s
# epoch 16 | loss: 2.21201 | val_0_custom_loss: 361.43675|  0:00:00s
# epoch 17 | loss: 2.12011 | val_0_custom_loss: 350.6731|  0:00:00s
# epoch 18 | loss: 2.24892 | val_0_custom_loss: 330.58197|  0:00:00s
# epoch 19 | loss: 2.14392 | val_0_custom_loss: 317.37698|  0:00:00s
# epoch 20 | loss: 1.99729 | val_0_custom_loss: 309.55888|  0:00:00s
# epoch 21 | loss: 2.10686 | val_0_custom_loss: 310.41962|  0:00:00s
# epoch 22 | loss: 2.04596 | val_0_custom_loss: 311.8006|  0:00:01s
# epoch 23 | loss: 2.03255 | val_0_custom_loss: 317.26221|  0:00:01s
# epoch 24 | loss: 1.96913 | val_0_custom_loss: 314.10985|  0:00:01s
# epoch 25 | loss: 1.93034 | val_0_custom_loss: 304.77015|  0:00:01s
# epoch 26 | loss: 2.31607 | val_0_custom_loss: 292.98046|  0:00:01s
# epoch 27 | loss: 1.81654 | val_0_custom_loss: 279.87693|  0:00:01s
# epoch 28 | loss: 1.85189 | val_0_custom_loss: 266.62131|  0:00:01s
# epoch 29 | loss: 2.243   | val_0_custom_loss: 255.94666|  0:00:01s
# epoch 30 | loss: 1.8598  | val_0_custom_loss: 247.44261|  0:00:01s
# epoch 31 | loss: 1.86695 | val_0_custom_loss: 240.5037|  0:00:01s
# epoch 32 | loss: 2.2028  | val_0_custom_loss: 234.1987|  0:00:01s
# epoch 33 | loss: 2.10475 | val_0_custom_loss: 226.80762|  0:00:01s
# epoch 34 | loss: 1.81936 | val_0_custom_loss: 219.85858|  0:00:01s
# epoch 35 | loss: 1.88841 | val_0_custom_loss: 213.96832|  0:00:01s
# epoch 36 | loss: 1.94832 | val_0_custom_loss: 209.22195|  0:00:01s
# epoch 37 | loss: 1.9265  | val_0_custom_loss: 205.88454|  0:00:01s
# epoch 38 | loss: 1.77685 | val_0_custom_loss: 203.17463|  0:00:01s
# epoch 39 | loss: 2.09856 | val_0_custom_loss: 201.19096|  0:00:01s
# epoch 40 | loss: 1.8298  | val_0_custom_loss: 198.82261|  0:00:01s
# epoch 41 | loss: 1.99826 | val_0_custom_loss: 196.70823|  0:00:01s
# epoch 42 | loss: 1.82395 | val_0_custom_loss: 194.29494|  0:00:01s
# epoch 43 | loss: 1.84236 | val_0_custom_loss: 192.44177|  0:00:01s
# epoch 44 | loss: 1.9771  | val_0_custom_loss: 190.46949|  0:00:01s
# epoch 45 | loss: 2.53256 | val_0_custom_loss: 189.69387|  0:00:01s
# epoch 46 | loss: 1.98947 | val_0_custom_loss: 188.45728|  0:00:02s
# epoch 47 | loss: 1.98929 | val_0_custom_loss: 186.55629|  0:00:02s
# epoch 48 | loss: 1.67307 | val_0_custom_loss: 184.77635|  0:00:02s
# epoch 49 | loss: 1.76728 | val_0_custom_loss: 183.12527|  0:00:02s
# epoch 50 | loss: 1.7699  | val_0_custom_loss: 181.80502|  0:00:02s
# epoch 51 | loss: 2.23722 | val_0_custom_loss: 180.37198|  0:00:02s
# epoch 52 | loss: 1.95777 | val_0_custom_loss: 179.09824|  0:00:02s
# epoch 53 | loss: 2.00254 | val_0_custom_loss: 177.54359|  0:00:02s
# epoch 54 | loss: 1.85022 | val_0_custom_loss: 176.43295|  0:00:02s
# epoch 55 | loss: 2.16341 | val_0_custom_loss: 174.79473|  0:00:02s
# epoch 56 | loss: 1.74936 | val_0_custom_loss: 173.25519|  0:00:02s
# epoch 57 | loss: 1.86008 | val_0_custom_loss: 171.54013|  0:00:02s
# epoch 58 | loss: 2.3656  | val_0_custom_loss: 169.83933|  0:00:02s
# epoch 59 | loss: 1.81449 | val_0_custom_loss: 168.10736|  0:00:02s
# epoch 60 | loss: 1.7534  | val_0_custom_loss: 166.55743|  0:00:02s
# epoch 61 | loss: 1.93394 | val_0_custom_loss: 165.11504|  0:00:02s
# epoch 62 | loss: 2.07483 | val_0_custom_loss: 163.75439|  0:00:02s
# epoch 63 | loss: 1.80775 | val_0_custom_loss: 162.54302|  0:00:02s
# epoch 64 | loss: 1.78703 | val_0_custom_loss: 161.35195|  0:00:02s
# epoch 65 | loss: 1.88953 | val_0_custom_loss: 160.22772|  0:00:02s
# epoch 66 | loss: 1.75892 | val_0_custom_loss: 159.19482|  0:00:02s
# epoch 67 | loss: 1.74152 | val_0_custom_loss: 158.05944|  0:00:02s
# epoch 68 | loss: 1.92174 | val_0_custom_loss: 156.8087|  0:00:02s
# epoch 69 | loss: 2.07828 | val_0_custom_loss: 155.58762|  0:00:02s
# epoch 70 | loss: 2.75323 | val_0_custom_loss: 154.5763|  0:00:03s
# epoch 71 | loss: 1.83266 | val_0_custom_loss: 153.42472|  0:00:03s
# epoch 72 | loss: 1.69985 | val_0_custom_loss: 152.22379|  0:00:03s
# epoch 73 | loss: 2.00054 | val_0_custom_loss: 151.04442|  0:00:03s
# epoch 74 | loss: 1.85154 | val_0_custom_loss: 149.89353|  0:00:03s
# epoch 75 | loss: 1.83347 | val_0_custom_loss: 148.62062|  0:00:03s
# epoch 76 | loss: 1.74053 | val_0_custom_loss: 147.37183|  0:00:03s
# epoch 77 | loss: 1.88921 | val_0_custom_loss: 146.14453|  0:00:03s
# epoch 78 | loss: 1.7727  | val_0_custom_loss: 145.04475|  0:00:03s
# epoch 79 | loss: 1.87666 | val_0_custom_loss: 143.93222|  0:00:03s
# epoch 80 | loss: 1.81736 | val_0_custom_loss: 142.78144|  0:00:03s
# epoch 81 | loss: 1.81725 | val_0_custom_loss: 141.75539|  0:00:03s
# epoch 82 | loss: 2.12361 | val_0_custom_loss: 140.73864|  0:00:03s
# epoch 83 | loss: 2.05249 | val_0_custom_loss: 139.57745|  0:00:03s
# epoch 84 | loss: 1.69304 | val_0_custom_loss: 138.58328|  0:00:03s
# epoch 85 | loss: 1.77593 | val_0_custom_loss: 137.47933|  0:00:03s
# epoch 86 | loss: 1.93859 | val_0_custom_loss: 136.40469|  0:00:03s
# epoch 87 | loss: 1.76759 | val_0_custom_loss: 135.4209|  0:00:03s
# epoch 88 | loss: 1.75593 | val_0_custom_loss: 134.47523|  0:00:03s
# epoch 89 | loss: 1.86829 | val_0_custom_loss: 133.51121|  0:00:03s
# epoch 90 | loss: 1.98059 | val_0_custom_loss: 132.53192|  0:00:03s
# epoch 91 | loss: 1.77978 | val_0_custom_loss: 131.71611|  0:00:03s
# epoch 92 | loss: 1.8646  | val_0_custom_loss: 130.92285|  0:00:04s
# epoch 93 | loss: 1.67208 | val_0_custom_loss: 130.13355|  0:00:04s
# epoch 94 | loss: 1.79195 | val_0_custom_loss: 211.5884|  0:00:04s
# epoch 95 | loss: 1.86254 | val_0_custom_loss: 210.83942|  0:00:04s
# epoch 96 | loss: 1.97302 | val_0_custom_loss: 210.15358|  0:00:04s
# epoch 97 | loss: 1.68849 | val_0_custom_loss: 127.19951|  0:00:04s
# epoch 98 | loss: 2.05003 | val_0_custom_loss: 126.45713|  0:00:04s
# epoch 99 | loss: 1.74755 | val_0_custom_loss: 125.73105|  0:00:04s
# epoch 100| loss: 2.0317  | val_0_custom_loss: 125.10759|  0:00:04s
# epoch 101| loss: 2.10642 | val_0_custom_loss: 124.49582|  0:00:04s
# epoch 102| loss: 1.8113  | val_0_custom_loss: 123.91309|  0:00:04s
# epoch 103| loss: 1.90563 | val_0_custom_loss: 123.3316|  0:00:04s
# epoch 104| loss: 1.84939 | val_0_custom_loss: 122.78793|  0:00:04s
# epoch 105| loss: 2.09512 | val_0_custom_loss: 122.08244|  0:00:04s
# epoch 106| loss: 1.70406 | val_0_custom_loss: 121.49671|  0:00:04s
# epoch 107| loss: 1.98113 | val_0_custom_loss: 120.90887|  0:00:04s
# epoch 108| loss: 1.64878 | val_0_custom_loss: 120.42321|  0:00:04s
# epoch 109| loss: 1.90054 | val_0_custom_loss: 119.94369|  0:00:04s
# epoch 110| loss: 1.75794 | val_0_custom_loss: 119.45851|  0:00:04s
# epoch 111| loss: 1.88881 | val_0_custom_loss: 119.02002|  0:00:04s
# epoch 112| loss: 2.07955 | val_0_custom_loss: 118.6066|  0:00:04s
# epoch 113| loss: 1.71228 | val_0_custom_loss: 118.21169|  0:00:05s
# epoch 114| loss: 1.91824 | val_0_custom_loss: 117.79484|  0:00:05s
# epoch 115| loss: 1.84093 | val_0_custom_loss: 117.44678|  0:00:05s
# epoch 116| loss: 1.76179 | val_0_custom_loss: 117.11048|  0:00:05s
# epoch 117| loss: 2.21107 | val_0_custom_loss: 116.75529|  0:00:05s
# epoch 118| loss: 2.31723 | val_0_custom_loss: 116.30575|  0:00:05s
# epoch 119| loss: 2.41697 | val_0_custom_loss: 115.99629|  0:00:05s
# epoch 120| loss: 1.87858 | val_0_custom_loss: 115.67903|  0:00:05s
# epoch 121| loss: 2.62854 | val_0_custom_loss: 115.34805|  0:00:05s
# epoch 122| loss: 2.15795 | val_0_custom_loss: 115.02261|  0:00:05s
# epoch 123| loss: 1.69304 | val_0_custom_loss: 114.7699|  0:00:05s
# epoch 124| loss: 1.89968 | val_0_custom_loss: 114.49738|  0:00:05s
# epoch 125| loss: 1.80851 | val_0_custom_loss: 114.25877|  0:00:05s
# epoch 126| loss: 1.7657  | val_0_custom_loss: 114.06433|  0:00:05s
# epoch 127| loss: 1.74541 | val_0_custom_loss: 113.80615|  0:00:05s
# epoch 128| loss: 1.98322 | val_0_custom_loss: 113.53533|  0:00:05s
# epoch 129| loss: 1.95123 | val_0_custom_loss: 113.26169|  0:00:05s
# epoch 130| loss: 1.81107 | val_0_custom_loss: 112.99679|  0:00:05s
# epoch 131| loss: 1.7191  | val_0_custom_loss: 112.78283|  0:00:05s
# epoch 132| loss: 1.82418 | val_0_custom_loss: 112.55835|  0:00:05s
# epoch 133| loss: 1.85785 | val_0_custom_loss: 112.31847|  0:00:05s
# epoch 134| loss: 1.71323 | val_0_custom_loss: 112.11229|  0:00:05s
# epoch 135| loss: 1.79387 | val_0_custom_loss: 111.89154|  0:00:05s
# epoch 136| loss: 1.78341 | val_0_custom_loss: 111.68262|  0:00:06s
# epoch 137| loss: 2.01106 | val_0_custom_loss: 111.39176|  0:00:06s
# epoch 138| loss: 1.71194 | val_0_custom_loss: 111.11755|  0:00:06s
# epoch 139| loss: 1.99887 | val_0_custom_loss: 110.82276|  0:00:06s
# epoch 140| loss: 1.91671 | val_0_custom_loss: 110.54691|  0:00:06s
# epoch 141| loss: 1.8586  | val_0_custom_loss: 110.28743|  0:00:06s
# epoch 142| loss: 2.0458  | val_0_custom_loss: 110.03383|  0:00:06s
# epoch 143| loss: 2.07518 | val_0_custom_loss: 109.7513|  0:00:06s
# epoch 144| loss: 3.15237 | val_0_custom_loss: 109.48537|  0:00:06s
# epoch 145| loss: 1.91855 | val_0_custom_loss: 109.26902|  0:00:06s
# epoch 146| loss: 1.72327 | val_0_custom_loss: 109.05402|  0:00:06s
# epoch 147| loss: 1.8849  | val_0_custom_loss: 108.82989|  0:00:06s
# epoch 148| loss: 2.12522 | val_0_custom_loss: 108.65421|  0:00:06s
# epoch 149| loss: 1.71136 | val_0_custom_loss: 108.47659|  0:00:06s
# epoch 150| loss: 1.75366 | val_0_custom_loss: 108.30021|  0:00:06s
# epoch 151| loss: 1.67739 | val_0_custom_loss: 108.12058|  0:00:06s
# epoch 152| loss: 1.73806 | val_0_custom_loss: 107.94164|  0:00:06s
# epoch 153| loss: 1.86376 | val_0_custom_loss: 107.81321|  0:00:06s
# epoch 154| loss: 1.78159 | val_0_custom_loss: 107.67741|  0:00:06s
# epoch 155| loss: 1.92887 | val_0_custom_loss: 107.48893|  0:00:06s
# epoch 156| loss: 1.69798 | val_0_custom_loss: 107.35506|  0:00:06s
# epoch 157| loss: 1.78174 | val_0_custom_loss: 107.21508|  0:00:06s
# epoch 158| loss: 2.28591 | val_0_custom_loss: 107.09015|  0:00:06s
# epoch 159| loss: 1.82128 | val_0_custom_loss: 107.07036|  0:00:06s
# epoch 160| loss: 1.6196  | val_0_custom_loss: 106.95475|  0:00:07s
# epoch 161| loss: 1.78451 | val_0_custom_loss: 106.87535|  0:00:07s
# epoch 162| loss: 1.73114 | val_0_custom_loss: 106.72442|  0:00:07s
# epoch 163| loss: 1.75497 | val_0_custom_loss: 106.58598|  0:00:07s
# epoch 164| loss: 2.23894 | val_0_custom_loss: 106.41324|  0:00:07s
# epoch 165| loss: 1.77298 | val_0_custom_loss: 106.27547|  0:00:07s
# epoch 166| loss: 1.87995 | val_0_custom_loss: 106.14103|  0:00:07s
# epoch 167| loss: 1.90416 | val_0_custom_loss: 106.04782|  0:00:07s
# epoch 168| loss: 1.92638 | val_0_custom_loss: 105.95958|  0:00:07s
# epoch 169| loss: 1.78083 | val_0_custom_loss: 187.90173|  0:00:07s
# epoch 170| loss: 1.97581 | val_0_custom_loss: 187.6952|  0:00:07s
# epoch 171| loss: 1.72656 | val_0_custom_loss: 187.52321|  0:00:07s
# epoch 172| loss: 1.89242 | val_0_custom_loss: 187.3972|  0:00:07s
# epoch 173| loss: 1.7416  | val_0_custom_loss: 187.31617|  0:00:07s
# epoch 174| loss: 1.69382 | val_0_custom_loss: 187.23781|  0:00:07s
# epoch 175| loss: 2.08583 | val_0_custom_loss: 187.08464|  0:00:07s
# epoch 176| loss: 1.74884 | val_0_custom_loss: 186.95608|  0:00:07s
# epoch 177| loss: 1.74977 | val_0_custom_loss: 104.6975|  0:00:07s
# epoch 178| loss: 1.93044 | val_0_custom_loss: 104.5964|  0:00:07s
# epoch 179| loss: 1.76257 | val_0_custom_loss: 104.4451|  0:00:07s
# epoch 180| loss: 2.05288 | val_0_custom_loss: 104.33536|  0:00:07s
# epoch 181| loss: 1.71268 | val_0_custom_loss: 104.26846|  0:00:07s
# epoch 182| loss: 1.93513 | val_0_custom_loss: 104.21258|  0:00:07s
# epoch 183| loss: 1.75645 | val_0_custom_loss: 104.18805|  0:00:07s
# epoch 184| loss: 1.82044 | val_0_custom_loss: 104.11911|  0:00:07s
# epoch 185| loss: 1.70669 | val_0_custom_loss: 104.05187|  0:00:07s
# epoch 186| loss: 1.88932 | val_0_custom_loss: 104.0277|  0:00:08s
# epoch 187| loss: 1.71627 | val_0_custom_loss: 103.96327|  0:00:08s
# epoch 188| loss: 1.86462 | val_0_custom_loss: 103.9929|  0:00:08s
# epoch 189| loss: 1.88891 | val_0_custom_loss: 103.92824|  0:00:08s
# epoch 190| loss: 1.85059 | val_0_custom_loss: 103.84654|  0:00:08s
# epoch 191| loss: 1.68435 | val_0_custom_loss: 103.77153|  0:00:08s
# epoch 192| loss: 1.844   | val_0_custom_loss: 103.69122|  0:00:08s
# epoch 193| loss: 1.77016 | val_0_custom_loss: 103.60532|  0:00:08s
# epoch 194| loss: 1.96895 | val_0_custom_loss: 103.52795|  0:00:08s
# epoch 195| loss: 2.00829 | val_0_custom_loss: 103.44268|  0:00:08s
# epoch 196| loss: 1.72813 | val_0_custom_loss: 103.3599|  0:00:08s
# epoch 197| loss: 1.82358 | val_0_custom_loss: 103.28859|  0:00:08s
# epoch 198| loss: 1.78409 | val_0_custom_loss: 103.21405|  0:00:08s
# epoch 199| loss: 1.86938 | val_0_custom_loss: 103.14964|  0:00:08s
# epoch 200| loss: 2.10991 | val_0_custom_loss: 103.07919|  0:00:08s
# epoch 201| loss: 1.69901 | val_0_custom_loss: 103.02255|  0:00:08s
# epoch 202| loss: 1.73518 | val_0_custom_loss: 102.95093|  0:00:08s
# epoch 203| loss: 2.07404 | val_0_custom_loss: 102.89509|  0:00:08s
# epoch 204| loss: 1.91064 | val_0_custom_loss: 102.78129|  0:00:08s
# epoch 205| loss: 1.70096 | val_0_custom_loss: 102.72011|  0:00:08s
# epoch 206| loss: 1.77385 | val_0_custom_loss: 102.65776|  0:00:08s
# epoch 207| loss: 1.64117 | val_0_custom_loss: 102.59864|  0:00:08s
# epoch 208| loss: 1.82144 | val_0_custom_loss: 102.54669|  0:00:08s
# epoch 209| loss: 2.24267 | val_0_custom_loss: 102.50301|  0:00:08s
# epoch 210| loss: 1.82012 | val_0_custom_loss: 102.41528|  0:00:09s
# epoch 211| loss: 1.90484 | val_0_custom_loss: 102.34714|  0:00:09s
# epoch 212| loss: 1.78538 | val_0_custom_loss: 102.3082|  0:00:09s
# epoch 213| loss: 1.9137  | val_0_custom_loss: 102.26162|  0:00:09s
# epoch 214| loss: 1.77653 | val_0_custom_loss: 102.21476|  0:00:09s
# epoch 215| loss: 1.83466 | val_0_custom_loss: 102.1666|  0:00:09s
# epoch 216| loss: 1.63504 | val_0_custom_loss: 102.12625|  0:00:09s
# epoch 217| loss: 1.84247 | val_0_custom_loss: 102.08386|  0:00:09s
# epoch 218| loss: 1.93858 | val_0_custom_loss: 102.02958|  0:00:09s
# epoch 219| loss: 1.91592 | val_0_custom_loss: 102.00664|  0:00:09s
# epoch 220| loss: 2.07359 | val_0_custom_loss: 101.9691|  0:00:09s
# epoch 221| loss: 1.7274  | val_0_custom_loss: 101.94948|  0:00:09s
# epoch 222| loss: 2.73121 | val_0_custom_loss: 101.92893|  0:00:09s
# epoch 223| loss: 1.91426 | val_0_custom_loss: 101.90177|  0:00:09s
# epoch 224| loss: 2.12155 | val_0_custom_loss: 101.86502|  0:00:09s
# epoch 225| loss: 2.03635 | val_0_custom_loss: 101.86235|  0:00:09s
# epoch 226| loss: 1.72979 | val_0_custom_loss: 101.85303|  0:00:09s
# epoch 227| loss: 1.82466 | val_0_custom_loss: 101.84664|  0:00:09s
# epoch 228| loss: 1.73059 | val_0_custom_loss: 101.842 |  0:00:09s
# epoch 229| loss: 1.68238 | val_0_custom_loss: 101.76907|  0:00:09s
# epoch 230| loss: 1.71566 | val_0_custom_loss: 101.76696|  0:00:09s
# epoch 231| loss: 1.74528 | val_0_custom_loss: 101.76856|  0:00:09s
# epoch 232| loss: 1.8359  | val_0_custom_loss: 101.76159|  0:00:09s
# epoch 233| loss: 1.76007 | val_0_custom_loss: 101.81572|  0:00:09s
# epoch 234| loss: 2.00345 | val_0_custom_loss: 101.80614|  0:00:09s
# epoch 235| loss: 1.7203  | val_0_custom_loss: 101.81529|  0:00:10s
# epoch 236| loss: 1.89818 | val_0_custom_loss: 101.8045|  0:00:10s
# epoch 237| loss: 1.64646 | val_0_custom_loss: 101.79379|  0:00:10s
# epoch 238| loss: 1.72925 | val_0_custom_loss: 101.81315|  0:00:10s
# epoch 239| loss: 1.69671 | val_0_custom_loss: 101.81841|  0:00:10s
# epoch 240| loss: 1.72912 | val_0_custom_loss: 101.82642|  0:00:10s
# epoch 241| loss: 1.73512 | val_0_custom_loss: 101.81932|  0:00:10s
# epoch 242| loss: 1.76885 | val_0_custom_loss: 101.83304|  0:00:10s
# epoch 243| loss: 1.75185 | val_0_custom_loss: 101.83633|  0:00:10s
# epoch 244| loss: 1.65712 | val_0_custom_loss: 102.01338|  0:00:10s
# epoch 245| loss: 1.94098 | val_0_custom_loss: 102.03004|  0:00:10s
# epoch 246| loss: 1.68392 | val_0_custom_loss: 102.04728|  0:00:10s
# epoch 247| loss: 1.8953  | val_0_custom_loss: 102.05967|  0:00:10s
# epoch 248| loss: 1.91537 | val_0_custom_loss: 102.05925|  0:00:10s
# epoch 249| loss: 2.13371 | val_0_custom_loss: 102.06739|  0:00:10s
# epoch 250| loss: 2.33374 | val_0_custom_loss: 299.24391|  0:00:10s
# epoch 251| loss: 1.8549  | val_0_custom_loss: 299.26477|  0:00:10s
# epoch 252| loss: 1.84519 | val_0_custom_loss: 299.26023|  0:00:10s
# epoch 253| loss: 1.74651 | val_0_custom_loss: 299.25955|  0:00:10s
# epoch 254| loss: 1.90742 | val_0_custom_loss: 299.28198|  0:00:10s
# epoch 255| loss: 1.75663 | val_0_custom_loss: 299.28961|  0:00:10s
# epoch 256| loss: 1.72207 | val_0_custom_loss: 299.30393|  0:00:10s
# epoch 257| loss: 2.31355 | val_0_custom_loss: 299.30536|  0:00:10s
# epoch 258| loss: 1.75511 | val_0_custom_loss: 299.32691|  0:00:10s
# epoch 259| loss: 2.07473 | val_0_custom_loss: 299.36743|  0:00:10s
# epoch 260| loss: 1.77609 | val_0_custom_loss: 299.38249|  0:00:10s
# epoch 261| loss: 1.67101 | val_0_custom_loss: 299.3961|  0:00:10s
# epoch 262| loss: 1.74784 | val_0_custom_loss: 299.40853|  0:00:10s
# epoch 263| loss: 1.72033 | val_0_custom_loss: 299.41085|  0:00:10s
# epoch 264| loss: 1.91248 | val_0_custom_loss: 299.4198|  0:00:10s
# epoch 265| loss: 1.80794 | val_0_custom_loss: 299.42834|  0:00:10s
# epoch 266| loss: 2.59889 | val_0_custom_loss: 299.52027|  0:00:10s
# epoch 267| loss: 1.82705 | val_0_custom_loss: 299.53182|  0:00:10s
# epoch 268| loss: 2.25701 | val_0_custom_loss: 299.52337|  0:00:10s
# epoch 269| loss: 1.78871 | val_0_custom_loss: 299.53375|  0:00:11s
# epoch 270| loss: 1.85122 | val_0_custom_loss: 299.5353|  0:00:11s
# epoch 271| loss: 1.73729 | val_0_custom_loss: 299.54829|  0:00:11s
# epoch 272| loss: 1.75632 | val_0_custom_loss: 299.56632|  0:00:11s
# epoch 273| loss: 1.90925 | val_0_custom_loss: 299.58428|  0:00:11s
# epoch 274| loss: 1.6923  | val_0_custom_loss: 299.58325|  0:00:11s
# epoch 275| loss: 1.73572 | val_0_custom_loss: 299.60088|  0:00:11s
# epoch 276| loss: 2.02553 | val_0_custom_loss: 299.61372|  0:00:11s
# epoch 277| loss: 2.13644 | val_0_custom_loss: 299.62879|  0:00:11s
# epoch 278| loss: 1.79094 | val_0_custom_loss: 299.64593|  0:00:11s
# epoch 279| loss: 1.76505 | val_0_custom_loss: 299.6786|  0:00:11s
# epoch 280| loss: 1.99855 | val_0_custom_loss: 299.71691|  0:00:11s
# epoch 281| loss: 1.68961 | val_0_custom_loss: 299.72637|  0:00:11s
# epoch 282| loss: 1.83847 | val_0_custom_loss: 299.74913|  0:00:11s
#
# Early stopping occurred at epoch 282 with best_epoch = 232 and best_val_0_custom_loss = 101.76159
# Best weights from best epoch are automatically used!

# %% [markdown]
# ## 3. Complete Dataset
# Costs for each run

# %%
costs
# Out:
# {0: [191.91324125898947, 97.83432983206126]}

# %% [markdown]
# ### 3.1 Reconstruct Dataset
# choose best model based on min. squared custom loss (punishing large outliers in losses for single features)

# %%
cost_totals = [sum([x**2 for x in c]) for _, c in costs.items()]
best_model = cost_totals.index(min(cost_totals))
features_best = features_reconstr[best_model]
print(f"Best model: run {best_model} with custom losses {costs[best_model]} for features {list(features_to_predict)}")
# Out:
# Best model: run 0 with custom losses [128.34218140647008, 101.76159026675083] for features ['F2', 'F3']

# %% [markdown]
# ### 3.2 Plot changes (comp. to original data)

# %%
# scatter plot with combined data
orig_data = features.copy()
orig_data["change"] = 0
changed_data = features_best[features_mv.isna().any(axis=1)]
comp_data = pd.concat([orig_data, changed_data]).reset_index(drop=True).fillna(1)

# line plot connecting filled data to true data points
reconstr_data = features_best[features_mv.isna().any(axis=1)]
true_data = features[features_mv.isna().any(axis=1)]

# plot
fig = plt.figure(figsize=(8,8))
ax  = fig.add_subplot(projection = '3d')
ax.scatter(comp_data["F1"], comp_data["F2"], comp_data["F3"], c=[comp_data["change"]])

for i in range(len(reconstr_data)):
    ax.plot([reconstr_data["F1"].iloc[i], true_data["F1"].iloc[i]],[reconstr_data["F2"].iloc[i], true_data["F2"].iloc[i]],[reconstr_data["F3"].iloc[i], true_data["F3"].iloc[i]], color="black", linewidth=.5)


plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
plt.show
if save_output:
    plt.savefig(os.path.join(plots_path, "4_imputation_differences.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## 4. Clustering

# %%
# apply clustering
clusters_reconstr = []
for run in range(config["RQ2"]["runs"]):
    dbscan_reconstr = DBSCAN(**config["DBSCAN"]).fit(features_reconstr[run])
    clusters_reconstr.append(dbscan_reconstr.labels_)

# %% [markdown]
# ### 4.1. Plot of clustering based on best model predictions

# %%
# plot new clustering
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(projection='3d')
ax.scatter(features_reconstr[0].iloc[:, 0], features_reconstr[0].iloc[:, 1], features_reconstr[0].iloc[:, 2], c=clusters_reconstr[0])
plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "3_DBSCAN_imputed_data.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## 5. Cluster Performance

# %% [markdown]
# ### 5.1 Feature Distributions
# #### 5.1.1 Distr. Plots based on best model predictions

# %%
# plot distributions
bins = len(astropy.stats.freedman_bin_width(features[feature], return_bins=True)[1])
n_feat = len(features_best.columns)

fig, (ax) = plt.subplots(n_feat, 2, figsize=(n_feat*2,6))
for n, feature in enumerate(features_best.columns):
    ax[n, 0].hist(features[feature], bins=bins)
    ax[n, 0].set_title(f"{feature}_orig")
    ax[n, 1].hist(features_best[feature], bins=bins)
    ax[n, 1].set_title(f"{feature}_filled")

fig.tight_layout()
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "feature distributions.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# #### 5.1.2 KL Divergence

# %%
# KL Divergence
def kl_divergence(feature1, feature2):
    
    # calculate probability distributions
    def probability_dist(x, y, bins):
        # transforms 2 series into their probability distributions
        # histogram
        hist_xy = np.histogram2d(x, y, bins=bins)[0]

        # compute marginals
        hist_xy = hist_xy + sys.float_info.min # prevent division with 0
        hist_xy = hist_xy / np.sum(hist_xy)
        hist_x = np.sum(hist_xy, axis=1)
        hist_y = np.sum(hist_xy, axis=0)
        return(hist_x, hist_y)

    # calculate kl divergence
    bins = len(astropy.stats.freedman_bin_width(feature1, return_bins=True)[1])
    distr1, distr2 = probability_dist(feature1, feature2, bins)
    return torch.nn.functional.kl_div(torch.tensor(distr1).log(), torch.tensor(distr2), log_target=False, reduction='sum').item()

# %%
output["kl_divergence"] = {}

# save kl divergence
for run in range(config["RQ2"]["runs"]):
    for feature in features_to_predict:
        output["kl_divergence"][f"run{run}_{feature}"] = kl_divergence(features[feature], features_reconstr[run][feature])

# %% [markdown]
# ### 5.2 Cluster Noise

# %%
output["cluster_noise"] = {}
output["cluster_noise"][f"original"] = sum(clusters_orig == -1)

for run in range(config["RQ2"]["runs"]):
        output["cluster_noise"][f"run{run}"] = sum(clusters_reconstr[run] == -1)

# %% [markdown]
# ### 5.3 Silhouette Score

# %%
from sklearn.metrics import silhouette_score

output["silhouette_scores"] = {}
output["silhouette_scores"]["orig_data"] = float(silhouette_score(features, np.ravel(clusters)))

for run in range(config["RQ2"]["runs"]):
    output["silhouette_scores"][f"run{run}"] = float(silhouette_score(features_reconstr[run], clusters_reconstr[run]))

# %% [markdown]
# ### 5.4. Outlierness

# %%
# todo

# %% [markdown]
# ### 5.5. Save Output

# %%
with open(output_path, "w") as f:
            toml.dump(output, f)
