# %% [markdown]
# ## Change Log
# - Use KL divergence in custom loss function

# %%
# %%javascript
# IPython.notebook.kernel.execute('nb_name = "' + IPython.notebook.notebook_name + '"')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import random
import math

import sys
import os
sys.path.append(os.getcwd() + "/pytorch_tabnet/")

from sklearn.cluster import DBSCAN
from scipy.special import rel_entr

# %% [markdown]
# ## 0. Experiment Setup

# %%
# should an output folder be created to save the experiment data?
save_output = True

# %%
# read config file
import toml
config = toml.load("config.toml")

# rnd seed to support reproducable results
seed_value =  config["general"]["random_seed"] if config["general"]["random_seed"] else random.randrange(sys.maxsize)
random.seed(seed_value)

# TabNet hyperparameters
regressor_param = {"optimizer_fn" : torch.optim.Adam,
                   "optimizer_params" : dict(lr=2e-2),
                   "scheduler_params" : {"step_size": 2, "gamma": 0.9},
                   "scheduler_fn" : torch.optim.lr_scheduler.StepLR,
                   "mask_type" : 'entmax',
                  }

if save_output:
    # create experiment folder
    from datetime import datetime
    
    experiment_name = config["general"]["experiment_name"]
    experiment_folder = experiment_name if experiment_name else f"Exp {datetime.now().strftime('%Y_%m_%d %H-%M-%S')}"
    experiment_path = os.path.join("Experiments", experiment_folder)
    os.mkdir(experiment_path)
    plots_path = os.path.join(experiment_path, "plots")
    os.mkdir(plots_path)
    
    # save config file
    import shutil
    shutil.copy2("config.toml", experiment_path)
    
    # save random seed
    if not config["general"]["random_seed"]:
        config["general"]["random_seed"] = seed_value
        config_path = os.path.join(experiment_path, "config.toml")
        with open(config_path, "w") as f:
            toml.dump(config, f)
    
    # save notebook
    shutil.copy2(nb_name, experiment_path)

# %% [markdown]
# ## 1. Datasets
#
# Different datasets are to be used for the experiments.
# - toy dataset using make_blobs from sklearn mainly to setup and test the notebook
# - DAMI Benchmark datasets with the respective best practice hyperparameters (https://www.dbs.ifi.lmu.de/research/outlier-evaluation/DAMI/)
#
# ### 1.0. Create toy dataset
# As of now, only a toy dataset is used (n_features features with clusters centered around different points).

# %%
from sklearn.datasets import make_blobs

features_arr, clusters_arr = make_blobs(**config["toy_data"])

# name feature and cluster (ground truth) columns
features = pd.DataFrame(features_arr, columns=[f"F{x + 1}" for x in range(features_arr.shape[1])])
clusters = pd.DataFrame(clusters_arr, columns=["C"])

# %% [markdown]
# ### 1.1. plot data

# %%
# plot dataset
# %matplotlib notebook
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(projection='3d')
ax.scatter(features_arr[:, 0], features_arr[:, 1], features_arr[:, 2], c=clusters_arr)
plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
plt.show()
plt.savefig(os.path.join(plots_path, "0_ground_truth_clusters.png"))
# Out:
# <img src="data:image/png;base64,..." width="576">

# %% [markdown]
# ### 1.2. Create missing data
# Create a specified amount of missing values in the given feature columns (for complete datasets).

# %%
# create missing values in feature column(s)
mv_config = {feature:mv_ratio for feature,mv_ratio in zip(list(features.columns), config["general"]["missing_percent"])}
features_mv = features.copy()

for f, mv in mv_config.items():
    features_mv[f] = features_mv[f].mask(np.random.random(features.shape[0]) < mv)

# %%
import missingno as msno
# %matplotlib inline

# plot missing values
msno.matrix(features_mv)
plt.show()
plt.savefig(os.path.join(plots_path, "missing_values.png"))

# %% [markdown]
# ### 1.3. Initial Clustering (without missing values)
# Use the cluster algorithm on dataset without missing values.\
# Get cluster means for loss function input.

# %%
# run DBSCAN on original data
dbscan_orig = DBSCAN(**config["DBSCAN"]).fit(features)
clusters_orig = dbscan_orig.labels_

# %%
# plot clustering
# %matplotlib notebook
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(projection='3d')
ax.scatter(features.iloc[:, 0], features.iloc[:, 1], features.iloc[:, 2], c=clusters_orig)
plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
plt.show()
plt.savefig(os.path.join(plots_path, "1_DBSCAN_original_data.png"))
# Out:
# <img src="data:image/png;base64,..." width="576">

# %%
# get cluster means (used to calculate the cluster mean loss)
complete_data = features.copy()
complete_data["C"] = clusters_orig
cluster_means = complete_data.groupby("C").agg("mean")
cluster_means = cluster_means if -1 not in cluster_means.index else cluster_means.drop(-1)

# %% [markdown]
# ## 2. Filling Strategies
#
#
# ### 2.1. Define custom-loss
# The loss function for the model fitting shall be customized to improve cluster perforamnce. The custom loss is divided into 2 separate losses
#
# 1. **Reconstruction Loss**\
# Classic loss function, such as RMSE.
# 2. **Cluster-Mean Loss**\
# The distance to the nearest cluster mean shall be minimized.
# 3. **KL Divergence Loss**\
# Deviation of original distribution shall be minimized \
# (implementation based on https://stackoverflow.com/questions/57687458/how-to-calculate-probabilities-using-numpy-histogram-and-then-use-it-for-calcula)
#
# The chosen approach to implement the cluster-mean loss is as follows:\
# **Adapt the loss function** to calculate a distance to each cluster. The minimum distance (to the nearest cluster) will be used as a cluster-mean-loss. Minimizing this loss should result in the data point moving closer to the nearest cluster mean.\
# Potential Problem: loss functions currently work with y_true (true values) and y_score (predicted values). Calculating the distance would require all features. Calculating only the 1 dimensional distance will result in missing values being put into wrong clusters - depending on the first estimate.

# %%
# define custom loss function: extend L2-loss by cluster-mean-loss

from pytorch_tabnet.metrics import Metric
from sklearn.metrics import mean_squared_error

class custom_loss(Metric):

    def __init__(self):
        self._name = "custom_loss"
        self._maximize = False

    def __call__(self, y_true, y_score, cluster_means, target_feature, x_val, y_val):
        # reconstruction loss
        rmse = np.sqrt(mean_squared_error(y_true, y_score))
        
        # cluster mean loss
        cml = self.cluster_mean_loss(cluster_means, y_score, target_feature, x_val, y_val)
        
        # KL divergence loss
        bins = 20
        dist1, dist2 = probability_dist(y_true, y_score, bins)
        KL_div_1_2 = {sum(rel_entr(dist1, dist2))}
        KL_div_2_1 = {sum(rel_entr(dist2, dist1))}
        KLdl = KL_div_1_2 + KL_div_2_1
        
        # total loss
        custom_loss = cml + rmse + KLdl
        return custom_loss
    
    # calculate sum of distances to the closest cluster mean
    def cluster_mean_loss(self, cluster_means, y_score, target_feature, x_val, y_val):
        
        # reorder cluster_means to match x_val columns (predicted feature is last column)
        cols = cluster_means.columns.tolist()
        feature_col = features.columns.get_loc(target_feature)
        cols = cols[:feature_col] + cols[feature_col+1:] + [target_feature]
        
        # x values extended by predicted values
        x_extended = pd.DataFrame(np.hstack((x_val, y_score)), columns=cols)


        # calculate distances to each cluster and select the closest one
        dist = []
        for cluster in range(cluster_means.shape[0]):
            dist.append(np.linalg.norm((x_extended - cluster_means.iloc[cluster]), axis=1))
            
        dist = pd.DataFrame(dist).T
        min_dist = dist.assign(min_dist=lambda d: d.min(1))["min_dist"]
        
        return sum(min_dist)
    
    # calculate probabilities
    def probability_dist(x, y, bins):
        # histogram
        hist_xy = np.histogram2d(x, y, bins=bins)[0]

        # compute marginals
        hist_xy = hist_xy + sys.float_info.min # prevent division with 0
        hist_xy = hist_xy / np.sum(hist_xy)
        hist_x = np.sum(hist_xy, axis=1)
        hist_y = np.sum(hist_xy, axis=0)
        return(hist_x, hist_y)

# %% [markdown]
# ### 2.2. Fill missing values (TabNet).
#
# **Approach 1:**\
# For each feature that contains missing values, use all rows with complete other features as train set and predict missing values of the feature.\
# &rarr; Problem: lots of models, especially for high-dimensional datasets.
# Also problem, if more than one feature is missing values. &rarr; see Approach 2
#
# **Approach 2:**\
# Mask missing values as -1 (or some other value) and fit a model predicting each feature just like in approach 1.\
# &rarr; one model for each feature containing missing values.\
# Possible adaption: use predicted values to predict subsequent values (instead of using -1)

# %%
from pytorch_tabnet.tab_model import TabNetRegressor
from sklearn.model_selection import train_test_split

features_to_predict = features_mv.columns[features_mv.isnull().any()]
models = []
features_reconstr = []
costs = {}

for run in range(config["RQ2"]["runs"]):
    costs[run] = []
    for feature in features_to_predict:
        print(f"Run {run+1}, predicting {feature}")
        features_reconstr.append(features_mv.copy())

        # select % of features for prediction based on pred_features (e.g. 10% of randomly selected features)
        number_of_features = math.ceil(config["RQ2"]["pred_features"] * (len(features_mv.columns)) - 1)
        features_mv_masked = features_mv.copy().drop(feature, axis=1).sample(n=number_of_features, axis='columns')
        selected_features = features_mv_masked.columns
        
        print(f"Predictions based on features {list(selected_features)}")
        
        # mask other columns' missing values as defined in config (missing_value_mask)
        features_mv_masked[feature] = features_mv[feature]
        features_mv_masked[selected_features] = features_mv_masked[(selected_features)].fillna(config["general"]["missing_value_mask"])
        
        # separate complete rows as train data
        # separate column with missing values as target
        test_data = features_mv_masked[features_mv_masked[feature].isna()].drop(feature, axis=1).to_numpy()
        train_data = features_mv_masked[features_mv_masked[feature].notna()]
        train_features = train_data.drop(columns=feature).to_numpy()
        train_target = train_data[feature].to_numpy().reshape(-1,1)

        x_train, x_val, y_train, y_val = train_test_split(train_features, train_target, test_size=0.75)

        # create & train model
        model = TabNetRegressor(**regressor_param)
        model.fit(
            x_train, y_train,
            eval_set=[(x_val, y_val)],
            eval_metric=['custom_loss'],
            **config["model_param"],
            cluster_means=cluster_means,
            target_feature=feature,
            x_val=x_val,
            y_val=y_val,
        )
        
        # add costs to dict
        costs[run].append(model.best_cost)
        
        # add model to list
        models.append(model)

        # fill missing values with model predictions
        features_reconstr[run].loc[features_reconstr[run][feature].isna(),feature] = [x[0] for x in models[len(models)-1].predict(test_data)]
# Out:
# Run 1, predicting F2
# Predictions based on features ['F3', 'F1']
# Device used : cpu
# epoch 0  | loss: 68.70894| val_0_custom_loss: 10587.95152|  0:00:00s
# epoch 1  | loss: 46.42882| val_0_custom_loss: 13275.80737|  0:00:00s
# epoch 2  | loss: 33.44363| val_0_custom_loss: 13882.3349|  0:00:00s
# epoch 3  | loss: 25.5792 | val_0_custom_loss: 11026.30231|  0:00:00s
# epoch 4  | loss: 18.88762| val_0_custom_loss: 8072.61303|  0:00:00s
# epoch 5  | loss: 14.80087| val_0_custom_loss: 6210.37444|  0:00:00s
# epoch 6  | loss: 10.20169| val_0_custom_loss: 5812.18421|  0:00:00s
# epoch 7  | loss: 8.11229 | val_0_custom_loss: 5489.7475|  0:00:00s
# epoch 8  | loss: 6.77721 | val_0_custom_loss: 5067.75339|  0:00:00s
# epoch 9  | loss: 5.8074  | val_0_custom_loss: 4671.47356|  0:00:00s
# epoch 10 | loss: 4.94544 | val_0_custom_loss: 4326.35054|  0:00:00s
# epoch 11 | loss: 4.33208 | val_0_custom_loss: 3976.7371|  0:00:00s
# epoch 12 | loss: 4.14062 | val_0_custom_loss: 3367.73315|  0:00:00s
# epoch 13 | loss: 3.76002 | val_0_custom_loss: 2877.46939|  0:00:00s
# epoch 14 | loss: 3.46244 | val_0_custom_loss: 3039.58339|  0:00:00s
# epoch 15 | loss: 3.01921 | val_0_custom_loss: 3038.96293|  0:00:00s
# epoch 16 | loss: 2.70876 | val_0_custom_loss: 2700.00594|  0:00:00s
# epoch 17 | loss: 2.45647 | val_0_custom_loss: 2440.03401|  0:00:00s
# epoch 18 | loss: 2.14045 | val_0_custom_loss: 2246.4961|  0:00:00s
# epoch 19 | loss: 1.99974 | val_0_custom_loss: 2013.32725|  0:00:00s
# epoch 20 | loss: 1.9503  | val_0_custom_loss: 2002.95999|  0:00:01s
# epoch 21 | loss: 1.95841 | val_0_custom_loss: 2005.31717|  0:00:01s
# epoch 22 | loss: 1.93745 | val_0_custom_loss: 1830.91161|  0:00:01s
# epoch 23 | loss: 1.88901 | val_0_custom_loss: 1874.01558|  0:00:01s
# epoch 24 | loss: 1.8084  | val_0_custom_loss: 1704.44312|  0:00:01s
# epoch 25 | loss: 1.71028 | val_0_custom_loss: 1648.14561|  0:00:01s
# epoch 26 | loss: 1.64544 | val_0_custom_loss: 1650.10446|  0:00:01s
# epoch 27 | loss: 1.56859 | val_0_custom_loss: 1554.90224|  0:00:01s
# epoch 28 | loss: 1.50752 | val_0_custom_loss: 1533.34172|  0:00:01s
# epoch 29 | loss: 1.40572 | val_0_custom_loss: 1588.73604|  0:00:01s
# epoch 30 | loss: 1.35369 | val_0_custom_loss: 1541.39888|  0:00:01s
# epoch 31 | loss: 1.32796 | val_0_custom_loss: 1518.23355|  0:00:01s
# epoch 32 | loss: 1.2405  | val_0_custom_loss: 1470.01352|  0:00:01s
# epoch 33 | loss: 1.25395 | val_0_custom_loss: 1475.44417|  0:00:01s
# epoch 34 | loss: 1.23496 | val_0_custom_loss: 1476.02596|  0:00:01s
# epoch 35 | loss: 1.11175 | val_0_custom_loss: 1429.00599|  0:00:01s
# epoch 36 | loss: 1.13908 | val_0_custom_loss: 1408.92442|  0:00:01s
# epoch 37 | loss: 1.13715 | val_0_custom_loss: 1364.24341|  0:00:01s
# epoch 38 | loss: 1.07225 | val_0_custom_loss: 1312.88714|  0:00:01s
# epoch 39 | loss: 1.0461  | val_0_custom_loss: 1289.76522|  0:00:01s
# epoch 40 | loss: 1.03082 | val_0_custom_loss: 1262.19898|  0:00:01s
# epoch 41 | loss: 0.97451 | val_0_custom_loss: 1271.36718|  0:00:01s
# epoch 42 | loss: 0.93826 | val_0_custom_loss: 1264.58376|  0:00:01s
# epoch 43 | loss: 0.93599 | val_0_custom_loss: 1246.76138|  0:00:01s
# epoch 44 | loss: 0.90448 | val_0_custom_loss: 1232.58108|  0:00:01s
# epoch 45 | loss: 0.86711 | val_0_custom_loss: 1240.08927|  0:00:01s
# epoch 46 | loss: 0.86053 | val_0_custom_loss: 1227.40354|  0:00:02s
# epoch 47 | loss: 0.85322 | val_0_custom_loss: 1246.53946|  0:00:02s
# epoch 48 | loss: 0.8201  | val_0_custom_loss: 1256.3712|  0:00:02s
# epoch 49 | loss: 0.78749 | val_0_custom_loss: 1263.72279|  0:00:02s
# epoch 50 | loss: 0.77659 | val_0_custom_loss: 1286.41091|  0:00:02s
# epoch 51 | loss: 0.76461 | val_0_custom_loss: 1344.54966|  0:00:02s
# epoch 52 | loss: 0.73834 | val_0_custom_loss: 1332.10604|  0:00:02s
# epoch 53 | loss: 0.7157  | val_0_custom_loss: 1339.35584|  0:00:02s
# epoch 54 | loss: 0.70639 | val_0_custom_loss: 1337.12716|  0:00:02s
# epoch 55 | loss: 0.69511 | val_0_custom_loss: 1367.12477|  0:00:02s
# epoch 56 | loss: 0.672   | val_0_custom_loss: 1383.75144|  0:00:02s
# epoch 57 | loss: 0.65407 | val_0_custom_loss: 1403.55049|  0:00:02s
# epoch 58 | loss: 0.6435  | val_0_custom_loss: 1436.55183|  0:00:02s
# epoch 59 | loss: 0.63186 | val_0_custom_loss: 1429.23726|  0:00:02s
# epoch 60 | loss: 0.61668 | val_0_custom_loss: 1441.01324|  0:00:02s
# epoch 61 | loss: 0.6049  | val_0_custom_loss: 1463.09585|  0:00:02s
# epoch 62 | loss: 0.59328 | val_0_custom_loss: 1457.75282|  0:00:02s
# epoch 63 | loss: 0.58102 | val_0_custom_loss: 1436.43084|  0:00:02s
# epoch 64 | loss: 0.56781 | val_0_custom_loss: 1426.4707|  0:00:02s
# epoch 65 | loss: 0.5569  | val_0_custom_loss: 1426.15272|  0:00:02s
# epoch 66 | loss: 0.54396 | val_0_custom_loss: 1429.27979|  0:00:02s
# epoch 67 | loss: 0.53157 | val_0_custom_loss: 1432.39747|  0:00:02s
# epoch 68 | loss: 0.52119 | val_0_custom_loss: 1425.19418|  0:00:02s
# epoch 69 | loss: 0.51095 | val_0_custom_loss: 1424.80857|  0:00:02s
# epoch 70 | loss: 0.4989  | val_0_custom_loss: 1434.75743|  0:00:02s
# epoch 71 | loss: 0.48892 | val_0_custom_loss: 1422.12128|  0:00:02s
# epoch 72 | loss: 0.47859 | val_0_custom_loss: 1413.40795|  0:00:02s
# epoch 73 | loss: 0.46854 | val_0_custom_loss: 1400.58128|  0:00:02s
# epoch 74 | loss: 0.45876 | val_0_custom_loss: 1386.87525|  0:00:03s
# epoch 75 | loss: 0.45026 | val_0_custom_loss: 1376.09501|  0:00:03s
# epoch 76 | loss: 0.44137 | val_0_custom_loss: 1370.55102|  0:00:03s
# epoch 77 | loss: 0.43371 | val_0_custom_loss: 1376.05265|  0:00:03s
# epoch 78 | loss: 0.42658 | val_0_custom_loss: 1391.90514|  0:00:03s
# epoch 79 | loss: 0.41991 | val_0_custom_loss: 1395.05785|  0:00:03s
# epoch 80 | loss: 0.4136  | val_0_custom_loss: 1385.48887|  0:00:03s
# epoch 81 | loss: 0.4088  | val_0_custom_loss: 1379.20433|  0:00:03s
# epoch 82 | loss: 0.40467 | val_0_custom_loss: 1382.01188|  0:00:03s
# epoch 83 | loss: 0.40017 | val_0_custom_loss: 1396.52841|  0:00:03s
# epoch 84 | loss: 0.39566 | val_0_custom_loss: 1381.12938|  0:00:03s
# epoch 85 | loss: 0.39191 | val_0_custom_loss: 1366.28332|  0:00:03s
# epoch 86 | loss: 0.38792 | val_0_custom_loss: 1362.65613|  0:00:03s
# epoch 87 | loss: 0.38429 | val_0_custom_loss: 1354.59323|  0:00:03s
# epoch 88 | loss: 0.38105 | val_0_custom_loss: 1331.52236|  0:00:03s
# epoch 89 | loss: 0.37868 | val_0_custom_loss: 1311.83565|  0:00:03s
# epoch 90 | loss: 0.37564 | val_0_custom_loss: 1296.8126|  0:00:03s
# epoch 91 | loss: 0.37346 | val_0_custom_loss: 1284.49827|  0:00:03s
# epoch 92 | loss: 0.37115 | val_0_custom_loss: 1274.84919|  0:00:03s
# epoch 93 | loss: 0.36864 | val_0_custom_loss: 1267.50613|  0:00:03s
# epoch 94 | loss: 0.36681 | val_0_custom_loss: 1261.97544|  0:00:03s
# epoch 95 | loss: 0.365   | val_0_custom_loss: 1256.97393|  0:00:03s
# epoch 96 | loss: 0.3631  | val_0_custom_loss: 1252.06855|  0:00:03s
#
# Early stopping occurred at epoch 96 with best_epoch = 46 and best_val_0_custom_loss = 1227.40354
# Best weights from best epoch are automatically used!
# Run 1, predicting F3
# Predictions based on features ['F1', 'F2']
# Device used : cpu
# epoch 0  | loss: 35.37451| val_0_custom_loss: 5670.60378|  0:00:00s
# epoch 1  | loss: 31.51757| val_0_custom_loss: 5354.52972|  0:00:00s
# epoch 2  | loss: 21.0277 | val_0_custom_loss: 6309.77177|  0:00:00s
# epoch 3  | loss: 13.98489| val_0_custom_loss: 5346.23722|  0:00:00s
# epoch 4  | loss: 9.26661 | val_0_custom_loss: 4341.86386|  0:00:00s
# epoch 5  | loss: 7.10272 | val_0_custom_loss: 3362.56368|  0:00:00s
# epoch 6  | loss: 6.03986 | val_0_custom_loss: 3262.93474|  0:00:00s
# epoch 7  | loss: 5.37351 | val_0_custom_loss: 3471.68132|  0:00:00s
# epoch 8  | loss: 4.61505 | val_0_custom_loss: 3445.70035|  0:00:00s
# epoch 9  | loss: 3.84037 | val_0_custom_loss: 3245.14629|  0:00:00s
# epoch 10 | loss: 3.13792 | val_0_custom_loss: 3084.02665|  0:00:00s
# epoch 11 | loss: 2.63952 | val_0_custom_loss: 2956.33579|  0:00:00s
# epoch 12 | loss: 2.31286 | val_0_custom_loss: 2709.02894|  0:00:00s
# epoch 13 | loss: 2.24007 | val_0_custom_loss: 2533.02816|  0:00:00s
# epoch 14 | loss: 2.1623  | val_0_custom_loss: 2397.42614|  0:00:00s
# epoch 15 | loss: 2.06563 | val_0_custom_loss: 2248.66812|  0:00:00s
# epoch 16 | loss: 2.03852 | val_0_custom_loss: 2175.2973|  0:00:00s
# epoch 17 | loss: 2.03463 | val_0_custom_loss: 2057.73894|  0:00:00s
# epoch 18 | loss: 1.99085 | val_0_custom_loss: 1951.45488|  0:00:00s
# epoch 19 | loss: 1.9305  | val_0_custom_loss: 1821.39232|  0:00:00s
# epoch 20 | loss: 1.87799 | val_0_custom_loss: 1726.67002|  0:00:00s
# epoch 21 | loss: 1.82438 | val_0_custom_loss: 1635.63597|  0:00:00s
# epoch 22 | loss: 1.76528 | val_0_custom_loss: 1565.68699|  0:00:00s
# epoch 23 | loss: 1.72925 | val_0_custom_loss: 1521.80377|  0:00:00s
# epoch 24 | loss: 1.69529 | val_0_custom_loss: 1468.94241|  0:00:00s
# epoch 25 | loss: 1.65898 | val_0_custom_loss: 1416.91797|  0:00:00s
# epoch 26 | loss: 1.63412 | val_0_custom_loss: 1373.79719|  0:00:01s
# epoch 27 | loss: 1.60673 | val_0_custom_loss: 1335.59823|  0:00:01s
# epoch 28 | loss: 1.57712 | val_0_custom_loss: 1291.37107|  0:00:01s
# epoch 29 | loss: 1.55128 | val_0_custom_loss: 1247.86792|  0:00:01s
# epoch 30 | loss: 1.52393 | val_0_custom_loss: 1213.44302|  0:00:01s
# epoch 31 | loss: 1.50341 | val_0_custom_loss: 1183.37224|  0:00:01s
# epoch 32 | loss: 1.4824  | val_0_custom_loss: 1159.89677|  0:00:01s
# epoch 33 | loss: 1.45878 | val_0_custom_loss: 1146.17826|  0:00:01s
# epoch 34 | loss: 1.43612 | val_0_custom_loss: 1137.26727|  0:00:01s
# epoch 35 | loss: 1.41847 | val_0_custom_loss: 1131.1283|  0:00:01s
# epoch 36 | loss: 1.3994  | val_0_custom_loss: 1124.08991|  0:00:01s
# epoch 37 | loss: 1.38155 | val_0_custom_loss: 1113.88368|  0:00:01s
# epoch 38 | loss: 1.36354 | val_0_custom_loss: 1100.25261|  0:00:01s
# epoch 39 | loss: 1.34527 | val_0_custom_loss: 1085.6474|  0:00:01s
# epoch 40 | loss: 1.32444 | val_0_custom_loss: 1074.27369|  0:00:01s
# epoch 41 | loss: 1.30608 | val_0_custom_loss: 1066.35644|  0:00:01s
# epoch 42 | loss: 1.28725 | val_0_custom_loss: 1057.90064|  0:00:01s
# epoch 43 | loss: 1.26964 | val_0_custom_loss: 1049.41515|  0:00:01s
# epoch 44 | loss: 1.25046 | val_0_custom_loss: 1039.25649|  0:00:01s
# epoch 45 | loss: 1.23437 | val_0_custom_loss: 1025.9604|  0:00:02s
# epoch 46 | loss: 1.21799 | val_0_custom_loss: 1010.71239|  0:00:02s
# epoch 47 | loss: 1.20405 | val_0_custom_loss: 998.26297|  0:00:02s
# epoch 48 | loss: 1.19079 | val_0_custom_loss: 987.05035|  0:00:02s
# epoch 49 | loss: 1.17887 | val_0_custom_loss: 976.90476|  0:00:02s
# epoch 50 | loss: 1.16749 | val_0_custom_loss: 966.08384|  0:00:02s
# epoch 51 | loss: 1.15767 | val_0_custom_loss: 954.90976|  0:00:02s
# epoch 52 | loss: 1.14805 | val_0_custom_loss: 942.88087|  0:00:02s
# epoch 53 | loss: 1.13915 | val_0_custom_loss: 930.71893|  0:00:02s
# epoch 54 | loss: 1.13007 | val_0_custom_loss: 918.62468|  0:00:02s
# epoch 55 | loss: 1.12197 | val_0_custom_loss: 907.32113|  0:00:02s
# epoch 56 | loss: 1.11389 | val_0_custom_loss: 896.92181|  0:00:02s
# epoch 57 | loss: 1.10649 | val_0_custom_loss: 887.39199|  0:00:02s
# epoch 58 | loss: 1.09962 | val_0_custom_loss: 877.56509|  0:00:02s
# epoch 59 | loss: 1.09337 | val_0_custom_loss: 867.52539|  0:00:02s
# epoch 60 | loss: 1.08721 | val_0_custom_loss: 856.61045|  0:00:02s
# epoch 61 | loss: 1.08213 | val_0_custom_loss: 844.09668|  0:00:02s
# epoch 62 | loss: 1.07646 | val_0_custom_loss: 830.78792|  0:00:02s
# epoch 63 | loss: 1.07159 | val_0_custom_loss: 817.95587|  0:00:02s
# epoch 64 | loss: 1.06689 | val_0_custom_loss: 805.76403|  0:00:02s
# epoch 65 | loss: 1.06256 | val_0_custom_loss: 794.2559|  0:00:03s
# epoch 66 | loss: 1.05819 | val_0_custom_loss: 783.73233|  0:00:03s
# epoch 67 | loss: 1.05421 | val_0_custom_loss: 774.15574|  0:00:03s
# epoch 68 | loss: 1.05004 | val_0_custom_loss: 765.40152|  0:00:03s
# epoch 69 | loss: 1.04646 | val_0_custom_loss: 756.97044|  0:00:03s
# epoch 70 | loss: 1.043   | val_0_custom_loss: 748.59653|  0:00:03s
# epoch 71 | loss: 1.03983 | val_0_custom_loss: 740.1056|  0:00:03s
# epoch 72 | loss: 1.03666 | val_0_custom_loss: 732.0124|  0:00:03s
# epoch 73 | loss: 1.03376 | val_0_custom_loss: 724.38614|  0:00:03s
# epoch 74 | loss: 1.03099 | val_0_custom_loss: 717.30295|  0:00:03s
# epoch 75 | loss: 1.02853 | val_0_custom_loss: 710.20364|  0:00:03s
# epoch 76 | loss: 1.02604 | val_0_custom_loss: 703.1311|  0:00:03s
# epoch 77 | loss: 1.02377 | val_0_custom_loss: 696.05574|  0:00:03s
# epoch 78 | loss: 1.02147 | val_0_custom_loss: 689.09977|  0:00:03s
# epoch 79 | loss: 1.01944 | val_0_custom_loss: 682.02249|  0:00:03s
# epoch 80 | loss: 1.01748 | val_0_custom_loss: 674.90328|  0:00:03s
# epoch 81 | loss: 1.01566 | val_0_custom_loss: 667.91895|  0:00:03s
# epoch 82 | loss: 1.01378 | val_0_custom_loss: 661.07649|  0:00:03s
# epoch 83 | loss: 1.01213 | val_0_custom_loss: 654.38205|  0:00:03s
# epoch 84 | loss: 1.0105  | val_0_custom_loss: 647.69518|  0:00:03s
# epoch 85 | loss: 1.00902 | val_0_custom_loss: 641.0301|  0:00:03s
# epoch 86 | loss: 1.00753 | val_0_custom_loss: 634.45484|  0:00:03s
# epoch 87 | loss: 1.00619 | val_0_custom_loss: 628.02265|  0:00:03s
# epoch 88 | loss: 1.00486 | val_0_custom_loss: 621.73193|  0:00:03s
# epoch 89 | loss: 1.00364 | val_0_custom_loss: 615.49537|  0:00:03s
# epoch 90 | loss: 1.00241 | val_0_custom_loss: 609.43775|  0:00:04s
# epoch 91 | loss: 1.00132 | val_0_custom_loss: 603.56592|  0:00:04s
# epoch 92 | loss: 1.00024 | val_0_custom_loss: 597.81419|  0:00:04s
# epoch 93 | loss: 0.99924 | val_0_custom_loss: 592.13734|  0:00:04s
# epoch 94 | loss: 0.99823 | val_0_custom_loss: 586.75729|  0:00:04s
# epoch 95 | loss: 0.99734 | val_0_custom_loss: 581.55187|  0:00:04s
# epoch 96 | loss: 0.99645 | val_0_custom_loss: 576.55391|  0:00:04s
# epoch 97 | loss: 0.99572 | val_0_custom_loss: 571.70051|  0:00:04s
# epoch 98 | loss: 0.99485 | val_0_custom_loss: 567.11547|  0:00:04s
# epoch 99 | loss: 0.99415 | val_0_custom_loss: 562.71336|  0:00:04s
# epoch 100| loss: 0.99346 | val_0_custom_loss: 558.53705|  0:00:04s
# epoch 101| loss: 0.99285 | val_0_custom_loss: 554.68017|  0:00:04s
# epoch 102| loss: 0.99221 | val_0_custom_loss: 551.01291|  0:00:04s
# epoch 103| loss: 0.99163 | val_0_custom_loss: 547.45327|  0:00:04s
# epoch 104| loss: 0.99104 | val_0_custom_loss: 543.9865|  0:00:04s
# epoch 105| loss: 0.99052 | val_0_custom_loss: 540.64175|  0:00:04s
# epoch 106| loss: 0.99001 | val_0_custom_loss: 537.374 |  0:00:04s
# epoch 107| loss: 0.98955 | val_0_custom_loss: 534.16131|  0:00:04s
# epoch 108| loss: 0.98909 | val_0_custom_loss: 530.99634|  0:00:04s
# epoch 109| loss: 0.98866 | val_0_custom_loss: 528.02402|  0:00:04s
# epoch 110| loss: 0.98825 | val_0_custom_loss: 525.20707|  0:00:04s
# epoch 111| loss: 0.98786 | val_0_custom_loss: 522.51314|  0:00:04s
# epoch 112| loss: 0.9875  | val_0_custom_loss: 519.95904|  0:00:04s
# epoch 113| loss: 0.98717 | val_0_custom_loss: 517.54241|  0:00:04s
# epoch 114| loss: 0.98682 | val_0_custom_loss: 515.32749|  0:00:04s
# epoch 115| loss: 0.98651 | val_0_custom_loss: 513.34862|  0:00:05s
# epoch 116| loss: 0.98621 | val_0_custom_loss: 511.49038|  0:00:05s
# epoch 117| loss: 0.98593 | val_0_custom_loss: 509.71424|  0:00:05s
# epoch 118| loss: 0.98566 | val_0_custom_loss: 507.99479|  0:00:05s
# epoch 119| loss: 0.98541 | val_0_custom_loss: 506.36769|  0:00:05s
# epoch 120| loss: 0.98516 | val_0_custom_loss: 504.8458|  0:00:05s
# epoch 121| loss: 0.98493 | val_0_custom_loss: 503.4261|  0:00:05s
# epoch 122| loss: 0.9847  | val_0_custom_loss: 502.0919|  0:00:05s
# epoch 123| loss: 0.98451 | val_0_custom_loss: 500.88935|  0:00:05s
# epoch 124| loss: 0.98432 | val_0_custom_loss: 499.74542|  0:00:05s
# epoch 125| loss: 0.98413 | val_0_custom_loss: 498.67176|  0:00:05s
# epoch 126| loss: 0.98395 | val_0_custom_loss: 497.64191|  0:00:05s
# epoch 127| loss: 0.98378 | val_0_custom_loss: 496.63548|  0:00:05s
# epoch 128| loss: 0.98362 | val_0_custom_loss: 495.67467|  0:00:05s
# epoch 129| loss: 0.98347 | val_0_custom_loss: 494.73668|  0:00:05s
# epoch 130| loss: 0.98333 | val_0_custom_loss: 493.78422|  0:00:05s
# epoch 131| loss: 0.98319 | val_0_custom_loss: 492.81276|  0:00:05s
# epoch 132| loss: 0.98306 | val_0_custom_loss: 491.87903|  0:00:05s
# epoch 133| loss: 0.98294 | val_0_custom_loss: 490.94838|  0:00:05s
# epoch 134| loss: 0.98282 | val_0_custom_loss: 490.02356|  0:00:05s
# epoch 135| loss: 0.98271 | val_0_custom_loss: 489.11003|  0:00:05s
# epoch 136| loss: 0.9826  | val_0_custom_loss: 488.20289|  0:00:05s
# epoch 137| loss: 0.9825  | val_0_custom_loss: 487.33157|  0:00:05s
# epoch 138| loss: 0.9824  | val_0_custom_loss: 486.47949|  0:00:05s
# epoch 139| loss: 0.98231 | val_0_custom_loss: 485.64226|  0:00:05s
# epoch 140| loss: 0.98222 | val_0_custom_loss: 484.79796|  0:00:05s
# epoch 141| loss: 0.98214 | val_0_custom_loss: 483.98054|  0:00:06s
# epoch 142| loss: 0.98206 | val_0_custom_loss: 483.18309|  0:00:06s
# epoch 143| loss: 0.98198 | val_0_custom_loss: 482.38942|  0:00:06s
# epoch 144| loss: 0.98191 | val_0_custom_loss: 481.60625|  0:00:06s
# epoch 145| loss: 0.98185 | val_0_custom_loss: 480.84327|  0:00:06s
# epoch 146| loss: 0.98178 | val_0_custom_loss: 480.08367|  0:00:06s
# epoch 147| loss: 0.98173 | val_0_custom_loss: 479.34952|  0:00:06s
# epoch 148| loss: 0.98167 | val_0_custom_loss: 478.66338|  0:00:06s
# epoch 149| loss: 0.98162 | val_0_custom_loss: 477.94436|  0:00:06s
# epoch 150| loss: 0.98156 | val_0_custom_loss: 477.23112|  0:00:06s
# epoch 151| loss: 0.98151 | val_0_custom_loss: 476.54879|  0:00:06s
# epoch 152| loss: 0.98147 | val_0_custom_loss: 475.88767|  0:00:06s
# epoch 153| loss: 0.98142 | val_0_custom_loss: 475.25786|  0:00:06s
# epoch 154| loss: 0.98138 | val_0_custom_loss: 474.64814|  0:00:06s
# epoch 155| loss: 0.98134 | val_0_custom_loss: 474.05738|  0:00:06s
# epoch 156| loss: 0.9813  | val_0_custom_loss: 473.46895|  0:00:06s
# epoch 157| loss: 0.98127 | val_0_custom_loss: 472.88746|  0:00:06s
# epoch 158| loss: 0.98123 | val_0_custom_loss: 472.32598|  0:00:06s
# epoch 159| loss: 0.9812  | val_0_custom_loss: 471.76105|  0:00:06s
# epoch 160| loss: 0.98117 | val_0_custom_loss: 471.1927|  0:00:06s
# epoch 161| loss: 0.98114 | val_0_custom_loss: 470.62944|  0:00:06s
# epoch 162| loss: 0.98111 | val_0_custom_loss: 470.06074|  0:00:06s
# epoch 163| loss: 0.98109 | val_0_custom_loss: 469.49993|  0:00:06s
# epoch 164| loss: 0.98106 | val_0_custom_loss: 468.93441|  0:00:06s
# epoch 165| loss: 0.98104 | val_0_custom_loss: 468.37924|  0:00:06s
# epoch 166| loss: 0.98101 | val_0_custom_loss: 467.84544|  0:00:07s
# epoch 167| loss: 0.98099 | val_0_custom_loss: 467.33365|  0:00:07s
# epoch 168| loss: 0.98097 | val_0_custom_loss: 466.83453|  0:00:07s
# epoch 169| loss: 0.98095 | val_0_custom_loss: 466.34605|  0:00:07s
# epoch 170| loss: 0.98094 | val_0_custom_loss: 465.86491|  0:00:07s
# epoch 171| loss: 0.98092 | val_0_custom_loss: 465.41514|  0:00:07s
# epoch 172| loss: 0.9809  | val_0_custom_loss: 464.97054|  0:00:07s
# epoch 173| loss: 0.98089 | val_0_custom_loss: 464.52889|  0:00:07s
# epoch 174| loss: 0.98087 | val_0_custom_loss: 464.08487|  0:00:07s
# epoch 175| loss: 0.98086 | val_0_custom_loss: 463.61019|  0:00:07s
# epoch 176| loss: 0.98084 | val_0_custom_loss: 463.15913|  0:00:07s
# epoch 177| loss: 0.98083 | val_0_custom_loss: 462.70795|  0:00:07s
# epoch 178| loss: 0.98082 | val_0_custom_loss: 462.23988|  0:00:07s
# epoch 179| loss: 0.98081 | val_0_custom_loss: 461.7781|  0:00:07s
# epoch 180| loss: 0.9808  | val_0_custom_loss: 461.32986|  0:00:07s
# epoch 181| loss: 0.98079 | val_0_custom_loss: 460.90376|  0:00:07s
# epoch 182| loss: 0.98078 | val_0_custom_loss: 460.51693|  0:00:07s
# epoch 183| loss: 0.98077 | val_0_custom_loss: 460.1595|  0:00:07s
# epoch 184| loss: 0.98076 | val_0_custom_loss: 459.82516|  0:00:07s
# epoch 185| loss: 0.98075 | val_0_custom_loss: 459.51601|  0:00:07s
# epoch 186| loss: 0.98074 | val_0_custom_loss: 459.19357|  0:00:07s
# epoch 187| loss: 0.98074 | val_0_custom_loss: 458.87774|  0:00:07s
# epoch 188| loss: 0.98073 | val_0_custom_loss: 458.55719|  0:00:07s
# epoch 189| loss: 0.98072 | val_0_custom_loss: 458.2517|  0:00:07s
# epoch 190| loss: 0.98071 | val_0_custom_loss: 457.9676|  0:00:08s
# epoch 191| loss: 0.98071 | val_0_custom_loss: 457.69175|  0:00:08s
# epoch 192| loss: 0.9807  | val_0_custom_loss: 457.42994|  0:00:08s
# epoch 193| loss: 0.9807  | val_0_custom_loss: 457.19221|  0:00:08s
# epoch 194| loss: 0.98069 | val_0_custom_loss: 456.97839|  0:00:08s
# epoch 195| loss: 0.98069 | val_0_custom_loss: 456.78294|  0:00:08s
# epoch 196| loss: 0.98068 | val_0_custom_loss: 456.59976|  0:00:08s
# epoch 197| loss: 0.98068 | val_0_custom_loss: 456.43005|  0:00:08s
# epoch 198| loss: 0.98067 | val_0_custom_loss: 456.26838|  0:00:08s
# epoch 199| loss: 0.98067 | val_0_custom_loss: 456.11652|  0:00:08s
# epoch 200| loss: 0.98067 | val_0_custom_loss: 455.9657|  0:00:08s
# epoch 201| loss: 0.98066 | val_0_custom_loss: 455.82437|  0:00:08s
# epoch 202| loss: 0.98066 | val_0_custom_loss: 455.69169|  0:00:08s
# epoch 203| loss: 0.98066 | val_0_custom_loss: 455.54964|  0:00:08s
# epoch 204| loss: 0.98065 | val_0_custom_loss: 455.40337|  0:00:08s
# epoch 205| loss: 0.98065 | val_0_custom_loss: 455.26304|  0:00:08s
# epoch 206| loss: 0.98065 | val_0_custom_loss: 455.12973|  0:00:08s
# epoch 207| loss: 0.98064 | val_0_custom_loss: 455.00164|  0:00:08s
# epoch 208| loss: 0.98064 | val_0_custom_loss: 454.86009|  0:00:08s
# epoch 209| loss: 0.98064 | val_0_custom_loss: 454.70557|  0:00:08s
# epoch 210| loss: 0.98064 | val_0_custom_loss: 454.55189|  0:00:08s
# epoch 211| loss: 0.98064 | val_0_custom_loss: 454.40299|  0:00:08s
# epoch 212| loss: 0.98063 | val_0_custom_loss: 454.25113|  0:00:08s
# epoch 213| loss: 0.98063 | val_0_custom_loss: 454.10072|  0:00:08s
# epoch 214| loss: 0.98063 | val_0_custom_loss: 453.95329|  0:00:08s
# epoch 215| loss: 0.98063 | val_0_custom_loss: 453.80451|  0:00:09s
# epoch 216| loss: 0.98063 | val_0_custom_loss: 453.64472|  0:00:09s
# epoch 217| loss: 0.98062 | val_0_custom_loss: 453.47841|  0:00:09s
# epoch 218| loss: 0.98062 | val_0_custom_loss: 453.31278|  0:00:09s
# epoch 219| loss: 0.98062 | val_0_custom_loss: 453.14428|  0:00:09s
# epoch 220| loss: 0.98062 | val_0_custom_loss: 452.97579|  0:00:09s
# epoch 221| loss: 0.98062 | val_0_custom_loss: 452.80653|  0:00:09s
# epoch 222| loss: 0.98062 | val_0_custom_loss: 452.63209|  0:00:09s
# epoch 223| loss: 0.98062 | val_0_custom_loss: 452.45405|  0:00:09s
# epoch 224| loss: 0.98062 | val_0_custom_loss: 452.27254|  0:00:09s
# epoch 225| loss: 0.98061 | val_0_custom_loss: 452.0914|  0:00:09s
# epoch 226| loss: 0.98061 | val_0_custom_loss: 451.89723|  0:00:09s
# epoch 227| loss: 0.98061 | val_0_custom_loss: 451.69465|  0:00:09s
# epoch 228| loss: 0.98061 | val_0_custom_loss: 451.48802|  0:00:09s
# epoch 229| loss: 0.98061 | val_0_custom_loss: 451.28265|  0:00:09s
# epoch 230| loss: 0.98061 | val_0_custom_loss: 451.08058|  0:00:09s
# epoch 231| loss: 0.98061 | val_0_custom_loss: 450.88133|  0:00:09s
# epoch 232| loss: 0.98061 | val_0_custom_loss: 450.6864|  0:00:09s
# epoch 233| loss: 0.98061 | val_0_custom_loss: 450.49685|  0:00:09s
# epoch 234| loss: 0.98061 | val_0_custom_loss: 450.30852|  0:00:09s
# epoch 235| loss: 0.98061 | val_0_custom_loss: 450.12159|  0:00:09s
# epoch 236| loss: 0.98061 | val_0_custom_loss: 449.93892|  0:00:09s
# epoch 237| loss: 0.98061 | val_0_custom_loss: 449.76239|  0:00:09s
# epoch 238| loss: 0.9806  | val_0_custom_loss: 449.58346|  0:00:09s
# epoch 239| loss: 0.9806  | val_0_custom_loss: 449.4061|  0:00:09s
# epoch 240| loss: 0.9806  | val_0_custom_loss: 449.2308|  0:00:10s
# epoch 241| loss: 0.9806  | val_0_custom_loss: 449.06194|  0:00:10s
# epoch 242| loss: 0.9806  | val_0_custom_loss: 448.88353|  0:00:10s
# epoch 243| loss: 0.9806  | val_0_custom_loss: 448.68873|  0:00:10s
# epoch 244| loss: 0.9806  | val_0_custom_loss: 448.49755|  0:00:10s
# epoch 245| loss: 0.9806  | val_0_custom_loss: 448.31118|  0:00:10s
# epoch 246| loss: 0.9806  | val_0_custom_loss: 448.1286|  0:00:10s
# epoch 247| loss: 0.9806  | val_0_custom_loss: 447.94021|  0:00:10s
# epoch 248| loss: 0.9806  | val_0_custom_loss: 447.75139|  0:00:10s
# epoch 249| loss: 0.9806  | val_0_custom_loss: 447.56333|  0:00:10s
# epoch 250| loss: 0.9806  | val_0_custom_loss: 447.37965|  0:00:10s
# epoch 251| loss: 0.9806  | val_0_custom_loss: 447.20086|  0:00:10s
# epoch 252| loss: 0.9806  | val_0_custom_loss: 447.02825|  0:00:10s
# epoch 253| loss: 0.9806  | val_0_custom_loss: 446.85841|  0:00:10s
# epoch 254| loss: 0.9806  | val_0_custom_loss: 446.69401|  0:00:10s
# epoch 255| loss: 0.9806  | val_0_custom_loss: 446.53626|  0:00:10s
# epoch 256| loss: 0.9806  | val_0_custom_loss: 446.38118|  0:00:10s
# epoch 257| loss: 0.9806  | val_0_custom_loss: 446.22972|  0:00:10s
# epoch 258| loss: 0.9806  | val_0_custom_loss: 446.07898|  0:00:10s
# epoch 259| loss: 0.9806  | val_0_custom_loss: 445.93191|  0:00:10s
# epoch 260| loss: 0.9806  | val_0_custom_loss: 445.78934|  0:00:11s
# epoch 261| loss: 0.9806  | val_0_custom_loss: 445.65294|  0:00:11s
# epoch 262| loss: 0.9806  | val_0_custom_loss: 445.51233|  0:00:11s
# epoch 263| loss: 0.9806  | val_0_custom_loss: 445.37269|  0:00:11s
# epoch 264| loss: 0.9806  | val_0_custom_loss: 445.23304|  0:00:11s
# epoch 265| loss: 0.9806  | val_0_custom_loss: 445.08881|  0:00:11s
# epoch 266| loss: 0.9806  | val_0_custom_loss: 444.94733|  0:00:11s
# epoch 267| loss: 0.9806  | val_0_custom_loss: 444.8071|  0:00:11s
# epoch 268| loss: 0.9806  | val_0_custom_loss: 444.67287|  0:00:11s
# epoch 269| loss: 0.9806  | val_0_custom_loss: 444.54337|  0:00:11s
# epoch 270| loss: 0.9806  | val_0_custom_loss: 444.40119|  0:00:11s
# epoch 271| loss: 0.9806  | val_0_custom_loss: 444.26049|  0:00:11s
# epoch 272| loss: 0.9806  | val_0_custom_loss: 444.12096|  0:00:11s
# epoch 273| loss: 0.9806  | val_0_custom_loss: 443.98468|  0:00:11s
# epoch 274| loss: 0.9806  | val_0_custom_loss: 443.85127|  0:00:11s
# epoch 275| loss: 0.9806  | val_0_custom_loss: 443.71856|  0:00:11s
# epoch 276| loss: 0.9806  | val_0_custom_loss: 443.58432|  0:00:11s
# epoch 277| loss: 0.9806  | val_0_custom_loss: 443.445 |  0:00:11s
# epoch 278| loss: 0.9806  | val_0_custom_loss: 443.30898|  0:00:12s
# epoch 279| loss: 0.9806  | val_0_custom_loss: 443.17554|  0:00:12s
# epoch 280| loss: 0.9806  | val_0_custom_loss: 443.04389|  0:00:12s
# epoch 281| loss: 0.9806  | val_0_custom_loss: 442.91434|  0:00:12s
# epoch 282| loss: 0.9806  | val_0_custom_loss: 442.78987|  0:00:12s
# epoch 283| loss: 0.9806  | val_0_custom_loss: 442.66915|  0:00:12s
# epoch 284| loss: 0.9806  | val_0_custom_loss: 442.55118|  0:00:12s
# epoch 285| loss: 0.9806  | val_0_custom_loss: 442.43697|  0:00:12s
# epoch 286| loss: 0.9806  | val_0_custom_loss: 442.31979|  0:00:12s
# epoch 287| loss: 0.9806  | val_0_custom_loss: 442.19621|  0:00:12s
# epoch 288| loss: 0.9806  | val_0_custom_loss: 442.0767|  0:00:12s
# epoch 289| loss: 0.9806  | val_0_custom_loss: 441.9603|  0:00:12s
# epoch 290| loss: 0.9806  | val_0_custom_loss: 441.84679|  0:00:12s
# epoch 291| loss: 0.9806  | val_0_custom_loss: 441.73645|  0:00:12s
# epoch 292| loss: 0.9806  | val_0_custom_loss: 441.62981|  0:00:12s
# epoch 293| loss: 0.9806  | val_0_custom_loss: 441.52748|  0:00:12s
# epoch 294| loss: 0.9806  | val_0_custom_loss: 441.428 |  0:00:12s
# epoch 295| loss: 0.9806  | val_0_custom_loss: 441.33139|  0:00:12s
# epoch 296| loss: 0.9806  | val_0_custom_loss: 441.23806|  0:00:12s
# epoch 297| loss: 0.9806  | val_0_custom_loss: 441.14641|  0:00:12s
# epoch 298| loss: 0.9806  | val_0_custom_loss: 441.05187|  0:00:13s
# epoch 299| loss: 0.9806  | val_0_custom_loss: 440.95553|  0:00:13s
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_custom_loss = 440.95553
# Best weights from best epoch are automatically used!

# %% [markdown]
# ## 3. Complete Dataset
# Costs for each run

# %%
costs
# Out:
# {0: [1227.40353824381, 440.955533180112]}

# %% [markdown]
# ### 3.1 Reconstruct Dataset
# choose best model based on min. squared custom loss (punishing large outliers in losses for single features)

# %%
cost_totals = [sum([x**2 for x in c]) for _, c in costs.items()]
best_model = cost_totals.index(min(cost_totals))
features_final = features_reconstr[best_model]
print(f"Best model: run {best_model} with custom losses {costs[best_model]} for features {list(features_to_predict)}")
# Out:
# Best model: run 0 with custom losses [1227.40353824381, 440.955533180112] for features ['F2', 'F3']

# %% [markdown]
# ### 3.2 Plot changes (comp. to original data)

# %%
# scatter plot with combined data
orig_data = features.copy()
orig_data["change"] = 0
changed_data = features_final[features_mv.isna().any(axis=1)]
comp_data = pd.concat([orig_data, changed_data]).reset_index(drop=True).fillna(1)

# line plot connecting filled data to true data points
reconstr_data = features_final[features_mv.isna().any(axis=1)]
true_data = features[features_mv.isna().any(axis=1)]

# plot
fig = plt.figure(figsize=(8,8))
ax  = fig.add_subplot(projection = '3d')
ax.scatter(comp_data["F1"], comp_data["F2"], comp_data["F3"], c=[comp_data["change"]])

for i in range(len(reconstr_data)):
    ax.plot([reconstr_data["F1"].iloc[i], true_data["F1"].iloc[i]],[reconstr_data["F2"].iloc[i], true_data["F2"].iloc[i]],[reconstr_data["F3"].iloc[i], true_data["F3"].iloc[i]], color="black", linewidth=.5)


plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
plt.show
plt.savefig(os.path.join(plots_path, "4_imputation_differences.png"))
# Out:
# <img src="data:image/png;base64,..." width="576">

# %% [markdown]
# ## 4. Clustering

# %%
# apply clustering
dbscan_reconstr = DBSCAN(**config["DBSCAN"]).fit(features_final)
clusters_reconstr = dbscan_reconstr.labels_

# %%
# plot new clustering
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(projection='3d')
ax.scatter(features_final.iloc[:, 0], features_final.iloc[:, 1], features_final.iloc[:, 2], c=clusters_reconstr)
plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
plt.show()
plt.savefig(os.path.join(plots_path, "3_DBSCAN_imputed_data.png"))
# Out:
# <img src="data:image/png;base64,..." width="576">

# %% [markdown]
# ## 5. Cluster Performance

# %%
results = {}

# %% [markdown]
# ### 5.1 Feature Distributions
# #### 5.1.1 Distr. Plots

# %%
# plot distributions
bins = 20
n_feat = len(features_final.columns)

fig, (ax) = plt.subplots(n_feat, 2, figsize=(n_feat*2,6))
for n, feature in enumerate(features_final.columns):
    ax[n, 0].hist(features[feature], bins=bins)
    ax[n, 0].set_title(f"{feature}_orig")
    ax[n, 1].hist(features_final[feature], bins=bins)
    ax[n, 1].set_title(f"{feature}_filled")

fig.tight_layout()
plt.show()
plt.savefig(os.path.join(plots_path, "feature distributions.png"))
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# #### 5.1.2 KL Divergence
# Based on implementation from https://stackoverflow.com/questions/57687458/how-to-calculate-probabilities-using-numpy-histogram-and-then-use-it-for-calcula

# %%
# calculating the kl divergence (relative entropy) with scipy

# calculate probabilities
def probability_dist(x, y, bins):
    # histogram
    hist_xy = np.histogram2d(x, y, bins=bins)[0]

    # compute marginals
    hist_xy = hist_xy + sys.float_info.min # prevent division with 0
    hist_xy = hist_xy / np.sum(hist_xy)
    hist_x = np.sum(hist_xy, axis=1)
    hist_y = np.sum(hist_xy, axis=0)
    return(hist_x, hist_y)

# calculate kl divergence
results["KL_Divergence"] = {}
for n, feature in enumerate(features_final):
    dist1, dist2 = probability_dist(features[feature], features_final[feature], bins)
    KL_div_1_2 = {sum(rel_entr(dist1, dist2))}
    KL_div_2_1 = {sum(rel_entr(dist2, dist1))}
    results["KL_Divergence"][f"{feature}_orig --> {feature}_reconstr"] = KL_div_1_2
    results["KL_Divergence"][f"{feature}_reconstr --> {feature}_orig"] = KL_div_2_1
    
    print(f"KL divergence {feature}_orig to {feature}_filled: {KL_div_1_2}")
    print(f"KL divergence {feature}_reconstr to {feature}_orig: {KL_div_2_1}")
    print("")
# Out:
# KL divergence F1_orig to F1_filled: {0.0}
# KL divergence F1_reconstr to F1_orig: {0.0}
#
# KL divergence F2_orig to F2_filled: {0.008533316800716307}
# KL divergence F2_reconstr to F2_orig: {0.008248045591266113}
#
# KL divergence F3_orig to F3_filled: {53.204893759981516}
# KL divergence F3_reconstr to F3_orig: {10.801061382270916}

# %% [markdown]
# ### 5.2 Cluster Performance
# #### 5.3 Noise

# %%
print(f"DBSCAN noise orig_data: {sum(clusters_orig == -1)}")
print(f"DBSCAN noise reconstr_data:{sum(clusters_reconstr == -1)}")
# Out:
# DBSCAN noise orig_data: 1
# DBSCAN noise reconstr_data:2

# %% [markdown]
# #### 5.4 Silhouette Score

# %%
from sklearn.metrics import silhouette_score

silhouette_orig = silhouette_score(features, np.ravel(clusters))
silhouette_reconstr = silhouette_score(features_final, clusters_reconstr)

results["silhouette_score"] = {}
results["silhouette_score"]["orig_data"] = silhouette_orig
results["silhouette_score"]["reconstr_data"] = silhouette_reconstr
print(f"Silhouette Score orig_data: {silhouette_orig}")
print(f"Silhouette Score reconstr_data: {silhouette_reconstr}")
# Out:
# Silhouette Score orig_data: 0.686605699880095
# Silhouette Score reconstr_data: 0.6670414032296427
