# %% [markdown]
# ## Intro
# #### Setup of an experiment
# - Experiments can be setup by using the config parameter "experiment_variable" and assigning the experiment values as a list, e.g.
#     - experiment_variable = "train_val_split"
#     - config["training"]["train_val_split"] = [0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]
# - note: only the following parameters can be used for experiments:
#     - all parameters of the categories "training" and "model_param",
#     - parameters "missing_percent", "missing_outliers", "missing_value_features", "st_deviations"
#     - for other parameters (such as custom loss weights or different datasets), run each parameter as a signle experiment
#
# #### Loading experiments
# - run chapter 1 to get the data and generate missing values
# - skip chapter 2 (time consuming calculations)
# - load outputs saved in output.toml (such as metrics) with:
#         output = toml.load("output.toml")
# - load reconstructed datasets with:
#         with open(os.path.join("X_reconstr", 'X_reconstr.pkl'), 'rb') as f:
#             X_reconstr = pickle.load(f)
# - run chapter 3-5
#
# #### Summary

# %% [markdown]
# ![PNG%20image.png](attachment:PNG%20image.png)

# %%
# %%javascript
# IPython.notebook.kernel.execute('nb_name = "' + IPython.notebook.notebook_name + '"')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import random
import math
import scipy
import astropy.stats
import pickle
import sys
import os
sys.path.append(os.getcwd() + "/pytorch_tabnet/")

from sklearn.cluster import DBSCAN

# %% [markdown]
# ## 0. Experiment Setup

# %%
# should an output folder be created to save the experiment data?
save_output = True
save_models = False

# %%
# read config file
import toml
config = toml.load("config.toml")

# determine experimental parameter from config
experiment_variable_values = ""
experiment_dict_key = ""
for category_name, category_values in config.items():
    if config["general"]["experiment_variable"] in category_values:
        experiment_variable_values = category_values[config["general"]["experiment_variable"]]
        experiment_dict_key = category_name
        
# rnd seed to support reproducable results
seed_value =  config["general"]["random_seed"] if config["general"]["random_seed"] else random.randrange(2**32 -1)
random.seed(seed_value)
np.random.seed(seed_value)

# TabNet hyperparameters
experiment_variable = config["general"]["experiment_variable"]
regressor_param = {"optimizer_fn" : torch.optim.Adam,
                   "optimizer_params" : {"lr":0.05},
                   "scheduler_params" : {"step_size": 0.2, "gamma": 0.9},
                   "scheduler_fn" : torch.optim.lr_scheduler.StepLR,
                   "mask_type" : 'entmax',
                   "device_name" : 'cuda', # only working on NVIDIA GPUs
                   "verbose" : 0
                  }

# create experiment folder structure
if save_output or save_models:  
    from datetime import datetime
    
    experiment_name = config["general"]["experiment_name"]
    experiment_folder = f"{datetime.now().strftime('%Y_%m_%d %H-%M-%S')} {experiment_name} " if experiment_name else f"{datetime.now().strftime('%Y_%m_%d %H-%M-%S')} {config['general']['dataset']}-{config['general']['experiment_variable']}-{config['model_param']['eval_metric'][0]}"
    
    experiment_path = os.path.join("04_Experiments", experiment_folder)
    os.mkdir(experiment_path)
    
    plots_path = os.path.join(experiment_path, "plots")
    os.mkdir(plots_path)
    
    models_path = os.path.join(experiment_path, "models")
    os.mkdir(models_path)
    
    X_reconstr_path = os.path.join(experiment_path, "X_reconstr")
    os.mkdir(X_reconstr_path)
    
    # save config file
    import shutil
    shutil.copy2("config.toml", experiment_path)
    config_path = os.path.join(experiment_path, "config.toml")
    
    # save random seed
    if not config["general"]["random_seed"]:
        config["general"]["random_seed"] = seed_value
        with open(config_path, "w") as f:
            toml.dump(config, f)
    
    # save model hyperparameters
    with open(os.path.join(experiment_path, 'config.toml'), 'a') as config_file:
        config_file.write("\n#[regressor_param]\n")
        for key, value in regressor_param.items(): 
            config_file.write('#%s = %s\n' % (key, str(value)))
    
    # create output file
    output_path = os.path.join(experiment_path, "output.toml")
    output_file = open(output_path, "w")

output = {}

# %% [markdown]
# ## 1. Datasets
#
# ### 1.0. Choose dataset
# Get dataset from config.

# %%
if config["general"]["dataset"] == "wine":
    from sklearn.datasets import load_wine
    from sklearn.preprocessing import scale, StandardScaler

    wine = load_wine()
    X, labels_true = pd.DataFrame(wine.data, columns=wine['feature_names']), wine.target
    X_scaled = pd.DataFrame(StandardScaler().fit_transform(X), columns=wine['feature_names'])
else:
    raise ValueError(f"The dataset {config['general']['dataset']} is not implemented.")

# %% [markdown]
# #### Determine feature distributions
# To examine the influence and predictability of outliers, we want to choose a feature of the dataset, that has a distribution including an adequate number of outliers.\

# %%
X_scaled.hist(layout=(4,4), figsize=(12,12), density=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Examine outlierness
# Examine the number of outliers in both directions. For the given outlier definition (distance to the mean in standard deviations, e.g. 3 * std) the share of outliers in both direction should be large enough.
# The outlier definition (x times standard_deviation) is defined in the config.

# %%
def n_outliers(data):
    return data[(data < X[experiment_feature].mean() - config["outlier_definition"]["st_deviations"] * X[experiment_feature].std()) | (data > X[experiment_feature].mean() + config["outlier_definition"]["st_deviations"] * X[experiment_feature].std())].count()

# %%
def is_outlier(data):
    upper_outlier = data > X[experiment_feature].mean() + config["outlier_definition"]["st_deviations"] * X[experiment_feature].std()
    lower_outlier = data < X[experiment_feature].mean() - config["outlier_definition"]["st_deviations"] * X[experiment_feature].std()
    return (upper_outlier | lower_outlier), lower_outlier, upper_outlier

# %%
X_outliers_up = X.agg(lambda x: x[x > x.mean() + config["outlier_definition"]["st_deviations"] * x.std()].count()) / X.shape[0]
X_outliers_low = X.agg(lambda x: x[x < x.mean() - config["outlier_definition"]["st_deviations"] * x.std()].count()) / X.shape[0]

# %% [markdown]
# #### Select feature
# The selected feature should have at least a certain number of outliers in total and a minimum number of outliers in each direction.

# %%
# filter by minimum outliers in each direction
X_outliers_up = X_outliers_up[(X_outliers_up > config["outlier_definition"]["min_outliers_per_direction"]) & (X_outliers_low > config["outlier_definition"]["min_outliers_per_direction"])]
X_outliers_low = X_outliers_low[(X_outliers_up > config["outlier_definition"]["min_outliers_per_direction"]) & (X_outliers_low > config["outlier_definition"]["min_outliers_per_direction"])]

# filter by minimum outliers in total
X_outliers_total = X_outliers_up + X_outliers_low
X_outliers_total = X_outliers_total[X_outliers_total > config["outlier_definition"]["min_outliers_total"]]

# choose the feature with the most equal number of lower/upper outliers
if X_outliers_total.empty:
    raise ValueError("The given dataset does not have a feature fullfilling the required outlier requirements.")
else:
    experiment_feature = abs(X_outliers_up[X_outliers_total.index] - X_outliers_low[X_outliers_total.index]).idxmin()
    output["experiment_feature"] = experiment_feature
    
    # number of outliers for later use in metrics
    X_n_outliers = n_outliers(X[experiment_feature])
    
    # series of outliers
    std_orig = X[experiment_feature].std()
    mean_orig = X[experiment_feature].mean()
    X_outliers = X[experiment_feature][(X[experiment_feature] < mean_orig - config["outlier_definition"]["st_deviations"] * std_orig) | (X[experiment_feature] > mean_orig + config["outlier_definition"]["st_deviations"] * std_orig)]

# %% [markdown]
# ### 1.1. Create missing data
# #### 1.1.1. Create a specified amount of missing values
# missing values will be generated for the selected feature in 1.0 as well as for randomly chosen amount of features defined in config --> general --> missing_value_features.
#
# The data will be sampled until at least a certain amount of outliers are replaced by missing values. This enables us to examine the impact of outliers later on.

# %%
# create datasets with missing values
X_mv = {}
X_mv_n_outliers = {}

# if the experiment variable is affecting the dataset, we need a dict of the different datasets, else only one dataset named "data"
variable_datasets = config["general"]["experiment_variable"] in ["missing_percent", "missing_outliers", "missing_value_features", "st_deviations"]
X_mv_keys = experiment_variable_values if variable_datasets else ["data"]

for experiment_value in X_mv_keys:
    
    if variable_datasets:
        config[experiment_dict_key][config["general"]["experiment_variable"]] = experiment_value
    
    n_outliers_req = round(config["general"]["missing_outliers"] * X_n_outliers)
    n_outliers_generated = round(config["general"]["missing_percent"] * len(X))
    if n_outliers_generated < n_outliers_req:
        raise ValueError("The ratio of missing values created has to be larger than than the required ratio of outlier-missing-values. Increase 'missing percent' or decrease 'missing_outliers' before proceeding.")
        
    # create missing values in feature column(s) and assure, that at least x% of missing values were outliers
    rnd_features = random.sample(list(X.loc[:, X.columns != experiment_feature].columns), config["general"]["missing_value_features"])
    mv_config = {feature:config["general"]["missing_percent"] for feature in rnd_features}
    X_mv[experiment_value] = X.copy()

    # remove at least n_outliers_req outliers
    _, l_outliers, u_outliers = is_outlier(X_mv[experiment_value][experiment_feature])
    sample_upper_outliers = X_mv[experiment_value][experiment_feature][u_outliers].sample(math.floor(n_outliers_req / 2))
    sample_lower_outliers = X_mv[experiment_value][experiment_feature][l_outliers].sample(math.ceil(n_outliers_req / 2))
    sample_rest = X_mv[experiment_value][experiment_feature].sample(n_outliers_generated - n_outliers_req)

    X_mv[experiment_value][experiment_feature][sample_rest.index.union(sample_lower_outliers.index).union(sample_upper_outliers.index)] = np.nan

    # remove values in other features
    for f, mv in mv_config.items():
        X_mv[experiment_value][f] = X_mv[experiment_value][f].mask(np.random.random(len(X)) < mv)

    # calculate share of outliers in sample
    mvs = X[experiment_feature][X_mv[experiment_value][experiment_feature].isna()]
    X_mv_n_outliers[str(experiment_value)] = n_outliers(mvs)

# %%
import missingno as msno
# %matplotlib inline

# plot missing values
fig = msno.matrix(X_mv[experiment_value])
plt.title(f"missing values for {experiment_variable}: {experiment_value}", fontsize=22)
plt.show()
if save_output:
    #plt.savefig(os.path.join(plots_path, "missing_values.png"), **config["plots"])
    fig_copy = fig.get_figure()
    fig_copy.savefig(os.path.join(plots_path, "missing_values.png"), **config["plots"], bbox_inches = 'tight')

# %% [markdown]
# #### 1.1.2. Save outlier numbers to output

# %%
output["n_outliers"] = {}
output["n_outliers"]["X"] = X_n_outliers
output["n_outliers"]["X_mv"] = X_mv_n_outliers

# %% [markdown]
# #### 1.1.3. Distribution after removing random values

# %%
mv = X.copy()[X_mv[experiment_value][experiment_feature].isna()]

fig, ax = plt.subplots(figsize=(12,8))
X[experiment_feature].plot.hist(ax=ax, alpha=0.5)
X_mv[experiment_value][experiment_feature].plot.hist(ax=ax, alpha=0.5, color='green')
mv[experiment_feature].plot.hist(ax=ax, alpha=0.5, color='red')

ax2 = ax.twinx()
X[experiment_feature].plot.kde(ax=ax2)
X_mv[experiment_value][experiment_feature].plot.kde(ax=ax2, color='green')
mv[experiment_feature].plot.kde(ax=ax2, color='red')
plt.title(f"Distribution for {experiment_variable}: {experiment_value} ")
plt.legend(['original data', 'without missing values', 'missing values'])

plt.show()

# %% [markdown]
# #### 1.1.3. Kurtosis
# If the data is sufficiently close to a normal distribution, the Kurtosis measure could be used to compare the tailedness of the data before and after predictions. This does, however not necessarily apply for the given feature.

# %%
scipy.stats.kurtosistest(X_mv[experiment_value][X_mv[experiment_value][experiment_feature].notna()][experiment_feature])
# Out:
# KurtosistestResult(statistic=-0.34646791643255404, pvalue=0.7289910918076232)

# %% [markdown]
# ### 1.3. Initial Clustering (without missing values)

# %% [markdown]
# #### 1.3.1 DBSCAN (for wine dataset)
# Automatically determine DBSCAN hyperparameters min_samples and eps.\
# min_samples results in 26 for the wine dataset (dimensionality 13).\
# for eps we choose 2.5 (elbow of the graph).

# %%
from sklearn.neighbors import NearestNeighbors

min_samples = 2 * len(X_scaled.columns)

neighbors = NearestNeighbors(n_neighbors=min_samples)
neighbors_fit = neighbors.fit(X_scaled)
distances, indices = neighbors_fit.kneighbors(X_scaled)
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)

# %% [markdown]
# Use the cluster algorithm on dataset without missing values shows, that DBSCAN is not performaing well with 13 dimensional dataset (curse of dimensionality leads to either 1 or 0 clusters).

# %%
# run DBSCAN on original data
config["DBSCAN"]["eps"] = 2.5
config["DBSCAN"]["min_samples"] = min_samples
if save_output or save_models:
    with open(config_path, "w") as f:
        toml.dump(config, f)

dbscan_orig = DBSCAN(**config["DBSCAN"]).fit(X_scaled)
labels_orig = dbscan_orig.labels_
print(f"DBSCAN noise: {(sum(abs(labels_orig[labels_orig == -1]))*100) / len(labels_true)}%")
# Out:
# DBSCAN noise: 73.03370786516854%

# %% [markdown]
# #### 1.3.2 K-Means
# As an alternative, we use k-means for the initial clustering (k=3). This does clearly work better with a more than 96% correct labeling of data.

# %%
from sklearn.cluster import KMeans
k_mean_orig = KMeans(n_clusters=3, random_state=seed_value).fit(X_scaled)
labels_orig = k_mean_orig.labels_

# %% [markdown]
# Using munkres/hungarian algorithm to allign the k-means cluster names with the original cluster means.\
# Source: https://gist.github.com/siolag161/dc6e42b64e1bde1f263b

# %%
from munkres import Munkres
from sklearn.metrics import confusion_matrix

# use Munkres / Hungarian algorithm to relabel clusters in order to match original label names
def make_cost_matrix(c1, c2):
    """
    """
    uc1 = np.unique(c1)
    uc2 = np.unique(c2)
    l1 = uc1.size
    l2 = uc2.size
    assert(l1 == l2 and np.all(uc1 == uc2))

    m = np.ones([l1, l2])
    for i in range(l1):
        it_i = np.nonzero(c1 == uc1[i])[0]
        for j in range(l2):
            it_j = np.nonzero(c2 == uc2[j])[0]
            m_ij = np.intersect1d(it_j, it_i)
            m[i,j] =  -m_ij.size
    return m

# %%
cost_matrix = make_cost_matrix(labels_orig, labels_true)
indexes = Munkres().compute(cost_matrix)
mapping = [new for (_, new) in indexes]
labels_orig_renamed = np.choose(labels_orig, mapping).astype(np.int64)

mislabeled = labels_true - labels_orig_renamed
mislabeled[mislabeled != 0] = 1
mislabeled_orig = sum(mislabeled) / len(mislabeled)
print(f"{round(mislabeled_orig * 100, 2)}% mislabeled")
# Out:
# 3.37% mislabeled

# %% [markdown]
# Get cluster means for loss function input.

# %%
# get cluster means (used to calculate the cluster mean loss)
complete_data = X.copy()
complete_data["C"] = labels_orig
cluster_means = complete_data.groupby("C").agg("mean")
cluster_means = cluster_means if -1 not in cluster_means.index else cluster_means.drop(-1)

# %% [markdown]
# ## 2. Filling Strategies
# Applying different imputation strategies to the incomplete dataset.
#
# ### 2.1. Define custom-loss
# The loss function for the model fitting shall be customized to improve cluster perforamnce. The custom loss is divided into 2 separate losses
#
# 1. **Reconstruction Loss**\
# Classic loss function, such as RMSE.
# 2. **Cluster-Mean Loss**\
# The distance to the nearest cluster mean shall be minimized.
# 3. **KL Divergence Loss**\
# Deviation of original distribution shall be minimized \
# (prob distribution based on https://stackoverflow.com/questions/57687458/how-to-calculate-probabilities-using-numpy-histogram-and-then-use-it-for-calcula \
# number of bins: D. Freedman & P. Diaconis (1981) “On the histogram as a density estimator: L2 theory”. Probability Theory and Related Fields 57 (4): 453-476)
#
# The chosen approach to implement the cluster-mean loss is as follows:\
# **Adapt the loss function** to calculate a distance to each cluster. The minimum distance (to the nearest cluster) will be used as a cluster-mean-loss. Minimizing this loss should result in the data point moving closer to the nearest cluster mean.\
# Potential Problem: loss functions currently work with y_true (true values) and y_score (predicted values). Calculating the distance would require all features. Calculating only the 1 dimensional distance will result in missing values being put into wrong clusters - depending on the first estimate.

# %%
# define custom loss function: extend L2-loss by cluster-mean-loss and KL divergence

from pytorch_tabnet.metrics import Metric
from sklearn.metrics import mean_squared_error

class custom_loss(Metric):

    def __init__(self):
        self._name = "custom_loss"
        self._maximize = False

    def __call__(self, y_true, y_score, cluster_means, y_name, x_val, y_val, cl_weights = [0.5, 1, 0.0001]):
        # reconstruction loss
        rmse = np.sqrt(mean_squared_error(y_true, y_score))
        
        # cluster mean loss
        cml = 0 if cl_weights[2] == 0 else self.cluster_mean_loss(cluster_means, y_score, y_name, x_val, y_val)
        
        # KL divergence loss
        # - range of values
        min_val = min(min(y_true[:,0]), min(y_score[:,0]))
        max_val = max(max(y_true[:,0]), max(y_score[:,0]))
        # - prob. density function
        distr_pred = scipy.stats.gaussian_kde(y_score[:,0]).evaluate(np.linspace(min_val,max_val,100)) + sys.float_info.min
        distr_true = scipy.stats.gaussian_kde(y_true[:,0]).evaluate(np.linspace(min_val,max_val,100)) + sys.float_info.min
        # - calc. KL divergence on normalized pdf
        KLdl = torch.nn.functional.kl_div((torch.tensor(distr_true/sum(distr_true))).log(), torch.tensor(distr_pred/sum(distr_pred)), log_target=False, reduction='sum').item()
        
        # total loss
        custom_loss = cl_weights[0] * rmse + cl_weights[1] * KLdl + cl_weights[2] * cml
        return custom_loss
    
    # calculate sum of distances to the closest cluster mean
    def cluster_mean_loss(self, cluster_means, y_score, y_name, x_val, y_val):
        
        # reorder cluster_means to match x_val columns (predicted feature is last column)
        cols = cluster_means.columns.tolist()
        feature_col = X.columns.get_loc(y_name)
        cols = cols[:feature_col] + cols[feature_col+1:] + [y_name]
        
        # x values extended by predicted values
        x_extended = pd.DataFrame(np.hstack((x_val, y_score)), columns=cols)


        # calculate distances to each cluster and select the closest one
        dist = []
        for cluster in range(cluster_means.shape[0]):
            dist.append(np.linalg.norm((x_extended - cluster_means.iloc[cluster]), axis=1))
            
        dist = pd.DataFrame(dist).T
        min_dist = dist.assign(min_dist=lambda d: d.min(1))["min_dist"]
        
        return sum(min_dist)

# %% [markdown]
# ### 2.2. Fill missing values (TabNet)
#
# **Approach 1:**\
# For each feature that contains missing values, use all rows with complete other features as train set and predict missing values of the feature.\
# &rarr; Problem: lots of models, especially for high-dimensional datasets.
# Also problem, if more than one feature is missing values. &rarr; see Approach 2
#
# **Approach 2:**\
# Mask missing values as -1 (or some other value) and fit a model predicting each feature just like in approach 1.\
# This way the amount of required models can be reduced and the model can learn correlations from the presence of missing values. However we cannot expect an improvement from learning correlations when the missing data is MCAR, as "missing values (MCAR) are interpreted as a random reduction of the dataset, which provide no further information for assigning incomplete feature
# vectors to clusters." (H. Timm, et al., "Different approaches to fuzzy clustering of incomplete datasets")\
# &rarr; one model for each feature containing missing values.\
# Possible adaption: use predicted values to predict subsequent values (instead of using -1)
#
# **Approach 3:**
# To further reduce the number of trained models and in order to focus on features with an appropriate number of outliers: only predict and examine one feature (see chosen feature above) and leave the others with their masked values.\
# &rarr; Problem: missing value mask of other features impacts the subsequent clustering. Additionally, due to the MCAR missing value generation for the used datasets, there is no useful information in the missing values of other features. Thus, the model cannot learn anything from the masked values. It does however make sense to implement it this way for further research of real incomplete datasets.\
# As we are interested in the predictive performance of the experiment feature, a solution to the subsequent clustering problem is, to reconstruct the other features with their original values (i.e. the predictions are based on the incomplete dataset, but the clustering will be based on the predicted feature plus the original other features).

# %%
import time

from pytorch_tabnet.tab_model import TabNetRegressor
from sklearn.model_selection import train_test_split

X_reconstr = {}
X_reconstr["TabNet"] = {}
output["costs"] = {}
output["runtimes"] = {}
output["predictions"] = {}

for run in range(config["general"]["runs"]):
    
    print(f"Run {run + 1} / {config['general']['runs']} --------------------------------------------------")
    X_reconstr["TabNet"][run] = []
    output["costs"][f"run_{run}"] = {}
    output["runtimes"][f"run_{run}"] = {}
    output["predictions"][f"run_{run}"] = {}
    
    for i, experiment_value in enumerate(experiment_variable_values):
                    
        config[experiment_dict_key][config["general"]["experiment_variable"]] = experiment_value
        
        time_start = time.time()
        X_reconstr["TabNet"][run].append(X.copy())
        X_reconstr["TabNet"][run][i][experiment_feature] = X_mv[experiment_value][experiment_feature] if variable_datasets else X_mv[X_mv_keys[0]][experiment_feature]

        output["costs"][f"run_{run}"][str(experiment_value)] = {}
        output["runtimes"][f"run_{run}"][str(experiment_value)] = {}
        output["predictions"][f"run_{run}"][str(experiment_value)] = {}

        # select % of features for prediction based on pred_features (e.g. 10% of randomly selected features)
        n_features = math.ceil(config["RQ2"]["pred_features"] * (len(X.columns)) - 1)
        X_mv_masked = X_mv[experiment_value].copy().drop(experiment_feature, axis=1).sample(n=n_features, axis='columns')
        other_features = X_mv_masked.columns

        # mask other columns' missing values as defined in config (missing_value_mask)
        X_mv_masked[experiment_feature] = X_mv[experiment_value][experiment_feature]
        X_mv_masked[other_features] = X_mv_masked[(other_features)].fillna(config["general"]["missing_value_mask"])

        # separate complete rows as train data
        # separate column with missing values as target
        test_data = X_mv_masked[X_mv_masked[experiment_feature].isna()].drop(experiment_feature, axis=1).to_numpy()
        train_data = X_mv_masked[X_mv_masked[experiment_feature].notna()]
        train_features = train_data.drop(columns=experiment_feature).to_numpy()
        train_target = train_data[experiment_feature].to_numpy().reshape(-1,1)

        x_train, x_val, y_train, y_val = train_test_split(train_features, train_target, train_size=config["training"]["train_val_split"])

        # create & train model
        model = TabNetRegressor(**regressor_param)
        if config["model_param"]["eval_metric"] == ["custom_loss"]:
            model.fit(
                x_train, y_train,
                eval_set=[(x_val, y_val)],
                **config["model_param"],
                cluster_means=cluster_means,
                y_name=experiment_feature,
                x_val=x_val,
                y_val=y_val,
                cl_weights=config["training"]["cl_weights"]
            )
        else:
            model.fit(
                x_train, y_train,
                eval_set=[(x_val, y_val)],
                **config["model_param"]
            )     

        # save costs
        output["costs"][f"run_{run}"][str(experiment_value)] = float(model.best_cost)

        # save predictions
        predictions = [x[0] for x in model.predict(test_data)]
        output["predictions"][f"run_{run}"][str(experiment_value)] = predictions

        # fill missing values with model predictions
        X_reconstr["TabNet"][run][i].loc[X_reconstr["TabNet"][run][i][experiment_feature].isna(), experiment_feature] = predictions

        # save models
        if save_models:
            torch.save(model, os.path.join(models_path, f"Model_run{run}_{config['general']['experiment_variable']}{experiment_value}.pt"))            

        #track runtime
        time_end = time.time()
        output["runtimes"][f"run_{run}"][str(experiment_value)] = time_end - time_start
# Out:
# Run 1 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 230 and best_val_0_custom_loss = 0.3373
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 232 and best_val_0_custom_loss = 0.37339
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 67 with best_epoch = 17 and best_val_0_custom_loss = 189.15912
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 207 and best_val_0_custom_loss = 0.3087
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 206 with best_epoch = 156 and best_val_0_custom_loss = 0.22359
# Best weights from best epoch are automatically used!
# Run 2 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 193 with best_epoch = 143 and best_val_0_custom_loss = 0.25036
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_custom_loss = 39.74672
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 164 with best_epoch = 114 and best_val_0_custom_loss = 0.34941
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 142 with best_epoch = 92 and best_val_0_custom_loss = 0.5486
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 134 with best_epoch = 84 and best_val_0_custom_loss = 0.90691
# Best weights from best epoch are automatically used!
# Run 3 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_custom_loss = 138.1971
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 88 with best_epoch = 38 and best_val_0_custom_loss = 1.39943
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 103 with best_epoch = 53 and best_val_0_custom_loss = 0.69474
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 187 with best_epoch = 137 and best_val_0_custom_loss = 0.21949
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.27732
# Best weights from best epoch are automatically used!
# Run 4 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 192 with best_epoch = 142 and best_val_0_custom_loss = 0.32159
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.23299
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 100 with best_epoch = 50 and best_val_0_custom_loss = 10.33288
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_custom_loss = 2.27419
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 134 with best_epoch = 84 and best_val_0_custom_loss = 1.06048
# Best weights from best epoch are automatically used!
# Run 5 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.27822
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 176 with best_epoch = 126 and best_val_0_custom_loss = 0.4556
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 244 with best_epoch = 194 and best_val_0_custom_loss = 0.26441
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 97 with best_epoch = 47 and best_val_0_custom_loss = 5.58373
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_custom_loss = 0.7451
# Best weights from best epoch are automatically used!
# Run 6 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 204 and best_val_0_custom_loss = 0.27207
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 229 and best_val_0_custom_loss = 0.19112
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 107 with best_epoch = 57 and best_val_0_custom_loss = 2.76969
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 244 and best_val_0_custom_loss = 0.39603
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 232 and best_val_0_custom_loss = 0.30756
# Best weights from best epoch are automatically used!
# Run 7 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 121 with best_epoch = 71 and best_val_0_custom_loss = 0.48866
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 111 with best_epoch = 61 and best_val_0_custom_loss = 0.28763
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 153 with best_epoch = 103 and best_val_0_custom_loss = 0.42431
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 111 with best_epoch = 61 and best_val_0_custom_loss = 0.19114
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 149 with best_epoch = 99 and best_val_0_custom_loss = 0.50119
# Best weights from best epoch are automatically used!
# Run 8 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 230 with best_epoch = 180 and best_val_0_custom_loss = 0.22766
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_custom_loss = 83.99633
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 220 and best_val_0_custom_loss = 0.21302
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.86691
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.413
# Best weights from best epoch are automatically used!
# Run 9 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_custom_loss = 217.67671
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.81874
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.38555
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.24253
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.4641
# Best weights from best epoch are automatically used!
# Run 10 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 218 and best_val_0_custom_loss = 0.5181
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 228 with best_epoch = 178 and best_val_0_custom_loss = 0.29698
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 246 and best_val_0_custom_loss = 0.27101
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 237 and best_val_0_custom_loss = 0.3064
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 79 with best_epoch = 29 and best_val_0_custom_loss = 2.11634
# Best weights from best epoch are automatically used!
# Run 11 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 71 with best_epoch = 21 and best_val_0_custom_loss = 2.57529
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.31115
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 142 with best_epoch = 92 and best_val_0_custom_loss = 0.42645
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 92 with best_epoch = 42 and best_val_0_custom_loss = 39.85475
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.26558
# Best weights from best epoch are automatically used!
# Run 12 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 243 and best_val_0_custom_loss = 0.36254
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 246 and best_val_0_custom_loss = 0.29507
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 199 with best_epoch = 149 and best_val_0_custom_loss = 0.36301
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.27235
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 90 with best_epoch = 40 and best_val_0_custom_loss = 0.6137
# Best weights from best epoch are automatically used!
# Run 13 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.40252
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 96 with best_epoch = 46 and best_val_0_custom_loss = 0.24407
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 94 with best_epoch = 44 and best_val_0_custom_loss = 2.83112
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 64 with best_epoch = 14 and best_val_0_custom_loss = 49.01063
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 182 with best_epoch = 132 and best_val_0_custom_loss = 0.40948
# Best weights from best epoch are automatically used!
# Run 14 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 126 with best_epoch = 76 and best_val_0_custom_loss = 6.96357
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 248 and best_val_0_custom_loss = 1.11168
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 218 and best_val_0_custom_loss = 0.32173
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 233 and best_val_0_custom_loss = 0.57509
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 105 with best_epoch = 55 and best_val_0_custom_loss = 1.16846
# Best weights from best epoch are automatically used!
# Run 15 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 217 and best_val_0_custom_loss = 0.17375
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 61 with best_epoch = 11 and best_val_0_custom_loss = 2.19383
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 69 with best_epoch = 19 and best_val_0_custom_loss = 25.39864
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 119 with best_epoch = 69 and best_val_0_custom_loss = 0.49241
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 248 with best_epoch = 198 and best_val_0_custom_loss = 0.31197
# Best weights from best epoch are automatically used!
# Run 16 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 83 with best_epoch = 33 and best_val_0_custom_loss = 10.74628
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 231 with best_epoch = 181 and best_val_0_custom_loss = 0.38055
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 52 with best_epoch = 2 and best_val_0_custom_loss = 23.80031
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 241 with best_epoch = 191 and best_val_0_custom_loss = 0.2812
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 218 and best_val_0_custom_loss = 0.17724
# Best weights from best epoch are automatically used!
# Run 17 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 202 with best_epoch = 152 and best_val_0_custom_loss = 0.3031
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 228 and best_val_0_custom_loss = 0.24073
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 232 and best_val_0_custom_loss = 0.29125
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 149 with best_epoch = 99 and best_val_0_custom_loss = 0.37826
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 104 with best_epoch = 54 and best_val_0_custom_loss = 0.64095
# Best weights from best epoch are automatically used!
# Run 18 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 231 with best_epoch = 181 and best_val_0_custom_loss = 0.25878
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 157 with best_epoch = 107 and best_val_0_custom_loss = 2.86661
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 246 and best_val_0_custom_loss = 0.70334
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 99 with best_epoch = 49 and best_val_0_custom_loss = 0.80256
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 212 with best_epoch = 162 and best_val_0_custom_loss = 0.43054
# Best weights from best epoch are automatically used!
# Run 19 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 121 with best_epoch = 71 and best_val_0_custom_loss = 0.35799
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 69 with best_epoch = 19 and best_val_0_custom_loss = 1.341
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 200 and best_val_0_custom_loss = 0.40733
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.30677
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 159 with best_epoch = 109 and best_val_0_custom_loss = 0.23755
# Best weights from best epoch are automatically used!
# Run 20 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 140 with best_epoch = 90 and best_val_0_custom_loss = 3.41996
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 105 with best_epoch = 55 and best_val_0_custom_loss = 17.99088
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 208 with best_epoch = 158 and best_val_0_custom_loss = 0.214
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 83 with best_epoch = 33 and best_val_0_custom_loss = 3.83257
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 191 with best_epoch = 141 and best_val_0_custom_loss = 0.25917
# Best weights from best epoch are automatically used!
# Run 21 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 248 and best_val_0_custom_loss = 0.35274
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 218 with best_epoch = 168 and best_val_0_custom_loss = 0.5651
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 1.22411
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 196 with best_epoch = 146 and best_val_0_custom_loss = 0.38493
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 248 and best_val_0_custom_loss = 0.34512
# Best weights from best epoch are automatically used!
# Run 22 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 78 with best_epoch = 28 and best_val_0_custom_loss = 0.35128
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 248 with best_epoch = 198 and best_val_0_custom_loss = 0.30115
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 246 with best_epoch = 196 and best_val_0_custom_loss = 0.22285
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 237 and best_val_0_custom_loss = 0.27351
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.25885
# Best weights from best epoch are automatically used!
# Run 23 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 103 with best_epoch = 53 and best_val_0_custom_loss = 49.92825
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_custom_loss = 517.25549
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 220 with best_epoch = 170 and best_val_0_custom_loss = 0.31731
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.25979
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 133 with best_epoch = 83 and best_val_0_custom_loss = 0.34691
# Best weights from best epoch are automatically used!
# Run 24 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 111 with best_epoch = 61 and best_val_0_custom_loss = 1.24677
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 226 with best_epoch = 176 and best_val_0_custom_loss = 0.25753
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 124 with best_epoch = 74 and best_val_0_custom_loss = 0.52978
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 237 and best_val_0_custom_loss = 0.21523
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 217 and best_val_0_custom_loss = 0.2841
# Best weights from best epoch are automatically used!
# Run 25 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 221 with best_epoch = 171 and best_val_0_custom_loss = 0.30067
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 169 with best_epoch = 119 and best_val_0_custom_loss = 0.46171
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 95 with best_epoch = 45 and best_val_0_custom_loss = 3.49128
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 243 and best_val_0_custom_loss = 0.28353
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 228 with best_epoch = 178 and best_val_0_custom_loss = 0.23108
# Best weights from best epoch are automatically used!
# Run 26 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 248 and best_val_0_custom_loss = 0.29301
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 203 with best_epoch = 153 and best_val_0_custom_loss = 0.65505
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.37165
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 144 with best_epoch = 94 and best_val_0_custom_loss = 3.50381
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 247 with best_epoch = 197 and best_val_0_custom_loss = 0.23263
# Best weights from best epoch are automatically used!
# Run 27 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 99 with best_epoch = 49 and best_val_0_custom_loss = 0.36426
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 111 with best_epoch = 61 and best_val_0_custom_loss = 5.05251
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 226 with best_epoch = 176 and best_val_0_custom_loss = 0.28735
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 212 with best_epoch = 162 and best_val_0_custom_loss = 0.24979
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 211 and best_val_0_custom_loss = 0.41577
# Best weights from best epoch are automatically used!
# Run 28 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 88 with best_epoch = 38 and best_val_0_custom_loss = 5.7247
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 244 and best_val_0_custom_loss = 0.23461
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 203 with best_epoch = 153 and best_val_0_custom_loss = 1.32452
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 205 with best_epoch = 155 and best_val_0_custom_loss = 0.31052
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 222 with best_epoch = 172 and best_val_0_custom_loss = 0.38877
# Best weights from best epoch are automatically used!
# Run 29 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.29061
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.28963
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 235 and best_val_0_custom_loss = 0.29506
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 116 with best_epoch = 66 and best_val_0_custom_loss = 2.4985
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 83 with best_epoch = 33 and best_val_0_custom_loss = 1.32497
# Best weights from best epoch are automatically used!
# Run 30 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 222 and best_val_0_custom_loss = 0.28321
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 189 with best_epoch = 139 and best_val_0_custom_loss = 0.34555
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 239 with best_epoch = 189 and best_val_0_custom_loss = 0.3542
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 84 with best_epoch = 34 and best_val_0_custom_loss = 35.57074
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.22248
# Best weights from best epoch are automatically used!
# Run 31 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 233 and best_val_0_custom_loss = 0.34655
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 222 and best_val_0_custom_loss = 0.21313
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 197 with best_epoch = 147 and best_val_0_custom_loss = 0.3293
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 207 with best_epoch = 157 and best_val_0_custom_loss = 0.52048
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.26977
# Best weights from best epoch are automatically used!
# Run 32 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 227 with best_epoch = 177 and best_val_0_custom_loss = 0.21877
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 108 with best_epoch = 58 and best_val_0_custom_loss = 0.48738
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.3706
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 248 and best_val_0_custom_loss = 0.22393
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.61802
# Best weights from best epoch are automatically used!
# Run 33 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.25547
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 224 and best_val_0_custom_loss = 0.28009
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 207 and best_val_0_custom_loss = 0.22541
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 83 with best_epoch = 33 and best_val_0_custom_loss = 30.45779
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.81404
# Best weights from best epoch are automatically used!
# Run 34 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 84 with best_epoch = 34 and best_val_0_custom_loss = 0.51778
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.26836
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 127 with best_epoch = 77 and best_val_0_custom_loss = 1.67527
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 76 with best_epoch = 26 and best_val_0_custom_loss = 12.03125
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 226 with best_epoch = 176 and best_val_0_custom_loss = 0.81539
# Best weights from best epoch are automatically used!
# Run 35 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 179 with best_epoch = 129 and best_val_0_custom_loss = 0.30927
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 200 with best_epoch = 150 and best_val_0_custom_loss = 1.57978
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.28041
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 95 with best_epoch = 45 and best_val_0_custom_loss = 0.4701
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 90 with best_epoch = 40 and best_val_0_custom_loss = 0.36147
# Best weights from best epoch are automatically used!
# Run 36 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 96 with best_epoch = 46 and best_val_0_custom_loss = 0.38289
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 84 with best_epoch = 34 and best_val_0_custom_loss = 7.44596
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 89 with best_epoch = 39 and best_val_0_custom_loss = 0.39947
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 92 with best_epoch = 42 and best_val_0_custom_loss = 9.83428
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 207 with best_epoch = 157 and best_val_0_custom_loss = 0.26472
# Best weights from best epoch are automatically used!
# Run 37 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 107 with best_epoch = 57 and best_val_0_custom_loss = 0.44771
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 219 with best_epoch = 169 and best_val_0_custom_loss = 0.26918
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_custom_loss = 3.39991
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 168 with best_epoch = 118 and best_val_0_custom_loss = 0.69158
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 90 with best_epoch = 40 and best_val_0_custom_loss = 0.46699
# Best weights from best epoch are automatically used!
# Run 38 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 169 with best_epoch = 119 and best_val_0_custom_loss = 0.6563
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 54 with best_epoch = 4 and best_val_0_custom_loss = 10.06136
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 244 with best_epoch = 194 and best_val_0_custom_loss = 0.29499
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_custom_loss = 10.87819
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 237 and best_val_0_custom_loss = 0.58972
# Best weights from best epoch are automatically used!
# Run 39 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 180 with best_epoch = 130 and best_val_0_custom_loss = 0.28626
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 190 with best_epoch = 140 and best_val_0_custom_loss = 0.265
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 76 with best_epoch = 26 and best_val_0_custom_loss = 0.80404
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.26961
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 228 and best_val_0_custom_loss = 0.2355
# Best weights from best epoch are automatically used!
# Run 40 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 183 with best_epoch = 133 and best_val_0_custom_loss = 1.33984
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 207 with best_epoch = 157 and best_val_0_custom_loss = 0.26226
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.35868
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.31806
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_custom_loss = 0.35331
# Best weights from best epoch are automatically used!
# Run 41 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.31202
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 246 and best_val_0_custom_loss = 0.29127
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 244 and best_val_0_custom_loss = 0.3948
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 95 with best_epoch = 45 and best_val_0_custom_loss = 4.1313
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 87 with best_epoch = 37 and best_val_0_custom_loss = 1.04652
# Best weights from best epoch are automatically used!
# Run 42 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 218 with best_epoch = 168 and best_val_0_custom_loss = 0.24648
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 100 with best_epoch = 50 and best_val_0_custom_loss = 7.57787
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 196 with best_epoch = 146 and best_val_0_custom_loss = 0.33893
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 144 with best_epoch = 94 and best_val_0_custom_loss = 0.27253
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 246 with best_epoch = 196 and best_val_0_custom_loss = 0.24819
# Best weights from best epoch are automatically used!
# Run 43 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 243 and best_val_0_custom_loss = 0.23971
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 1.61799
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 180 with best_epoch = 130 and best_val_0_custom_loss = 0.40006
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 63 with best_epoch = 13 and best_val_0_custom_loss = 51.8921
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 105 with best_epoch = 55 and best_val_0_custom_loss = 1.20847
# Best weights from best epoch are automatically used!
# Run 44 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 129 with best_epoch = 79 and best_val_0_custom_loss = 1.09347
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 247 and best_val_0_custom_loss = 0.38068
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 245 and best_val_0_custom_loss = 0.23362
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 244 and best_val_0_custom_loss = 0.24861
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 100 with best_epoch = 50 and best_val_0_custom_loss = 0.31069
# Best weights from best epoch are automatically used!
# Run 45 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 240 with best_epoch = 190 and best_val_0_custom_loss = 0.33309
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 231 with best_epoch = 181 and best_val_0_custom_loss = 0.21453
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 98 with best_epoch = 48 and best_val_0_custom_loss = 6.88595
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 57 with best_epoch = 7 and best_val_0_custom_loss = 10.59143
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 140 with best_epoch = 90 and best_val_0_custom_loss = 0.27074
# Best weights from best epoch are automatically used!
# Run 46 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 138 with best_epoch = 88 and best_val_0_custom_loss = 0.66618
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 136 with best_epoch = 86 and best_val_0_custom_loss = 0.29489
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 64 with best_epoch = 14 and best_val_0_custom_loss = 0.94157
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 144 with best_epoch = 94 and best_val_0_custom_loss = 0.27683
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 147 with best_epoch = 97 and best_val_0_custom_loss = 0.40011
# Best weights from best epoch are automatically used!
# Run 47 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 228 with best_epoch = 178 and best_val_0_custom_loss = 0.33648
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 141 with best_epoch = 91 and best_val_0_custom_loss = 0.4166
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 78 with best_epoch = 28 and best_val_0_custom_loss = 8.40337
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 129 with best_epoch = 79 and best_val_0_custom_loss = 2.13739
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.24786
# Best weights from best epoch are automatically used!
# Run 48 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 246 and best_val_0_custom_loss = 0.25317
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 232 and best_val_0_custom_loss = 0.26843
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 138 with best_epoch = 88 and best_val_0_custom_loss = 0.46668
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 201 with best_epoch = 151 and best_val_0_custom_loss = 0.27612
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 214 and best_val_0_custom_loss = 0.28658
# Best weights from best epoch are automatically used!
# Run 49 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.18465
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 136 with best_epoch = 86 and best_val_0_custom_loss = 0.60574
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 212 with best_epoch = 162 and best_val_0_custom_loss = 0.24517
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.66611
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_custom_loss = 27.91352
# Best weights from best epoch are automatically used!
# Run 50 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.26511
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 244 with best_epoch = 194 and best_val_0_custom_loss = 0.20443
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 224 with best_epoch = 174 and best_val_0_custom_loss = 0.74372
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_custom_loss = 2.98511
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 94 with best_epoch = 44 and best_val_0_custom_loss = 0.45283
# Best weights from best epoch are automatically used!
# Run 51 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 224 and best_val_0_custom_loss = 0.38984
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 121 with best_epoch = 71 and best_val_0_custom_loss = 0.52873
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 222 and best_val_0_custom_loss = 0.29654
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 105 with best_epoch = 55 and best_val_0_custom_loss = 0.52773
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 155 with best_epoch = 105 and best_val_0_custom_loss = 0.91797
# Best weights from best epoch are automatically used!
# Run 52 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 236 and best_val_0_custom_loss = 0.56245
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_custom_loss = 0.88658
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.8962
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 246 and best_val_0_custom_loss = 0.28875
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 137 with best_epoch = 87 and best_val_0_custom_loss = 0.29559
# Best weights from best epoch are automatically used!
# Run 53 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 176 with best_epoch = 126 and best_val_0_custom_loss = 0.26488
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 112 with best_epoch = 62 and best_val_0_custom_loss = 3.26053
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 245 with best_epoch = 195 and best_val_0_custom_loss = 0.22198
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.51962
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 232 with best_epoch = 182 and best_val_0_custom_loss = 0.30361
# Best weights from best epoch are automatically used!
# Run 54 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 93 with best_epoch = 43 and best_val_0_custom_loss = 1.44401
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 110 with best_epoch = 60 and best_val_0_custom_loss = 0.74904
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 99 with best_epoch = 49 and best_val_0_custom_loss = 0.4164
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 225 and best_val_0_custom_loss = 0.18627
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 219 and best_val_0_custom_loss = 0.48346
# Best weights from best epoch are automatically used!
# Run 55 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 223 with best_epoch = 173 and best_val_0_custom_loss = 0.60673
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 232 and best_val_0_custom_loss = 0.29122
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 134 with best_epoch = 84 and best_val_0_custom_loss = 13.8679
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 128 with best_epoch = 78 and best_val_0_custom_loss = 5.07719
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 161 with best_epoch = 111 and best_val_0_custom_loss = 0.95586
# Best weights from best epoch are automatically used!
# Run 56 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 230 with best_epoch = 180 and best_val_0_custom_loss = 0.25678
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 132 with best_epoch = 82 and best_val_0_custom_loss = 0.30607
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_custom_loss = 12.46133
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 241 and best_val_0_custom_loss = 0.61007
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 87 with best_epoch = 37 and best_val_0_custom_loss = 1.19581
# Best weights from best epoch are automatically used!
# Run 57 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 229 and best_val_0_custom_loss = 0.45971
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 240 and best_val_0_custom_loss = 0.25808
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 120 with best_epoch = 70 and best_val_0_custom_loss = 0.47308
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 215 and best_val_0_custom_loss = 0.22765
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.22764
# Best weights from best epoch are automatically used!
# Run 58 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 213 with best_epoch = 163 and best_val_0_custom_loss = 0.28597
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 219 with best_epoch = 169 and best_val_0_custom_loss = 0.2386
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.25239
# ...
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 79 with best_epoch = 29 and best_val_0_custom_loss = 57.78496
# Best weights from best epoch are automatically used!
# Run 82 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 187 with best_epoch = 137 and best_val_0_custom_loss = 0.32879
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_custom_loss = 0.75827
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 248 and best_val_0_custom_loss = 0.30583
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 212 and best_val_0_custom_loss = 0.22872
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 227 and best_val_0_custom_loss = 0.35066
# Best weights from best epoch are automatically used!
# Run 83 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 247 with best_epoch = 197 and best_val_0_custom_loss = 0.42051
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 149 with best_epoch = 99 and best_val_0_custom_loss = 0.58
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 222 and best_val_0_custom_loss = 0.3655
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_custom_loss = 98.81352
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 106 with best_epoch = 56 and best_val_0_custom_loss = 0.93717
# Best weights from best epoch are automatically used!
# Run 84 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 244 with best_epoch = 194 and best_val_0_custom_loss = 0.26983
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.34254
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 115 with best_epoch = 65 and best_val_0_custom_loss = 0.30891
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 195 with best_epoch = 145 and best_val_0_custom_loss = 0.1814
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 125 with best_epoch = 75 and best_val_0_custom_loss = 1.51538
# Best weights from best epoch are automatically used!
# Run 85 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 245 with best_epoch = 195 and best_val_0_custom_loss = 0.27669
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 93 with best_epoch = 43 and best_val_0_custom_loss = 0.2763
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 190 with best_epoch = 140 and best_val_0_custom_loss = 0.44763
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 247 and best_val_0_custom_loss = 0.19518
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 111 with best_epoch = 61 and best_val_0_custom_loss = 1.25158
# Best weights from best epoch are automatically used!
# Run 86 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 136 with best_epoch = 86 and best_val_0_custom_loss = 0.42982
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 229 with best_epoch = 179 and best_val_0_custom_loss = 0.28255
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 219 and best_val_0_custom_loss = 0.25202
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.05732
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 82 with best_epoch = 32 and best_val_0_custom_loss = 0.55595
# Best weights from best epoch are automatically used!
# Run 87 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_custom_loss = 109.70076
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 82 with best_epoch = 32 and best_val_0_custom_loss = 0.60934
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 247 with best_epoch = 197 and best_val_0_custom_loss = 0.2419
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.44153
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.3002
# Best weights from best epoch are automatically used!
# Run 88 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 114 with best_epoch = 64 and best_val_0_custom_loss = 7.14669
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_custom_loss = 0.53334
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 92 with best_epoch = 42 and best_val_0_custom_loss = 3.44772
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 89 with best_epoch = 39 and best_val_0_custom_loss = 2.35332
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 118 with best_epoch = 68 and best_val_0_custom_loss = 1.34638
# Best weights from best epoch are automatically used!
# Run 89 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 237 with best_epoch = 187 and best_val_0_custom_loss = 0.34923
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 237 with best_epoch = 187 and best_val_0_custom_loss = 0.34959
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 66 with best_epoch = 16 and best_val_0_custom_loss = 0.81302
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 74 with best_epoch = 24 and best_val_0_custom_loss = 143.74802
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 209 and best_val_0_custom_loss = 0.26661
# Best weights from best epoch are automatically used!
# Run 90 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.35614
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 139 with best_epoch = 89 and best_val_0_custom_loss = 14.95501
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 64 with best_epoch = 14 and best_val_0_custom_loss = 42.55603
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 211 and best_val_0_custom_loss = 0.22979
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 163 with best_epoch = 113 and best_val_0_custom_loss = 0.38322
# Best weights from best epoch are automatically used!
# Run 91 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 244 and best_val_0_custom_loss = 0.26
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 204 with best_epoch = 154 and best_val_0_custom_loss = 0.26925
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.3994
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 185 with best_epoch = 135 and best_val_0_custom_loss = 0.59033
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 61 with best_epoch = 11 and best_val_0_custom_loss = 9.2844
# Best weights from best epoch are automatically used!
# Run 92 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 82 with best_epoch = 32 and best_val_0_custom_loss = 0.44745
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 223 with best_epoch = 173 and best_val_0_custom_loss = 0.30547
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 190 with best_epoch = 140 and best_val_0_custom_loss = 0.254
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 245 and best_val_0_custom_loss = 0.39814
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 240 and best_val_0_custom_loss = 0.27495
# Best weights from best epoch are automatically used!
# Run 93 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 176 with best_epoch = 126 and best_val_0_custom_loss = 1.54612
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.31057
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 114 with best_epoch = 64 and best_val_0_custom_loss = 0.34891
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.31083
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 112 with best_epoch = 62 and best_val_0_custom_loss = 0.17285
# Best weights from best epoch are automatically used!
# Run 94 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 120 with best_epoch = 70 and best_val_0_custom_loss = 0.26942
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 231 with best_epoch = 181 and best_val_0_custom_loss = 0.24986
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 84 with best_epoch = 34 and best_val_0_custom_loss = 112.46401
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 230 and best_val_0_custom_loss = 0.21286
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 152 with best_epoch = 102 and best_val_0_custom_loss = 0.24421
# Best weights from best epoch are automatically used!
# Run 95 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_custom_loss = 180.38836
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 112 with best_epoch = 62 and best_val_0_custom_loss = 0.274
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_custom_loss = 213.69994
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 67 with best_epoch = 17 and best_val_0_custom_loss = 17.05332
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.37408
# Best weights from best epoch are automatically used!
# Run 96 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 246 and best_val_0_custom_loss = 0.33439
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.79847
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 60 with best_epoch = 10 and best_val_0_custom_loss = 338.99266
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 85 with best_epoch = 35 and best_val_0_custom_loss = 0.39992
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_custom_loss = 57.03484
# Best weights from best epoch are automatically used!
# Run 97 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 108 with best_epoch = 58 and best_val_0_custom_loss = 2.40827
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.31859
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 109 with best_epoch = 59 and best_val_0_custom_loss = 0.41599
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.24098
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 162 with best_epoch = 112 and best_val_0_custom_loss = 0.84016
# Best weights from best epoch are automatically used!
# Run 98 / 100 --------------------------------------------------
#
# Early stopping occurred at epoch 78 with best_epoch = 28 and best_val_0_custom_loss = 3.26207
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 97 with best_epoch = 47 and best_val_0_custom_loss = 0.60827
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 139 with best_epoch = 89 and best_val_0_custom_loss = 0.68564
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 240 and best_val_0_custom_loss = 0.33971
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.17512
# Best weights from best epoch are automatically used!
# Run 99 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 245 and best_val_0_custom_loss = 1.15695
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 78 with best_epoch = 28 and best_val_0_custom_loss = 0.8307
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 115 with best_epoch = 65 and best_val_0_custom_loss = 1.35657
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 0.26057
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_custom_loss = 1.57207
# Best weights from best epoch are automatically used!
# Run 100 / 100 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 210 and best_val_0_custom_loss = 0.4027
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 65 with best_epoch = 15 and best_val_0_custom_loss = 11.03526
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 184 with best_epoch = 134 and best_val_0_custom_loss = 0.23948
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 160 with best_epoch = 110 and best_val_0_custom_loss = 1.30855
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 231 and best_val_0_custom_loss = 0.2629
# Best weights from best epoch are automatically used!

# %% [markdown]
# ### 2.2. Fill missing values (Heuristic Imputation)
# Replacing missing values by a heuristic (such as the mean) of their respective feature.

# %%
from sklearn.impute import SimpleImputer

X_reconstr["Heuristic"] = {}
for experiment_value in X_mv_keys:
    X_reconstr["Heuristic"][experiment_value] = {}
    X_reconstr["Heuristic"][experiment_value]["mean"] = pd.DataFrame(SimpleImputer(missing_values=np.nan, strategy='mean').fit_transform(X_mv[experiment_value]), columns=wine['feature_names'])
    X_reconstr["Heuristic"][experiment_value]["median"] = pd.DataFrame(SimpleImputer(missing_values=np.nan, strategy='median').fit_transform(X_mv[experiment_value]), columns=wine['feature_names'])

# %% [markdown]
# ### 2.3. Fill missing values (Multivariate Imputation)

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

X_reconstr["Multivariate"] = {}
for experiment_value in X_mv_keys:
    X_reconstr["Multivariate"][experiment_value] = pd.DataFrame(IterativeImputer(max_iter=10, random_state=seed_value).fit_transform(X_mv[experiment_value]), columns=wine['feature_names'])

# %% [markdown]
# Save reconstructed datasets

# %%
if save_output:
    with open(os.path.join(X_reconstr_path, 'x_reconstr.pkl'), 'wb') as f:
        pickle.dump(X_reconstr, f)

# %% [markdown]
# ## 3. Reconstruct Dataset
# choose best TabNet model based on min. squared custom loss.

# %%
best_per_run = []
best_per_run_index = []
for run in range(config["general"]["runs"]):
    cost_list = list(output["costs"][f"run_{run}"].values())
    best_per_run.append(min(cost_list))
    best_per_run_index.append(cost_list.index(min(cost_list)))
    
best_run = best_per_run.index(min(best_per_run))
best_model = best_per_run_index[best_run]
print(f"Best model: run {best_run} model {best_model}")

X_best = X_reconstr["TabNet"][best_run][best_model]
# Out:
# Best model: run 92 model 4

# %% [markdown]
# ## 4. Clustering
# Apply k-means (k=3) on reconstructed data. In order to make the clusters comparable, the k-Means labels will be replaced using Munkres / Hungarian algorithm as explained here:\
# https://gist.github.com/siolag161/dc6e42b64e1bde1f263b \
# https://github.com/benchaplin/hungarian-algorithm
#
# ### 4.1. TabNet

# %%
labels_reconstr_tabnet = []
for run in range(config["general"]["runs"]):
    labels_reconstr_tabnet.append([])
    for i, var in enumerate(experiment_variable_values):
        
        X_reconstr_scaled = pd.DataFrame(StandardScaler().fit_transform(X_reconstr["TabNet"][run][i]))
        k_mean_reconstr = KMeans(n_clusters=3).fit(X_reconstr_scaled)
        
        cost_matrix = make_cost_matrix(k_mean_reconstr.labels_, labels_true)
        indexes = Munkres().compute(cost_matrix)
        mapping = [new for (_, new) in indexes]
        
        labels_reconstr_tabnet[run].append(np.choose(k_mean_reconstr.labels_,mapping).astype(np.int64))

# %% [markdown]
# ### 4.2. Heuristic (mean)

# %%
labels_reconstr_heuristic = []

for experiment_value in X_mv_keys:
    
    X_reconstr_scaled = pd.DataFrame(StandardScaler().fit_transform(X_reconstr["Heuristic"][experiment_value]["mean"]))
    k_mean_reconstr = KMeans(n_clusters=3).fit(X_reconstr_scaled)

    cost_matrix = make_cost_matrix(k_mean_reconstr.labels_, labels_true)
    indexes = Munkres().compute(cost_matrix)
    mapping = [new for (_, new) in indexes]

    labels_reconstr_heuristic.append(np.choose(k_mean_reconstr.labels_,mapping).astype(np.int64))

# %% [markdown]
# ### 4.3. Multivariate (iterative) Imputation

# %%
labels_reconstr_multivariate = []

for experiment_value in X_mv_keys:
    
    X_reconstr_scaled = pd.DataFrame(StandardScaler().fit_transform(X_reconstr["Multivariate"][experiment_value]))
    k_mean_reconstr = KMeans(n_clusters=3).fit(X_reconstr_scaled)

    cost_matrix = make_cost_matrix(k_mean_reconstr.labels_, labels_true)
    indexes = Munkres().compute(cost_matrix)
    mapping = [new for (_, new) in indexes]

    labels_reconstr_multivariate.append(np.choose(k_mean_reconstr.labels_,mapping).astype(np.int64))

# %% [markdown]
# ## 5. Cluster Performance
# Performance metrics to measure distribution preservance and cluster performance
# ### 5.1 Feature Distributions
# Quality / Performance of distribution preservance
# #### 5.1.1 Distr. Plot based on best model's predictions
# Plot distribution (changes) using the lowest cost TabNet model.

# %%
# get max values to determine common scale
y1, _, _ = plt.hist(X[experiment_feature])
y2, _, _ = plt.hist(X_best[experiment_feature])

mv = X.copy()[X_mv[experiment_variable_values[best_model]][experiment_feature].isna()]
y3, _, _ = plt.hist(mv[experiment_feature])

data_multivariate = list(X_reconstr["Multivariate"].values())[best_model][experiment_feature]
y4, _, _ = plt.hist(data_multivariate)

data_heuristic_mean = list(X_reconstr["Heuristic"].values())[best_model]["mean"][experiment_feature]
y5, _, _ = plt.hist(data_heuristic_mean)

y_max = max([y1.max(), y2.max(), y3.max(), y4.max(), y5.max()]) * 1.5
x_max = X[experiment_feature].max() * 1.5
x_min = X[experiment_feature].min() * 0.5

fontsize = 12

plt.close()

# %%
fig, axs = plt.subplots(1,3, figsize=(18,8))
# Frequencies

X[experiment_feature].plot.hist(ax=axs[0], alpha=0.6, color='gray', label='original distribution')
X_best[experiment_feature].plot.hist(ax=axs[0], alpha=0.4, color='m', label='lowest cost TabNet imputation')
mv[experiment_feature].plot.hist(ax=axs[0], alpha=1, color='r', label='removed values')
axs[0].set_title(f"TabNet ({config['model_param']['eval_metric'][0]}) Imputation", fontsize=fontsize)
axs[0].set_ylim([0, y_max])

X[experiment_feature].plot.hist(ax=axs[1], alpha=0.6, color='gray')
data_multivariate.plot.hist(ax=axs[1], alpha=0.4, color='b', label='multivariate imputation')
mv[experiment_feature].plot.hist(ax=axs[1], alpha=1, color='r')
axs[1].get_yaxis().set_visible(False)
axs[1].set_title("Multivariate (Iterative) Imputation",fontsize=fontsize)
axs[1].set_ylim([0, y_max])

X[experiment_feature].plot.hist(ax=axs[2], alpha=0.6, color='gray')
data_heuristic_mean.plot.hist(ax=axs[2], alpha=0.4, color='g', label='heuristics imputation')
mv[experiment_feature].plot.hist(ax=axs[2], alpha=1, color='r')
axs[2].get_yaxis().set_visible(False)
axs[2].set_title("Heuristic (mean) Imputation",fontsize=fontsize)
axs[2].set_ylim([0, y_max])

# Densities

ax1 = axs[0].twinx()
X[experiment_feature].plot.kde(ax=ax1, color='k', linewidth=2.5)
X_best[experiment_feature].plot.kde(ax=ax1, color='m', linewidth=2.5)
ax1.get_yaxis().set_visible(False)
ax1.set_xlim([x_min, x_max])
_, ymax1 = ax1.get_ylim()
#mv[experiment_feature].plot.kde(ax=ax2, color='red')

ax2 = axs[1].twinx()
X[experiment_feature].plot.kde(ax=ax2, color='k', linewidth=2.5)
data_multivariate.plot.kde(ax=ax2, color='b', linewidth=2.5)
ax2.get_yaxis().set_visible(False)
ax2.set_xlim([x_min, x_max])
_, ymax2 = ax2.get_ylim()

ax3 = axs[2].twinx()
X[experiment_feature].plot.kde(ax=ax3, color='k', linewidth=2.5)
data_heuristic_mean.plot.kde(ax=ax3, color='g', linewidth=2.5)
ax3.set_xlim([x_min, x_max])
_, ymax3 = ax3.get_ylim()
ymax = max([ymax1, ymax2, ymax3])

ax1.set_ylim([0, ymax])
ax2.set_ylim([0, ymax])
ax3.set_ylim([0, ymax])

plt.suptitle(f"Lowest cost reconstructed distribution\n({config['general']['experiment_variable']} = {experiment_variable_values[best_model]})",fontsize=20)

if save_output:
    plt.savefig(os.path.join(plots_path, "5_distributions.png"), **config["plots"])

lines_labels = [fig.axes[0].get_legend_handles_labels(), ([fig.axes[1].get_legend_handles_labels()[0][1]], [fig.axes[1].get_legend_handles_labels()[1][1]]), ([fig.axes[2].get_legend_handles_labels()[0][1]], [fig.axes[2].get_legend_handles_labels()[1][1]])]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
fig.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, -0.05), shadow=True, ncol=10, fontsize=fontsize)
plt.tight_layout()  
plt.show()

# %% [markdown]
# #### 5.1.2 KL Divergence
# Calculate the KL divergence using the normalized (sum=1) probability density function as input.

# %%
# KL Divergence
def kl_divergence(d_pred, d_true):
    min_val = min(min(d_pred), min(d_true))
    max_val = max(max(d_pred), max(d_true))
    
    distr_pred = scipy.stats.gaussian_kde(d_pred).evaluate(np.linspace(min_val,max_val,100)) + sys.float_info.min
    distr_true = scipy.stats.gaussian_kde(d_true).evaluate(np.linspace(min_val,max_val,100)) + sys.float_info.min

    return torch.nn.functional.kl_div(torch.tensor(distr_true/sum(distr_true)).log(), torch.tensor(distr_pred/sum(distr_pred)), log_target=False, reduction='sum').item()

# %% [markdown]
# Save KL divergence to output.

# %%
output["kl_divergence"] = {}
output["kl_divergence"]["Heuristic"] = {}
output["kl_divergence"]["Multivariate"] = {}
output["kl_divergence"]["TabNet"] = {}

for experiment_value in experiment_variable_values:
    output["kl_divergence"]["Heuristic"][str(experiment_value)] = kl_divergence(X_reconstr["Heuristic"][experiment_value]["mean"][experiment_feature], X[experiment_feature])
    output["kl_divergence"]["Multivariate"][str(experiment_value)] = kl_divergence(X_reconstr["Multivariate"][experiment_value][experiment_feature], X[experiment_feature])

# save kl divergence
for run in range(config["general"]["runs"]):
    output["kl_divergence"]["TabNet"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        output["kl_divergence"]["TabNet"][f"run_{run}"][str(experiment_value)] = kl_divergence(X_reconstr["TabNet"][run][i][experiment_feature], X[experiment_feature])

# %% [markdown]
# Create KL divergence plot.

# %%
# plot
data = {}
for experiment_value in experiment_variable_values:
    data[str(experiment_value)] = [x[str(experiment_value)] for x in output["kl_divergence"]["TabNet"].values()]

fig, ax = plt.subplots(figsize = (8,5))

if variable_datasets:
    ax.errorbar(x = list(output["kl_divergence"]["Heuristic"].keys()), y = list(output["kl_divergence"]["Heuristic"].values()), color = 'g', linewidth=2.5)
    ax.errorbar(x = list(output["kl_divergence"]["Multivariate"].keys()), y = list(output["kl_divergence"]["Multivariate"].values()), color = 'b', linewidth=2.5)
else:
    plt.axhline(y=output["kl_divergence"]["Heuristic"]["data"], color='g', linestyle='--', linewidth=1.5)
    plt.axhline(y=output["kl_divergence"]["Multivariate"]["data"], color='b', linestyle='--', linewidth=1.5)

ax.errorbar(x = list(data.keys()), y = [np.median(x) for x in data.values()], yerr = [np.std(x) for x in data.values()], elinewidth=1, ecolor='black', color = 'm', linewidth=2.5)

plt.xlabel(f"{config['general']['experiment_variable']}")
plt.ylabel(f"D({experiment_feature}_pred || {experiment_feature}_true)")
plt.title("KL Divergence")
plt.legend(['X_reconstr Heuristics (mean)', 'X_reconstr Multivariate', 'X_reconstr TabNet\n(median, Std.)'],fontsize=10, loc=(0.62, 0.06))

plt.tight_layout() 

if save_output:
    plt.savefig(os.path.join(plots_path, "5_kl_divergence.png"), **config["plots"])
    

    plt.show()

# %% [markdown]
# ## Problem of KL Divergence
# Punishes outliers heavily

# %%
d_orig = X[experiment_feature]
d_tab = X_reconstr["TabNet"][0][2][experiment_feature]
d_heu = X_reconstr["Heuristic"][0.2]["mean"][experiment_feature]
min_val = min(min(d_orig), min(d_tab))
max_val = max(max(d_orig), max(d_tab))
distr_tab = d_tab.plot.kde(ind=list(np.linspace(min_val,max_val,100)), color="m").get_lines()[0].get_ydata() 
distr_tab /= sum(distr_tab)
distr_true = d_orig.plot.kde(ind=list(np.linspace(min_val,max_val,100)), color="gray").get_lines()[1].get_ydata()
distr_true /= sum(distr_true)
distr_heu = d_heu.plot.kde(ind=list(np.linspace(min_val,max_val,100)), color="g").get_lines()[2].get_ydata()
distr_heu /= sum(distr_heu)

# %%
print(f"KL-Div TabNet: {kl_divergence(d_tab, d_orig)}")
print(f"KL-Div Heuristics: {kl_divergence(d_heu, d_orig)}")
# Out:
# KL-Div TabNet: 15.89627377181639
# KL-Div Heuristics: 0.03779048321924984

# %% [markdown]
# #### 5.1.2 Share of correctly predicted outliers
# To examine the quality of the outlier predictions, we take the prediction values of the (original) outliers and check, if they would be outliers in the **original** distribution.

# %%
# indices of removed outliers (missing values)
X_mv_outliers = {}
output["n_outliers"]["X_reconstr_heuristic_mean"] = {}
output["n_outliers"]["X_reconstr_heuristic_median"] = {}
output["n_outliers"]["X_reconstr_multivariate"] = {}
output["n_outliers"]["X_reconstr_tabnet"] = {}

for experiment_value in X_mv_keys:
    X_mv_outliers[experiment_value] = X_mv[experiment_value][experiment_feature][X_mv[experiment_value][experiment_feature].isna()].index.intersection(X_outliers.index)

    # check if the predicted values are outsiders in the original distribution
    x = X_reconstr["Heuristic"][experiment_value]["mean"][experiment_feature].iloc[X_mv_outliers[experiment_value]]
    x_outliers, _, _ = is_outlier(x)
    output["n_outliers"]["X_reconstr_heuristic_mean"][str(experiment_value)] = x_outliers.sum()
    
    x = X_reconstr["Heuristic"][experiment_value]["median"][experiment_feature].iloc[X_mv_outliers[experiment_value]]
    x_outliers, _, _ = is_outlier(x)
    output["n_outliers"]["X_reconstr_heuristic_median"][str(experiment_value)] = x_outliers.sum()
    
    x = X_reconstr["Multivariate"][experiment_value][experiment_feature].iloc[X_mv_outliers[experiment_value]]
    x_outliers, _, _ = is_outlier(x)
    output["n_outliers"]["X_reconstr_multivariate"][str(experiment_value)] = x_outliers.sum()
    


for run in range(config["general"]["runs"]):
    output["n_outliers"]["X_reconstr_tabnet"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        x = X_reconstr["TabNet"][run][i][experiment_feature].iloc[X_mv_outliers[experiment_value]]
        x_outliers, _, _ = is_outlier(x)
        output["n_outliers"]["X_reconstr_tabnet"][f"run_{run}"][str(experiment_value)] =  x_outliers.sum()

# %% [markdown]
# Create plot of outlier prediction quality.

# %%
# share of outliers
data = {}
for experiment_value in experiment_variable_values:
    data[str(experiment_value)] = [x[str(experiment_value)]/X_mv_n_outliers[str(experiment_value)] for x in output["n_outliers"]["X_reconstr_tabnet"].values()]

fig, ax = plt.subplots(figsize = (8,5))

plt.xlabel(config["general"]["experiment_variable"])
plt.ylabel(experiment_feature)

if variable_datasets:
    ax.errorbar(x = list(output["n_outliers"]["X_reconstr_heuristic_mean"].keys()), y = list(output["n_outliers"]["X_reconstr_heuristic_mean"].values())/ X_mv_n_outliers[str(experiment_value)], color = 'g', linewidth=2.5)
    ax.errorbar(x = list(output["n_outliers"]["X_reconstr_multivariate"].keys()), y = list(output["n_outliers"]["X_reconstr_multivariate"].values())/ X_mv_n_outliers[str(experiment_value)], color = 'b', linewidth=2.5)
else:
    plt.axhline(y=output["n_outliers"]["X_reconstr_heuristic_mean"]/X_mv_n_outliers, color='g', linestyle='--', linewidth=2.5)
    plt.axhline(y=output["n_outliers"]["X_reconstr_multivariate"]/X_mv_n_outliers, color='b', linestyle='--', linewidth=2.5)
ax.errorbar(x = list(data.keys()), y = [np.median(x) for x in data.values()], yerr = [np.std(x) for x in data.values()], elinewidth=1, ecolor='black', color = 'm', linewidth=2.5)

plt.title("% of outliers")
plt.legend(['X_reconstr Heuristics (mean)', 'X_reconstr Multivariate', 'X_reconstr TabNet\n(median, St.Dev.)'],fontsize=10, loc=(0.62, 0.06))
plt.tight_layout() 

if save_output:
    plt.savefig(os.path.join(plots_path, "5_outliers.png"), **config["plots"])
    
plt.show()

# %% [markdown]
# ### 5.2. Cluster Performance
# #### 5.2.1. ARI Score

# %%
from sklearn.metrics.cluster import adjusted_rand_score

output["ARI_score"] = {}
output["ARI_score"]["orig_data"] = adjusted_rand_score(labels_orig, labels_true)
output["ARI_score"]["Heuristic"] = {}
output["ARI_score"]["Multivariate"] = {}

for i, experiment_value in enumerate(experiment_variable_values):    
    output["ARI_score"]["Heuristic"][str(experiment_value)] = adjusted_rand_score(labels_reconstr_heuristic[i], labels_true)
    output["ARI_score"]["Multivariate"][str(experiment_value)] = adjusted_rand_score(labels_reconstr_multivariate[i], labels_true)

output["ARI_score"]["TabNet"] = {}

for run in range(config["general"]["runs"]):
    output["ARI_score"]["TabNet"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        ari = adjusted_rand_score(labels_reconstr_tabnet[run][i], labels_true)
        output["ARI_score"]["TabNet"][f"run_{run}"][str(experiment_value)] = ari

# %%
# plot
ari = output["ARI_score"]["TabNet"].copy()

data = {}
for experiment_value in experiment_variable_values:
    data[str(experiment_value)] = [x[str(experiment_value)] for x in ari.values()]

fig, ax = plt.subplots(figsize = (8,5))

plt.axhline(y=output['ARI_score']['orig_data'], color='r', linestyle='-')

if variable_datasets:
    ax.errorbar(x = list(output["ARI_score"]["Heuristic"].keys()), y = list(output["ARI_score"]["Heuristic"].values()), color = 'g', linewidth=2.5)
    ax.errorbar(x = list(output["ARI_score"]["Multivariate"].keys()), y = list(output["ARI_score"]["Multivariate"].values()), color = 'b', linewidth=2.5)    
else:
    plt.axhline(y=output["ARI_score"]["Heuristic"], color='g', linestyle='--', linewidth=2.5)
    plt.axhline(y=output["ARI_score"]["Multivariate"], color='b', linestyle='--', linewidth=2.5)

ax.errorbar(x = list(data.keys()), y = [np.median(x) for x in data.values()], yerr = [np.std(x) for x in data.values()], elinewidth=1, ecolor='black', color = 'm', linewidth=2.5)


plt.xlabel(config["general"]["experiment_variable"])
plt.ylabel("ARI Score")
plt.title(f"ARI Score, {config['general']['runs']} runs")
plt.legend(['X', 'X_reconstr Heuristics (mean)', 'X_reconstr Multivariate', 'X_reconstr TabNet\n(median, St.Dev.)'],fontsize=10, loc=(0.56, 0.05))

if save_output:
    plt.savefig(os.path.join(plots_path, "5_ARI-score.png"), **config["plots"])

plt.show()

# %% [markdown]
# ### 5.3. Save Output

# %%
if save_output:
    # save output file
    with open(output_path, "w") as f:
                toml.dump(output, f)

    # save notebook
    shutil.copy2(nb_name, experiment_path)

# %% [markdown]
# ## 6. Old Code
