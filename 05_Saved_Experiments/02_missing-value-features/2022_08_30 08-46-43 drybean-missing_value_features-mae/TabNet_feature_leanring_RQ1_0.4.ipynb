# %% [markdown]
# ## Intro
# #### Setup of an experiment
# - Experiments can be setup by using the config parameter "experiment_variable" and assigning the experiment values as a list, e.g.
#     - experiment_variable = "train_val_split"
#     - config["training"]["train_val_split"] = [0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]
# - note: only the following parameters can be used for experiments:
#     - all parameters of the categories "training" and "model_param",
#     - parameters "missing_percent", "missing_outliers", "missing_value_features", "st_deviations"
#     - for other parameters (such as custom loss weights or different datasets), run each parameter as a signle experiment
#
# #### Loading experiments
# - run chapter 1 to get the data and generate missing values
# - skip chapter 2 (time consuming calculations)
# - load outputs saved in output.toml (such as metrics) and reconstructed datasets with:
#         output = toml.load("output.toml")
#         with open(os.path.join("X_reconstr", 'X_reconstr.pkl'), 'rb') as f:
#             X_reconstr = pickle.load(f)
# - run chapter 3-5

# %%
# %%javascript
# IPython.notebook.kernel.execute('nb_name = "' + IPython.notebook.notebook_name + '"')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import random
import math
import scipy
import astropy.stats
import pickle
import sys
import os
sys.path.append(os.getcwd() + "/pytorch_tabnet/")

from sklearn.cluster import DBSCAN

# %% [markdown]
# ## 0. Experiment Setup

# %%
# should an output folder be created to save the experiment data?
save_output = True
save_models = False

# %%
# read config file
import toml
config = toml.load("config.toml")

# determine experimental parameter from config
experiment_variable_values = ""
experiment_dict_key = ""
for category_name, category_values in config.items():
    if config["general"]["experiment_variable"] in category_values:
        experiment_variable_values = category_values[config["general"]["experiment_variable"]]
        experiment_dict_key = category_name
        
# rnd seed to support reproducable results
def set_seeds(seed):
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    torch.use_deterministic_algorithms(True)

seed_value =  config["general"]["random_seed"] if config["general"]["random_seed"] else random.randrange(2**32 -1)
seed_train_test_split = config["general"]["seed_train_test_split"] if config["general"]["seed_train_test_split"] else random.sample(range(2**32 -1), config["general"]["models"])
set_seeds(seed_value)

# TabNet hyperparameters
experiment_variable = config["general"]["experiment_variable"]
regressor_param = {"scheduler_params" : {"step_size": 10},
                   "scheduler_fn" : torch.optim.lr_scheduler.StepLR,
                   "mask_type" : 'entmax',
                   "device_name" : 'cuda', # only working on NVIDIA GPUs
                   "seed" : seed_value,
                   "verbose" : 0
                  }

# create experiment folder structure
if save_output or save_models:  
    from datetime import datetime
    
    experiment_name = config["general"]["experiment_name"]
    experiment_folder = f"{datetime.now().strftime('%Y_%m_%d %H-%M-%S')} {experiment_name} " if experiment_name else f"{datetime.now().strftime('%Y_%m_%d %H-%M-%S')} {config['general']['dataset']}-{config['general']['experiment_variable']}-{config['model_param']['eval_metric'][0]}"
    
    experiment_path = os.path.join("04_Experiments", experiment_folder)
    os.mkdir(experiment_path)
    
    plots_path = os.path.join(experiment_path, "plots")
    os.mkdir(plots_path)
    
    models_path = os.path.join(experiment_path, "models")
    os.mkdir(models_path)
    
    X_reconstr_path = os.path.join(experiment_path, "X_reconstr")
    os.mkdir(X_reconstr_path)
    
    # save config file
    import shutil
    shutil.copy2("config.toml", experiment_path)
    config_path = os.path.join(experiment_path, "config.toml")
    
    # save random seeds
    if not config["general"]["random_seed"]:
        config["general"]["random_seed"] = seed_value
        with open(config_path, "w") as f:
            toml.dump(config, f)
    if not config["general"]["seed_train_test_split"]:
        config["general"]["seed_train_test_split"] = seed_train_test_split
        with open(config_path, "w") as f:
            toml.dump(config, f)       
    
    # save model hyperparameters
    with open(os.path.join(experiment_path, 'config.toml'), 'a') as config_file:
        config_file.write("\n#[regressor_param]\n")
        for key, value in regressor_param.items(): 
            config_file.write('#%s = %s\n' % (key, str(value)))
    
    # create output file
    output_path = os.path.join(experiment_path, "output.toml")
    output_file = open(output_path, "w")

output = {}

# %% [markdown]
# ## 1. Datasets
#
# ### 1.0. Choose dataset
# Get dataset from config.

# %%
from sklearn.preprocessing import scale, StandardScaler

if config["general"]["dataset"] == "wine":
    from sklearn.datasets import load_wine

    dataset = load_wine()
    feature_names = dataset['feature_names']
    X, labels_true = pd.DataFrame(dataset.data, columns=feature_names), dataset.target
    X_scaled = pd.DataFrame(StandardScaler().fit_transform(X), columns=dataset['feature_names'])
    
elif config["general"]["dataset"] == "iris":
    from sklearn.datasets import load_iris
    
    dataset = load_iris()
    feature_names = dataset['feature_names']
    X, labels_true = pd.DataFrame(dataset.data, columns=feature_names), dataset.target
    X_scaled = pd.DataFrame(StandardScaler().fit_transform(X), columns=dataset['feature_names'])
    
elif config["general"]["dataset"] == "drybean":
    dataset = pd.read_excel("01_Datasets/Dry_Bean_Dataset.xlsx")
    X = dataset.iloc[:,:-1]
    feature_names = X.columns
    labels_true = np.array(dataset.iloc[:,-1].astype("category").cat.codes)
    X_scaled = pd.DataFrame(StandardScaler().fit_transform(X), columns=X.columns)
    
else:
    raise ValueError(f"The dataset {config['general']['dataset']} is not implemented.")

# %% [markdown]
# #### Determine feature distributions
# To examine the influence and predictability of outliers, we want to choose a feature of the dataset, that has a distribution including an adequate number of outliers.

# %%
rows = math.ceil(X_scaled.shape[1]/4)
X_scaled.hist(layout=(rows,4), figsize=(12,3*rows), density=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Examine outlierness
# Examine the number of outliers in both directions. For the given outlier definition (distance to the mean in standard deviations, e.g. 3 * std) the share of outliers in both direction should be large enough.
# The outlier definition (x times standard_deviation) is defined in the config.

# %%
def n_outliers(data):
    return data[(data < X[experiment_feature].mean() - config["outlier_definition"]["st_deviations"] * X[experiment_feature].std()) | (data > X[experiment_feature].mean() + config["outlier_definition"]["st_deviations"] * X[experiment_feature].std())].count()

# %%
def is_outlier(data):
    upper_outlier = data > X[experiment_feature].mean() + config["outlier_definition"]["st_deviations"] * X[experiment_feature].std()
    lower_outlier = data < X[experiment_feature].mean() - config["outlier_definition"]["st_deviations"] * X[experiment_feature].std()
    return (upper_outlier | lower_outlier), lower_outlier, upper_outlier

# %%
X_outliers_up = X.agg(lambda x: x[x > x.mean() + config["outlier_definition"]["st_deviations"] * x.std()].count()) / X.shape[0]
X_outliers_low = X.agg(lambda x: x[x < x.mean() - config["outlier_definition"]["st_deviations"] * x.std()].count()) / X.shape[0]

# %% [markdown]
# #### Select feature
# The selected feature should have at least a certain number of outliers in total and a minimum number of outliers in each direction.

# %%
# filter by minimum outliers in each direction
X_outliers_up = X_outliers_up[(X_outliers_up > config["outlier_definition"]["min_outliers_per_direction"]) & (X_outliers_low > config["outlier_definition"]["min_outliers_per_direction"])]
X_outliers_low = X_outliers_low[(X_outliers_up > config["outlier_definition"]["min_outliers_per_direction"]) & (X_outliers_low > config["outlier_definition"]["min_outliers_per_direction"])]

# filter by minimum outliers in total
X_outliers_total = X_outliers_up + X_outliers_low
X_outliers_total = X_outliers_total[X_outliers_total > config["outlier_definition"]["min_outliers_total"]]

# choose the feature with the most equal number of lower/upper outliers
if X_outliers_total.empty:
    raise ValueError("The given dataset does not have a feature fullfilling the required outlier requirements.")
else:
    experiment_feature = abs(X_outliers_up[X_outliers_total.index] - X_outliers_low[X_outliers_total.index]).idxmin()
    output["experiment_feature"] = experiment_feature
    print(f"experiment feature: {experiment_feature}")
    # number of outliers for later use in metrics
    X_n_outliers = n_outliers(X[experiment_feature])
    
    # series of outliers
    std_orig = X[experiment_feature].std()
    mean_orig = X[experiment_feature].mean()
    X_outliers = X[experiment_feature][(X[experiment_feature] < mean_orig - config["outlier_definition"]["st_deviations"] * std_orig) | (X[experiment_feature] > mean_orig + config["outlier_definition"]["st_deviations"] * std_orig)]
# Out:
# experiment feature: Compactness

# %% [markdown]
# ### 1.1. Create missing data
# #### 1.1.1. Create a specified amount of missing values
# missing values will be generated for the selected feature in 1.0 as well as for randomly chosen amount of features defined in config --> general --> missing_value_features.
#
# The data will be sampled until at least a certain amount of outliers are replaced by missing values. This enables us to examine the impact of outliers later on.

# %%
# create datasets with missing values
X_mv = {}
X_mv_n_outliers = {}

# if the experiment variable is affecting the dataset, we need a dict of the different datasets, else only one dataset named "data"
variable_hyperparams = not config["general"]["experiment_variable"] in ["missing_percent", "missing_outliers", "missing_value_features", "st_deviations"]
X_mv_keys = experiment_variable_values if not variable_hyperparams else [experiment_variable]

for experiment_value in X_mv_keys:

    if not variable_hyperparams:
        config[experiment_dict_key][config["general"]["experiment_variable"]] = experiment_value

    n_outliers_req = round(config["general"]["missing_outliers"] * X_n_outliers)
    n_outliers_generated = round(config["general"]["missing_percent"] * len(X))
    if n_outliers_generated < n_outliers_req:
        raise ValueError("The ratio of missing values created has to be larger than than the required ratio of outlier-missing-values. Increase 'missing percent' or decrease 'missing_outliers' before proceeding.")

    X_mv[experiment_value] = []
    X_mv_n_outliers[str(experiment_value)] = []
    
    for run in range(config["general"]["runs"]):

        # create missing values in feature column(s) and assure, that at least x% of missing values were outliers
        n_mv_features = round(len(feature_names)*experiment_value) if experiment_variable == "missing_value_features" else round(len(feature_names)*config["general"]["missing_value_features"])
        rnd_features = random.sample(list(X.loc[:, X.columns != experiment_feature].columns), n_mv_features)
        mv_config = {feature:config["general"]["missing_percent"] for feature in rnd_features}

        if run == 0 or experiment_variable != "missing_value_features":
            # remove at least n_outliers_req outliers
            X_mv[experiment_value].append(X.copy())
            
            _, l_outliers, u_outliers = is_outlier(X_mv[experiment_value][run][experiment_feature])
            sample_upper_outliers = X_mv[experiment_value][run][experiment_feature][u_outliers].sample(math.floor(n_outliers_req / 2))
            sample_lower_outliers = X_mv[experiment_value][run][experiment_feature][l_outliers].sample(math.ceil(n_outliers_req / 2))
            sample_rest = X_mv[experiment_value][run][experiment_feature].sample(n_outliers_generated - n_outliers_req)
            
            X_mv[experiment_value][run].loc[sample_rest.index.union(sample_lower_outliers.index).union(sample_upper_outliers.index),experiment_feature] = np.nan
            
        else:
            # use same experiment_feature mvs for all runs, only vary other missing features
            X_mv[experiment_value].append(X_mv[X_mv_keys[0]][0].copy())
  
        # remove values in other features
        for f, mv in mv_config.items():
            X_mv[experiment_value][run][f] = X_mv[experiment_value][run][f].mask(np.random.random(len(X)) < mv)

        # calculate share of outliers in sample
        mvs = X[experiment_feature][X_mv[experiment_value][run][experiment_feature].isna()]
        X_mv_n_outliers[str(experiment_value)].append(n_outliers(mvs))

# %%
import missingno as msno
# %matplotlib inline

# plot missing values
fig = msno.matrix(X_mv[experiment_value][run])
plt.title(f"missing values for {experiment_variable}: {experiment_value} (run {run})", fontsize=22)
plt.show()
if save_output:
    fig_copy = fig.get_figure()
    fig_copy.savefig(os.path.join(plots_path, "missing_values.png"), **config["plots"], bbox_inches = 'tight')

# %% [markdown]
# #### 1.1.2. Save outlier numbers to output

# %%
output["n_outliers"] = {}
output["n_outliers"]["X"] = X_n_outliers
output["n_outliers"]["X_mv"] = X_mv_n_outliers

# %% [markdown]
# #### 1.1.3. Distribution after removing random values

# %%
mv = X.copy()[X_mv[experiment_value][run][experiment_feature].isna()]

fig, ax = plt.subplots(figsize=(12,8))
X[experiment_feature].plot.hist(ax=ax, alpha=0.5)
X_mv[experiment_value][run][experiment_feature].plot.hist(ax=ax, alpha=0.5, color='green')
mv[experiment_feature].plot.hist(ax=ax, alpha=0.5, color='red')

ax2 = ax.twinx()
X[experiment_feature].plot.kde(ax=ax2)
X_mv[experiment_value][run][experiment_feature].plot.kde(ax=ax2, color='green')
mv[experiment_feature].plot.kde(ax=ax2, color='red')
plt.title(f"Distribution for {experiment_variable}: {experiment_value} (run {run})")
plt.legend(['original data', 'without missing values', 'missing values'])

plt.show()

# %% [markdown]
# #### 1.1.3. Kurtosis
# If the data is sufficiently close to a normal distribution, the Kurtosis measure could be used to compare the tailedness of the data before and after predictions. This does, however not necessarily apply for the given feature.

# %%
scipy.stats.kurtosistest(X_mv[experiment_value][run][X_mv[experiment_value][run][experiment_feature].notna()][experiment_feature])
# Out:
# KurtosistestResult(statistic=-1.9808382602758965, pvalue=0.04760941462673687)

# %% [markdown]
# ### 1.3. Initial Clustering (without missing values)

# %% [markdown]
# #### 1.3.1 DBSCAN (for wine dataset)
# Generel problem with DBSCAN: curse of dimensionality for datasets with high feature counts.
#
# Automatically determine DBSCAN hyperparameters min_samples and eps.\
# min_samples results in 26 for the wine dataset (dimensionality 13).\
# for eps we choose 2.5 (elbow of the graph).

# %%
from sklearn.neighbors import NearestNeighbors

min_samples = 2 * len(X_scaled.columns)

neighbors = NearestNeighbors(n_neighbors=min_samples)
neighbors_fit = neighbors.fit(X_scaled)
distances, indices = neighbors_fit.kneighbors(X_scaled)
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)

# %% [markdown]
# Use the cluster algorithm on dataset without missing values shows, that DBSCAN is not performaing well with 13 dimensional dataset (curse of dimensionality leads to either 1 or 0 clusters).

# %%
# run DBSCAN on original data
config["DBSCAN"]["eps"] = 1
config["DBSCAN"]["min_samples"] = min_samples

if save_output or save_models:
    config[experiment_dict_key][config["general"]["experiment_variable"]] = experiment_variable_values
    with open(config_path, "w") as f:
        toml.dump(config, f)
        
dbscan_orig = DBSCAN(**config["DBSCAN"]).fit(X_scaled)
labels_orig = dbscan_orig.labels_
print(f"DBSCAN noise: {(sum(abs(labels_orig[labels_orig == -1]))*100) / len(labels_true)}%")
print(f"DBSCAN clusters: {np.unique(labels_orig)}")
# Out:
# DBSCAN noise: 14.069502608184557%
# DBSCAN clusters: [-1  0  1]

# %% [markdown]
# #### 1.3.2 K-Means
# As an alternative, we use k-means for the initial clustering (k=3). This does clearly work better with a more than 96% correct labeling of data.

# %%
from sklearn.cluster import KMeans
k_mean_orig = KMeans(n_clusters=len(np.unique(labels_true)), random_state=seed_value).fit(X_scaled)
labels_orig = k_mean_orig.labels_

# %% [markdown]
# Using munkres/hungarian algorithm to allign the k-means cluster names with the original cluster means.\
# Source: https://gist.github.com/siolag161/dc6e42b64e1bde1f263b

# %%
from munkres import Munkres
from sklearn.metrics import confusion_matrix

# use Munkres / Hungarian algorithm to relabel clusters in order to match original label names
def make_cost_matrix(c1, c2):
    """
    """
    uc1 = np.unique(c1)
    uc2 = np.unique(c2)
    l1 = uc1.size
    l2 = uc2.size
    #if not (l1 == l2 and np.all(uc1 == uc2)):
    #    raise ValueError(f"Clustering could not detect the correct number of clusters (k={len(uc2)})")

    m = np.ones([l1, l2])
    for i in range(l1):
        it_i = np.nonzero(c1 == uc1[i])[0]
        for j in range(l2):
            it_j = np.nonzero(c2 == uc2[j])[0]
            m_ij = np.intersect1d(it_j, it_i)
            m[i,j] =  -m_ij.size
    return m

# %%
cost_matrix = make_cost_matrix(labels_orig, labels_true)
indexes = Munkres().compute(cost_matrix)
mapping = [new for (_, new) in indexes]
labels_orig_renamed = np.choose(labels_orig, mapping).astype(np.int64)

mislabeled = labels_true - labels_orig_renamed
mislabeled[mislabeled != 0] = 1
mislabeled_orig = sum(mislabeled) / len(mislabeled)
print(f"{round(mislabeled_orig * 100, 2)}% mislabeled")
# Out:
# 21.35% mislabeled

# %% [markdown]
# Get cluster means for loss function input.

# %%
# get cluster means (used to calculate the cluster mean loss)
complete_data = X.copy()
complete_data["C"] = labels_orig
cluster_means = complete_data.groupby("C").agg("mean")
cluster_means = cluster_means if -1 not in cluster_means.index else cluster_means.drop(-1)

# %% [markdown]
# ## 2. Filling Strategies
# Applying different imputation strategies to the incomplete dataset.
#
# ### 2.1. Define custom-loss
# The loss function for the model fitting shall be customized to improve cluster perforamnce. The custom loss is divided into 2 separate losses
#
# 1. **Reconstruction Loss**\
# Classic loss function, such as RMSE.
# 2. **Cluster-Mean Loss**\
# The distance to the nearest cluster mean shall be minimized.
# 3. **KL Divergence Loss**\
# Deviation of original distribution shall be minimized \
# (prob distribution based on https://stackoverflow.com/questions/57687458/how-to-calculate-probabilities-using-numpy-histogram-and-then-use-it-for-calcula \
# number of bins: D. Freedman & P. Diaconis (1981) “On the histogram as a density estimator: L2 theory”. Probability Theory and Related Fields 57 (4): 453-476)
#
# The chosen approach to implement the cluster-mean loss is as follows:\
# **Adapt the loss function** to calculate a distance to each cluster. The minimum distance (to the nearest cluster) will be used as a cluster-mean-loss. Minimizing this loss should result in the data point moving closer to the nearest cluster mean.\
# Potential Problem: loss functions currently work with y_true (true values) and y_score (predicted values). Calculating the distance would require all features. Calculating only the 1 dimensional distance will result in missing values being put into wrong clusters - depending on the first estimate.

# %%
# define custom loss function: extend L2-loss by cluster-mean-loss and KL divergence

from pytorch_tabnet.metrics import Metric
from sklearn.metrics import mean_squared_error

class custom_loss(Metric):

    def __init__(self):
        self._name = "custom_loss"
        self._maximize = False

    def __call__(self, y_true, y_score, cluster_means, y_name, x_val, y_val, cl_weights = [0.5, 1, 0.0001]):
        # reconstruction loss
        rmse = np.sqrt(mean_squared_error(y_true, y_score))
        
        # cluster mean loss
        cml = 0 if cl_weights[2] == 0 else self.cluster_mean_loss(cluster_means, y_score, y_name, x_val, y_val)
        
        # KL divergence loss
        # - range of values
        min_val = min(min(y_true[:,0]), min(y_score[:,0]))
        max_val = max(max(y_true[:,0]), max(y_score[:,0]))
        # - prob. density function
        distr_pred = scipy.stats.gaussian_kde(y_score[:,0]).evaluate(np.linspace(min_val,max_val,100)) + sys.float_info.min
        distr_true = scipy.stats.gaussian_kde(y_true[:,0]).evaluate(np.linspace(min_val,max_val,100)) + sys.float_info.min
        # - calc. KL divergence on normalized pdf
        KLdl = torch.nn.functional.kl_div((torch.tensor(distr_pred/sum(distr_pred))).log(), torch.tensor(distr_true/sum(distr_true)), log_target=False, reduction='sum').item()
        
        # total loss
        custom_loss = cl_weights[0] * rmse + cl_weights[1] * KLdl + cl_weights[2] * cml
        return custom_loss
    
    # calculate sum of distances to the closest cluster mean
    def cluster_mean_loss(self, cluster_means, y_score, y_name, x_val, y_val):
        
        # reorder cluster_means to match x_val columns (predicted feature is last column)
        cols = cluster_means.columns.tolist()
        feature_col = X.columns.get_loc(y_name)
        cols = cols[:feature_col] + cols[feature_col+1:] + [y_name]
        
        # x values extended by predicted values
        x_extended = pd.DataFrame(np.hstack((x_val, y_score)), columns=cols)


        # calculate distances to each cluster and select the closest one
        dist = []
        for cluster in range(cluster_means.shape[0]):
            dist.append(np.linalg.norm((x_extended - cluster_means.iloc[cluster]), axis=1))
            
        dist = pd.DataFrame(dist).T
        min_dist = dist.assign(min_dist=lambda d: d.min(1))["min_dist"]
        
        return sum(min_dist)

# %% [markdown]
# ### 2.2. Fill missing values (TabNet)
#
# In general, we want to train a fixed (see config) number of models and make predictions on all datasets. The final prediction value will be the median value of all trained models. The median is used here, as it has shown, that most models will have a similar prediction performance, but some "bad" model outliers with significantly worse performance can occur.
#
# **Approach 1:**\
# For each feature that contains missing values, use all rows with complete other features as train set and predict missing values of the feature.\
# &rarr; Problem: lots of models, especially for high-dimensional datasets.
# Also problem, if more than one feature is missing values. &rarr; see Approach 2
#
# **Approach 2:**\
# Mask missing values as -1 (or some other value) and fit a model predicting each feature just like in approach 1.\
# This way the amount of required models can be reduced and the model can learn correlations from the presence of missing values. However we cannot expect an improvement from learning correlations when the missing data is MCAR, as "missing values (MCAR) are interpreted as a random reduction of the dataset, which provide no further information for assigning incomplete feature
# vectors to clusters." (H. Timm, et al., "Different approaches to fuzzy clustering of incomplete datasets")\
# &rarr; one model for each feature containing missing values.\
# Possible adaption: use predicted values to predict subsequent values (instead of using -1)
#
# **Approach 3:**
# To further reduce the number of trained models and in order to focus on features with an appropriate number of outliers: only predict and examine one feature (see chosen feature above) and leave the others with their masked values.\
# &rarr; Problem: missing value mask of other features impacts the subsequent clustering. Additionally, due to the MCAR missing value generation for the used datasets, there is no useful information in the missing values of other features. Thus, the model cannot learn anything from the masked values. It does however make sense to implement it this way for further research of real incomplete datasets.\
# As we are interested in the predictive performance of the experiment feature, a solution to the subsequent clustering problem is, to reconstruct the other features with their original values (i.e. the predictions are based on the incomplete dataset, but the clustering will be based on the predicted feature plus the original other features).

# %%
import time

from pytorch_tabnet.tab_model import TabNetRegressor
from sklearn.model_selection import train_test_split

X_reconstr = {}
X_reconstr["TabNet"] = {}
output["costs"] = {}
output["runtimes"] = {}
output["predictions"] = {}

for i, experiment_value in enumerate(experiment_variable_values):
    
    X_reconstr["TabNet"][str(experiment_value)] = []
    output["costs"][str(experiment_value)] = {}
    output["runtimes"][str(experiment_value)] = {}
    output["predictions"][str(experiment_value)] = {}
    
    config[experiment_dict_key][config["general"]["experiment_variable"]] = experiment_value
    ds_name = experiment_variable if variable_hyperparams else experiment_value
    
    for run in range(config["general"]["runs"]):
        
        print(f"{i*config['general']['runs'] + run} / {len(experiment_variable_values) * config['general']['runs']} --------------------------------------------------")
        
        output["costs"][str(experiment_value)][f"run_{run}"] = {}
        output["runtimes"][str(experiment_value)][f"run_{run}"] = {}
        output["predictions"][str(experiment_value)][f"run_{run}"] = {}   
        
        time_start = time.time()
        
        X_reconstr["TabNet"][str(experiment_value)].append(X.copy())
        X_reconstr["TabNet"][str(experiment_value)][run][experiment_feature] = X_mv[X_mv_keys[0]][run][experiment_feature] if variable_hyperparams else X_mv[experiment_value][run][experiment_feature]

        # select % of features used for predictions (e.g. 10% of randomly selected features)
        n_features = math.ceil(config["RQ2"]["pred_features"] * (len(X.columns)) - 1)
        X_mv_masked = X_mv[ds_name][run].copy().drop(experiment_feature, axis=1).sample(n=n_features, axis='columns')
        other_features = X_mv_masked.columns

        # mask other columns' missing values as defined in config (missing_value_mask)
        X_mv_masked[experiment_feature] = X_mv[ds_name][run][experiment_feature]
        X_mv_masked[other_features] = X_mv_masked[(other_features)].fillna(config["general"]["missing_value_mask"])

        # separate complete rows as train data
        # separate column with missing values as target
        test_data = X_mv_masked[X_mv_masked[experiment_feature].isna()].drop(experiment_feature, axis=1).to_numpy()
        train_data = X_mv_masked[X_mv_masked[experiment_feature].notna()]
        train_features = train_data.drop(columns=experiment_feature).to_numpy()
        train_target = train_data[experiment_feature].to_numpy().reshape(-1,1)
        
        models = []
        for model in range(config["general"]["models"]):

            x_train, x_val, y_train, y_val = train_test_split(train_features, train_target, train_size=config["training"]["train_val_split"], random_state = seed_train_test_split[model])
                
            # create & train model
            tabnet_model = TabNetRegressor(**regressor_param)
            if config["model_param"]["eval_metric"] == ["custom_loss"]:
                tabnet_model.fit(
                    x_train, y_train,
                    eval_set=[(x_val, y_val)],
                    **config["model_param"],
                    cluster_means=cluster_means,
                    y_name=experiment_feature,
                    x_val=x_val,
                    y_val=y_val,
                    cl_weights=config["training"]["cl_weights"]
                )
            else:
                tabnet_model.fit(
                    x_train, y_train,
                    eval_set=[(x_val, y_val)],
                    **config["model_param"]
                )
                
            models.append(tabnet_model)
        
        # chose model based on minimum costs
        model_costs = [m.best_cost for m in models]
        best_model = models[model_costs.index(min(model_costs))]
        
        # save costs
        output["costs"][str(experiment_value)][f"run_{run}"] = float(best_model.best_cost)

        # save predictions
        predictions = [x[0] for x in best_model.predict(test_data)]
        output["predictions"][str(experiment_value)][f"run_{run}"] = predictions

        # fill missing values with model predictions
        X_reconstr["TabNet"][str(experiment_value)][run].loc[X_reconstr["TabNet"][str(experiment_value)][run][experiment_feature].isna(), experiment_feature] = predictions

        # save models
        if save_models:
            torch.save(best_model, os.path.join(models_path, f"Model_{config['general']['experiment_variable']}{experiment_value}_run_{run}.pt"))            

        #track runtime
        time_end = time.time()
        output["runtimes"][str(experiment_value)][f"run_{run}"] = time_end - time_start
# Out:
# 0 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 193 with best_epoch = 143 and best_val_0_mae = 0.0165
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 172 with best_epoch = 122 and best_val_0_mae = 0.01747
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 218 with best_epoch = 168 and best_val_0_mae = 0.01929
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 161 with best_epoch = 111 and best_val_0_mae = 0.01791
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 186 with best_epoch = 136 and best_val_0_mae = 0.01865
# Best weights from best epoch are automatically used!
# 1 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 216 with best_epoch = 166 and best_val_0_mae = 0.01593
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 220 with best_epoch = 170 and best_val_0_mae = 0.01419
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 229 with best_epoch = 179 and best_val_0_mae = 0.01483
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 220 with best_epoch = 170 and best_val_0_mae = 0.01459
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 169 with best_epoch = 119 and best_val_0_mae = 0.01597
# Best weights from best epoch are automatically used!
# 2 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 157 with best_epoch = 107 and best_val_0_mae = 0.01717
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 217 with best_epoch = 167 and best_val_0_mae = 0.0185
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 231 and best_val_0_mae = 0.0178
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 134 with best_epoch = 84 and best_val_0_mae = 0.01569
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 218 with best_epoch = 168 and best_val_0_mae = 0.01594
# Best weights from best epoch are automatically used!
# 3 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 165 with best_epoch = 115 and best_val_0_mae = 0.01778
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 117 with best_epoch = 67 and best_val_0_mae = 0.01657
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 199 with best_epoch = 149 and best_val_0_mae = 0.01411
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 118 with best_epoch = 68 and best_val_0_mae = 0.01781
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 166 with best_epoch = 116 and best_val_0_mae = 0.01761
# Best weights from best epoch are automatically used!
# 4 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 205 with best_epoch = 155 and best_val_0_mae = 0.01608
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 222 with best_epoch = 172 and best_val_0_mae = 0.01275
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 210 and best_val_0_mae = 0.01608
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 208 with best_epoch = 158 and best_val_0_mae = 0.01538
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 184 with best_epoch = 134 and best_val_0_mae = 0.01688
# Best weights from best epoch are automatically used!
# 5 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 137 with best_epoch = 87 and best_val_0_mae = 0.01621
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 197 with best_epoch = 147 and best_val_0_mae = 0.01558
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 143 with best_epoch = 93 and best_val_0_mae = 0.01598
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 234 with best_epoch = 184 and best_val_0_mae = 0.01972
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 144 with best_epoch = 94 and best_val_0_mae = 0.01648
# Best weights from best epoch are automatically used!
# 6 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 154 with best_epoch = 104 and best_val_0_mae = 0.01585
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 196 with best_epoch = 146 and best_val_0_mae = 0.01506
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 183 with best_epoch = 133 and best_val_0_mae = 0.01603
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 164 with best_epoch = 114 and best_val_0_mae = 0.01716
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 232 with best_epoch = 182 and best_val_0_mae = 0.01602
# Best weights from best epoch are automatically used!
# 7 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 117 with best_epoch = 67 and best_val_0_mae = 0.01314
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 124 with best_epoch = 74 and best_val_0_mae = 0.0152
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 169 with best_epoch = 119 and best_val_0_mae = 0.0126
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 173 with best_epoch = 123 and best_val_0_mae = 0.01475
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 143 with best_epoch = 93 and best_val_0_mae = 0.01146
# Best weights from best epoch are automatically used!
# 8 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 203 with best_epoch = 153 and best_val_0_mae = 0.01441
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 235 with best_epoch = 185 and best_val_0_mae = 0.01617
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 124 with best_epoch = 74 and best_val_0_mae = 0.0187
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 168 with best_epoch = 118 and best_val_0_mae = 0.01325
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 173 with best_epoch = 123 and best_val_0_mae = 0.01942
# Best weights from best epoch are automatically used!
# 9 / 50 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 228 and best_val_0_mae = 0.01421
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 245 with best_epoch = 195 and best_val_0_mae = 0.01784
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 125 with best_epoch = 75 and best_val_0_mae = 0.01359
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 221 with best_epoch = 171 and best_val_0_mae = 0.01711
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 151 with best_epoch = 101 and best_val_0_mae = 0.01566
# Best weights from best epoch are automatically used!
# 10 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 197 with best_epoch = 147 and best_val_0_mae = 0.0133
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 157 with best_epoch = 107 and best_val_0_mae = 0.01247
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 188 with best_epoch = 138 and best_val_0_mae = 0.01677
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 153 with best_epoch = 103 and best_val_0_mae = 0.01378
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 199 with best_epoch = 149 and best_val_0_mae = 0.0145
# Best weights from best epoch are automatically used!
# 11 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 203 with best_epoch = 153 and best_val_0_mae = 0.01732
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 227 with best_epoch = 177 and best_val_0_mae = 0.01745
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 208 and best_val_0_mae = 0.01862
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 218 with best_epoch = 168 and best_val_0_mae = 0.01712
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 242 with best_epoch = 192 and best_val_0_mae = 0.01968
# Best weights from best epoch are automatically used!
# 12 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 120 with best_epoch = 70 and best_val_0_mae = 0.01294
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 190 with best_epoch = 140 and best_val_0_mae = 0.01438
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 179 with best_epoch = 129 and best_val_0_mae = 0.01309
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 208 with best_epoch = 158 and best_val_0_mae = 0.01148
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 158 with best_epoch = 108 and best_val_0_mae = 0.01315
# Best weights from best epoch are automatically used!
# 13 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 237 with best_epoch = 187 and best_val_0_mae = 0.01637
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 126 with best_epoch = 76 and best_val_0_mae = 0.01317
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 138 with best_epoch = 88 and best_val_0_mae = 0.0169
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 218 with best_epoch = 168 and best_val_0_mae = 0.01749
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 180 with best_epoch = 130 and best_val_0_mae = 0.01583
# Best weights from best epoch are automatically used!
# 14 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 139 with best_epoch = 89 and best_val_0_mae = 0.01671
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 145 with best_epoch = 95 and best_val_0_mae = 0.02054
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 174 with best_epoch = 124 and best_val_0_mae = 0.01452
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 239 with best_epoch = 189 and best_val_0_mae = 0.0196
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 162 with best_epoch = 112 and best_val_0_mae = 0.0187
# Best weights from best epoch are automatically used!
# 15 / 50 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 222 and best_val_0_mae = 0.01501
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 191 with best_epoch = 141 and best_val_0_mae = 0.01645
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 213 with best_epoch = 163 and best_val_0_mae = 0.01732
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 221 with best_epoch = 171 and best_val_0_mae = 0.02114
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 231 and best_val_0_mae = 0.01592
# Best weights from best epoch are automatically used!
# 16 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 129 with best_epoch = 79 and best_val_0_mae = 0.01715
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 218 with best_epoch = 168 and best_val_0_mae = 0.01848
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 151 with best_epoch = 101 and best_val_0_mae = 0.0178
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 181 with best_epoch = 131 and best_val_0_mae = 0.01503
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 153 with best_epoch = 103 and best_val_0_mae = 0.01815
# Best weights from best epoch are automatically used!
# 17 / 50 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 210 and best_val_0_mae = 0.02229
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 178 with best_epoch = 128 and best_val_0_mae = 0.02075
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 139 with best_epoch = 89 and best_val_0_mae = 0.01988
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 205 with best_epoch = 155 and best_val_0_mae = 0.01929
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 228 with best_epoch = 178 and best_val_0_mae = 0.02218
# Best weights from best epoch are automatically used!
# 18 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 160 with best_epoch = 110 and best_val_0_mae = 0.01692
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 158 with best_epoch = 108 and best_val_0_mae = 0.016
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 213 with best_epoch = 163 and best_val_0_mae = 0.01741
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 169 with best_epoch = 119 and best_val_0_mae = 0.01541
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 121 with best_epoch = 71 and best_val_0_mae = 0.01394
# Best weights from best epoch are automatically used!
# 19 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 172 with best_epoch = 122 and best_val_0_mae = 0.02008
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 170 with best_epoch = 120 and best_val_0_mae = 0.01674
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 186 with best_epoch = 136 and best_val_0_mae = 0.01507
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 155 with best_epoch = 105 and best_val_0_mae = 0.01701
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 227 and best_val_0_mae = 0.01843
# Best weights from best epoch are automatically used!
# 20 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 173 with best_epoch = 123 and best_val_0_mae = 0.01815
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 168 with best_epoch = 118 and best_val_0_mae = 0.01711
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 218 with best_epoch = 168 and best_val_0_mae = 0.01574
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 156 with best_epoch = 106 and best_val_0_mae = 0.0189
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 129 with best_epoch = 79 and best_val_0_mae = 0.01594
# Best weights from best epoch are automatically used!
# 21 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 186 with best_epoch = 136 and best_val_0_mae = 0.02166
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 215 and best_val_0_mae = 0.02391
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 192 with best_epoch = 142 and best_val_0_mae = 0.02467
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 186 with best_epoch = 136 and best_val_0_mae = 0.01996
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 214 with best_epoch = 164 and best_val_0_mae = 0.01513
# Best weights from best epoch are automatically used!
# 22 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 164 with best_epoch = 114 and best_val_0_mae = 0.01869
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 238 with best_epoch = 188 and best_val_0_mae = 0.02119
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 126 with best_epoch = 76 and best_val_0_mae = 0.01781
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 204 with best_epoch = 154 and best_val_0_mae = 0.02006
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 156 with best_epoch = 106 and best_val_0_mae = 0.01694
# Best weights from best epoch are automatically used!
# 23 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 141 with best_epoch = 91 and best_val_0_mae = 0.01936
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 237 with best_epoch = 187 and best_val_0_mae = 0.01743
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 120 with best_epoch = 70 and best_val_0_mae = 0.01528
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 116 with best_epoch = 66 and best_val_0_mae = 0.01729
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 138 with best_epoch = 88 and best_val_0_mae = 0.01629
# Best weights from best epoch are automatically used!
# 24 / 50 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 214 and best_val_0_mae = 0.02029
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 233 with best_epoch = 183 and best_val_0_mae = 0.01979
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 208 with best_epoch = 158 and best_val_0_mae = 0.02248
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 244 with best_epoch = 194 and best_val_0_mae = 0.02321
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 245 with best_epoch = 195 and best_val_0_mae = 0.01959
# Best weights from best epoch are automatically used!
# 25 / 50 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 233 and best_val_0_mae = 0.02012
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 199 with best_epoch = 149 and best_val_0_mae = 0.02201
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 179 with best_epoch = 129 and best_val_0_mae = 0.01556
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 226 and best_val_0_mae = 0.02302
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 211 with best_epoch = 161 and best_val_0_mae = 0.02068
# Best weights from best epoch are automatically used!
# 26 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 88 with best_epoch = 38 and best_val_0_mae = 0.02724
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 241 and best_val_0_mae = 0.02633
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 243 with best_epoch = 193 and best_val_0_mae = 0.02182
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 234 with best_epoch = 184 and best_val_0_mae = 0.02359
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 224 and best_val_0_mae = 0.02096
# Best weights from best epoch are automatically used!
# 27 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 194 with best_epoch = 144 and best_val_0_mae = 0.02133
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 233 with best_epoch = 183 and best_val_0_mae = 0.02047
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 219 with best_epoch = 169 and best_val_0_mae = 0.02286
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 185 with best_epoch = 135 and best_val_0_mae = 0.02154
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 157 with best_epoch = 107 and best_val_0_mae = 0.0196
# Best weights from best epoch are automatically used!
# 28 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 160 with best_epoch = 110 and best_val_0_mae = 0.01841
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 215 with best_epoch = 165 and best_val_0_mae = 0.01753
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 159 with best_epoch = 109 and best_val_0_mae = 0.02162
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 180 with best_epoch = 130 and best_val_0_mae = 0.02163
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 168 with best_epoch = 118 and best_val_0_mae = 0.01915
# Best weights from best epoch are automatically used!
# 29 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 231 with best_epoch = 181 and best_val_0_mae = 0.01928
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 210 and best_val_0_mae = 0.0197
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 200 and best_val_0_mae = 0.0171
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 216 with best_epoch = 166 and best_val_0_mae = 0.01726
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 228 with best_epoch = 178 and best_val_0_mae = 0.01876
# Best weights from best epoch are automatically used!
# 30 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 167 with best_epoch = 117 and best_val_0_mae = 0.01897
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 166 with best_epoch = 116 and best_val_0_mae = 0.01566
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 131 with best_epoch = 81 and best_val_0_mae = 0.01703
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 129 with best_epoch = 79 and best_val_0_mae = 0.01669
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 162 with best_epoch = 112 and best_val_0_mae = 0.01779
# Best weights from best epoch are automatically used!
# 31 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 181 with best_epoch = 131 and best_val_0_mae = 0.01664
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 240 with best_epoch = 190 and best_val_0_mae = 0.01727
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 160 with best_epoch = 110 and best_val_0_mae = 0.01819
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 120 with best_epoch = 70 and best_val_0_mae = 0.01747
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 115 with best_epoch = 65 and best_val_0_mae = 0.0195
# Best weights from best epoch are automatically used!
# 32 / 50 --------------------------------------------------
# Early stopping occurred at epoch 182 with best_epoch = 132 and best_val_0_mae = 0.02103
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 213 and best_val_0_mae = 0.02258
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 198 with best_epoch = 148 and best_val_0_mae = 0.02107
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 207 and best_val_0_mae = 0.02177
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 182 with best_epoch = 132 and best_val_0_mae = 0.02013
# Best weights from best epoch are automatically used!
# 33 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 212 with best_epoch = 162 and best_val_0_mae = 0.01823
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 192 with best_epoch = 142 and best_val_0_mae = 0.01851
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 133 with best_epoch = 83 and best_val_0_mae = 0.01958
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_mae = 0.01723
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 232 with best_epoch = 182 and best_val_0_mae = 0.02281
# Best weights from best epoch are automatically used!
# 34 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 180 with best_epoch = 130 and best_val_0_mae = 0.02213
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 144 with best_epoch = 94 and best_val_0_mae = 0.02388
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 142 with best_epoch = 92 and best_val_0_mae = 0.02072
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 160 with best_epoch = 110 and best_val_0_mae = 0.02056
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 161 with best_epoch = 111 and best_val_0_mae = 0.02183
# Best weights from best epoch are automatically used!
# 35 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 238 with best_epoch = 188 and best_val_0_mae = 0.01407
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 199 with best_epoch = 149 and best_val_0_mae = 0.01558
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 205 and best_val_0_mae = 0.01565
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 177 with best_epoch = 127 and best_val_0_mae = 0.01743
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 119 with best_epoch = 69 and best_val_0_mae = 0.01655
# Best weights from best epoch are automatically used!
# 36 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 207 with best_epoch = 157 and best_val_0_mae = 0.02152
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 152 with best_epoch = 102 and best_val_0_mae = 0.02139
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 194 with best_epoch = 144 and best_val_0_mae = 0.0197
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 215 with best_epoch = 165 and best_val_0_mae = 0.01901
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 239 with best_epoch = 189 and best_val_0_mae = 0.02128
# Best weights from best epoch are automatically used!
# 37 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 210 with best_epoch = 160 and best_val_0_mae = 0.02266
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 134 with best_epoch = 84 and best_val_0_mae = 0.02254
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 134 with best_epoch = 84 and best_val_0_mae = 0.01807
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 155 with best_epoch = 105 and best_val_0_mae = 0.02653
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 159 with best_epoch = 109 and best_val_0_mae = 0.02474
# Best weights from best epoch are automatically used!
# 38 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 165 with best_epoch = 115 and best_val_0_mae = 0.02396
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 180 with best_epoch = 130 and best_val_0_mae = 0.02
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 170 with best_epoch = 120 and best_val_0_mae = 0.02059
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 153 with best_epoch = 103 and best_val_0_mae = 0.02253
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 170 with best_epoch = 120 and best_val_0_mae = 0.02015
# Best weights from best epoch are automatically used!
# 39 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 189 with best_epoch = 139 and best_val_0_mae = 0.02267
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 127 with best_epoch = 77 and best_val_0_mae = 0.01887
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 207 with best_epoch = 157 and best_val_0_mae = 0.02358
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 219 and best_val_0_mae = 0.01992
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 209 and best_val_0_mae = 0.0226
# Best weights from best epoch are automatically used!
# 40 / 50 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 229 and best_val_0_mae = 0.02024
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 135 with best_epoch = 85 and best_val_0_mae = 0.01771
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 224 and best_val_0_mae = 0.01867
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 245 with best_epoch = 195 and best_val_0_mae = 0.0219
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 133 with best_epoch = 83 and best_val_0_mae = 0.02419
# Best weights from best epoch are automatically used!
# 41 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 127 with best_epoch = 77 and best_val_0_mae = 0.02123
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 156 with best_epoch = 106 and best_val_0_mae = 0.0231
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 178 with best_epoch = 128 and best_val_0_mae = 0.02288
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 181 with best_epoch = 131 and best_val_0_mae = 0.02321
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 217 with best_epoch = 167 and best_val_0_mae = 0.0233
# Best weights from best epoch are automatically used!
# 42 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 150 with best_epoch = 100 and best_val_0_mae = 0.02261
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 154 with best_epoch = 104 and best_val_0_mae = 0.02251
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 131 with best_epoch = 81 and best_val_0_mae = 0.01973
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 120 with best_epoch = 70 and best_val_0_mae = 0.02233
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 121 with best_epoch = 71 and best_val_0_mae = 0.0239
# Best weights from best epoch are automatically used!
# 43 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 219 with best_epoch = 169 and best_val_0_mae = 0.02959
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 201 and best_val_0_mae = 0.02552
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 171 with best_epoch = 121 and best_val_0_mae = 0.02631
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 185 with best_epoch = 135 and best_val_0_mae = 0.02492
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 213 with best_epoch = 163 and best_val_0_mae = 0.02387
# Best weights from best epoch are automatically used!
# 44 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 200 with best_epoch = 150 and best_val_0_mae = 0.0213
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 122 with best_epoch = 72 and best_val_0_mae = 0.02191
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 128 with best_epoch = 78 and best_val_0_mae = 0.02534
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 155 with best_epoch = 105 and best_val_0_mae = 0.02449
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 114 with best_epoch = 64 and best_val_0_mae = 0.02502
# Best weights from best epoch are automatically used!
# 45 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 205 with best_epoch = 155 and best_val_0_mae = 0.03248
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 242 with best_epoch = 192 and best_val_0_mae = 0.03052
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 224 with best_epoch = 174 and best_val_0_mae = 0.03048
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 210 with best_epoch = 160 and best_val_0_mae = 0.02916
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 236 with best_epoch = 186 and best_val_0_mae = 0.03041
# Best weights from best epoch are automatically used!
# 46 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 155 with best_epoch = 105 and best_val_0_mae = 0.02652
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 128 with best_epoch = 78 and best_val_0_mae = 0.02019
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 126 with best_epoch = 76 and best_val_0_mae = 0.02844
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 146 with best_epoch = 96 and best_val_0_mae = 0.01931
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 184 with best_epoch = 134 and best_val_0_mae = 0.02841
# Best weights from best epoch are automatically used!
# 47 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 221 with best_epoch = 171 and best_val_0_mae = 0.02548
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 236 with best_epoch = 186 and best_val_0_mae = 0.02092
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 225 with best_epoch = 175 and best_val_0_mae = 0.02069
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 243 and best_val_0_mae = 0.0207
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 133 with best_epoch = 83 and best_val_0_mae = 0.02055
# Best weights from best epoch are automatically used!
# 48 / 50 --------------------------------------------------
# Stop training because you reached max_epochs = 250 with best_epoch = 223 and best_val_0_mae = 0.02184
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 244 and best_val_0_mae = 0.02644
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 210 with best_epoch = 160 and best_val_0_mae = 0.02286
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 207 with best_epoch = 157 and best_val_0_mae = 0.02104
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 224 with best_epoch = 174 and best_val_0_mae = 0.02254
# Best weights from best epoch are automatically used!
# 49 / 50 --------------------------------------------------
#
# Early stopping occurred at epoch 124 with best_epoch = 74 and best_val_0_mae = 0.01701
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 183 with best_epoch = 133 and best_val_0_mae = 0.01552
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 189 with best_epoch = 139 and best_val_0_mae = 0.0196
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 213 and best_val_0_mae = 0.01648
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 214 and best_val_0_mae = 0.0179
# Best weights from best epoch are automatically used!

# %% [markdown]
# ### 2.2. Fill missing values (Heuristic Imputation - mean)
# Replacing missing values by a heuristic (such as the mean) of their respective feature.

# %%
# update X_reconstr. when loading older experiments ("Heuristic" and "Multivariate" were renamed)
_ = X_reconstr.pop("Heuristic") if "Heuristic" in X_reconstr else None
_ = X_reconstr.pop("Multivariate") if "Multivariate" in X_reconstr else None

# %%
from sklearn.impute import SimpleImputer

X_reconstr["Mean_substitution"] = {}

for experiment_value in X_mv_keys:
    X_reconstr["Mean_substitution"][experiment_value] = []
    for run in range(config["general"]["runs"]):
        X_temp = X.copy()
        X_temp[experiment_feature] = X_mv[experiment_value][run][experiment_feature]
        X_reconstr["Mean_substitution"][experiment_value].append(pd.DataFrame(SimpleImputer(missing_values=np.nan, strategy='mean').fit_transform(X_temp), columns=feature_names))

# %% [markdown]
# ### 2.3. Fill missing values (Regression Imputation)

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

X_reconstr["Regression"] = {}
for experiment_value in X_mv_keys:
    X_reconstr["Regression"][experiment_value] = []
    for run in range(config["general"]["runs"]):
        X_temp = X.copy()
        X_temp[experiment_feature] = X_mv[experiment_value][run][experiment_feature]
        X_reconstr["Regression"][experiment_value].append(pd.DataFrame(IterativeImputer(max_iter=10, random_state=seed_value).fit_transform(X_temp), columns=feature_names))

# %% [markdown]
# Save reconstructed datasets

# %%
if save_output:
    with open(os.path.join(X_reconstr_path, 'x_reconstr.pkl'), 'wb') as f:
        pickle.dump(X_reconstr, f)

# %% [markdown]
# ## 3. Reconstruct Dataset
# choose best TabNet model based on min. squared custom loss.

# %%
best_runs = [min(values.values()) for run, values in output["costs"].items()]
best_runs_index = [list(values.values()).index(min(values.values())) for run, values in output["costs"].items()]
    
best_experiment_value_index = best_runs.index(min(best_runs))
best_experiment_value = experiment_variable_values[best_experiment_value_index]
best_run = best_runs_index[best_experiment_value_index]

print(f"Best model: run {best_run} for {experiment_variable} {best_experiment_value}")

X_best = X_reconstr["TabNet"][str(best_experiment_value)][best_run]
# Out:
# Best model: run 7 for missing_value_features 0.1

# %% [markdown]
# ## 4. Clustering
# Apply k-means (k=3) on reconstructed data. In order to make the clusters comparable, the k-Means labels will be replaced using Munkres / Hungarian algorithm as explained here:\
# https://gist.github.com/siolag161/dc6e42b64e1bde1f263b \
# https://github.com/benchaplin/hungarian-algorithm
#
# ### 4.1. TabNet

# %%
labels_reconstr_tabnet = []

for i, experiment_value in enumerate(experiment_variable_values):

    labels_reconstr_tabnet.append([])
    
    for run in range(config["general"]["runs"]):
        X_reconstr_scaled = pd.DataFrame(StandardScaler().fit_transform(X_reconstr["TabNet"][str(experiment_value)][run]))
        k_mean_reconstr = KMeans(n_clusters=len(np.unique(labels_true))).fit(X_reconstr_scaled)
        
        cost_matrix = make_cost_matrix(k_mean_reconstr.labels_, labels_true)
        indexes = Munkres().compute(cost_matrix)
        mapping = [new for (_, new) in indexes]
        
        labels_reconstr_tabnet[i].append(np.choose(k_mean_reconstr.labels_,mapping).astype(np.int64))

# %% [markdown]
# ### 4.2. Mean Substitution

# %%
labels_reconstr_mean_sub = []

for i, experiment_value in enumerate(X_mv_keys):

    labels_reconstr_mean_sub.append([])
    
    for run in range(config["general"]["runs"]):
        X_reconstr_scaled = pd.DataFrame(StandardScaler().fit_transform(X_reconstr["Mean_substitution"][experiment_value][run]))
        k_mean_reconstr = KMeans(n_clusters=len(np.unique(labels_true))).fit(X_reconstr_scaled)

        cost_matrix = make_cost_matrix(k_mean_reconstr.labels_, labels_true)
        indexes = Munkres().compute(cost_matrix)
        mapping = [new for (_, new) in indexes]

        labels_reconstr_mean_sub[i].append(np.choose(k_mean_reconstr.labels_,mapping).astype(np.int64))

# %% [markdown]
# ### 4.3. Regression Imputation

# %%
labels_reconstr_regression = []

for i, experiment_value in enumerate(X_mv_keys):

    labels_reconstr_regression.append([])
    
    for run in range(config["general"]["runs"]):
        X_reconstr_scaled = pd.DataFrame(StandardScaler().fit_transform(X_reconstr["Regression"][experiment_value][run]))
        k_mean_reconstr = KMeans(n_clusters=len(np.unique(labels_true))).fit(X_reconstr_scaled)

        cost_matrix = make_cost_matrix(k_mean_reconstr.labels_, labels_true)
        indexes = Munkres().compute(cost_matrix)
        mapping = [new for (_, new) in indexes]

        labels_reconstr_regression[i].append(np.choose(k_mean_reconstr.labels_,mapping).astype(np.int64))

# %% [markdown]
# ## 5. Cluster Performance
# Performance metrics to measure distribution preservance and cluster performance
# ### 5.1 Feature Distributions
# Quality / Performance of distribution preservance
# #### 5.1.1 Distr. Plot based on best model's predictions
# Plot distribution (changes) using the lowest cost TabNet model.

# %%
# get max values to determine common scale
y1, _, _ = plt.hist(X[experiment_feature])
y2, _, _ = plt.hist(X_best[experiment_feature])

ds_name = experiment_variable if variable_hyperparams else best_experiment_value

mv = X.copy()[X_mv[ds_name][best_run][experiment_feature].isna()]
y3, _, _ = plt.hist(mv[experiment_feature])

data_regression = X_reconstr["Regression"][ds_name][best_run][experiment_feature]
y4, _, _ = plt.hist(data_regression)

data_mean_sub = X_reconstr["Mean_substitution"][ds_name][best_run][experiment_feature]
y5, _, _ = plt.hist(data_mean_sub)

y_max = max([y1.max(), y2.max(), y3.max(), y4.max(), y5.max()]) * 1.5
x_max = max(X[experiment_feature].max(), X_best[experiment_feature].max(), data_regression.max(), data_mean_sub.max()) * 1.2
x_min = min(X[experiment_feature].min(), X_best[experiment_feature].min(), data_regression.min(), data_mean_sub.min()) * 0.8

fontsize = 12

plt.close()

# %%
fig, axs = plt.subplots(1,3, figsize=(18,8))
# Frequencies

X[experiment_feature].plot.hist(ax=axs[0], alpha=0.6, color='gray', label='original distribution')
X_best[experiment_feature].plot.hist(ax=axs[0], alpha=0.4, color='m', label='lowest cost TabNet imputation')
mv[experiment_feature].plot.hist(ax=axs[0], alpha=1, color='r', label='removed values')
axs[0].set_title(f"TabNet ({config['model_param']['eval_metric'][0]}) Imputation", fontsize=fontsize)
axs[0].set_ylim([0, y_max])

X[experiment_feature].plot.hist(ax=axs[1], alpha=0.6, color='gray')
data_regression.plot.hist(ax=axs[1], alpha=0.4, color='b', label='Regression imputation')
mv[experiment_feature].plot.hist(ax=axs[1], alpha=1, color='r')
axs[1].get_yaxis().set_visible(False)
axs[1].set_title("Regression Imputation",fontsize=fontsize)
axs[1].set_ylim([0, y_max])

X[experiment_feature].plot.hist(ax=axs[2], alpha=0.6, color='gray')
data_mean_sub.plot.hist(ax=axs[2], alpha=0.4, color='g', label='Mean substitution')
mv[experiment_feature].plot.hist(ax=axs[2], alpha=1, color='r')
axs[2].get_yaxis().set_visible(False)
axs[2].set_title("Mean Substitution",fontsize=fontsize)
axs[2].set_ylim([0, y_max])

# Densities

ax1 = axs[0].twinx()
X[experiment_feature].plot.kde(ax=ax1, color='k', linewidth=2.5)
X_best[experiment_feature].plot.kde(ax=ax1, color='m', linewidth=2.5)
ax1.get_yaxis().set_visible(False)
ax1.set_xlim([x_min, x_max])
_, ymax1 = ax1.get_ylim()
#mv[experiment_feature].plot.kde(ax=ax2, color='red')

ax2 = axs[1].twinx()
X[experiment_feature].plot.kde(ax=ax2, color='k', linewidth=2.5)
data_regression.plot.kde(ax=ax2, color='b', linewidth=2.5)
ax2.get_yaxis().set_visible(False)
ax2.set_xlim([x_min, x_max])
_, ymax2 = ax2.get_ylim()

ax3 = axs[2].twinx()
X[experiment_feature].plot.kde(ax=ax3, color='k', linewidth=2.5)
data_mean_sub.plot.kde(ax=ax3, color='g', linewidth=2.5)
ax3.set_xlim([x_min, x_max])
_, ymax3 = ax3.get_ylim()
ymax = max([ymax1, ymax2, ymax3])

ax1.set_ylim([0, ymax])
ax2.set_ylim([0, ymax])
ax3.set_ylim([0, ymax])

plt.suptitle(f"Lowest cost reconstructed distribution\n({config['general']['experiment_variable']} = {best_experiment_value})",fontsize=20)

if save_output:
    plt.savefig(os.path.join(plots_path, "5_distributions.png"), **config["plots"])

lines_labels = [fig.axes[0].get_legend_handles_labels(), ([fig.axes[1].get_legend_handles_labels()[0][1]], [fig.axes[1].get_legend_handles_labels()[1][1]]), ([fig.axes[2].get_legend_handles_labels()[0][1]], [fig.axes[2].get_legend_handles_labels()[1][1]])]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
fig.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, -0.05), shadow=True, ncol=10, fontsize=fontsize)
plt.tight_layout()  
plt.show()

# %% [markdown]
# ## 5.1.2 KL Divergence
# Calculate the KL divergence using the normalized (sum=1) probability density function as input.

# %%
# KL Divergence
def kl_divergence(d_pred, d_true):
    min_val = min(min(d_pred), min(d_true))
    max_val = max(max(d_pred), max(d_true))
    
    distr_pred = scipy.stats.gaussian_kde(d_pred).evaluate(np.linspace(min_val,max_val,100)) + sys.float_info.min
    distr_true = scipy.stats.gaussian_kde(d_true).evaluate(np.linspace(min_val,max_val,100)) + sys.float_info.min

    return torch.nn.functional.kl_div(torch.tensor(distr_pred/sum(distr_pred)).log(), torch.tensor(distr_true/sum(distr_true)), log_target=False, reduction='sum').item()

# %% [markdown]
# Save KL divergence to output.

# %%
output["kl_divergence"] = {}
output["kl_divergence"]["Mean_substitution"] = {}
output["kl_divergence"]["Regression"] = {}
output["kl_divergence"]["TabNet"] = {}

for experiment_value in X_mv_keys:    
    output["kl_divergence"]["Mean_substitution"][str(experiment_value)] = {}
    output["kl_divergence"]["Regression"][str(experiment_value)] = {}
    
    for run in range(config["general"]["runs"]):
        output["kl_divergence"]["Mean_substitution"][str(experiment_value)][f"run_{run}"] = kl_divergence(X_reconstr["Mean_substitution"][experiment_value][run][experiment_feature], X[experiment_feature])
        output["kl_divergence"]["Regression"][str(experiment_value)][f"run_{run}"] = kl_divergence(X_reconstr["Regression"][experiment_value][run][experiment_feature], X[experiment_feature])



for i, experiment_value in enumerate(experiment_variable_values):    
    output["kl_divergence"]["TabNet"][str(experiment_value)] = {}
    
    for run in range(config["general"]["runs"]):
        output["kl_divergence"]["TabNet"][str(experiment_value)][f"run_{run}"] = kl_divergence(X_reconstr["TabNet"][str(experiment_value)][run][experiment_feature], X[experiment_feature])

# %% [markdown]
# Create KL divergence plot.

# %%
# plot
data = {}
data["Mean_substitution"] = {k: list(v.values()) for k,v in output["kl_divergence"]["Mean_substitution"].items()}
data["Regression"] = {k: list(v.values()) for k,v in output["kl_divergence"]["Regression"].items()}
data["TabNet"] = {k: list(v.values()) for k,v in output["kl_divergence"]["TabNet"].items()}

fig, ax = plt.subplots(figsize = (8,5))

if variable_hyperparams:
    plt.axhline(y=[np.median(x) for x in data["Mean_substitution"].values()], color='g', linestyle='-', linewidth=2.5)
    plt.axhline(y=[np.median(x) for x in data["Regression"].values()], color='b', linestyle='--', linewidth=2.5)
else:
    ax.errorbar(x = list(data["Mean_substitution"].keys()), y = [np.median(x) for x in data["Mean_substitution"].values()], yerr = [np.std(x) for x in data["Mean_substitution"].values()], elinewidth=1, ecolor='g', linestyle='-', color = 'g', linewidth=2.5, fmt='o', capsize=10)
    ax.errorbar(x = list(data["Regression"].keys()), y = [np.median(x) for x in data["Regression"].values()], yerr = [np.std(x) for x in data["Regression"].values()], elinewidth=1,linestyle='--',  ecolor='b', color = 'b', linewidth=2.5, fmt='o', capsize=10)

ax.errorbar(x = list(data["TabNet"].keys()), y = [np.median(x) for x in data["TabNet"].values()], yerr = [np.std(x) for x in data["TabNet"].values()], elinewidth=1,linestyle='-', ecolor='m', color = 'm', linewidth=2.5, fmt='o', capsize=10)

plt.xlabel(f"{config['general']['experiment_variable']}")
plt.ylabel(f"D({experiment_feature}_pred || {experiment_feature}_true)")
plt.title("median (+ st. dev.) KL Divergence")
plt.legend(['Mean_substitution', 'Regression', 'TabNet'],fontsize=10, loc=(0.72, 0.8))

plt.tight_layout() 

if save_output:
    plt.savefig(os.path.join(plots_path, "5_kl_divergence.png"), **config["plots"])
    plt.show()

# %% [markdown]
# #### 5.1.2 Share of correctly predicted outliers
# To examine the quality of the outlier predictions, we take the prediction values of the (original) outliers and check, if they would be outliers in the **original** distribution.

# %%
X_mv_outliers = {}
output["n_outliers"]["Mean_substitution"] = {}
output["n_outliers"]["Regression"] = {}
output["n_outliers"]["TabNet"] = {}

for experiment_value in X_mv_keys:
    X_mv_outliers[experiment_value] = []
    output["n_outliers"]["Mean_substitution"][str(experiment_value)] = {}
    output["n_outliers"]["Regression"][str(experiment_value)] = {}
    
    for run in range(config["general"]["runs"]):
        
        # indices of removed outliers (missing values)
        X_mv_outliers[experiment_value].append(X_mv[experiment_value][run][experiment_feature][X_mv[experiment_value][run][experiment_feature].isna()].index.intersection(X_outliers.index))
        
        # check if the predicted values are outsiders in the original distribution
        x = X_reconstr["Mean_substitution"][experiment_value][run][experiment_feature].iloc[X_mv_outliers[experiment_value][run]]
        x_outliers, _, _ = is_outlier(x)
        output["n_outliers"]["Mean_substitution"][str(experiment_value)][f"run_{run}"] = x_outliers.sum()

        x = X_reconstr["Regression"][experiment_value][run][experiment_feature].iloc[X_mv_outliers[experiment_value][run]]
        x_outliers, _, _ = is_outlier(x)
        output["n_outliers"]["Regression"][str(experiment_value)][f"run_{run}"] = x_outliers.sum()
    

for i, experiment_value in enumerate(experiment_variable_values):
    output["n_outliers"]["TabNet"][str(experiment_value)] = {}
    
    for run in range(config["general"]["runs"]):

        x = X_reconstr["TabNet"][str(experiment_value)][run][experiment_feature].iloc[X_mv_outliers[experiment_variable if variable_hyperparams else experiment_value][run]]
        x_outliers, _, _ = is_outlier(x)
        output["n_outliers"]["TabNet"][str(experiment_value)][f"run_{run}"] =  x_outliers.sum()

# %% [markdown]
# Create plot of outlier prediction quality.

# %%
# share of outliers
data = {}
data["Mean_substitution"] = {k: [value / X_mv_n_outliers[k][i] for i, value in enumerate(v.values())] for k,v in output["n_outliers"]["Mean_substitution"].items()}
data["Regression"] = {k: [value / X_mv_n_outliers[k][i] for i, value in enumerate(v.values())] for k,v in output["n_outliers"]["Regression"].items()}
data["TabNet"] = {k: [value / X_mv_n_outliers[experiment_variable if variable_hyperparams else k][i] for i, value in enumerate(v.values())] for k,v in output["n_outliers"]["TabNet"].items()}

fig, ax = plt.subplots(figsize = (8,5))

plt.xlabel(config["general"]["experiment_variable"])
plt.ylabel(experiment_feature)

if variable_hyperparams:
    plt.axhline(y=[np.median(x) for x in data["Mean_substitution"].values()], color='g', linestyle='-', linewidth=2.5)
    plt.axhline(y=[np.median(x) for x in data["Regression"].values()], color='b', linestyle='--', linewidth=2.5)
else:
    ax.errorbar(x = list(data["Mean_substitution"].keys()), y = [np.median(x) for x in data["Mean_substitution"].values()], yerr = [np.std(x) for x in data["Mean_substitution"].values()], elinewidth=1, ecolor='g', linestyle='-', color = 'g', linewidth=2.5, fmt='o', capsize=10)
    ax.errorbar(x = list(data["Regression"].keys()), y = [np.median(x) for x in data["Regression"].values()], yerr = [np.std(x) for x in data["Regression"].values()], elinewidth=1,linestyle='--',  ecolor='b', color = 'b', linewidth=2.5, fmt='o', capsize=10)

ax.errorbar(x = list(data["TabNet"].keys()), y = [np.median(x) for x in data["TabNet"].values()], yerr = [np.std(x) for x in data["TabNet"].values()], elinewidth=1,linestyle='-', ecolor='m', color = 'm', linewidth=2.5, fmt='o', capsize=10)

plt.title("median (+ st. dev.) % of outliers")
plt.legend(['Mean_substitution', 'Regression', 'TabNet'],fontsize=10, loc=(0.72, 0.06))
plt.tight_layout() 

if save_output:
    plt.savefig(os.path.join(plots_path, "5_outliers.png"), **config["plots"])
    
plt.show()

# %% [markdown]
# ### 5.2. Cluster Performance
# #### 5.2.1. ARI Score

# %%
from sklearn.metrics.cluster import adjusted_rand_score

output["ARI_score"] = {}
output["ARI_score"]["orig_data"] = adjusted_rand_score(labels_orig, labels_true)
output["ARI_score"]["Mean_substitution"] = {}
output["ARI_score"]["Regression"] = {}
output["ARI_score"]["TabNet"] = {}

for i, experiment_value in enumerate(X_mv_keys):
    output["ARI_score"]["Mean_substitution"][str(experiment_value)] = {}
    output["ARI_score"]["Regression"][str(experiment_value)] = {}
    
    for run in range(config["general"]["runs"]):
        output["ARI_score"]["Mean_substitution"][str(experiment_value)][f"run_{run}"] = adjusted_rand_score(labels_reconstr_mean_sub[i][run], labels_true)
        output["ARI_score"]["Regression"][str(experiment_value)][f"run_{run}"] = adjusted_rand_score(labels_reconstr_multivariate[i][run], labels_true)
        

for i, experiment_value in enumerate(experiment_variable_values):
    output["ARI_score"]["TabNet"][str(experiment_value)] = {}
    
    for run in range(config["general"]["runs"]):    
        ari = adjusted_rand_score(labels_reconstr_tabnet[i][run], labels_true)
        output["ARI_score"]["TabNet"][str(experiment_value)][f"run_{run}"] = ari
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [41], in <cell line: 9>()
#      13     for run in range(config["general"]["runs"]):
#      14         output["ARI_score"]["Mean_substitution"][str(experiment_value)][f"run_{run}"] = adjusted_rand_score(labels_reconstr_mean_sub[i][run], labels_true)
# ---> 15         output["ARI_score"]["Regression"][str(experiment_value)][f"run_{run}"] = adjusted_rand_score(labels_reconstr_multivariate[i][run], labels_true)
#      18 for i, experiment_value in enumerate(experiment_variable_values):
#      19     output["ARI_score"]["TabNet"][str(experiment_value)] = {}
#
# NameError: name 'labels_reconstr_multivariate' is not defined

# %%
# plot
ari = output["ARI_score"]["TabNet"].copy()

data = {}
data["Mean_substitution"] = {k: list(v.values()) for k,v in output["ARI_score"]["Mean_substitution"].items()}
data["Regression"] = {k: list(v.values()) for k,v in output["ARI_score"]["Regression"].items()}
data["TabNet"] = {k: list(v.values()) for k,v in output["ARI_score"]["TabNet"].items()}

fig, ax = plt.subplots(figsize = (8,5))

plt.axhline(y=output['ARI_score']['orig_data'], color='r', linestyle='-')

if variable_hyperparams:
    plt.axhline(y=[np.median(x) for x in data["Mean_substitution"].values()], color='g', linestyle='-', linewidth=2.5)
    plt.axhline(y=[np.median(x) for x in data["Regression"].values()], color='b', linestyle='--', linewidth=2.5)
else:
    ax.errorbar(x = list(data["Mean_substitution"].keys()), y = [np.median(x) for x in data["Mean_substitution"].values()], yerr = [np.std(x) for x in data["Mean_substitution"].values()], elinewidth=1, ecolor='g', linestyle='-', color = 'g', linewidth=2.5, fmt='o', capsize=10)
    ax.errorbar(x = list(data["Regression"].keys()), y = [np.median(x) for x in data["Regression"].values()], yerr = [np.std(x) for x in data["Regression"].values()], elinewidth=1,linestyle='--',  ecolor='b', color = 'b', linewidth=2.5, fmt='o', capsize=10)

ax.errorbar(x = list(data["TabNet"].keys()), y = [np.median(x) for x in data["TabNet"].values()], yerr = [np.std(x) for x in data["TabNet"].values()], elinewidth=1,linestyle='-', ecolor='m', color = 'm', linewidth=2.5, fmt='o', capsize=10)

plt.xlabel(config["general"]["experiment_variable"])
plt.ylabel("ARI Score")
plt.title(f"ARI Score (+ st. dev.)")
plt.legend(['Original', 'Mean_substitution', 'Regression', 'TabNet'],fontsize=10, loc=(0.68, 0.05))

if save_output:
    plt.savefig(os.path.join(plots_path, "5_ARI-score.png"), **config["plots"])

plt.show()

# %% [markdown]
# ### RQ 3: Decision Tree
# Train decision tree on predicted data (missing values) only. This will reflect the predictions of the model.

# %%
from sklearn import tree

X_dt = X_reconstr["TabNet"][str(best_experiment_value)][best_run][X_mv[best_experiment_value][best_run][experiment_feature].isna()]
y_dt = X_dt[experiment_feature]
X_dt = X_dt.drop(experiment_feature, axis=1)

tree_Regressor = tree.DecisionTreeRegressor()
dt = tree_Regressor.fit(X_dt, y_dt)

# %%
plt.figure(figsize=(30,20))
dt_plot = tree.plot_tree(dt, fontsize=10)

# %% [markdown]
# ### Save Output

# %%
if save_output:
    # save output file
    with open(output_path, "w") as f:
                toml.dump(output, f)

    # save notebook
    shutil.copy2(nb_name, experiment_path)
    
if save_output or save_models:
    config[experiment_dict_key][config["general"]["experiment_variable"]] = experiment_variable_values
    with open(config_path, "w") as f:
        toml.dump(config, f)

# %% [markdown]
# ## 6. Old Code

# %% [markdown]
# ## Distribution of KL Divergence
# non-symmetric, here: punishes outliers heavily

# %% [markdown]
# d_orig = X[experiment_feature]
# d_tab = X_reconstr["TabNet"]['0.25'][2][experiment_feature]
# d_heu = X_reconstr["Heuristic"][0.2][2][experiment_feature]
# min_val = min(min(d_orig), min(d_tab))
# max_val = max(max(d_orig), max(d_tab))
#
# distr_tab = d_tab.plot.kde(ind=list(np.linspace(min_val,max_val,100)), color="m", label="TabNet",legend=True).get_lines()[0].get_ydata()
# distr_tab /= sum(distr_tab)
# distr_true = d_orig.plot.kde(ind=list(np.linspace(min_val,max_val,100)), color="gray", label="Original Data",legend=True).get_lines()[1].get_ydata()
# distr_true /= sum(distr_true)
# distr_heu = d_heu.plot.kde(ind=list(np.linspace(min_val,max_val,100)), color="g", title="Probability density functions", label="Heuristic",legend=True).get_lines()[2].get_ydata()
# distr_heu /= sum(distr_heu)
# plt.text(5.2, .55, f"KL Divergence\nD (TabNet || Original Data)\n{round(kl_divergence(d_tab, d_orig),4)}\nD (Heuristic || Original Data)\n{round(kl_divergence(d_heu, d_orig),4)}", fontsize = 12, horizontalalignment="right")
# if save_output:
#     plt.savefig(os.path.join(plots_path, "problem_KL-divergence.png"), **config["plots"], bbox_inches="tight")
