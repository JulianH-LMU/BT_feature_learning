# %% [markdown]
# ## Change Log
# - Base pipeline implementing the concept for RQ1 and RQ2
# - Missing config parameters based on input file
# - Missing output file with experiment results

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import random
import math

import sys
import os
sys.path.append(os.getcwd() + "/pytorch_tabnet/")

from sklearn.cluster import DBSCAN

# %% [markdown]
# ## 0. Configuration Parameters
# Customizing constants for the run(s).

# %%
# config
np.random.seed(23452346)

# percentage of features that used to predict missing values (features will be randomly chosen)
pred_features = 100

# number of prediction runs performed with the randomly chosen features
runs = 2

# DBSCAN hyperparameters
eps=3
min_samples=5

# %% [markdown]
# ## 1. Datasets
#
# ### 1.0. Create or load dataset
# As of now, only a toy dataset is used (3 features with 3 clusters centered around different points).

# %%
from sklearn.datasets import make_blobs

features_arr, clusters_arr = make_blobs(n_samples=[50, 100, 50],
                                centers=[[1, 5, 1], [7, 12, 9], [10, 2, 5]],
                                n_features=3,
                                cluster_std=1.5, )

# %% [markdown]
# ### 1.1. plot data

# %%
# plot dataset
# %matplotlib notebook
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(projection='3d')
ax.scatter(features_arr[:, 0], features_arr[:, 1], features_arr[:, 2], c=clusters_arr)
plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### 1.2. Create missing data
# Create a specified amount of missing values in the given feature columns (for complete datasets).

# %%
# name feature and cluster (ground truth) columns
features = pd.DataFrame(features_arr, columns=[f"F{x + 1}" for x in range(features_arr.shape[1])])
clusters = pd.DataFrame(clusters_arr, columns=["C"])

# create missing values in feature column(s)
mv_percent = [0, 15, 10]  # percentages of missing values created in the feature columns
mv_config = {feature:mv_ratio for feature,mv_ratio in zip(list(features.columns), mv_percent)}
features_mv = features.copy()

for f, mv in mv_config.items():
    features_mv[f] = features_mv[f].mask(np.random.random(features.shape[0]) < mv / 100)

# %%
import missingno as msno
# %matplotlib inline
# plot missing values
msno.matrix(features_mv)
plt.show()

# %% [markdown]
# ### 1.3. Initial Clustering (without missing values)
# Use the cluster algorithm on dataset without missing values.\
# Get cluster means for loss function input.

# %%
dbscan_orig = DBSCAN(eps=eps, min_samples=min_samples).fit(features)
clusters_orig = dbscan_orig.labels_

# %%
# plot clustering
# %matplotlib notebook
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(projection='3d')
ax.scatter(features.iloc[:, 0], features.iloc[:, 1], features.iloc[:, 2], c=clusters_orig)
plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# get cluster means
complete_data = features.copy()
complete_data["C"] = clusters_orig
cluster_means = complete_data.groupby("C").agg("mean")

# %% [markdown]
# ## 2. Filling Strategies
#
#
# **custom-loss**\
# The loss function for the model fitting shall be customized, depending on the goal to improve cluster perforamnce. The custom loss is divided into 2 separate losses
#
# 1. **Reconstruction Loss**\
# Classic loss function, such as RMSE.
# 2. **Cluster-Mean Loss**\
# The distance to the nearest cluster mean shall be minimized.
#
# The chosen approach to implement the cluster-mean loss is as follows:\
# **Adapt the loss function** to calculate a distance to each cluster. The minimum distance (to the nearest cluster) will be used as a cluster-mean-loss. Minimizing this loss should result in the data point moving closer to the nearest cluster mean.\
# Potential Problem: loss functions currently work with y_true (true values) and y_score (predicted values). Calculating the distance would require all features. Calculating only the 1 dimensional distance will result in missing values being put into wrong clusters - depending on the first estimate.

# %%
# define custom loss function: extend L2-loss by cluster-mean-loss

from pytorch_tabnet.metrics import Metric
from sklearn.metrics import mean_squared_error

class custom_loss(Metric):

    def __init__(self):
        self._name = "custom_loss"
        self._maximize = False

    def __call__(self, y_true, y_score, cluster_means, target_feature):
        rmse = np.sqrt(mean_squared_error(y_true, y_score))
        cml = self.cluster_mean_loss(cluster_means, y_score, target_feature)
        custom_loss = cml + rmse
        return custom_loss
    
    # calculate sum of distances to the closest cluster mean
    def cluster_mean_loss(self, cluster_means, y_score, target_feature):

        dist = pd.DataFrame(y_score, columns=[target_feature])
        
        # calculate distances to each cluster and select the closest one
        for feature, cluster in cluster_means.iterrows():
            dist[f"D{feature}"] = abs(dist[target_feature] - cluster[target_feature])
            
        dist = dist.drop(target_feature,axis=1)
        min_dist = dist.assign(min_dist=lambda d: d.min(1))["min_dist"]
        return sum(abs(min_dist))

# %% [markdown]
# Fill missing values (here with TabNet).
#
# **Approach 1:**\
# For each feature that contains missing values, use all rows with complete other features as train set and predict missing values of the feature.\
# &rarr; Problem: lots of models, especially for high-dimensional datasets.
# Also problem, if more than one feature is missing values. &rarr; see Approach 2
#
# **Approach 2:**\
# Mask missing values as -1 (or some other value) and fit a model predicting each feature just like in approach 1.\
# &rarr; one model for each feature containing missing values.\
# Possible adaption: use predicted values to predict subsequent values (instead of using -1)

# %%
from pytorch_tabnet.tab_model import TabNetRegressor
from sklearn.model_selection import train_test_split

features_to_predict = features_mv.columns[features_mv.isnull().any()]
models = []
features_reconstr = []
costs = {}

for run in range(runs):
    costs[run] = []
    for feature in features_to_predict:
        print(f"Run {run+1}, predicting {feature}")
        features_reconstr.append(features_mv.copy())

        # select % of features for prediction based on pred_features (e.g. 10% of randomly selected features)
        number_of_features = math.ceil((pred_features / 100) * (len(features_mv.columns)) - 1)
        features_mv_masked = features_mv.copy().drop(feature, axis=1).sample(n=number_of_features, axis='columns')
        selected_features = features_mv_masked.columns
        
        print(f"Predictions based on features {list(selected_features)}")
        
        # mask other columns' missing values as -1
        features_mv_masked[feature] = features_mv[feature]
        features_mv_masked[selected_features] = features_mv_masked[(selected_features)].fillna(-1)
        
        # separate complete rows as train data
        # separate column with missing values as target
        test_data = features_mv_masked[features_mv_masked[feature].isna()].drop(feature, axis=1).to_numpy()
        train_data = features_mv_masked[features_mv_masked[feature].notna()]
        train_features = train_data.drop(columns=feature).to_numpy()
        train_target = train_data[feature].to_numpy().reshape(-1,1)

        x_train, x_val, y_train, y_val = train_test_split(train_features, train_target, test_size=0.75)

        # create & train model
        model = TabNetRegressor(optimizer_fn=torch.optim.Adam,
                            optimizer_params=dict(lr=2e-2),
                            scheduler_params={"step_size": 5, "gamma": 0.9},
                            scheduler_fn=torch.optim.lr_scheduler.StepLR,
                            mask_type='entmax')

        model.fit(
            x_train, y_train,
            eval_set=[(x_val, y_val)],
            eval_metric=['custom_loss'],
            max_epochs=300, patience=20,
            cluster_means=cluster_means,
            target_feature=feature,
        )
        
        # add costs to dict
        costs[run].append(model.best_cost)
        
        # add model to list
        models.append(model)

        # fill missing values with model predictions
        features_reconstr[run].loc[features_reconstr[run][feature].isna(),feature] = [x[0] for x in models[len(models)-1].predict(test_data)]
# Out:
# Run 1, predicting F2
# Predictions based on features ['F1', 'F3']
# Device used : cpu
# epoch 0  | loss: 35.55313| val_0_custom_loss: 6273.48068|  0:00:00s
# epoch 1  | loss: 23.38431| val_0_custom_loss: 3420.12589|  0:00:00s
# epoch 2  | loss: 13.08827| val_0_custom_loss: 2957.1468|  0:00:00s
# epoch 3  | loss: 8.11243 | val_0_custom_loss: 3527.69084|  0:00:00s
# epoch 4  | loss: 5.66566 | val_0_custom_loss: 3289.71263|  0:00:00s
# epoch 5  | loss: 3.25343 | val_0_custom_loss: 2783.83615|  0:00:00s
# epoch 6  | loss: 2.39589 | val_0_custom_loss: 2207.83751|  0:00:00s
# epoch 7  | loss: 2.14611 | val_0_custom_loss: 1596.866|  0:00:00s
# epoch 8  | loss: 2.19361 | val_0_custom_loss: 1161.26857|  0:00:00s
# epoch 9  | loss: 2.08587 | val_0_custom_loss: 876.57591|  0:00:00s
# epoch 10 | loss: 1.85352 | val_0_custom_loss: 576.61717|  0:00:00s
# epoch 11 | loss: 1.60777 | val_0_custom_loss: 387.86883|  0:00:00s
# epoch 12 | loss: 1.51422 | val_0_custom_loss: 366.34911|  0:00:00s
# epoch 13 | loss: 1.46445 | val_0_custom_loss: 333.47713|  0:00:00s
# epoch 14 | loss: 1.43585 | val_0_custom_loss: 402.21198|  0:00:00s
# epoch 15 | loss: 1.36838 | val_0_custom_loss: 575.43465|  0:00:00s
# epoch 16 | loss: 1.27281 | val_0_custom_loss: 792.98899|  0:00:00s
# epoch 17 | loss: 1.25984 | val_0_custom_loss: 905.93726|  0:00:00s
# epoch 18 | loss: 1.26334 | val_0_custom_loss: 982.18876|  0:00:00s
# epoch 19 | loss: 1.24293 | val_0_custom_loss: 1021.09224|  0:00:00s
# epoch 20 | loss: 1.18981 | val_0_custom_loss: 917.69327|  0:00:00s
# epoch 21 | loss: 1.15019 | val_0_custom_loss: 877.44169|  0:00:00s
# epoch 22 | loss: 1.14663 | val_0_custom_loss: 848.20336|  0:00:00s
# epoch 23 | loss: 1.13016 | val_0_custom_loss: 793.38673|  0:00:00s
# epoch 24 | loss: 1.08741 | val_0_custom_loss: 760.04364|  0:00:00s
# epoch 25 | loss: 1.08991 | val_0_custom_loss: 761.03914|  0:00:00s
# epoch 26 | loss: 1.05876 | val_0_custom_loss: 809.73517|  0:00:01s
# epoch 27 | loss: 1.03789 | val_0_custom_loss: 785.74314|  0:00:01s
# epoch 28 | loss: 1.02241 | val_0_custom_loss: 723.60544|  0:00:01s
# epoch 29 | loss: 0.99326 | val_0_custom_loss: 652.99648|  0:00:01s
# epoch 30 | loss: 1.0014  | val_0_custom_loss: 596.59717|  0:00:01s
# epoch 31 | loss: 0.97728 | val_0_custom_loss: 539.14714|  0:00:01s
# epoch 32 | loss: 0.94322 | val_0_custom_loss: 466.19406|  0:00:01s
# epoch 33 | loss: 0.92275 | val_0_custom_loss: 417.59138|  0:00:01s
#
# Early stopping occurred at epoch 33 with best_epoch = 13 and best_val_0_custom_loss = 333.47713
# Best weights from best epoch are automatically used!
# Run 1, predicting F3
# Predictions based on features ['F2', 'F1']
# Device used : cpu
# epoch 0  | loss: 28.50927| val_0_custom_loss: 7634.78879|  0:00:00s
# epoch 1  | loss: 23.22365| val_0_custom_loss: 6729.65339|  0:00:00s
# epoch 2  | loss: 14.05128| val_0_custom_loss: 6959.65727|  0:00:00s
# epoch 3  | loss: 8.44932 | val_0_custom_loss: 8805.26999|  0:00:00s
# epoch 4  | loss: 5.69616 | val_0_custom_loss: 9846.51247|  0:00:00s
# epoch 5  | loss: 3.90183 | val_0_custom_loss: 8761.29573|  0:00:00s
# epoch 6  | loss: 3.15478 | val_0_custom_loss: 7551.01145|  0:00:00s
# epoch 7  | loss: 2.51052 | val_0_custom_loss: 6425.63763|  0:00:00s
# epoch 8  | loss: 2.91546 | val_0_custom_loss: 5550.71901|  0:00:00s
# epoch 9  | loss: 2.45558 | val_0_custom_loss: 4853.30604|  0:00:00s
# epoch 10 | loss: 1.90177 | val_0_custom_loss: 4075.98249|  0:00:00s
# epoch 11 | loss: 1.88238 | val_0_custom_loss: 3495.44208|  0:00:00s
# epoch 12 | loss: 1.82394 | val_0_custom_loss: 3178.39277|  0:00:00s
# epoch 13 | loss: 1.76745 | val_0_custom_loss: 2824.68687|  0:00:00s
# epoch 14 | loss: 1.57754 | val_0_custom_loss: 2331.73778|  0:00:00s
# epoch 15 | loss: 1.51581 | val_0_custom_loss: 2011.05643|  0:00:00s
# epoch 16 | loss: 1.42921 | val_0_custom_loss: 1804.2509|  0:00:00s
# epoch 17 | loss: 1.35271 | val_0_custom_loss: 1739.40263|  0:00:00s
# epoch 18 | loss: 1.2761  | val_0_custom_loss: 1598.54473|  0:00:00s
# epoch 19 | loss: 1.21931 | val_0_custom_loss: 1441.93476|  0:00:00s
# epoch 20 | loss: 1.17746 | val_0_custom_loss: 1258.15914|  0:00:00s
# epoch 21 | loss: 1.12137 | val_0_custom_loss: 1070.14571|  0:00:00s
# epoch 22 | loss: 1.07671 | val_0_custom_loss: 896.29114|  0:00:01s
# epoch 23 | loss: 1.04158 | val_0_custom_loss: 703.63659|  0:00:01s
# epoch 24 | loss: 1.00511 | val_0_custom_loss: 569.99522|  0:00:01s
# epoch 25 | loss: 0.97309 | val_0_custom_loss: 512.38576|  0:00:01s
# epoch 26 | loss: 0.94878 | val_0_custom_loss: 457.59876|  0:00:01s
# epoch 27 | loss: 0.90516 | val_0_custom_loss: 399.81542|  0:00:01s
# epoch 28 | loss: 0.85945 | val_0_custom_loss: 355.91653|  0:00:01s
# epoch 29 | loss: 0.82398 | val_0_custom_loss: 295.33585|  0:00:01s
# epoch 30 | loss: 0.79554 | val_0_custom_loss: 216.32658|  0:00:01s
# epoch 31 | loss: 0.76086 | val_0_custom_loss: 168.94724|  0:00:01s
# epoch 32 | loss: 0.77246 | val_0_custom_loss: 132.01589|  0:00:01s
# epoch 33 | loss: 0.77198 | val_0_custom_loss: 107.24323|  0:00:01s
# epoch 34 | loss: 0.74057 | val_0_custom_loss: 102.64666|  0:00:01s
# epoch 35 | loss: 0.73693 | val_0_custom_loss: 109.72171|  0:00:01s
# epoch 36 | loss: 0.70137 | val_0_custom_loss: 125.50714|  0:00:01s
# epoch 37 | loss: 0.72802 | val_0_custom_loss: 135.96793|  0:00:01s
# epoch 38 | loss: 0.73791 | val_0_custom_loss: 144.29188|  0:00:01s
# epoch 39 | loss: 0.6735  | val_0_custom_loss: 149.11292|  0:00:01s
# epoch 40 | loss: 0.74829 | val_0_custom_loss: 144.43372|  0:00:01s
# epoch 41 | loss: 0.76828 | val_0_custom_loss: 136.25251|  0:00:01s
# epoch 42 | loss: 0.6682  | val_0_custom_loss: 125.66658|  0:00:01s
# epoch 43 | loss: 0.7513  | val_0_custom_loss: 118.87349|  0:00:01s
# epoch 44 | loss: 0.8248  | val_0_custom_loss: 115.90323|  0:00:02s
# epoch 45 | loss: 0.72975 | val_0_custom_loss: 111.7419|  0:00:02s
# epoch 46 | loss: 0.64713 | val_0_custom_loss: 108.8955|  0:00:02s
# epoch 47 | loss: 0.66571 | val_0_custom_loss: 107.79385|  0:00:02s
# epoch 48 | loss: 0.65492 | val_0_custom_loss: 108.59581|  0:00:02s
# epoch 49 | loss: 0.6198  | val_0_custom_loss: 108.47402|  0:00:02s
# epoch 50 | loss: 0.64026 | val_0_custom_loss: 109.05148|  0:00:02s
# epoch 51 | loss: 0.62308 | val_0_custom_loss: 109.1256|  0:00:02s
# epoch 52 | loss: 0.58728 | val_0_custom_loss: 107.23136|  0:00:02s
# epoch 53 | loss: 0.6053  | val_0_custom_loss: 106.53457|  0:00:02s
# epoch 54 | loss: 0.59176 | val_0_custom_loss: 106.5222|  0:00:02s
#
# Early stopping occurred at epoch 54 with best_epoch = 34 and best_val_0_custom_loss = 102.64666
# Best weights from best epoch are automatically used!
# Run 2, predicting F2
# Predictions based on features ['F3', 'F1']
# Device used : cpu
# epoch 0  | loss: 50.11642| val_0_custom_loss: 8204.88027|  0:00:00s
# epoch 1  | loss: 32.36793| val_0_custom_loss: 10997.57747|  0:00:00s
# epoch 2  | loss: 22.99987| val_0_custom_loss: 4274.98556|  0:00:00s
# epoch 3  | loss: 16.49858| val_0_custom_loss: 6495.34961|  0:00:00s
# epoch 4  | loss: 11.66131| val_0_custom_loss: 6437.02586|  0:00:00s
# epoch 5  | loss: 7.90733 | val_0_custom_loss: 7584.36645|  0:00:00s
# epoch 6  | loss: 8.3341  | val_0_custom_loss: 6649.12015|  0:00:00s
# epoch 7  | loss: 5.01324 | val_0_custom_loss: 4614.33398|  0:00:00s
# epoch 8  | loss: 4.37806 | val_0_custom_loss: 3033.65869|  0:00:00s
# epoch 9  | loss: 3.64747 | val_0_custom_loss: 2269.50175|  0:00:00s
# epoch 10 | loss: 3.52701 | val_0_custom_loss: 1657.41006|  0:00:00s
# epoch 11 | loss: 3.17132 | val_0_custom_loss: 1364.60524|  0:00:00s
# epoch 12 | loss: 3.1415  | val_0_custom_loss: 957.9466|  0:00:00s
# epoch 13 | loss: 2.90602 | val_0_custom_loss: 607.90628|  0:00:00s
# epoch 14 | loss: 2.56687 | val_0_custom_loss: 398.6301|  0:00:00s
# epoch 15 | loss: 2.43719 | val_0_custom_loss: 342.40291|  0:00:00s
# epoch 16 | loss: 2.53069 | val_0_custom_loss: 329.56895|  0:00:00s
# epoch 17 | loss: 2.37288 | val_0_custom_loss: 308.37854|  0:00:00s
# epoch 18 | loss: 2.24354 | val_0_custom_loss: 285.68264|  0:00:00s
# epoch 19 | loss: 2.12343 | val_0_custom_loss: 267.37359|  0:00:00s
# epoch 20 | loss: 2.09069 | val_0_custom_loss: 243.91882|  0:00:01s
# epoch 21 | loss: 2.04924 | val_0_custom_loss: 203.75979|  0:00:01s
# epoch 22 | loss: 2.00547 | val_0_custom_loss: 180.34035|  0:00:01s
# epoch 23 | loss: 1.94595 | val_0_custom_loss: 153.93852|  0:00:01s
# epoch 24 | loss: 1.89935 | val_0_custom_loss: 126.53707|  0:00:01s
# epoch 25 | loss: 1.85382 | val_0_custom_loss: 120.22508|  0:00:01s
# epoch 26 | loss: 1.83517 | val_0_custom_loss: 120.63633|  0:00:01s
# epoch 27 | loss: 1.78119 | val_0_custom_loss: 112.09311|  0:00:01s
# epoch 28 | loss: 1.73136 | val_0_custom_loss: 108.2836|  0:00:01s
# epoch 29 | loss: 1.70702 | val_0_custom_loss: 106.0549|  0:00:01s
# epoch 30 | loss: 1.7063  | val_0_custom_loss: 102.6114|  0:00:01s
# epoch 31 | loss: 1.6595  | val_0_custom_loss: 103.08091|  0:00:01s
# epoch 32 | loss: 1.60897 | val_0_custom_loss: 104.58821|  0:00:01s
# epoch 33 | loss: 1.57816 | val_0_custom_loss: 100.9562|  0:00:01s
# epoch 34 | loss: 1.57053 | val_0_custom_loss: 96.72746|  0:00:01s
# epoch 35 | loss: 1.52889 | val_0_custom_loss: 94.91344|  0:00:01s
# epoch 36 | loss: 1.45968 | val_0_custom_loss: 94.25316|  0:00:01s
# epoch 37 | loss: 1.4168  | val_0_custom_loss: 92.02858|  0:00:01s
# epoch 38 | loss: 1.39948 | val_0_custom_loss: 91.19713|  0:00:02s
# epoch 39 | loss: 1.36357 | val_0_custom_loss: 90.49177|  0:00:02s
# epoch 40 | loss: 1.31866 | val_0_custom_loss: 92.50226|  0:00:02s
# epoch 41 | loss: 1.3032  | val_0_custom_loss: 95.68278|  0:00:02s
# epoch 42 | loss: 1.27032 | val_0_custom_loss: 99.86494|  0:00:02s
# epoch 43 | loss: 1.21919 | val_0_custom_loss: 99.17286|  0:00:02s
# epoch 44 | loss: 1.21406 | val_0_custom_loss: 102.6163|  0:00:02s
# epoch 45 | loss: 1.13352 | val_0_custom_loss: 100.05754|  0:00:02s
# epoch 46 | loss: 1.16097 | val_0_custom_loss: 97.33668|  0:00:02s
# epoch 47 | loss: 1.11607 | val_0_custom_loss: 97.61989|  0:00:02s
# epoch 48 | loss: 1.08272 | val_0_custom_loss: 97.6362 |  0:00:02s
# epoch 49 | loss: 1.04796 | val_0_custom_loss: 97.84996|  0:00:02s
# epoch 50 | loss: 1.0246  | val_0_custom_loss: 100.90231|  0:00:02s
# epoch 51 | loss: 0.97187 | val_0_custom_loss: 103.24788|  0:00:02s
# epoch 52 | loss: 0.95029 | val_0_custom_loss: 103.25083|  0:00:02s
# epoch 53 | loss: 0.91811 | val_0_custom_loss: 109.32535|  0:00:02s
# epoch 54 | loss: 0.88993 | val_0_custom_loss: 110.12585|  0:00:02s
# epoch 55 | loss: 0.83138 | val_0_custom_loss: 105.86814|  0:00:02s
# epoch 56 | loss: 0.83151 | val_0_custom_loss: 108.87901|  0:00:02s
# epoch 57 | loss: 0.79808 | val_0_custom_loss: 112.6569|  0:00:02s
# epoch 58 | loss: 0.79324 | val_0_custom_loss: 115.67469|  0:00:02s
# epoch 59 | loss: 0.75729 | val_0_custom_loss: 116.06779|  0:00:02s
#
# Early stopping occurred at epoch 59 with best_epoch = 39 and best_val_0_custom_loss = 90.49177
# Best weights from best epoch are automatically used!
# Run 2, predicting F3
# Predictions based on features ['F1', 'F2']
# Device used : cpu
# epoch 0  | loss: 31.96283| val_0_custom_loss: 5056.11122|  0:00:00s
# epoch 1  | loss: 19.78412| val_0_custom_loss: 6699.37153|  0:00:00s
# epoch 2  | loss: 14.34132| val_0_custom_loss: 5955.36199|  0:00:00s
# epoch 3  | loss: 9.56898 | val_0_custom_loss: 2660.70166|  0:00:00s
# epoch 4  | loss: 6.28259 | val_0_custom_loss: 2676.41105|  0:00:00s
# epoch 5  | loss: 5.13699 | val_0_custom_loss: 2549.15704|  0:00:00s
# epoch 6  | loss: 4.59522 | val_0_custom_loss: 2446.10723|  0:00:00s
# epoch 7  | loss: 3.85566 | val_0_custom_loss: 2348.57479|  0:00:00s
# epoch 8  | loss: 3.25236 | val_0_custom_loss: 2238.0057|  0:00:00s
# epoch 9  | loss: 3.00049 | val_0_custom_loss: 2126.40265|  0:00:00s
# epoch 10 | loss: 2.76293 | val_0_custom_loss: 1991.99948|  0:00:00s
# epoch 11 | loss: 2.49588 | val_0_custom_loss: 1851.06163|  0:00:00s
# epoch 12 | loss: 2.30131 | val_0_custom_loss: 1687.70146|  0:00:00s
# epoch 13 | loss: 2.25846 | val_0_custom_loss: 1519.63192|  0:00:00s
# epoch 14 | loss: 2.15308 | val_0_custom_loss: 1374.05158|  0:00:00s
# epoch 15 | loss: 2.02346 | val_0_custom_loss: 1291.07584|  0:00:00s
# epoch 16 | loss: 1.94081 | val_0_custom_loss: 1298.66883|  0:00:01s
# epoch 17 | loss: 1.8168  | val_0_custom_loss: 1382.61318|  0:00:01s
# epoch 18 | loss: 1.78973 | val_0_custom_loss: 1458.73918|  0:00:01s
# epoch 19 | loss: 1.70493 | val_0_custom_loss: 1558.63995|  0:00:01s
# epoch 20 | loss: 1.69513 | val_0_custom_loss: 1626.05856|  0:00:01s
# epoch 21 | loss: 1.56698 | val_0_custom_loss: 1658.68364|  0:00:01s
# epoch 22 | loss: 1.59532 | val_0_custom_loss: 1663.71557|  0:00:01s
# epoch 23 | loss: 1.59647 | val_0_custom_loss: 1647.28128|  0:00:01s
# epoch 24 | loss: 1.47184 | val_0_custom_loss: 1603.23311|  0:00:01s
# epoch 25 | loss: 1.41014 | val_0_custom_loss: 1536.11508|  0:00:01s
# epoch 26 | loss: 1.40971 | val_0_custom_loss: 1495.91406|  0:00:01s
# epoch 27 | loss: 1.32139 | val_0_custom_loss: 1452.8709|  0:00:01s
# epoch 28 | loss: 1.26615 | val_0_custom_loss: 1392.4594|  0:00:01s
# epoch 29 | loss: 1.24083 | val_0_custom_loss: 1323.43889|  0:00:01s
# epoch 30 | loss: 1.15193 | val_0_custom_loss: 1259.38888|  0:00:01s
# epoch 31 | loss: 1.15141 | val_0_custom_loss: 1222.3337|  0:00:01s
# epoch 32 | loss: 1.12428 | val_0_custom_loss: 1175.74042|  0:00:01s
# epoch 33 | loss: 1.06649 | val_0_custom_loss: 1153.77611|  0:00:01s
# epoch 34 | loss: 1.04591 | val_0_custom_loss: 1103.75293|  0:00:02s
# epoch 35 | loss: 1.0214  | val_0_custom_loss: 1085.33134|  0:00:02s
# epoch 36 | loss: 0.96448 | val_0_custom_loss: 1055.40802|  0:00:02s
# epoch 37 | loss: 0.94401 | val_0_custom_loss: 996.4514|  0:00:02s
# epoch 38 | loss: 0.92449 | val_0_custom_loss: 971.85669|  0:00:02s
# epoch 39 | loss: 0.89453 | val_0_custom_loss: 955.11671|  0:00:02s
# epoch 40 | loss: 0.84683 | val_0_custom_loss: 945.23719|  0:00:02s
# epoch 41 | loss: 0.84065 | val_0_custom_loss: 930.20036|  0:00:02s
# epoch 42 | loss: 0.81834 | val_0_custom_loss: 907.96338|  0:00:02s
# epoch 43 | loss: 0.81617 | val_0_custom_loss: 900.72146|  0:00:02s
# epoch 44 | loss: 0.79737 | val_0_custom_loss: 884.18197|  0:00:02s
# epoch 45 | loss: 0.76759 | val_0_custom_loss: 847.96876|  0:00:02s
# epoch 46 | loss: 0.75524 | val_0_custom_loss: 812.65557|  0:00:02s
# epoch 47 | loss: 0.73599 | val_0_custom_loss: 788.54548|  0:00:02s
# epoch 48 | loss: 0.73041 | val_0_custom_loss: 756.57597|  0:00:02s
# epoch 49 | loss: 0.71414 | val_0_custom_loss: 723.0951|  0:00:02s
# epoch 50 | loss: 0.69772 | val_0_custom_loss: 699.98559|  0:00:03s
# epoch 51 | loss: 0.677   | val_0_custom_loss: 689.24842|  0:00:03s
# epoch 52 | loss: 0.67898 | val_0_custom_loss: 673.97963|  0:00:03s
# epoch 53 | loss: 0.66093 | val_0_custom_loss: 660.90124|  0:00:03s
# epoch 54 | loss: 0.65216 | val_0_custom_loss: 643.95652|  0:00:03s
# epoch 55 | loss: 0.64478 | val_0_custom_loss: 631.34578|  0:00:03s
# epoch 56 | loss: 0.61551 | val_0_custom_loss: 611.92212|  0:00:03s
# epoch 57 | loss: 0.61568 | val_0_custom_loss: 590.41434|  0:00:03s
# epoch 58 | loss: 0.59813 | val_0_custom_loss: 571.17906|  0:00:03s
# epoch 59 | loss: 0.58841 | val_0_custom_loss: 561.39845|  0:00:03s
# epoch 60 | loss: 0.58324 | val_0_custom_loss: 554.7048|  0:00:03s
# epoch 61 | loss: 0.55456 | val_0_custom_loss: 549.6034|  0:00:03s
# epoch 62 | loss: 0.54633 | val_0_custom_loss: 541.37708|  0:00:03s
# epoch 63 | loss: 0.53159 | val_0_custom_loss: 531.18632|  0:00:03s
# epoch 64 | loss: 0.52376 | val_0_custom_loss: 519.82795|  0:00:03s
# epoch 65 | loss: 0.51508 | val_0_custom_loss: 506.89  |  0:00:03s
# epoch 66 | loss: 0.49779 | val_0_custom_loss: 495.78385|  0:00:03s
# epoch 67 | loss: 0.49221 | val_0_custom_loss: 487.26563|  0:00:04s
# epoch 68 | loss: 0.47611 | val_0_custom_loss: 482.25238|  0:00:04s
# epoch 69 | loss: 0.46493 | val_0_custom_loss: 475.65849|  0:00:04s
# epoch 70 | loss: 0.45814 | val_0_custom_loss: 468.7239|  0:00:04s
# epoch 71 | loss: 0.4451  | val_0_custom_loss: 467.2961|  0:00:04s
# epoch 72 | loss: 0.43492 | val_0_custom_loss: 464.22803|  0:00:04s
# epoch 73 | loss: 0.42451 | val_0_custom_loss: 458.05952|  0:00:04s
# epoch 74 | loss: 0.41535 | val_0_custom_loss: 449.25638|  0:00:04s
# epoch 75 | loss: 0.4045  | val_0_custom_loss: 439.90169|  0:00:04s
# epoch 76 | loss: 0.40288 | val_0_custom_loss: 439.39457|  0:00:04s
# epoch 77 | loss: 0.3983  | val_0_custom_loss: 432.37613|  0:00:04s
# epoch 78 | loss: 0.3838  | val_0_custom_loss: 422.77938|  0:00:04s
# epoch 79 | loss: 0.38241 | val_0_custom_loss: 418.30088|  0:00:04s
# epoch 80 | loss: 0.38662 | val_0_custom_loss: 409.70434|  0:00:04s
# epoch 81 | loss: 0.37151 | val_0_custom_loss: 403.06622|  0:00:04s
# epoch 82 | loss: 0.38659 | val_0_custom_loss: 401.79849|  0:00:04s
# epoch 83 | loss: 0.36204 | val_0_custom_loss: 401.25327|  0:00:05s
# epoch 84 | loss: 0.40987 | val_0_custom_loss: 394.80995|  0:00:05s
# epoch 85 | loss: 0.40583 | val_0_custom_loss: 387.06161|  0:00:05s
# epoch 86 | loss: 0.34605 | val_0_custom_loss: 378.35191|  0:00:05s
# epoch 87 | loss: 0.39616 | val_0_custom_loss: 369.38977|  0:00:05s
# epoch 88 | loss: 0.39673 | val_0_custom_loss: 367.38026|  0:00:05s
# epoch 89 | loss: 0.35924 | val_0_custom_loss: 363.44144|  0:00:05s
# epoch 90 | loss: 0.38592 | val_0_custom_loss: 357.90806|  0:00:05s
# epoch 91 | loss: 0.3731  | val_0_custom_loss: 351.35946|  0:00:05s
# epoch 92 | loss: 0.33483 | val_0_custom_loss: 350.89347|  0:00:05s
# epoch 93 | loss: 0.35263 | val_0_custom_loss: 354.50401|  0:00:05s
# epoch 94 | loss: 0.34403 | val_0_custom_loss: 359.22282|  0:00:05s
# epoch 95 | loss: 0.33742 | val_0_custom_loss: 355.80895|  0:00:05s
# epoch 96 | loss: 0.33087 | val_0_custom_loss: 349.07189|  0:00:05s
# epoch 97 | loss: 0.32215 | val_0_custom_loss: 345.84986|  0:00:06s
# epoch 98 | loss: 0.31386 | val_0_custom_loss: 345.64895|  0:00:06s
# epoch 99 | loss: 0.32087 | val_0_custom_loss: 343.07083|  0:00:06s
# epoch 100| loss: 0.32147 | val_0_custom_loss: 338.2557|  0:00:06s
# epoch 101| loss: 0.31506 | val_0_custom_loss: 336.13333|  0:00:06s
# epoch 102| loss: 0.31047 | val_0_custom_loss: 336.5423|  0:00:06s
# epoch 103| loss: 0.30561 | val_0_custom_loss: 336.85633|  0:00:06s
# epoch 104| loss: 0.30535 | val_0_custom_loss: 336.07694|  0:00:06s
# epoch 105| loss: 0.29892 | val_0_custom_loss: 334.77869|  0:00:06s
# epoch 106| loss: 0.29834 | val_0_custom_loss: 333.47228|  0:00:06s
# epoch 107| loss: 0.29127 | val_0_custom_loss: 329.15508|  0:00:06s
# epoch 108| loss: 0.28945 | val_0_custom_loss: 326.96694|  0:00:06s
# epoch 109| loss: 0.28809 | val_0_custom_loss: 328.57211|  0:00:06s
# epoch 110| loss: 0.28585 | val_0_custom_loss: 329.45174|  0:00:06s
# epoch 111| loss: 0.28169 | val_0_custom_loss: 330.52758|  0:00:06s
# epoch 112| loss: 0.27837 | val_0_custom_loss: 331.2676|  0:00:06s
# epoch 113| loss: 0.27792 | val_0_custom_loss: 329.94585|  0:00:06s
# epoch 114| loss: 0.27368 | val_0_custom_loss: 327.82387|  0:00:06s
# epoch 115| loss: 0.27501 | val_0_custom_loss: 326.21637|  0:00:06s
# epoch 116| loss: 0.26954 | val_0_custom_loss: 324.18932|  0:00:06s
# epoch 117| loss: 0.2697  | val_0_custom_loss: 320.93612|  0:00:06s
# epoch 118| loss: 0.26657 | val_0_custom_loss: 317.76241|  0:00:06s
# epoch 119| loss: 0.26738 | val_0_custom_loss: 316.50683|  0:00:07s
# epoch 120| loss: 0.26108 | val_0_custom_loss: 316.58195|  0:00:07s
# epoch 121| loss: 0.26551 | val_0_custom_loss: 316.29435|  0:00:07s
# epoch 122| loss: 0.26453 | val_0_custom_loss: 315.84754|  0:00:07s
# epoch 123| loss: 0.25454 | val_0_custom_loss: 315.14199|  0:00:07s
# epoch 124| loss: 0.25562 | val_0_custom_loss: 313.6363|  0:00:07s
# epoch 125| loss: 0.25366 | val_0_custom_loss: 311.47187|  0:00:07s
# epoch 126| loss: 0.25053 | val_0_custom_loss: 308.84492|  0:00:07s
# epoch 127| loss: 0.25022 | val_0_custom_loss: 306.65384|  0:00:07s
# epoch 128| loss: 0.24953 | val_0_custom_loss: 305.19863|  0:00:07s
# epoch 129| loss: 0.24693 | val_0_custom_loss: 305.09305|  0:00:07s
# epoch 130| loss: 0.24558 | val_0_custom_loss: 304.24692|  0:00:07s
# epoch 131| loss: 0.24424 | val_0_custom_loss: 302.42069|  0:00:07s
# epoch 132| loss: 0.24369 | val_0_custom_loss: 300.20389|  0:00:07s
# epoch 133| loss: 0.24134 | val_0_custom_loss: 298.67907|  0:00:08s
# epoch 134| loss: 0.24063 | val_0_custom_loss: 297.69965|  0:00:08s
# epoch 135| loss: 0.24038 | val_0_custom_loss: 296.82732|  0:00:08s
# epoch 136| loss: 0.23786 | val_0_custom_loss: 296.03863|  0:00:08s
# epoch 137| loss: 0.23935 | val_0_custom_loss: 295.40338|  0:00:08s
# epoch 138| loss: 0.23614 | val_0_custom_loss: 295.19589|  0:00:08s
# epoch 139| loss: 0.24092 | val_0_custom_loss: 294.54438|  0:00:08s
# epoch 140| loss: 0.2419  | val_0_custom_loss: 293.05124|  0:00:08s
# epoch 141| loss: 0.23406 | val_0_custom_loss: 291.29752|  0:00:08s
# epoch 142| loss: 0.24107 | val_0_custom_loss: 290.02051|  0:00:08s
# epoch 143| loss: 0.24671 | val_0_custom_loss: 289.34231|  0:00:08s
# epoch 144| loss: 0.23726 | val_0_custom_loss: 288.81567|  0:00:08s
# epoch 145| loss: 0.23218 | val_0_custom_loss: 287.92542|  0:00:08s
# epoch 146| loss: 0.23283 | val_0_custom_loss: 286.70908|  0:00:08s
# epoch 147| loss: 0.23013 | val_0_custom_loss: 285.41333|  0:00:08s
# epoch 148| loss: 0.23183 | val_0_custom_loss: 284.2997|  0:00:08s
# epoch 149| loss: 0.22959 | val_0_custom_loss: 283.07693|  0:00:08s
# epoch 150| loss: 0.22921 | val_0_custom_loss: 282.0387|  0:00:08s
# epoch 151| loss: 0.22853 | val_0_custom_loss: 281.01207|  0:00:09s
# epoch 152| loss: 0.22667 | val_0_custom_loss: 280.19167|  0:00:09s
# epoch 153| loss: 0.22649 | val_0_custom_loss: 279.1737|  0:00:09s
# epoch 154| loss: 0.22645 | val_0_custom_loss: 277.6796|  0:00:09s
# epoch 155| loss: 0.22584 | val_0_custom_loss: 276.04059|  0:00:09s
# epoch 156| loss: 0.22526 | val_0_custom_loss: 274.71897|  0:00:09s
# epoch 157| loss: 0.22534 | val_0_custom_loss: 273.58571|  0:00:09s
# epoch 158| loss: 0.22355 | val_0_custom_loss: 272.30736|  0:00:09s
# epoch 159| loss: 0.22361 | val_0_custom_loss: 270.68151|  0:00:09s
# epoch 160| loss: 0.22274 | val_0_custom_loss: 269.03739|  0:00:09s
# epoch 161| loss: 0.22258 | val_0_custom_loss: 267.45809|  0:00:09s
# epoch 162| loss: 0.22189 | val_0_custom_loss: 265.92295|  0:00:09s
# epoch 163| loss: 0.2217  | val_0_custom_loss: 264.26889|  0:00:09s
# epoch 164| loss: 0.22131 | val_0_custom_loss: 262.85062|  0:00:09s
# epoch 165| loss: 0.22069 | val_0_custom_loss: 261.80951|  0:00:09s
# epoch 166| loss: 0.22049 | val_0_custom_loss: 260.58687|  0:00:09s
# epoch 167| loss: 0.22001 | val_0_custom_loss: 259.27039|  0:00:09s
# epoch 168| loss: 0.21974 | val_0_custom_loss: 258.0826|  0:00:10s
# epoch 169| loss: 0.21933 | val_0_custom_loss: 256.99634|  0:00:10s
# epoch 170| loss: 0.21895 | val_0_custom_loss: 255.69836|  0:00:10s
# epoch 171| loss: 0.21864 | val_0_custom_loss: 254.43607|  0:00:10s
# epoch 172| loss: 0.2183  | val_0_custom_loss: 253.24184|  0:00:10s
# epoch 173| loss: 0.21784 | val_0_custom_loss: 251.99513|  0:00:10s
# epoch 174| loss: 0.21755 | val_0_custom_loss: 250.96363|  0:00:10s
# epoch 175| loss: 0.21721 | val_0_custom_loss: 250.30881|  0:00:10s
# epoch 176| loss: 0.217   | val_0_custom_loss: 250.02733|  0:00:10s
# epoch 177| loss: 0.21674 | val_0_custom_loss: 249.87796|  0:00:10s
# epoch 178| loss: 0.21643 | val_0_custom_loss: 249.7474|  0:00:10s
# epoch 179| loss: 0.21626 | val_0_custom_loss: 249.30712|  0:00:10s
# epoch 180| loss: 0.21591 | val_0_custom_loss: 248.76146|  0:00:10s
# epoch 181| loss: 0.21577 | val_0_custom_loss: 248.23612|  0:00:10s
# epoch 182| loss: 0.21543 | val_0_custom_loss: 247.53843|  0:00:10s
# epoch 183| loss: 0.2153  | val_0_custom_loss: 246.45716|  0:00:10s
# epoch 184| loss: 0.21506 | val_0_custom_loss: 245.47655|  0:00:10s
# epoch 185| loss: 0.21483 | val_0_custom_loss: 244.82735|  0:00:10s
# epoch 186| loss: 0.21459 | val_0_custom_loss: 244.34844|  0:00:10s
# epoch 187| loss: 0.21444 | val_0_custom_loss: 243.84438|  0:00:11s
# epoch 188| loss: 0.2142  | val_0_custom_loss: 243.7032|  0:00:11s
# epoch 189| loss: 0.21402 | val_0_custom_loss: 243.34985|  0:00:11s
# epoch 190| loss: 0.21384 | val_0_custom_loss: 242.98966|  0:00:11s
# epoch 191| loss: 0.21369 | val_0_custom_loss: 242.50929|  0:00:11s
# epoch 192| loss: 0.2135  | val_0_custom_loss: 242.13767|  0:00:11s
# epoch 193| loss: 0.21333 | val_0_custom_loss: 241.87405|  0:00:11s
# epoch 194| loss: 0.21315 | val_0_custom_loss: 241.60702|  0:00:11s
# epoch 195| loss: 0.213   | val_0_custom_loss: 241.29271|  0:00:11s
# epoch 196| loss: 0.21287 | val_0_custom_loss: 240.96747|  0:00:11s
# epoch 197| loss: 0.21267 | val_0_custom_loss: 240.65335|  0:00:11s
# epoch 198| loss: 0.21252 | val_0_custom_loss: 240.2239|  0:00:11s
# epoch 199| loss: 0.21236 | val_0_custom_loss: 239.6998|  0:00:11s
# epoch 200| loss: 0.21223 | val_0_custom_loss: 238.98199|  0:00:11s
# epoch 201| loss: 0.21207 | val_0_custom_loss: 238.12089|  0:00:11s
# epoch 202| loss: 0.21194 | val_0_custom_loss: 237.51423|  0:00:11s
# epoch 203| loss: 0.21182 | val_0_custom_loss: 237.15029|  0:00:11s
# epoch 204| loss: 0.2117  | val_0_custom_loss: 236.45654|  0:00:11s
# epoch 205| loss: 0.21157 | val_0_custom_loss: 235.76437|  0:00:12s
# epoch 206| loss: 0.21145 | val_0_custom_loss: 234.88994|  0:00:12s
# epoch 207| loss: 0.21136 | val_0_custom_loss: 233.90419|  0:00:12s
# epoch 208| loss: 0.21123 | val_0_custom_loss: 232.9094|  0:00:12s
# epoch 209| loss: 0.21111 | val_0_custom_loss: 232.03683|  0:00:12s
# epoch 210| loss: 0.21102 | val_0_custom_loss: 231.37694|  0:00:12s
# epoch 211| loss: 0.21093 | val_0_custom_loss: 230.79393|  0:00:12s
# epoch 212| loss: 0.21079 | val_0_custom_loss: 230.19878|  0:00:12s
# epoch 213| loss: 0.21071 | val_0_custom_loss: 229.60816|  0:00:12s
# epoch 214| loss: 0.21062 | val_0_custom_loss: 229.10922|  0:00:12s
# epoch 215| loss: 0.2105  | val_0_custom_loss: 228.57531|  0:00:12s
# epoch 216| loss: 0.21043 | val_0_custom_loss: 228.05879|  0:00:12s
# epoch 217| loss: 0.21036 | val_0_custom_loss: 227.84008|  0:00:12s
# epoch 218| loss: 0.21027 | val_0_custom_loss: 227.46648|  0:00:12s
# epoch 219| loss: 0.21016 | val_0_custom_loss: 226.987 |  0:00:12s
# epoch 220| loss: 0.21011 | val_0_custom_loss: 226.4107|  0:00:12s
# epoch 221| loss: 0.21005 | val_0_custom_loss: 225.91443|  0:00:13s
# epoch 222| loss: 0.20994 | val_0_custom_loss: 225.69434|  0:00:13s
# epoch 223| loss: 0.20986 | val_0_custom_loss: 225.32273|  0:00:13s
# epoch 224| loss: 0.2098  | val_0_custom_loss: 224.89527|  0:00:13s
# epoch 225| loss: 0.20974 | val_0_custom_loss: 224.41471|  0:00:13s
# epoch 226| loss: 0.20965 | val_0_custom_loss: 224.24848|  0:00:13s
# epoch 227| loss: 0.20957 | val_0_custom_loss: 224.03489|  0:00:13s
# epoch 228| loss: 0.20951 | val_0_custom_loss: 223.7272|  0:00:13s
# epoch 229| loss: 0.20946 | val_0_custom_loss: 223.28296|  0:00:13s
# epoch 230| loss: 0.20939 | val_0_custom_loss: 222.78269|  0:00:13s
# epoch 231| loss: 0.2093  | val_0_custom_loss: 222.61228|  0:00:13s
# epoch 232| loss: 0.20922 | val_0_custom_loss: 222.51173|  0:00:13s
# epoch 233| loss: 0.20918 | val_0_custom_loss: 222.19505|  0:00:13s
# epoch 234| loss: 0.20912 | val_0_custom_loss: 221.77379|  0:00:13s
# epoch 235| loss: 0.20905 | val_0_custom_loss: 221.69682|  0:00:13s
# epoch 236| loss: 0.209   | val_0_custom_loss: 221.66338|  0:00:13s
# epoch 237| loss: 0.20893 | val_0_custom_loss: 221.35148|  0:00:14s
# epoch 238| loss: 0.20888 | val_0_custom_loss: 220.78703|  0:00:14s
# epoch 239| loss: 0.20883 | val_0_custom_loss: 220.277 |  0:00:14s
# epoch 240| loss: 0.20877 | val_0_custom_loss: 219.8183|  0:00:14s
# epoch 241| loss: 0.20872 | val_0_custom_loss: 219.02324|  0:00:14s
# epoch 242| loss: 0.20867 | val_0_custom_loss: 218.06392|  0:00:14s
# epoch 243| loss: 0.20864 | val_0_custom_loss: 217.08152|  0:00:14s
# epoch 244| loss: 0.20859 | val_0_custom_loss: 216.09998|  0:00:14s
# epoch 245| loss: 0.20853 | val_0_custom_loss: 215.17853|  0:00:14s
# epoch 246| loss: 0.20849 | val_0_custom_loss: 214.32286|  0:00:14s
# epoch 247| loss: 0.20846 | val_0_custom_loss: 213.44426|  0:00:14s
# epoch 248| loss: 0.20842 | val_0_custom_loss: 212.59833|  0:00:14s
# epoch 249| loss: 0.20836 | val_0_custom_loss: 211.6817|  0:00:14s
# epoch 250| loss: 0.20831 | val_0_custom_loss: 210.95901|  0:00:14s
# epoch 251| loss: 0.20827 | val_0_custom_loss: 210.26557|  0:00:14s
# epoch 252| loss: 0.20823 | val_0_custom_loss: 209.73042|  0:00:14s
# epoch 253| loss: 0.20819 | val_0_custom_loss: 209.26341|  0:00:15s
# epoch 254| loss: 0.20816 | val_0_custom_loss: 208.90123|  0:00:15s
# epoch 255| loss: 0.20812 | val_0_custom_loss: 208.77219|  0:00:15s
# epoch 256| loss: 0.20808 | val_0_custom_loss: 208.68705|  0:00:15s
# epoch 257| loss: 0.20805 | val_0_custom_loss: 208.82848|  0:00:15s
# epoch 258| loss: 0.20801 | val_0_custom_loss: 209.21363|  0:00:15s
# epoch 259| loss: 0.20797 | val_0_custom_loss: 209.43399|  0:00:15s
# epoch 260| loss: 0.20794 | val_0_custom_loss: 209.55503|  0:00:15s
# epoch 261| loss: 0.20791 | val_0_custom_loss: 209.27758|  0:00:15s
# epoch 262| loss: 0.20787 | val_0_custom_loss: 209.03319|  0:00:15s
# epoch 263| loss: 0.20784 | val_0_custom_loss: 208.79838|  0:00:15s
# epoch 264| loss: 0.20781 | val_0_custom_loss: 208.52645|  0:00:15s
# epoch 265| loss: 0.20778 | val_0_custom_loss: 208.25439|  0:00:15s
# epoch 266| loss: 0.20775 | val_0_custom_loss: 207.93419|  0:00:15s
# epoch 267| loss: 0.20772 | val_0_custom_loss: 207.55633|  0:00:15s
# epoch 268| loss: 0.2077  | val_0_custom_loss: 207.18469|  0:00:15s
# epoch 269| loss: 0.20767 | val_0_custom_loss: 206.92377|  0:00:15s
# epoch 270| loss: 0.20764 | val_0_custom_loss: 206.68547|  0:00:15s
# epoch 271| loss: 0.20761 | val_0_custom_loss: 206.55539|  0:00:15s
# epoch 272| loss: 0.20759 | val_0_custom_loss: 206.44439|  0:00:15s
# epoch 273| loss: 0.20756 | val_0_custom_loss: 206.13262|  0:00:16s
# epoch 274| loss: 0.20754 | val_0_custom_loss: 206.0411|  0:00:16s
# epoch 275| loss: 0.20751 | val_0_custom_loss: 205.9357|  0:00:16s
# epoch 276| loss: 0.20748 | val_0_custom_loss: 205.77531|  0:00:16s
# epoch 277| loss: 0.20746 | val_0_custom_loss: 205.61219|  0:00:16s
# epoch 278| loss: 0.20744 | val_0_custom_loss: 205.40315|  0:00:16s
# epoch 279| loss: 0.20742 | val_0_custom_loss: 205.14888|  0:00:16s
# epoch 280| loss: 0.20739 | val_0_custom_loss: 204.89826|  0:00:16s
# epoch 281| loss: 0.20737 | val_0_custom_loss: 204.65568|  0:00:16s
# epoch 282| loss: 0.20736 | val_0_custom_loss: 204.40206|  0:00:16s
# epoch 283| loss: 0.20734 | val_0_custom_loss: 204.14411|  0:00:16s
# epoch 284| loss: 0.20731 | val_0_custom_loss: 203.7606|  0:00:16s
# epoch 285| loss: 0.20729 | val_0_custom_loss: 203.34183|  0:00:16s
# epoch 286| loss: 0.20728 | val_0_custom_loss: 202.89786|  0:00:16s
# epoch 287| loss: 0.20725 | val_0_custom_loss: 202.45577|  0:00:16s
# epoch 288| loss: 0.20724 | val_0_custom_loss: 202.03434|  0:00:16s
# epoch 289| loss: 0.20722 | val_0_custom_loss: 201.62811|  0:00:17s
# epoch 290| loss: 0.2072  | val_0_custom_loss: 201.27383|  0:00:17s
# epoch 291| loss: 0.20718 | val_0_custom_loss: 200.82548|  0:00:17s
# epoch 292| loss: 0.20717 | val_0_custom_loss: 200.26694|  0:00:17s
# epoch 293| loss: 0.20715 | val_0_custom_loss: 199.7171|  0:00:17s
# epoch 294| loss: 0.20713 | val_0_custom_loss: 199.17406|  0:00:17s
# epoch 295| loss: 0.20711 | val_0_custom_loss: 198.64353|  0:00:17s
# epoch 296| loss: 0.2071  | val_0_custom_loss: 198.09775|  0:00:17s
# epoch 297| loss: 0.20708 | val_0_custom_loss: 197.58397|  0:00:17s
# epoch 298| loss: 0.20706 | val_0_custom_loss: 197.13664|  0:00:17s
# epoch 299| loss: 0.20705 | val_0_custom_loss: 196.68451|  0:00:17s
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_custom_loss = 196.68451
# Best weights from best epoch are automatically used!

# %% [markdown]
# ## 3. Complete Dataset
# Costs for each run

# %%
costs
# Out:
# {0: [333.47712995480543, 102.64665887477459],
#  1: [90.49177245829746, 196.6845074673694]}

# %% [markdown]
# ### 3.1 Reconstruct Dataset
# choose best model based on min. squared custom loss (punishing large outliers in losses for single features)

# %%
cost_totals = [sum([x**2 for x in c]) for _, c in costs.items()]
best_model = cost_totals.index(min(cost_totals))
features_final = features_reconstr[best_model]
print(f"Best model: run {best_model} with custom losses {costs[best_model]} for features {list(features_to_predict)}")
# Out:
# Best model: run 1 with custom losses [90.49177245829746, 196.6845074673694] for features ['F2', 'F3']

# %% [markdown]
# ### 3.2 Plot changes (comp. to original data)

# %%
# scatter plot with combined data
orig_data = features.copy()
orig_data["change"] = 0
changed_data = features_final[features_mv.isna().any(axis=1)]
comp_data = pd.concat([orig_data, changed_data]).reset_index(drop=True).fillna(1)

# line plot connecting filled data to true data points
reconstr_data = features_final[features_mv.isna().any(axis=1)]
true_data = features[features_mv.isna().any(axis=1)]

# plot
fig = plt.figure(figsize=(8,8))
ax  = fig.add_subplot(projection = '3d')
ax.scatter(comp_data["F1"], comp_data["F2"], comp_data["F3"], c=[comp_data["change"]])

for i in range(len(reconstr_data)):
    ax.plot([reconstr_data["F1"].iloc[i], true_data["F1"].iloc[i]],[reconstr_data["F2"].iloc[i], true_data["F2"].iloc[i]],[reconstr_data["F3"].iloc[i], true_data["F3"].iloc[i]], color="black", linewidth=.5)


plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
plt.show
# Out:
# <img src="data:image/png;base64,..." width="800">
# <function matplotlib.pyplot.show(block=None)>

# %% [markdown]
# ## 4. Clustering

# %%
# apply clustering
dbscan_reconstr = DBSCAN(eps=eps, min_samples=min_samples).fit(features_final)
clusters_reconstr = dbscan_reconstr.labels_

# %%
# plot new clustering
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(projection='3d')
ax.scatter(features_final.iloc[:, 0], features_final.iloc[:, 1], features_final.iloc[:, 2], c=clusters_reconstr)
plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## 5. Cluster Performance
# ### 5.1 Feature Distributions
# #### 5.1.1 Distr. Plots

# %%
# plot distributions
bins = 20
n_feat = len(features_final.columns)

fig, (ax) = plt.subplots(n_feat, 2, figsize=(n_feat*2,6))
for n, feature in enumerate(features_final.columns):
    ax[n, 0].hist(features[feature], bins=bins)
    ax[n, 0].set_title(f"{feature}_orig")
    ax[n, 1].hist(features_final[feature], bins=bins)
    ax[n, 1].set_title(f"{feature}_filled")

fig.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# #### 5.1.2 KL Divergence
# Based on implementation from https://stackoverflow.com/questions/57687458/how-to-calculate-probabilities-using-numpy-histogram-and-then-use-it-for-calcula

# %%
# calculating the kl divergence (relative entropy) with scipy
from scipy.special import rel_entr

# calculate probabilities
def probability_dist(x, y, bins):
    # histogram
    hist_xy = np.histogram2d(x, y, bins=bins)[0]

    # compute marginals
    hist_xy = hist_xy + sys.float_info.min # prevent division with 0
    hist_xy = hist_xy / np.sum(hist_xy)
    hist_x = np.sum(hist_xy, axis=1)
    hist_y = np.sum(hist_xy, axis=0)
    return(hist_x, hist_y)

# calculate kl divergence
for n, feature in enumerate(features_final):
    dist1, dist2 = probability_dist(features[feature], features_final[feature], bins)
    print(f"KL divergence {feature}_orig to {feature}_filled: {sum(rel_entr(dist1, dist2))}")
    print(f"KL divergence {feature}_filled to {feature}_orig: {sum(rel_entr(dist2, dist1))}")
    print("")
# Out:
# KL divergence F1_orig to F1_filled: 0.0
# KL divergence F1_filled to F1_orig: 0.0
#
# KL divergence F2_orig to F2_filled: 0.17187310316092583
# KL divergence F2_filled to F2_orig: 0.12727158541423966
#
# KL divergence F3_orig to F3_filled: 0.22570165451035684
# KL divergence F3_filled to F3_orig: 0.1734943253029426

# %% [markdown]
# ### 5.2 Cluster Performance
# #### 5.3 Outliers

# %%
print(f"Number of outliers orig_data: {sum(clusters_orig == -1)}")
print(f"Number of outliers filled_data:{sum(clusters_reconstr == -1)}")
# Out:
# Number of outliers orig_data: 1
# Number of outliers filled_data:6

# %% [markdown]
# #### 5.4 Silhouette Score

# %%
from sklearn.metrics import silhouette_score

print(f"Silhouette Score orig_data: {silhouette_score(features, np.ravel(clusters))}")
print(f"Silhouette Score filled_data: {silhouette_score(features_final, clusters_reconstr)}")
# Out:
# Silhouette Score orig_data: 0.6849069820802122
# Silhouette Score filled_data: 0.4240127540926069
