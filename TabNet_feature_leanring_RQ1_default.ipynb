# %% [markdown]
# ## Change Log
# - Experiments can be setup by using the config parameter "experiment_variable" and assigning the experiment values as a list
# - E.g.
#     - experiment_variable = "train_val_split"
#     - config["training"]["train_val_split"] = [0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]
# - note: only parameters of the category "training" and "model_param" can be used

# %%
# %%javascript
# IPython.notebook.kernel.execute('nb_name = "' + IPython.notebook.notebook_name + '"')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import random
import math

import sys
import os
sys.path.append(os.getcwd() + "/pytorch_tabnet/")

from sklearn.cluster import DBSCAN
from scipy.special import rel_entr

# %% [markdown]
# ## 0. Experiment Setup

# %%
# should an output folder be created to save the experiment data?
save_output = True
save_models = False

# %%
# read config file
import toml
config = toml.load("config.toml")

experiment_variable_values = ""
experiment_dict_key = ""
for category_name, category_values in config.items():
    if config["general"]["experiment_variable"] in category_values:
        experiment_variable_values = category_values[config["general"]["experiment_variable"]]
        experiment_dict_key = category_name
        
# rnd seed to support reproducable results
seed_value =  config["general"]["random_seed"] if config["general"]["random_seed"] else random.randrange(2**32 -1)
random.seed(seed_value)
np.random.seed(seed_value)

# TabNet hyperparameters
experiment_variable = config["general"]["experiment_variable"]
regressor_param = {"optimizer_fn" : torch.optim.Adam,
                   "optimizer_params" : {"lr":0.05},
                   "scheduler_params" : {"step_size": 2, "gamma": 0.9},
                   "scheduler_fn" : torch.optim.lr_scheduler.StepLR,
                   "mask_type" : 'entmax',
                   "device_name" : 'cuda', # only working on NVIDIA GPUs
                   "verbose" : 0
                  }

if save_output:
    # create experiment folder
    from datetime import datetime
    
    experiment_name = config["general"]["experiment_name"]
    experiment_folder = f"{experiment_name} {datetime.now().strftime('%Y_%m_%d %H-%M-%S')}" if experiment_name else f"{config['RQ2']['runs']}_runs_{config['general']['experiment_variable']} {datetime.now().strftime('%Y_%m_%d %H-%M-%S')}"
    
    experiment_path = os.path.join("Experiments", experiment_folder)
    os.mkdir(experiment_path)
    
    plots_path = os.path.join(experiment_path, "plots")
    os.mkdir(plots_path)
    
    models_path = os.path.join(experiment_path, "models")
    os.mkdir(models_path)
    
    # save config file
    import shutil
    shutil.copy2("config.toml", experiment_path)
    
    # save random seed
    if not config["general"]["random_seed"]:
        config["general"]["random_seed"] = seed_value
        config_path = os.path.join(experiment_path, "config.toml")
        with open(config_path, "w") as f:
            toml.dump(config, f)
    
    # save model hyperparameters
    with open(os.path.join(experiment_path, 'config.toml'), 'a') as config_file:
        config_file.write("\n#[regressor_param]\n")
        for key, value in regressor_param.items(): 
            config_file.write('#%s = %s\n' % (key, str(value)))
    
    # save notebook
    shutil.copy2(nb_name, experiment_path)
    
    # create output file
    output_path = os.path.join(experiment_path, "output.toml")
    output_file = open(output_path, "w")
    output = {}

# %% [markdown]
# ## 1. Datasets
#
# Different datasets are to be used for the experiments.
# - toy dataset using make_blobs from sklearn mainly to setup and test the notebook
# - DAMI Benchmark datasets with the respective best practice hyperparameters (https://www.dbs.ifi.lmu.de/research/outlier-evaluation/DAMI/)
#
# ### 1.0. Create toy dataset
# As of now, only a toy dataset is used (n_features features with clusters centered around different points).

# %%
from sklearn.datasets import make_blobs

if config["general"]["use_toy_data"]:
    features_arr, clusters_arr = make_blobs(**config["toy_data"], random_state=seed_value)

    # name feature and cluster (ground truth) columns
    features = pd.DataFrame(features_arr, columns=[f"F{x + 1}" for x in range(features_arr.shape[1])])
    clusters = pd.DataFrame(clusters_arr, columns=["C"])

# %%
# plot dataset
if config["general"]["use_toy_data"]:
    # %matplotlib notebook
    fig = plt.figure(figsize=(8, 8))
    ax = fig.add_subplot(projection='3d')
    ax.scatter(features_arr[:, 0], features_arr[:, 1], features_arr[:, 2], c=clusters_arr)
    plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
    plt.show()
    if save_output:
        plt.savefig(os.path.join(plots_path, "0_ground_truth_clusters.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### 1.1. Use existing datasets

# %%
if not config["general"]["use_toy_data"]:
    features = pd.read_csv(os.path.join('Datasets', 'housing.csv'))

# %% [markdown]
# ### 1.2. Create missing data
# Create a specified amount of missing values in the given feature columns (for complete datasets).

# %%
# create missing values in feature column(s)
mv_config = {feature:mv_ratio for feature,mv_ratio in zip(list(features.columns), config["general"]["missing_percent"])}
features_mv = features.copy()

for f, mv in mv_config.items():
    features_mv[f] = features_mv[f].mask(np.random.random(features.shape[0]) < mv)

# %%
import missingno as msno
# %matplotlib inline

# plot missing values
fig = msno.matrix(features_mv)
plt.show()
if save_output:
    #plt.savefig(os.path.join(plots_path, "missing_values.png"), **config["plots"])
    fig_copy = fig.get_figure()
    fig_copy.savefig(os.path.join(plots_path, "missing_values.png"), **config["plots"], bbox_inches = 'tight')

# %% [markdown]
# ### 1.3. Initial Clustering (without missing values)
# Use the cluster algorithm on dataset without missing values.\
# Get cluster means for loss function input.

# %%
# run DBSCAN on original data
dbscan_orig = DBSCAN(**config["DBSCAN"]).fit(features)
clusters_orig = dbscan_orig.labels_

# %%
# plot clustering
# %matplotlib notebook
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(projection='3d')
ax.scatter(features.iloc[:, 0], features.iloc[:, 1], features.iloc[:, 2], c=clusters_orig)
plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "1_DBSCAN_original_data.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# get cluster means (used to calculate the cluster mean loss)
complete_data = features.copy()
complete_data["C"] = clusters_orig
cluster_means = complete_data.groupby("C").agg("mean")
cluster_means = cluster_means if -1 not in cluster_means.index else cluster_means.drop(-1)

# %% [markdown]
# ## 2. Filling Strategies
#
#
# ### 2.1. Define custom-loss
# The loss function for the model fitting shall be customized to improve cluster perforamnce. The custom loss is divided into 2 separate losses
#
# 1. **Reconstruction Loss**\
# Classic loss function, such as RMSE.
# 2. **Cluster-Mean Loss**\
# The distance to the nearest cluster mean shall be minimized.
# 3. **KL Divergence Loss**\
# Deviation of original distribution shall be minimized \
# (prob distribution based on https://stackoverflow.com/questions/57687458/how-to-calculate-probabilities-using-numpy-histogram-and-then-use-it-for-calcula \
# number of bins: D. Freedman & P. Diaconis (1981) “On the histogram as a density estimator: L2 theory”. Probability Theory and Related Fields 57 (4): 453-476)
#
# The chosen approach to implement the cluster-mean loss is as follows:\
# **Adapt the loss function** to calculate a distance to each cluster. The minimum distance (to the nearest cluster) will be used as a cluster-mean-loss. Minimizing this loss should result in the data point moving closer to the nearest cluster mean.\
# Potential Problem: loss functions currently work with y_true (true values) and y_score (predicted values). Calculating the distance would require all features. Calculating only the 1 dimensional distance will result in missing values being put into wrong clusters - depending on the first estimate.

# %%
# define custom loss function: extend L2-loss by cluster-mean-loss

from pytorch_tabnet.metrics import Metric
from sklearn.metrics import mean_squared_error
import astropy.stats

class custom_loss(Metric):

    def __init__(self):
        self._name = "custom_loss"
        self._maximize = False

    def __call__(self, y_true, y_score, cluster_means, target_feature, x_val, y_val):
        # reconstruction loss
        rmse = np.sqrt(mean_squared_error(y_true, y_score))
        
        # cluster mean loss
        cml = self.cluster_mean_loss(cluster_means, y_score, target_feature, x_val, y_val)
        
        # KL divergence loss
        bins = len(astropy.stats.freedman_bin_width(y_true.reshape(1,-1)[0], return_bins=True)[1])
        distr1, distr2 = self.probability_dist(y_score, y_true, bins)
        KLdl = torch.nn.functional.kl_div(torch.tensor(distr1).log(), torch.tensor(distr2), log_target=False, reduction='sum').item()
        
        # total loss
        custom_loss = rmse + KLdl + cml
        return custom_loss
    
    # calculate sum of distances to the closest cluster mean
    def cluster_mean_loss(self, cluster_means, y_score, target_feature, x_val, y_val):
        
        # reorder cluster_means to match x_val columns (predicted feature is last column)
        cols = cluster_means.columns.tolist()
        feature_col = features.columns.get_loc(target_feature)
        cols = cols[:feature_col] + cols[feature_col+1:] + [target_feature]
        
        # x values extended by predicted values
        x_extended = pd.DataFrame(np.hstack((x_val, y_score)), columns=cols)


        # calculate distances to each cluster and select the closest one
        dist = []
        for cluster in range(cluster_means.shape[0]):
            dist.append(np.linalg.norm((x_extended - cluster_means.iloc[cluster]), axis=1))
            
        dist = pd.DataFrame(dist).T
        min_dist = dist.assign(min_dist=lambda d: d.min(1))["min_dist"]
        
        return sum(min_dist)
    
    # calculate probabilities
    def probability_dist(self, x, y, bins):
        # transforms 2 series into their probability distributions
        # histogram
        hist_xy = np.histogram2d(np.asarray(x)[:,0], np.asarray(y)[:,0], bins=bins)[0]

        # compute marginals
        hist_xy = hist_xy + sys.float_info.min # prevent division with 0
        hist_xy = hist_xy / np.sum(hist_xy)
        hist_x = np.sum(hist_xy, axis=1)
        hist_y = np.sum(hist_xy, axis=0)
        return(hist_x, hist_y)

# %% [markdown]
# ### 2.2. Fill missing values (TabNet).
#
# **Approach 1:**\
# For each feature that contains missing values, use all rows with complete other features as train set and predict missing values of the feature.\
# &rarr; Problem: lots of models, especially for high-dimensional datasets.
# Also problem, if more than one feature is missing values. &rarr; see Approach 2
#
# **Approach 2:**\
# Mask missing values as -1 (or some other value) and fit a model predicting each feature just like in approach 1.\
# &rarr; one model for each feature containing missing values.\
# Possible adaption: use predicted values to predict subsequent values (instead of using -1)

# %%
import time

from pytorch_tabnet.tab_model import TabNetRegressor
from sklearn.model_selection import train_test_split

features_to_predict = features_mv.columns[features_mv.isnull().any()]
features_reconstr = {}
costs = {}
output["runtimes"] = {}

for run in range(config["RQ2"]["runs"]):
    
    print(f"Run {run + 1} / {config['RQ2']['runs']}")
    features_reconstr[run] = []
    costs[run] = {}
    output["runtimes"][f"run_{run}"] = {}
    
    for i, experiment_value in enumerate(experiment_variable_values):
        
        config[experiment_dict_key][config["general"]["experiment_variable"]] = experiment_value
        
        time_start = time.time()
        features_reconstr[run].append(features_mv.copy())
        costs[run][str(experiment_value)] = []

        for feature in features_to_predict:
            
            # select % of features for prediction based on pred_features (e.g. 10% of randomly selected features)
            number_of_features = math.ceil(config["RQ2"]["pred_features"] * (len(features_mv.columns)) - 1)
            features_mv_masked = features_mv.copy().drop(feature, axis=1).sample(n=number_of_features, axis='columns')
            selected_features = features_mv_masked.columns

            # mask other columns' missing values as defined in config (missing_value_mask)
            features_mv_masked[feature] = features_mv[feature]
            features_mv_masked[selected_features] = features_mv_masked[(selected_features)].fillna(config["general"]["missing_value_mask"])

            # separate complete rows as train data
            # separate column with missing values as target
            test_data = features_mv_masked[features_mv_masked[feature].isna()].drop(feature, axis=1).to_numpy()
            train_data = features_mv_masked[features_mv_masked[feature].notna()]
            train_features = train_data.drop(columns=feature).to_numpy()
            train_target = train_data[feature].to_numpy().reshape(-1,1)

            x_train, x_val, y_train, y_val = train_test_split(train_features, train_target, train_size=config["training"]["train_val_split"])

            # create & train model
            model = TabNetRegressor(**regressor_param)
            if config["model_param"]["eval_metric"] == ["custom_loss"]:
                model.fit(
                    x_train, y_train,
                    eval_set=[(x_val, y_val)],
                    **config["model_param"],
                    cluster_means=cluster_means,
                    target_feature=feature,
                    x_val=x_val,
                    y_val=y_val,
                )
            else:
                model.fit(
                    x_train, y_train,
                    eval_set=[(x_val, y_val)],
                    **config["model_param"]
                )     

            #track runtime
            time_end = time.time()

            # add costs to dict
            costs[run][str(experiment_value)].append(model.best_cost)


            # fill missing values with model predictions
            features_reconstr[run][i].loc[features_reconstr[run][i][feature].isna(), feature] = [x[0] for x in model.predict(test_data)]

            # save outputs
            if save_models:

                # save model
                torch.save(model, os.path.join(models_path, f"Model_run{run}_{config['general']['experiment_variable']}{experiment_value}_{feature}.pt"))
            
            if save_output:
                # save runtimes
                output["runtimes"][f"run_{run}"][f"{config['general']['experiment_variable']}_{feature}"] = time_end - time_start
# Out:
# Run 1 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 158 and best_val_0_rmse = 2.27373
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.24495
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.75034
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 198 and best_val_0_rmse = 1.78115
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 154 and best_val_0_rmse = 3.43018
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.96988
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 185 with best_epoch = 135 and best_val_0_rmse = 3.00695
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.09031
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 78 with best_epoch = 28 and best_val_0_rmse = 4.22836
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.88598
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.34956
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.15216
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 66 with best_epoch = 16 and best_val_0_rmse = 4.41812
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.52742
# Best weights from best epoch are automatically used!
# Run 2 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.3122
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 171 and best_val_0_rmse = 2.09515
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 134 with best_epoch = 84 and best_val_0_rmse = 3.12572
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.93945
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.05299
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.1115
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.41123
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.89623
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 148 with best_epoch = 98 and best_val_0_rmse = 3.0174
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.84213
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.02065
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.08001
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 69 with best_epoch = 19 and best_val_0_rmse = 3.21092
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.83003
# Best weights from best epoch are automatically used!
# Run 3 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.94003
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.8278
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 5.24902
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.14373
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.0441
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 155 and best_val_0_rmse = 2.20395
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.33979
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.5856
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 199 with best_epoch = 149 and best_val_0_rmse = 2.62304
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.10438
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.6099
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.65192
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 172 with best_epoch = 122 and best_val_0_rmse = 2.19006
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.11394
# Best weights from best epoch are automatically used!
# Run 4 / 100
#
# Early stopping occurred at epoch 185 with best_epoch = 135 and best_val_0_rmse = 3.27239
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.40989
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 155 with best_epoch = 105 and best_val_0_rmse = 3.64198
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.11135
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.55563
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 193 and best_val_0_rmse = 2.11628
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 192 and best_val_0_rmse = 2.61147
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.63413
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.06795
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.74913
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.45501
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.44006
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.83711
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.72801
# Best weights from best epoch are automatically used!
# Run 5 / 100
#
# Early stopping occurred at epoch 193 with best_epoch = 143 and best_val_0_rmse = 2.74631
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 63 with best_epoch = 13 and best_val_0_rmse = 3.11536
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 138 with best_epoch = 88 and best_val_0_rmse = 2.92259
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.84439
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 76 with best_epoch = 26 and best_val_0_rmse = 6.21941
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 173 and best_val_0_rmse = 2.10061
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 58 with best_epoch = 8 and best_val_0_rmse = 9.64188
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 152 and best_val_0_rmse = 1.85874
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 198 and best_val_0_rmse = 1.98837
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.04886
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 161 and best_val_0_rmse = 3.07939
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.79916
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 155 with best_epoch = 105 and best_val_0_rmse = 2.81349
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 186 and best_val_0_rmse = 2.42757
# Best weights from best epoch are automatically used!
# Run 6 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 160 and best_val_0_rmse = 2.93655
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.17942
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.89091
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.67719
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 124 with best_epoch = 74 and best_val_0_rmse = 3.92635
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.17476
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.75083
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 181 and best_val_0_rmse = 1.8977
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.8167
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.75158
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.94584
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.29244
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 160 with best_epoch = 110 and best_val_0_rmse = 3.37439
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 179 and best_val_0_rmse = 1.40996
# Best weights from best epoch are automatically used!
# Run 7 / 100
#
# Early stopping occurred at epoch 134 with best_epoch = 84 and best_val_0_rmse = 4.81186
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.28487
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.7436
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.09552
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.52105
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.9885
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.36004
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.66158
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 117 with best_epoch = 67 and best_val_0_rmse = 2.96585
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.80854
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 133 with best_epoch = 83 and best_val_0_rmse = 4.85095
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.8937
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 181 and best_val_0_rmse = 3.0767
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.80797
# Best weights from best epoch are automatically used!
# Run 8 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.26797
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 190 and best_val_0_rmse = 1.89734
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.41834
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.82972
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.74657
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 188 and best_val_0_rmse = 2.28703
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.4359
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.23978
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.22877
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.47805
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 151 with best_epoch = 101 and best_val_0_rmse = 2.63587
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 183 and best_val_0_rmse = 2.06179
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.52426
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.2522
# Best weights from best epoch are automatically used!
# Run 9 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.27845
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.24729
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.04042
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 197 and best_val_0_rmse = 2.40765
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.88399
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 195 and best_val_0_rmse = 2.02246
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.41602
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 197 with best_epoch = 147 and best_val_0_rmse = 1.96468
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.88232
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 166 and best_val_0_rmse = 1.77177
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.82726
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.85979
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 184 and best_val_0_rmse = 1.98435
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.67732
# Best weights from best epoch are automatically used!
# Run 10 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 195 and best_val_0_rmse = 3.11746
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.97428
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 153 with best_epoch = 103 and best_val_0_rmse = 3.75835
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 192 with best_epoch = 142 and best_val_0_rmse = 2.51565
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.05698
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.02833
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.82441
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.00191
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 163 and best_val_0_rmse = 3.08367
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.52947
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.75909
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 196 and best_val_0_rmse = 2.02858
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.0781
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 159 and best_val_0_rmse = 1.69791
# Best weights from best epoch are automatically used!
# Run 11 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 193 and best_val_0_rmse = 2.84501
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.07672
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.24758
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.43663
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.23812
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 193 and best_val_0_rmse = 1.95647
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 197 with best_epoch = 147 and best_val_0_rmse = 3.27879
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.81342
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.15412
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.86436
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 197 with best_epoch = 147 and best_val_0_rmse = 2.05834
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.72454
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.15139
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.20735
# Best weights from best epoch are automatically used!
# Run 12 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.81654
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.75614
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.63413
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 167 and best_val_0_rmse = 1.6548
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.99882
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 156 and best_val_0_rmse = 1.78631
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.23792
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.69836
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.22273
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.48169
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.05741
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.06115
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 61 with best_epoch = 11 and best_val_0_rmse = 3.53503
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.83375
# Best weights from best epoch are automatically used!
# Run 13 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 154 and best_val_0_rmse = 3.02865
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 169 and best_val_0_rmse = 1.77473
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.44048
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.2705
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.31527
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.04833
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 175 and best_val_0_rmse = 2.49232
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.87474
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.31543
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.96457
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 92 with best_epoch = 42 and best_val_0_rmse = 3.7521
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.00644
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.21261
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.26694
# Best weights from best epoch are automatically used!
# Run 14 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.17944
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 119 with best_epoch = 69 and best_val_0_rmse = 2.90032
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.37058
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 152 and best_val_0_rmse = 2.39594
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.19634
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 181 and best_val_0_rmse = 2.50052
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.62919
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_rmse = 3.99248
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.24588
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.04377
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.55461
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.72551
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 191 with best_epoch = 141 and best_val_0_rmse = 3.38719
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 188 and best_val_0_rmse = 1.78981
# Best weights from best epoch are automatically used!
# Run 15 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.92207
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.87677
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.25609
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.02002
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 160 and best_val_0_rmse = 2.92998
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 184 and best_val_0_rmse = 2.26223
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 158 with best_epoch = 108 and best_val_0_rmse = 2.92073
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.11378
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 135 with best_epoch = 85 and best_val_0_rmse = 2.56627
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.0225
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.7735
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 89 with best_epoch = 39 and best_val_0_rmse = 2.89011
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.44842
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.25893
# Best weights from best epoch are automatically used!
# Run 16 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.61847
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.5174
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.94693
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.96662
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_rmse = 4.3798
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.96791
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.40516
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 181 and best_val_0_rmse = 1.82208
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 193 with best_epoch = 143 and best_val_0_rmse = 2.5397
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 163 with best_epoch = 113 and best_val_0_rmse = 2.10829
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.6994
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 169 and best_val_0_rmse = 2.07099
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.64869
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.59018
# Best weights from best epoch are automatically used!
# Run 17 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.89155
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 175 and best_val_0_rmse = 2.10801
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.30838
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 167 with best_epoch = 117 and best_val_0_rmse = 2.01827
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.71462
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.32588
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.35059
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.01696
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_rmse = 3.82706
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.08842
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.37867
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 194 and best_val_0_rmse = 2.15913
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 185 with best_epoch = 135 and best_val_0_rmse = 3.31506
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 199 with best_epoch = 149 and best_val_0_rmse = 1.59611
# Best weights from best epoch are automatically used!
# Run 18 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.95428
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.7073
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.75721
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.44903
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 98 with best_epoch = 48 and best_val_0_rmse = 4.85283
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 198 and best_val_0_rmse = 1.90961
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.04117
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.12081
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.50555
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.32446
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.96254
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.78999
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 197 and best_val_0_rmse = 2.56265
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 196 and best_val_0_rmse = 1.82035
# Best weights from best epoch are automatically used!
# Run 19 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.73637
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.32137
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.9723
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.25988
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 172 and best_val_0_rmse = 2.89649
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 85 with best_epoch = 35 and best_val_0_rmse = 5.10375
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.98129
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 198 and best_val_0_rmse = 1.61003
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 127 with best_epoch = 77 and best_val_0_rmse = 3.71337
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.05747
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.20569
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.30174
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_rmse = 4.35758
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 175 with best_epoch = 125 and best_val_0_rmse = 1.75973
# Best weights from best epoch are automatically used!
# Run 20 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.86035
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.53585
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 151 and best_val_0_rmse = 2.67506
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 172 and best_val_0_rmse = 1.69487
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 197 and best_val_0_rmse = 2.93842
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 188 and best_val_0_rmse = 2.02568
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.57733
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.13261
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.37647
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.01683
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.83818
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.38136
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 181 and best_val_0_rmse = 3.4702
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.40438
# Best weights from best epoch are automatically used!
# Run 21 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.13651
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 159 and best_val_0_rmse = 1.87703
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.27507
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.88407
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 4.54441
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 83 with best_epoch = 33 and best_val_0_rmse = 3.35019
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 161 and best_val_0_rmse = 2.69394
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.37124
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.0995
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.86043
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 196 with best_epoch = 146 and best_val_0_rmse = 2.29261
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.03169
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.94248
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 188 with best_epoch = 138 and best_val_0_rmse = 1.89055
# Best weights from best epoch are automatically used!
# Run 22 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.2569
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.00204
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.03463
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.98717
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.53625
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 63 with best_epoch = 13 and best_val_0_rmse = 6.32626
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.35681
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 164 with best_epoch = 114 and best_val_0_rmse = 1.99398
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.33654
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 170 and best_val_0_rmse = 1.8413
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 183 and best_val_0_rmse = 2.11383
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 153 and best_val_0_rmse = 1.84822
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.73746
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.86272
# Best weights from best epoch are automatically used!
# Run 23 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 187 and best_val_0_rmse = 2.89296
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 185 and best_val_0_rmse = 2.00938
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.1524
# ...
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 187 and best_val_0_rmse = 1.67775
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 162 and best_val_0_rmse = 2.71024
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 67 with best_epoch = 17 and best_val_0_rmse = 4.84833
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_rmse = 3.43796
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.28822
# Best weights from best epoch are automatically used!
# Run 94 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.08223
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 197 and best_val_0_rmse = 2.03091
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 148 with best_epoch = 98 and best_val_0_rmse = 4.3006
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.9179
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 158 with best_epoch = 108 and best_val_0_rmse = 4.15689
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.77996
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.43025
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.84919
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.57013
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.59959
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 171 and best_val_0_rmse = 1.69718
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.66294
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 159 and best_val_0_rmse = 1.67351
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.39671
# Best weights from best epoch are automatically used!
# Run 95 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 154 and best_val_0_rmse = 2.97435
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.33553
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.23909
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.0613
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 195 and best_val_0_rmse = 3.20453
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.16316
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.42835
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.23626
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 165 with best_epoch = 115 and best_val_0_rmse = 3.12508
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.98764
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.70083
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.67792
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 109 with best_epoch = 59 and best_val_0_rmse = 3.05022
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 198 with best_epoch = 148 and best_val_0_rmse = 2.01069
# Best weights from best epoch are automatically used!
# Run 96 / 100
#
# Early stopping occurred at epoch 156 with best_epoch = 106 and best_val_0_rmse = 3.08791
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 87 with best_epoch = 37 and best_val_0_rmse = 3.44212
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.14265
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.94534
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.9192
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.08044
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.59616
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.07975
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.34333
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.41166
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 140 with best_epoch = 90 and best_val_0_rmse = 2.5152
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.78978
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.48224
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.09159
# Best weights from best epoch are automatically used!
# Run 97 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.63177
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 169 and best_val_0_rmse = 1.82373
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 4.41627
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.97184
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 4.44374
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.04927
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.80127
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.02238
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.93273
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.98307
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.03546
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 186 with best_epoch = 136 and best_val_0_rmse = 1.92819
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.51416
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 199 with best_epoch = 149 and best_val_0_rmse = 2.38425
# Best weights from best epoch are automatically used!
# Run 98 / 100
#
# Early stopping occurred at epoch 84 with best_epoch = 34 and best_val_0_rmse = 4.64841
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.32564
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.55621
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.244
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 4.64549
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 181 and best_val_0_rmse = 2.15314
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.71176
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.07632
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.22692
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 152 and best_val_0_rmse = 1.7965
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.63919
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.44602
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.53976
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 193 and best_val_0_rmse = 1.56339
# Best weights from best epoch are automatically used!
# Run 99 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.23154
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.22081
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 153 with best_epoch = 103 and best_val_0_rmse = 3.10359
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.2105
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.81131
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.11727
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.31045
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.02015
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 173 and best_val_0_rmse = 2.69933
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.75642
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 76 with best_epoch = 26 and best_val_0_rmse = 4.38767
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.00537
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.54356
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2
# %% [markdown]
# ### 3.1 Reconstruct Dataset
# choose best model based on min. squared custom loss (punishing large outliers in losses for single features)

# %%
best_per_run = []
best_per_run_index = []
for run in range(config["RQ2"]["runs"]):
    cost_totals = [sum([x**2 for x in c]) for _, c in costs[run].items()]
    best_per_run.append(min(cost_totals))
    best_per_run_index.append(cost_totals.index(min(cost_totals)))
    
best_run = best_per_run.index(min(best_per_run))
best_model = best_per_run_index[best_run]
print(f"Best model: run {best_run} model {best_model}")

features_best = features_reconstr[best_run][best_model]
# Out:
# Best model: run 7 model 6

# %% [markdown]
# ### 3.2 Plot changes (comp. to original data)

# %%
# scatter plot with combined data
orig_data = features.copy()
orig_data["change"] = 0
changed_data = features_best[features_mv.isna().any(axis=1)]
comp_data = pd.concat([orig_data, changed_data]).reset_index(drop=True).fillna(1)

# line plot connecting filled data to true data points
reconstr_data = features_best[features_mv.isna().any(axis=1)]
true_data = features[features_mv.isna().any(axis=1)]

# plot
fig = plt.figure(figsize=(8,8))
ax  = fig.add_subplot(projection = '3d')
ax.scatter(comp_data["F1"], comp_data["F2"], comp_data["F3"], c=[comp_data["change"]])

for i in range(len(reconstr_data)):
    ax.plot([reconstr_data["F1"].iloc[i], true_data["F1"].iloc[i]],[reconstr_data["F2"].iloc[i], true_data["F2"].iloc[i]],[reconstr_data["F3"].iloc[i], true_data["F3"].iloc[i]], color="black", linewidth=.5)


plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
plt.show
if save_output:
    plt.savefig(os.path.join(plots_path, "4_imputation_differences.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## 4. Clustering

# %%
# apply clustering
clusters_reconstr = []
for run in range(config["RQ2"]["runs"]):
    clusters_reconstr.append([])
    for i, var in enumerate(experiment_variable_values):
        dbscan_reconstr = DBSCAN(**config["DBSCAN"]).fit(features_reconstr[run][i])
        clusters_reconstr[run].append(dbscan_reconstr.labels_)

# %% [markdown]
# ### 4.1. Plot of clustering based on best model predictions

# %%
# plot new clustering
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(projection='3d')
ax.scatter(features_reconstr[best_run][best_model].iloc[:, 0], features_reconstr[best_run][best_model].iloc[:, 1], features_reconstr[best_run][best_model].iloc[:, 2], c=clusters_reconstr[best_run][best_model])
plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "3_DBSCAN_imputed_data.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## 5. Cluster Performance

# %% [markdown]
# ### 5.1 Feature Distributions
# #### 5.1.1 Distr. Plots based on best model predictions

# %%
# plot distributions
bins = len(astropy.stats.freedman_bin_width(features[feature], return_bins=True)[1])
n_feat = len(features_best.columns)

fig, (ax) = plt.subplots(n_feat, 2, figsize=(n_feat*2,6))
for n, feature in enumerate(features_best.columns):
    ax[n, 0].hist(features[feature], bins=bins)
    ax[n, 0].set_title(f"{feature}_orig")
    ax[n, 1].hist(features_best[feature], bins=bins)
    ax[n, 1].set_title(f"{feature}_filled")

fig.tight_layout()
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "feature distributions.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# #### 5.1.2 KL Divergence

# %%
# KL Divergence
def kl_divergence(feature1, feature2):
    
    # calculate probability distributions
    def probability_dist(x, y, bins):
        # transforms 2 series into their probability distributions
        # histogram
        hist_xy = np.histogram2d(x, y, bins=bins)[0]

        # compute marginals
        hist_xy = hist_xy + sys.float_info.min # prevent division with 0
        hist_xy = hist_xy / np.sum(hist_xy)
        hist_x = np.sum(hist_xy, axis=1)
        hist_y = np.sum(hist_xy, axis=0)
        return(hist_x, hist_y)

    # calculate kl divergence
    bins = len(astropy.stats.freedman_bin_width(feature1, return_bins=True)[1])
    distr1, distr2 = probability_dist(feature1, feature2, bins)
    return torch.nn.functional.kl_div(torch.tensor(distr1).log(), torch.tensor(distr2), log_target=False, reduction='sum').item()

# %%
output["kl_divergence"] = {}

# save kl divergence
for run in range(config["RQ2"]["runs"]):
    output["kl_divergence"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        output["kl_divergence"][f"run_{run}"][str(experiment_value)] = {}
        for feature in features_to_predict:
            output["kl_divergence"][f"run_{run}"][str(experiment_value)][feature] = kl_divergence(features[feature], features_reconstr[run][i][feature])

# %%
# plot
data = {}
for feature in features_to_predict:
    data[feature] = {}
    for experiment_value in experiment_variable_values:
        data[feature][str(experiment_value)] = [x[str(experiment_value)][feature] for x in output["kl_divergence"].values()]

nr_features = len(features_to_predict)
fig, axs = plt.subplots(nr_features)
fig.suptitle(f"KL divergence, {config['RQ2']['runs']} runs", fontweight='bold')

for nr, feature in enumerate(features_to_predict):
    axs[nr].boxplot(data[feature].values(), patch_artist = True) # , showfliers=False
    axs[nr].set_xticklabels(data[feature].keys())
    axs[nr].set_xlabel(config["general"]["experiment_variable"])
    axs[nr].set_ylabel(feature, fontweight='bold')

plt.tight_layout() 
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "5_kl_divergence.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 5.2 Silhouette Score

# %%
from sklearn.metrics import silhouette_score

output["silhouette_scores"] = {}
output["silhouette_scores"]["orig_data"] = float(silhouette_score(features, np.ravel(clusters)))

for run in range(config["RQ2"]["runs"]):
    output["silhouette_scores"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        if len(np.unique(clusters_reconstr[run][i])) > 1:
            output["silhouette_scores"][f"run_{run}"][str(experiment_value)] = float(silhouette_score(features_reconstr[run][i], clusters_reconstr[run][i]))
        else:
            output["silhouette_scores"][f"run_{run}"][str(experiment_value)] = np.nan

# %%
# plot
sil_scores = output["silhouette_scores"].copy()
del(sil_scores["orig_data"])

data = {}
for experiment_value in experiment_variable_values:
    data[str(experiment_value)] = [x[str(experiment_value)] for x in sil_scores.values()]

fig, ax = plt.subplots()
ax.boxplot(data.values(), patch_artist = True)
ax.set_xticklabels(data.keys())
plt.axhline(y=output['silhouette_scores']['orig_data'], color='r', linestyle='-')
plt.xlabel(config["general"]["experiment_variable"])
plt.ylabel("silhouette score")
plt.title(f"silhouette scores, {config['RQ2']['runs']} runs\noriginal data: {round(output['silhouette_scores']['orig_data'], 2)}")
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "5_silhouette_scores.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 5.3. Outlierness
# #### 5.3.1 Global outliers (considering all features)

# %%
# Outliers detected as noise by DBSCAN
output["cluster_noise"] = {}
output["cluster_noise"][f"orig_data"] = sum(clusters_orig == -1)

for run in range(config["RQ2"]["runs"]):
    output["cluster_noise"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        output["cluster_noise"][f"run_{run}"][str(experiment_value)] = sum(clusters_reconstr[run][i] == -1)

# %%
# plot
noise = output["cluster_noise"].copy()
del(noise["orig_data"])

data = {}
for experiment_value in experiment_variable_values:
    data[str(experiment_value)] = [x[str(experiment_value)] for x in noise.values()]

fig, ax = plt.subplots()
ax.boxplot(data.values(), patch_artist = True)
ax.set_xticklabels(data.keys())
plt.axhline(y=output["cluster_noise"]['orig_data'], color='r', linestyle='-')
plt.xlabel(config["general"]["experiment_variable"])
plt.ylabel("number of noise data points")
plt.title(f"DBSCAN noise, {config['RQ2']['runs']} runs\noriginal data: {output['cluster_noise']['orig_data']}")
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "5_DBSCAN-noise.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 5.4. Save Output

# %%
with open(output_path, "w") as f:
            toml.dump(output, f)
