# %% [markdown]
# ## Change Log
# - Experiments can be setup by using the config parameter "experiment_variable" and assigning the experiment values as a list
# - E.g.
#     - experiment_variable = "train_val_split"
#     - config["training"]["train_val_split"] = [0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]
# - note: only parameters of the category "training" and "model_param" can be used

# %%
# %%javascript
# IPython.notebook.kernel.execute('nb_name = "' + IPython.notebook.notebook_name + '"')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import random
import math

import sys
import os
sys.path.append(os.getcwd() + "/pytorch_tabnet/")

from sklearn.cluster import DBSCAN
from scipy.special import rel_entr

# %% [markdown]
# ## 0. Experiment Setup

# %%
# should an output folder be created to save the experiment data?
save_output = True
save_models = False

# %%
# read config file
import toml
config = toml.load("config.toml")

experiment_variable_values = ""
experiment_dict_key = ""
for category_name, category_values in config.items():
    if config["general"]["experiment_variable"] in category_values:
        experiment_variable_values = category_values[config["general"]["experiment_variable"]]
        experiment_dict_key = category_name
        
# rnd seed to support reproducable results
seed_value =  config["general"]["random_seed"] if config["general"]["random_seed"] else random.randrange(2**32 -1)
random.seed(seed_value)
np.random.seed(seed_value)

# TabNet hyperparameters
experiment_variable = config["general"]["experiment_variable"]
regressor_param = {"optimizer_fn" : torch.optim.Adam,
                   "optimizer_params" : {"lr":0.05},
                   "scheduler_params" : {"step_size": 2, "gamma": 0.9},
                   "scheduler_fn" : torch.optim.lr_scheduler.StepLR,
                   "mask_type" : 'entmax',
                   "device_name" : 'cuda', # only working on NVIDIA GPUs
                   "verbose" : 0
                  }

if save_output or save_models:
    # create experiment folder
    from datetime import datetime
    
    experiment_name = config["general"]["experiment_name"]
    experiment_folder = f"{experiment_name} {datetime.now().strftime('%Y_%m_%d %H-%M-%S')}" if experiment_name else f"{config['RQ2']['runs']}_runs_{config['general']['experiment_variable']} {datetime.now().strftime('%Y_%m_%d %H-%M-%S')}"
    
    experiment_path = os.path.join("Experiments", experiment_folder)
    os.mkdir(experiment_path)
    
    plots_path = os.path.join(experiment_path, "plots")
    os.mkdir(plots_path)
    
    models_path = os.path.join(experiment_path, "models")
    os.mkdir(models_path)
    
    # save config file
    import shutil
    shutil.copy2("config.toml", experiment_path)
    
    # save random seed
    if not config["general"]["random_seed"]:
        config["general"]["random_seed"] = seed_value
        config_path = os.path.join(experiment_path, "config.toml")
        with open(config_path, "w") as f:
            toml.dump(config, f)
    
    # save model hyperparameters
    with open(os.path.join(experiment_path, 'config.toml'), 'a') as config_file:
        config_file.write("\n#[regressor_param]\n")
        for key, value in regressor_param.items(): 
            config_file.write('#%s = %s\n' % (key, str(value)))
    
    # save notebook
    shutil.copy2(nb_name, experiment_path)
    
    # create output file
    output_path = os.path.join(experiment_path, "output.toml")
    output_file = open(output_path, "w")

output = {}

# %% [markdown]
# ## 1. Datasets
#
# Different datasets are to be used for the experiments.
# - toy dataset using make_blobs from sklearn mainly to setup and test the notebook
# - DAMI Benchmark datasets with the respective best practice hyperparameters (https://www.dbs.ifi.lmu.de/research/outlier-evaluation/DAMI/)
#
# ### 1.0. Create toy dataset
# As of now, only a toy dataset is used (n_features features with clusters centered around different points).

# %%
from sklearn.datasets import make_blobs

if config["general"]["use_toy_data"]:
    features_arr, clusters_arr = make_blobs(**config["toy_data"], random_state=seed_value)

    # name feature and cluster (ground truth) columns
    features = pd.DataFrame(features_arr, columns=[f"F{x + 1}" for x in range(features_arr.shape[1])])
    clusters = pd.DataFrame(clusters_arr, columns=["C"])

# %%
# plot dataset
if config["general"]["use_toy_data"]:
    # %matplotlib notebook
    fig = plt.figure(figsize=(8, 8))
    ax = fig.add_subplot(projection='3d')
    ax.scatter(features_arr[:, 0], features_arr[:, 1], features_arr[:, 2], c=clusters_arr)
    plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
    plt.show()
    if save_output:
        plt.savefig(os.path.join(plots_path, "0_ground_truth_clusters.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### 1.1. Use existing datasets

# %%
if not config["general"]["use_toy_data"]:
    features = pd.read_csv(os.path.join('Datasets', 'housing.csv'))

# %% [markdown]
# ### 1.2. Create missing data
# Create a specified amount of missing values in the given feature columns (for complete datasets).

# %%
# create missing values in feature column(s)
mv_config = {feature:mv_ratio for feature,mv_ratio in zip(list(features.columns), config["general"]["missing_percent"])}
features_mv = features.copy()

for f, mv in mv_config.items():
    features_mv[f] = features_mv[f].mask(np.random.random(features.shape[0]) < mv)

# %%
import missingno as msno
# %matplotlib inline

# plot missing values
fig = msno.matrix(features_mv)
plt.show()
if save_output:
    #plt.savefig(os.path.join(plots_path, "missing_values.png"), **config["plots"])
    fig_copy = fig.get_figure()
    fig_copy.savefig(os.path.join(plots_path, "missing_values.png"), **config["plots"], bbox_inches = 'tight')

# %% [markdown]
# ### 1.3. Initial Clustering (without missing values)
# Use the cluster algorithm on dataset without missing values.\
# Get cluster means for loss function input.

# %%
# run DBSCAN on original data
dbscan_orig = DBSCAN(**config["DBSCAN"]).fit(features)
clusters_orig = dbscan_orig.labels_

# %%
# plot clustering
# %matplotlib notebook
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(projection='3d')
ax.scatter(features.iloc[:, 0], features.iloc[:, 1], features.iloc[:, 2], c=clusters_orig)
plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "1_DBSCAN_original_data.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# get cluster means (used to calculate the cluster mean loss)
complete_data = features.copy()
complete_data["C"] = clusters_orig
cluster_means = complete_data.groupby("C").agg("mean")
cluster_means = cluster_means if -1 not in cluster_means.index else cluster_means.drop(-1)

# %% [markdown]
# ## 2. Filling Strategies
#
#
# ### 2.1. Define custom-loss
# The loss function for the model fitting shall be customized to improve cluster perforamnce. The custom loss is divided into 2 separate losses
#
# 1. **Reconstruction Loss**\
# Classic loss function, such as RMSE.
# 2. **Cluster-Mean Loss**\
# The distance to the nearest cluster mean shall be minimized.
# 3. **KL Divergence Loss**\
# Deviation of original distribution shall be minimized \
# (prob distribution based on https://stackoverflow.com/questions/57687458/how-to-calculate-probabilities-using-numpy-histogram-and-then-use-it-for-calcula \
# number of bins: D. Freedman & P. Diaconis (1981) “On the histogram as a density estimator: L2 theory”. Probability Theory and Related Fields 57 (4): 453-476)
#
# The chosen approach to implement the cluster-mean loss is as follows:\
# **Adapt the loss function** to calculate a distance to each cluster. The minimum distance (to the nearest cluster) will be used as a cluster-mean-loss. Minimizing this loss should result in the data point moving closer to the nearest cluster mean.\
# Potential Problem: loss functions currently work with y_true (true values) and y_score (predicted values). Calculating the distance would require all features. Calculating only the 1 dimensional distance will result in missing values being put into wrong clusters - depending on the first estimate.

# %%
# define custom loss function: extend L2-loss by cluster-mean-loss

from pytorch_tabnet.metrics import Metric
from sklearn.metrics import mean_squared_error
import astropy.stats

class custom_loss(Metric):

    def __init__(self):
        self._name = "custom_loss"
        self._maximize = False

    def __call__(self, y_true, y_score, cluster_means, target_feature, x_val, y_val):
        # reconstruction loss
        rmse = np.sqrt(mean_squared_error(y_true, y_score))
        
        # cluster mean loss
        cml = self.cluster_mean_loss(cluster_means, y_score, target_feature, x_val, y_val)
        
        # KL divergence loss
        bins = len(astropy.stats.freedman_bin_width(y_true.reshape(1,-1)[0], return_bins=True)[1])
        distr1, distr2 = self.probability_dist(y_score, y_true, bins)
        KLdl = torch.nn.functional.kl_div(torch.tensor(distr1).log(), torch.tensor(distr2), log_target=False, reduction='sum').item()
        
        # total loss
        custom_loss = rmse + KLdl + cml
        return custom_loss
    
    # calculate sum of distances to the closest cluster mean
    def cluster_mean_loss(self, cluster_means, y_score, target_feature, x_val, y_val):
        
        # reorder cluster_means to match x_val columns (predicted feature is last column)
        cols = cluster_means.columns.tolist()
        feature_col = features.columns.get_loc(target_feature)
        cols = cols[:feature_col] + cols[feature_col+1:] + [target_feature]
        
        # x values extended by predicted values
        x_extended = pd.DataFrame(np.hstack((x_val, y_score)), columns=cols)


        # calculate distances to each cluster and select the closest one
        dist = []
        for cluster in range(cluster_means.shape[0]):
            dist.append(np.linalg.norm((x_extended - cluster_means.iloc[cluster]), axis=1))
            
        dist = pd.DataFrame(dist).T
        min_dist = dist.assign(min_dist=lambda d: d.min(1))["min_dist"]
        
        return sum(min_dist)
    
    # calculate probabilities
    def probability_dist(self, x, y, bins):
        # transforms 2 series into their probability distributions
        # histogram
        hist_xy = np.histogram2d(np.asarray(x)[:,0], np.asarray(y)[:,0], bins=bins)[0]

        # compute marginals
        hist_xy = hist_xy + sys.float_info.min # prevent division with 0
        hist_xy = hist_xy / np.sum(hist_xy)
        hist_x = np.sum(hist_xy, axis=1)
        hist_y = np.sum(hist_xy, axis=0)
        return(hist_x, hist_y)

# %% [markdown]
# ### 2.2. Fill missing values (TabNet).
#
# **Approach 1:**\
# For each feature that contains missing values, use all rows with complete other features as train set and predict missing values of the feature.\
# &rarr; Problem: lots of models, especially for high-dimensional datasets.
# Also problem, if more than one feature is missing values. &rarr; see Approach 2
#
# **Approach 2:**\
# Mask missing values as -1 (or some other value) and fit a model predicting each feature just like in approach 1.\
# &rarr; one model for each feature containing missing values.\
# Possible adaption: use predicted values to predict subsequent values (instead of using -1)

# %%
import time

from pytorch_tabnet.tab_model import TabNetRegressor
from sklearn.model_selection import train_test_split

features_to_predict = features_mv.columns[features_mv.isnull().any()]
features_reconstr = {}
output["costs"] = {}
output["runtimes"] = {}

for run in range(config["RQ2"]["runs"]):
    
    print(f"Run {run + 1} / {config['RQ2']['runs']}")
    features_reconstr[run] = []
    output["costs"][f"run_{run}"] = {}
    output["runtimes"][f"run_{run}"] = {}
    
    for i, experiment_value in enumerate(experiment_variable_values):
        
        config[experiment_dict_key][config["general"]["experiment_variable"]] = experiment_value
        
        time_start = time.time()
        features_reconstr[run].append(features_mv.copy())
        output["costs"][f"run_{run}"][str(experiment_value)] = {}
        output["runtimes"][f"run_{run}"][str(experiment_value)] = {}
        
        for feature in features_to_predict:
            
            # select % of features for prediction based on pred_features (e.g. 10% of randomly selected features)
            number_of_features = math.ceil(config["RQ2"]["pred_features"] * (len(features_mv.columns)) - 1)
            features_mv_masked = features_mv.copy().drop(feature, axis=1).sample(n=number_of_features, axis='columns')
            selected_features = features_mv_masked.columns

            # mask other columns' missing values as defined in config (missing_value_mask)
            features_mv_masked[feature] = features_mv[feature]
            features_mv_masked[selected_features] = features_mv_masked[(selected_features)].fillna(config["general"]["missing_value_mask"])

            # separate complete rows as train data
            # separate column with missing values as target
            test_data = features_mv_masked[features_mv_masked[feature].isna()].drop(feature, axis=1).to_numpy()
            train_data = features_mv_masked[features_mv_masked[feature].notna()]
            train_features = train_data.drop(columns=feature).to_numpy()
            train_target = train_data[feature].to_numpy().reshape(-1,1)

            x_train, x_val, y_train, y_val = train_test_split(train_features, train_target, train_size=config["training"]["train_val_split"])

            # create & train model
            model = TabNetRegressor(**regressor_param)
            if config["model_param"]["eval_metric"] == ["custom_loss"]:
                model.fit(
                    x_train, y_train,
                    eval_set=[(x_val, y_val)],
                    **config["model_param"],
                    cluster_means=cluster_means,
                    target_feature=feature,
                    x_val=x_val,
                    y_val=y_val,
                )
            else:
                model.fit(
                    x_train, y_train,
                    eval_set=[(x_val, y_val)],
                    **config["model_param"]
                )     

            #track runtime
            time_end = time.time()

            # add costs to dict
            output["costs"][f"run_{run}"][str(experiment_value)][feature] = model.best_cost


            # fill missing values with model predictions
            features_reconstr[run][i].loc[features_reconstr[run][i][feature].isna(), feature] = [x[0] for x in model.predict(test_data)]

            # save outputs
            if save_models:

                # save model
                torch.save(model, os.path.join(models_path, f"Model_run{run}_{config['general']['experiment_variable']}{experiment_value}_{feature}.pt"))
            
            if save_output:
                # save runtimes
                output["runtimes"][f"run_{run}"][str(experiment_value)][feature] = time_end - time_start
# Out:
# Run 1 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 4.26719
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 3.08981
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 3.01536
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 1.91532
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.91314
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.99103
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 185 with best_epoch = 135 and best_val_0_rmse = 3.00695
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 2.07912
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 109 with best_epoch = 59 and best_val_0_rmse = 3.15029
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 1.62058
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 347 and best_val_0_rmse = 2.06783
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 349 and best_val_0_rmse = 1.99781
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 392 with best_epoch = 342 and best_val_0_rmse = 2.52679
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 281 with best_epoch = 231 and best_val_0_rmse = 1.91401
# Best weights from best epoch are automatically used!
# Run 2 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 4.35361
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 3.37714
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 129 with best_epoch = 79 and best_val_0_rmse = 3.91835
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.43573
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 187 and best_val_0_rmse = 2.38469
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.95648
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 2.85704
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.6938
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 182 with best_epoch = 132 and best_val_0_rmse = 2.23348
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 1.60768
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 69 with best_epoch = 19 and best_val_0_rmse = 4.22267
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 349 and best_val_0_rmse = 1.90578
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 284 with best_epoch = 234 and best_val_0_rmse = 2.71983
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 254 with best_epoch = 204 and best_val_0_rmse = 1.98378
# Best weights from best epoch are automatically used!
# Run 3 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 4.20992
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.3985
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 76 with best_epoch = 26 and best_val_0_rmse = 4.19883
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.11162
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.57627
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.71377
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.89515
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 246 and best_val_0_rmse = 1.49102
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 246 with best_epoch = 196 and best_val_0_rmse = 2.91205
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 1.77656
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 270 with best_epoch = 220 and best_val_0_rmse = 2.69646
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 165 with best_epoch = 115 and best_val_0_rmse = 2.15713
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 371 with best_epoch = 321 and best_val_0_rmse = 2.00466
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 400 with best_epoch = 399 and best_val_0_rmse = 1.53748
# Best weights from best epoch are automatically used!
# Run 4 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 3.21984
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.18933
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.90387
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.04393
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.04508
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.02483
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 242 with best_epoch = 192 and best_val_0_rmse = 2.61147
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.50074
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 2.49015
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 282 with best_epoch = 232 and best_val_0_rmse = 1.65779
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 314 with best_epoch = 264 and best_val_0_rmse = 2.90532
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 349 and best_val_0_rmse = 1.50446
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 369 with best_epoch = 319 and best_val_0_rmse = 2.18406
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 400 with best_epoch = 399 and best_val_0_rmse = 1.53691
# Best weights from best epoch are automatically used!
# Run 5 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.64171
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_rmse = 2.99461
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 1.90631
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.06472
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.64901
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.90726
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 58 with best_epoch = 8 and best_val_0_rmse = 9.64188
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 202 with best_epoch = 152 and best_val_0_rmse = 1.85874
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 253 with best_epoch = 203 and best_val_0_rmse = 2.47872
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 298 and best_val_0_rmse = 1.82872
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 349 and best_val_0_rmse = 2.56249
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 302 with best_epoch = 252 and best_val_0_rmse = 1.58648
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 235 with best_epoch = 185 and best_val_0_rmse = 3.08635
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 236 with best_epoch = 186 and best_val_0_rmse = 2.35463
# Best weights from best epoch are automatically used!
# Run 6 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 3.60944
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 3.1316
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 3.9113
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.31529
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 198 and best_val_0_rmse = 3.0099
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.80656
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 248 and best_val_0_rmse = 2.67838
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 231 with best_epoch = 181 and best_val_0_rmse = 1.8977
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 298 with best_epoch = 248 and best_val_0_rmse = 2.52071
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 285 and best_val_0_rmse = 2.09557
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 349 and best_val_0_rmse = 3.32772
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 349 and best_val_0_rmse = 1.63339
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 66 with best_epoch = 16 and best_val_0_rmse = 5.67236
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 212 with best_epoch = 162 and best_val_0_rmse = 1.7743
# Best weights from best epoch are automatically used!
# Run 7 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 3.98311
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 3.09494
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 4.31395
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.16639
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.74009
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.71425
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 2.13341
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.53099
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 233 with best_epoch = 183 and best_val_0_rmse = 2.63297
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 207 with best_epoch = 157 and best_val_0_rmse = 1.7841
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 349 and best_val_0_rmse = 2.8462
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 349 and best_val_0_rmse = 1.81185
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 400 with best_epoch = 399 and best_val_0_rmse = 2.90584
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 400 with best_epoch = 388 and best_val_0_rmse = 1.86822
# Best weights from best epoch are automatically used!
# Run 8 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 5.24294
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 3.26682
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.70511
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.2062
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.36332
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 186 and best_val_0_rmse = 2.15635
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 248 and best_val_0_rmse = 2.36625
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 2.05155
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 298 and best_val_0_rmse = 2.21118
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 298 and best_val_0_rmse = 2.20779
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 142 with best_epoch = 92 and best_val_0_rmse = 2.99397
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 348 and best_val_0_rmse = 1.67651
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 248 with best_epoch = 198 and best_val_0_rmse = 1.95812
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 208 with best_epoch = 158 and best_val_0_rmse = 1.7647
# Best weights from best epoch are automatically used!
# Run 9 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 3.8775
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.09792
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 3.89546
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.36361
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 198 and best_val_0_rmse = 2.39014
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.65706
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 2.88832
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 197 with best_epoch = 147 and best_val_0_rmse = 1.96468
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 156 with best_epoch = 106 and best_val_0_rmse = 3.47525
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 1.85177
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 348 and best_val_0_rmse = 2.25181
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 295 with best_epoch = 245 and best_val_0_rmse = 1.94816
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 368 with best_epoch = 318 and best_val_0_rmse = 2.70838
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 400 with best_epoch = 399 and best_val_0_rmse = 1.91781
# Best weights from best epoch are automatically used!
# Run 10 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 94 and best_val_0_rmse = 3.70717
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.79081
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 3.10138
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 110 and best_val_0_rmse = 2.31557
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.03619
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 187 and best_val_0_rmse = 1.92826
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 2.51578
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.88551
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 2.827
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 284 with best_epoch = 234 and best_val_0_rmse = 1.48369
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 161 with best_epoch = 111 and best_val_0_rmse = 2.47353
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 254 with best_epoch = 204 and best_val_0_rmse = 2.03506
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 226 with best_epoch = 176 and best_val_0_rmse = 2.1016
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 174 with best_epoch = 124 and best_val_0_rmse = 1.92185
# Best weights from best epoch are automatically used!
# Run 11 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 3.5884
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.12734
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 3.09035
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.25674
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.96125
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.74816
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 197 with best_epoch = 147 and best_val_0_rmse = 3.27879
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.70766
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 281 with best_epoch = 231 and best_val_0_rmse = 3.04492
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 1.56098
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 229 with best_epoch = 179 and best_val_0_rmse = 2.65145
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 349 and best_val_0_rmse = 1.86427
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 201 with best_epoch = 151 and best_val_0_rmse = 3.21722
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 327 with best_epoch = 277 and best_val_0_rmse = 1.79605
# Best weights from best epoch are automatically used!
# Run 12 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 4.45393
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.58202
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.46932
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 147 and best_val_0_rmse = 1.52004
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.05364
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.74293
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 2.95713
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.60824
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 141 with best_epoch = 91 and best_val_0_rmse = 3.14019
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 254 with best_epoch = 204 and best_val_0_rmse = 1.23918
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 349 and best_val_0_rmse = 2.29767
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 329 and best_val_0_rmse = 1.67287
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 181 with best_epoch = 131 and best_val_0_rmse = 2.68897
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 280 with best_epoch = 230 and best_val_0_rmse = 1.81356
# Best weights from best epoch are automatically used!
# Run 13 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.91973
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.75772
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 3.62019
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.24265
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.03204
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.92012
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 225 with best_epoch = 175 and best_val_0_rmse = 2.49232
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.78432
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 2.33026
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 1.73767
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 347 and best_val_0_rmse = 2.6663
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 326 and best_val_0_rmse = 1.70307
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 316 with best_epoch = 266 and best_val_0_rmse = 2.41637
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 258 with best_epoch = 208 and best_val_0_rmse = 1.59544
# Best weights from best epoch are automatically used!
# Run 14 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 4.01228
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.69889
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_rmse = 4.89338
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 1.98998
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 61 with best_epoch = 11 and best_val_0_rmse = 6.22231
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.05656
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 2.27568
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_rmse = 3.99248
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 3.13414
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 241 with best_epoch = 191 and best_val_0_rmse = 1.76862
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 234 with best_epoch = 184 and best_val_0_rmse = 2.44086
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 341 and best_val_0_rmse = 1.51971
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 400 with best_epoch = 399 and best_val_0_rmse = 2.19881
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 260 with best_epoch = 210 and best_val_0_rmse = 1.88526
# Best weights from best epoch are automatically used!
# Run 15 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 3.54757
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.37044
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 4.01069
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.03196
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.65228
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 187 with best_epoch = 137 and best_val_0_rmse = 1.97804
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 158 with best_epoch = 108 and best_val_0_rmse = 2.92073
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 2.05145
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 2.16195
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 1.62491
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 174 with best_epoch = 124 and best_val_0_rmse = 2.85758
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 255 with best_epoch = 205 and best_val_0_rmse = 1.71089
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 400 with best_epoch = 378 and best_val_0_rmse = 2.31983
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 289 with best_epoch = 239 and best_val_0_rmse = 2.21623
# Best weights from best epoch are automatically used!
# Run 16 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 3.43319
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.87251
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 3.42656
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.22803
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 155 and best_val_0_rmse = 2.84179
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.70449
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 2.294
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 231 with best_epoch = 181 and best_val_0_rmse = 1.82208
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 2.60986
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 248 with best_epoch = 198 and best_val_0_rmse = 1.92491
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 349 and best_val_0_rmse = 2.14151
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 221 with best_epoch = 171 and best_val_0_rmse = 1.84505
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 214 with best_epoch = 164 and best_val_0_rmse = 1.71359
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 400 with best_epoch = 399 and best_val_0_rmse = 1.48387
# Best weights from best epoch are automatically used!
# Run 17 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 3.95679
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.32313
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.55627
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 63 with best_epoch = 13 and best_val_0_rmse = 3.14432
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.39846
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.36944
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 2.03577
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.71106
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 1.63205
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 1.80822
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 349 and best_val_0_rmse = 2.92955
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 212 with best_epoch = 162 and best_val_0_rmse = 2.03524
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 400 with best_epoch = 393 and best_val_0_rmse = 2.40786
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 198 with best_epoch = 148 and best_val_0_rmse = 1.7551
# Best weights from best epoch are automatically used!
# Run 18 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 3.60783
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.85076
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 3.92754
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 65 with best_epoch = 15 and best_val_0_rmse = 4.4277
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 180 with best_epoch = 130 and best_val_0_rmse = 2.58769
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.82839
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 2.90522
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 2.00962
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 2.20853
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 2.16859
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 349 and best_val_0_rmse = 2.39536
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 337 and best_val_0_rmse = 1.63065
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 400 with best_epoch = 398 and best_val_0_rmse = 2.17053
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 314 with best_epoch = 264 and best_val_0_rmse = 1.84997
# Best weights from best epoch are automatically used!
# Run 19 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 4.20897
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.6836
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 3.16058
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 1.77764
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 132 with best_epoch = 82 and best_val_0_rmse = 2.59595
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 163 and best_val_0_rmse = 2.15085
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 203 and best_val_0_rmse = 2.97865
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 208 and best_val_0_rmse = 1.60857
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 2.69174
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 298 and best_val_0_rmse = 1.84903
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 328 and best_val_0_rmse = 2.09647
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 254 with best_epoch = 204 and best_val_0_rmse = 2.13255
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 400 with best_epoch = 398 and best_val_0_rmse = 3.14624
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 211 with best_epoch = 161 and best_val_0_rmse = 1.90696
# Best weights from best epoch are automatically used!
# Run 20 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 3.60409
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.79495
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.20732
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 1.94472
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 170 and best_val_0_rmse = 2.76757
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 180 and best_val_0_rmse = 2.05478
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 2.51678
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 215 and best_val_0_rmse = 2.09834
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 254 with best_epoch = 204 and best_val_0_rmse = 3.58017
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 298 with best_epoch = 248 and best_val_0_rmse = 1.88444
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 349 and best_val_0_rmse = 2.9274
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 184 with best_epoch = 134 and best_val_0_rmse = 2.2096
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 400 with best_epoch = 354 and best_val_0_rmse = 2.63648
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 297 with best_epoch = 247 and best_val_0_rmse = 1.33949
# Best weights from best epoch are automatically used!
# Run 21 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 84 and best_val_0_rmse = 4.04816
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.29156
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 3.13537
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_rmse = 4.4875
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 185 and best_val_0_rmse = 3.18051
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 194 and best_val_0_rmse = 2.21414
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 211 with best_epoch = 161 and best_val_0_rmse = 2.69394
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 221 and best_val_0_rmse = 1.35906
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 264 with best_epoch = 214 and best_val_0_rmse = 2.9429
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 1.93134
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 241 with best_epoch = 191 and best_val_0_rmse = 2.29834
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 254 with best_epoch = 204 and best_val_0_rmse = 1.74453
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 400 with best_epoch = 394 and best_val_0_rmse = 2.98091
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 185 with best_epoch = 135 and best_val_0_rmse = 2.03488
# Best weights from best epoch are automatically used!
# Run 22 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 4.02115
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.72967
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 3.09571
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.13916
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 108 with best_epoch = 58 and best_val_0_rmse = 4.01253
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 198 and best_val_0_rmse = 1.88173
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 246 and best_val_0_rmse = 2.28042
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 164 with best_epoch = 114 and best_val_0_rmse = 1.99398
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 239 with best_epoch = 189 and best_val_0_rmse = 2.25432
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 219 with best_epoch = 169 and best_val_0_rmse = 1.7953
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_rmse = 4.55919
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 275 with best_epoch = 225 and best_val_0_rmse = 1.70382
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 400 with best_epoch = 369 and best_val_0_rmse = 2.59475
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 330 with best_epoch = 280 and best_val_0_rmse = 1.98905
# Best weights from best epoch are automatically used!
# Run 23 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 3.52597
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 3.74518
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 3.09604
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.75988
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 163 with best_epoch = 113 and best_val_0_rmse = 3.36102
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.27183
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 225 with best_epoch = 175 and best_val_0_rmse = 3.19806
# ...
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 206 with best_epoch = 156 and best_val_0_rmse = 1.92197
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 333 and best_val_0_rmse = 2.94021
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 349 and best_val_0_rmse = 2.1049
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 251 with best_epoch = 201 and best_val_0_rmse = 2.05475
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 400 with best_epoch = 399 and best_val_0_rmse = 1.9026
# Best weights from best epoch are automatically used!
# Run 94 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 3.59535
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.94133
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 3.4025
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.22494
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.56295
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.76728
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 2.12634
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 248 and best_val_0_rmse = 1.73989
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 1.88474
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 256 and best_val_0_rmse = 1.69765
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 220 with best_epoch = 170 and best_val_0_rmse = 1.6899
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 349 and best_val_0_rmse = 1.65122
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 400 with best_epoch = 399 and best_val_0_rmse = 2.58233
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 385 with best_epoch = 335 and best_val_0_rmse = 1.43826
# Best weights from best epoch are automatically used!
# Run 95 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 94 and best_val_0_rmse = 2.87666
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.86651
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 3.29721
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.03383
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.96369
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.15475
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 2.36036
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.9332
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 168 with best_epoch = 118 and best_val_0_rmse = 3.11813
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 1.69462
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 340 and best_val_0_rmse = 2.26481
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 298 with best_epoch = 248 and best_val_0_rmse = 1.53919
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 186 with best_epoch = 136 and best_val_0_rmse = 3.62667
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 236 with best_epoch = 186 and best_val_0_rmse = 1.76638
# Best weights from best epoch are automatically used!
# Run 96 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 3.24469
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 3.3107
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 3.70072
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.04883
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 165 with best_epoch = 115 and best_val_0_rmse = 3.30807
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.18667
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 3.3225
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 211 and best_val_0_rmse = 2.07194
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 2.0772
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 2.03159
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 293 with best_epoch = 243 and best_val_0_rmse = 2.37004
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 201 with best_epoch = 151 and best_val_0_rmse = 1.65648
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 314 with best_epoch = 264 and best_val_0_rmse = 2.13261
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 400 with best_epoch = 399 and best_val_0_rmse = 1.94191
# Best weights from best epoch are automatically used!
# Run 97 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 4.65591
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.58541
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 4.34244
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.20714
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 4.00647
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.96429
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 2.61524
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.96271
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 293 and best_val_0_rmse = 2.4246
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 1.78485
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 349 and best_val_0_rmse = 2.12897
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 349 and best_val_0_rmse = 1.87174
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 400 with best_epoch = 399 and best_val_0_rmse = 2.39695
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 248 with best_epoch = 198 and best_val_0_rmse = 1.89883
# Best weights from best epoch are automatically used!
# Run 98 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 78 and best_val_0_rmse = 3.22418
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.60908
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 1.99829
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.54219
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 1.93094
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 193 and best_val_0_rmse = 2.05978
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 2.37718
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 216 and best_val_0_rmse = 2.07355
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 2.75382
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 1.67543
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 349 and best_val_0_rmse = 1.71196
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 340 and best_val_0_rmse = 1.5662
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 400 with best_epoch = 399 and best_val_0_rmse = 1.99537
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 230 with best_epoch = 180 and best_val_0_rmse = 1.70092
# Best weights from best epoch are automatically used!
# Run 99 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 92 and best_val_0_rmse = 3.43127
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.57235
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.41361
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.53392
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 71 with best_epoch = 21 and best_val_0_rmse = 3.93935
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 2.0847
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 3.05773
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.93276
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 259 and best_val_0_rmse = 2.42248
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 1.9195
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 304 with best_epoch = 254 and best_val_0_rmse = 2.50571
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 350 with best_epoch = 349 and best_val_0_rmse = 1.93662
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 400 with best_epoch = 393 and best_val_0_rmse = 2.73326
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 400 with best_epoch = 399 and best_val_0_rmse = 1.80499
# Best weights from best epoch are automatically used!
# Run 100 / 100
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 4.08189
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_val_0_rmse = 2.65911
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 2.11913
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_rmse = 1.78035
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_rmse = 3.31225
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 153 and best_val_0_rmse = 1.92728
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 2.45507
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.84888
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 300 with best_epoch = 299 and best_val_0_rmse = 2.55301
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 239 with best_epoch = 189 and best_val_0_rmse = 1.74626
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 285 with best_epoch = 235 and best_val_0_rmse = 2.5965
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 333 with best_epoch = 283 and best_val_0_rmse = 1.6483
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 308 with best_epoch = 258 and best_val_0_rmse = 2.46688
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 225 with best_epoch = 175 and best_val_0_rmse = 1.84703
# Best weights from best epoch are automatically used!

# %% [markdown]
# ## 3. Complete Dataset
# Costs for each run

# %% [markdown]
# ### 3.1 Reconstruct Dataset
# choose best model based on min. squared custom loss (punishing large outliers in losses for single features)

# %%
best_per_run = []
best_per_run_index = []
for run in range(config["RQ2"]["runs"]):
    cost_list = list(output["costs"][f"run_{run}"].values())
    cost_totals = [sum(c**2 for c in list(x.values())) for x in cost_list]
    best_per_run.append(min(cost_totals))
    best_per_run_index.append(cost_totals.index(min(cost_totals)))
    
best_run = best_per_run.index(min(best_per_run))
best_model = best_per_run_index[best_run]
print(f"Best model: run {best_run} model {best_model}")

features_best = features_reconstr[best_run][best_model]
# Out:
# Best model: run 15 model 6

# %% [markdown]
# ### 3.2 Plot changes (comp. to original data)

# %%
# scatter plot with combined data
orig_data = features.copy()
orig_data["change"] = 0
changed_data = features_best[features_mv.isna().any(axis=1)]
comp_data = pd.concat([orig_data, changed_data]).reset_index(drop=True).fillna(1)

# line plot connecting filled data to true data points
reconstr_data = features_best[features_mv.isna().any(axis=1)]
true_data = features[features_mv.isna().any(axis=1)]

# plot
fig = plt.figure(figsize=(8,8))
ax  = fig.add_subplot(projection = '3d')
ax.scatter(comp_data["F1"], comp_data["F2"], comp_data["F3"], c=[comp_data["change"]])

for i in range(len(reconstr_data)):
    ax.plot([reconstr_data["F1"].iloc[i], true_data["F1"].iloc[i]],[reconstr_data["F2"].iloc[i], true_data["F2"].iloc[i]],[reconstr_data["F3"].iloc[i], true_data["F3"].iloc[i]], color="black", linewidth=.5)


plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
plt.show
if save_output:
    plt.savefig(os.path.join(plots_path, "4_imputation_differences.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## 4. Clustering

# %%
# apply clustering
clusters_reconstr = []
for run in range(config["RQ2"]["runs"]):
    clusters_reconstr.append([])
    for i, var in enumerate(experiment_variable_values):
        dbscan_reconstr = DBSCAN(**config["DBSCAN"]).fit(features_reconstr[run][i])
        clusters_reconstr[run].append(dbscan_reconstr.labels_)

# %% [markdown]
# ### 4.1. Plot of clustering based on best model predictions

# %%
# plot new clustering
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(projection='3d')
ax.scatter(features_reconstr[best_run][best_model].iloc[:, 0], features_reconstr[best_run][best_model].iloc[:, 1], features_reconstr[best_run][best_model].iloc[:, 2], c=clusters_reconstr[best_run][best_model])
plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "3_DBSCAN_imputed_data.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## 5. Cluster Performance

# %% [markdown]
# ### 5.1 Feature Distributions
# #### 5.1.1 Distr. Plots based on best model predictions

# %%
# plot distributions
bins = len(astropy.stats.freedman_bin_width(features[feature], return_bins=True)[1])
n_feat = len(features_best.columns)

fig, (ax) = plt.subplots(n_feat, 2, figsize=(n_feat*2,6))
for n, feature in enumerate(features_best.columns):
    ax[n, 0].hist(features[feature], bins=bins)
    ax[n, 0].set_title(f"{feature}_orig")
    ax[n, 1].hist(features_best[feature], bins=bins)
    ax[n, 1].set_title(f"{feature}_filled")

fig.tight_layout()
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "feature distributions.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# #### 5.1.2 KL Divergence

# %%
# KL Divergence
def kl_divergence(feature1, feature2):
    
    # calculate probability distributions
    def probability_dist(x, y, bins):
        # transforms 2 series into their probability distributions
        # histogram
        hist_xy = np.histogram2d(x, y, bins=bins)[0]

        # compute marginals
        hist_xy = hist_xy + sys.float_info.min # prevent division with 0
        hist_xy = hist_xy / np.sum(hist_xy)
        hist_x = np.sum(hist_xy, axis=1)
        hist_y = np.sum(hist_xy, axis=0)
        return(hist_x, hist_y)

    # calculate kl divergence
    bins = len(astropy.stats.freedman_bin_width(feature1, return_bins=True)[1])
    distr1, distr2 = probability_dist(feature1, feature2, bins)
    return torch.nn.functional.kl_div(torch.tensor(distr1).log(), torch.tensor(distr2), log_target=False, reduction='sum').item()

# %%
output["kl_divergence"] = {}

# save kl divergence
for run in range(config["RQ2"]["runs"]):
    output["kl_divergence"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        output["kl_divergence"][f"run_{run}"][str(experiment_value)] = {}
        for feature in features_to_predict:
            output["kl_divergence"][f"run_{run}"][str(experiment_value)][feature] = kl_divergence(features[feature], features_reconstr[run][i][feature])

# %%
# plot
data = {}
for feature in features_to_predict:
    data[feature] = {}
    for experiment_value in experiment_variable_values:
        data[feature][str(experiment_value)] = [x[str(experiment_value)][feature] for x in output["kl_divergence"].values()]

nr_features = len(features_to_predict)
fig, axs = plt.subplots(nr_features)
fig.suptitle(f"KL divergence, {config['RQ2']['runs']} runs", fontweight='bold')

for nr, feature in enumerate(features_to_predict):
    axs[nr].boxplot(data[feature].values(), patch_artist = True) # , showfliers=False
    axs[nr].set_xticklabels(data[feature].keys())
    axs[nr].set_xlabel(config["general"]["experiment_variable"])
    axs[nr].set_ylabel(feature, fontweight='bold')

plt.tight_layout() 
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "5_kl_divergence.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 5.2 Silhouette Score

# %%
from sklearn.metrics import silhouette_score

output["silhouette_scores"] = {}
output["silhouette_scores"]["orig_data"] = float(silhouette_score(features, np.ravel(clusters)))

for run in range(config["RQ2"]["runs"]):
    output["silhouette_scores"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        if len(np.unique(clusters_reconstr[run][i])) > 1:
            output["silhouette_scores"][f"run_{run}"][str(experiment_value)] = float(silhouette_score(features_reconstr[run][i], clusters_reconstr[run][i]))
        else:
            output["silhouette_scores"][f"run_{run}"][str(experiment_value)] = np.nan

# %%
# plot
sil_scores = output["silhouette_scores"].copy()
del(sil_scores["orig_data"])

data = {}
for experiment_value in experiment_variable_values:
    data[str(experiment_value)] = [x[str(experiment_value)] for x in sil_scores.values()]

fig, ax = plt.subplots()
ax.boxplot(data.values(), patch_artist = True)
ax.set_xticklabels(data.keys())
plt.axhline(y=output['silhouette_scores']['orig_data'], color='r', linestyle='-')
plt.xlabel(config["general"]["experiment_variable"])
plt.ylabel("silhouette score")
plt.title(f"silhouette scores, {config['RQ2']['runs']} runs\noriginal data: {round(output['silhouette_scores']['orig_data'], 2)}")
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "5_silhouette_scores.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 5.3. Outlierness
# #### 5.3.1 Global outliers (considering all features)

# %%
# Outliers detected as noise by DBSCAN
output["cluster_noise"] = {}
output["cluster_noise"][f"orig_data"] = sum(clusters_orig == -1)

for run in range(config["RQ2"]["runs"]):
    output["cluster_noise"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        output["cluster_noise"][f"run_{run}"][str(experiment_value)] = sum(clusters_reconstr[run][i] == -1)

# %%
# plot
noise = output["cluster_noise"].copy()
del(noise["orig_data"])

data = {}
for experiment_value in experiment_variable_values:
    data[str(experiment_value)] = [x[str(experiment_value)] for x in noise.values()]

fig, ax = plt.subplots()
ax.boxplot(data.values(), patch_artist = True)
ax.set_xticklabels(data.keys())
plt.axhline(y=output["cluster_noise"]['orig_data'], color='r', linestyle='-')
plt.xlabel(config["general"]["experiment_variable"])
plt.ylabel("number of noise data points")
plt.title(f"DBSCAN noise, {config['RQ2']['runs']} runs\noriginal data: {output['cluster_noise']['orig_data']}")
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "5_DBSCAN-noise.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 5.4. Save Output

# %%
if save_output:
    with open(output_path, "w") as f:
                toml.dump(output, f)
