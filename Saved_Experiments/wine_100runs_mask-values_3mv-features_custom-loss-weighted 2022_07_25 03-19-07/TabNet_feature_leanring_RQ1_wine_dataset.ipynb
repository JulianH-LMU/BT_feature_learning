# %% [markdown]
# ## Change Log
# - Experiments can be setup by using the config parameter "experiment_variable" and assigning the experiment values as a list
# - E.g.
#     - experiment_variable = "train_val_split"
#     - config["training"]["train_val_split"] = [0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]
# - note: only parameters of the category "training" and "model_param" can be used

# %%
# %%javascript
# IPython.notebook.kernel.execute('nb_name = "' + IPython.notebook.notebook_name + '"')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import random
import math

import sys
import os
sys.path.append(os.getcwd() + "/pytorch_tabnet/")

from sklearn.cluster import DBSCAN

# %% [markdown]
# ## 0. Experiment Setup

# %%
# should an output folder be created to save the experiment data?
save_output = True
save_models = False

# %%
# read config file
import toml
config = toml.load("config.toml")

# determine experimental parameter from config
experiment_variable_values = ""
experiment_dict_key = ""
for category_name, category_values in config.items():
    if config["general"]["experiment_variable"] in category_values:
        experiment_variable_values = category_values[config["general"]["experiment_variable"]]
        experiment_dict_key = category_name
        
# rnd seed to support reproducable results
seed_value =  config["general"]["random_seed"] if config["general"]["random_seed"] else random.randrange(2**32 -1)
random.seed(seed_value)
np.random.seed(seed_value)

# TabNet hyperparameters
experiment_variable = config["general"]["experiment_variable"]
regressor_param = {"optimizer_fn" : torch.optim.Adam,
                   "optimizer_params" : {"lr":0.05},
                   "scheduler_params" : {"step_size": 2, "gamma": 0.9},
                   "scheduler_fn" : torch.optim.lr_scheduler.StepLR,
                   "mask_type" : 'entmax',
                   "device_name" : 'cuda', # only working on NVIDIA GPUs
                   "verbose" : 0
                  }

# create experiment folder structure
if save_output or save_models:  
    from datetime import datetime
    
    experiment_name = config["general"]["experiment_name"]
    experiment_folder = f"{experiment_name} {datetime.now().strftime('%Y_%m_%d %H-%M-%S')}" if experiment_name else f"{config['RQ2']['runs']}_runs_{config['general']['experiment_variable']} {datetime.now().strftime('%Y_%m_%d %H-%M-%S')}"
    
    experiment_path = os.path.join("Experiments", experiment_folder)
    os.mkdir(experiment_path)
    
    plots_path = os.path.join(experiment_path, "plots")
    os.mkdir(plots_path)
    
    models_path = os.path.join(experiment_path, "models")
    os.mkdir(models_path)
    
    # save config file
    import shutil
    shutil.copy2("config.toml", experiment_path)
    
    # save random seed
    if not config["general"]["random_seed"]:
        config["general"]["random_seed"] = seed_value
        config_path = os.path.join(experiment_path, "config.toml")
        with open(config_path, "w") as f:
            toml.dump(config, f)
    
    # save model hyperparameters
    with open(os.path.join(experiment_path, 'config.toml'), 'a') as config_file:
        config_file.write("\n#[regressor_param]\n")
        for key, value in regressor_param.items(): 
            config_file.write('#%s = %s\n' % (key, str(value)))
    
    # create output file
    output_path = os.path.join(experiment_path, "output.toml")
    output_file = open(output_path, "w")

output = {}

# %% [markdown]
# ## 1. Datasets
#
# ### 1.0. Use wine dataset

# %%
from sklearn.datasets import load_wine
from sklearn.preprocessing import scale, StandardScaler

wine = load_wine()
X, y = pd.DataFrame(wine.data, columns=wine['feature_names']), wine.target
X_scaled = pd.DataFrame(StandardScaler().fit_transform(X), columns=wine['feature_names'])

# %% [markdown]
# ### 1.1. Create missing data
# Create a specified amount of missing values in the given feature columns (for complete datasets).

# %%
# create missing values in feature column(s)
mv_config = {feature:mv_ratio for feature,mv_ratio in zip(list(X.columns), config["general"]["missing_percent"])}
X_mv = X.copy()

for f, mv in mv_config.items():
    X_mv[f] = X_mv[f].mask(np.random.random(X.shape[0]) < mv)

# %%
import missingno as msno
# %matplotlib inline

# plot missing values
fig = msno.matrix(X_mv)
plt.show()
if save_output:
    #plt.savefig(os.path.join(plots_path, "missing_values.png"), **config["plots"])
    fig_copy = fig.get_figure()
    fig_copy.savefig(os.path.join(plots_path, "missing_values.png"), **config["plots"], bbox_inches = 'tight')

# %% [markdown]
# ### 1.3. Initial Clustering (without missing values)
# Automatically determine DBSCAN hyperparameters min_samples and eps.\
# min_samples results in 26 for the wine dataset (dimensionality 13).\
# for eps we choose 2 (elbow of the graph).

# %%
from sklearn.neighbors import NearestNeighbors

min_samples = 2 * len(X_scaled.columns)

neighbors = NearestNeighbors(n_neighbors=min_samples)
neighbors_fit = neighbors.fit(X_scaled)
distances, indices = neighbors_fit.kneighbors(X_scaled)
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)

# %% [markdown]
# Use the cluster algorithm on dataset without missing values shows, that DBSCAN is not performaing well with 13 dimensional dataset (empty space problem leads to either 1 or 0 clusters).

# %%
# run DBSCAN on original data
config["DBSCAN"]["eps"] = 2
config["DBSCAN"]["min_samples"] = min_samples
if save_output or save_models:
    with open(config_path, "w") as f:
        toml.dump(config, f)

dbscan_orig = DBSCAN(**config["DBSCAN"]).fit(X_scaled)
y_orig = dbscan_orig.labels_
print(f"DBSCAN noise: {(sum(abs(y_orig[y_orig == -1]))*100) / len(y)}%")
# Out:
# DBSCAN noise: 100.0%

# %% [markdown]
# As an alternative, we use k-means for the initial clustering (k=3). This does clearly work better with a more than 96% correct labeling of data.

# %%
from sklearn.cluster import KMeans
k_mean_orig = KMeans(n_clusters=3, random_state=seed_value).fit(X_scaled)
y_orig = k_mean_orig.labels_

# %%
from munkres import Munkres
from sklearn.metrics import confusion_matrix

# use Munkres / Hungarian algorithm to relabel clusters in order to match original label names
def make_cost_matrix(c1, c2):
    """
    """
    uc1 = np.unique(c1)
    uc2 = np.unique(c2)
    l1 = uc1.size
    l2 = uc2.size
    assert(l1 == l2 and np.all(uc1 == uc2))

    m = np.ones([l1, l2])
    for i in range(l1):
        it_i = np.nonzero(c1 == uc1[i])[0]
        for j in range(l2):
            it_j = np.nonzero(c2 == uc2[j])[0]
            m_ij = np.intersect1d(it_j, it_i)
            m[i,j] =  -m_ij.size
    return m

# %%
cost_matrix = make_cost_matrix(y_orig, y)
indexes = Munkres().compute(cost_matrix)
mapping = [new for (_, new) in indexes]
y_orig_renamed = np.choose(y_orig, mapping).astype(np.int64)

mislabeled = y - y_orig_renamed
mislabeled[mislabeled != 0] = 1
mislabeled_orig = sum(mislabeled) / len(mislabeled)
print(f"{round(mislabeled_orig * 100, 2)}% mislabeled")
# Out:
# 3.37% mislabeled

# %% [markdown]
# Get cluster means for loss function input.

# %%
# get cluster means (used to calculate the cluster mean loss)
complete_data = X.copy()
complete_data["C"] = y_orig
cluster_means = complete_data.groupby("C").agg("mean")
cluster_means = cluster_means if -1 not in cluster_means.index else cluster_means.drop(-1)

# %% [markdown]
# ## 2. Filling Strategies
#
#
# ### 2.1. Define custom-loss
# The loss function for the model fitting shall be customized to improve cluster perforamnce. The custom loss is divided into 2 separate losses
#
# 1. **Reconstruction Loss**\
# Classic loss function, such as RMSE.
# 2. **Cluster-Mean Loss**\
# The distance to the nearest cluster mean shall be minimized.
# 3. **KL Divergence Loss**\
# Deviation of original distribution shall be minimized \
# (prob distribution based on https://stackoverflow.com/questions/57687458/how-to-calculate-probabilities-using-numpy-histogram-and-then-use-it-for-calcula \
# number of bins: D. Freedman & P. Diaconis (1981) “On the histogram as a density estimator: L2 theory”. Probability Theory and Related Fields 57 (4): 453-476)
#
# The chosen approach to implement the cluster-mean loss is as follows:\
# **Adapt the loss function** to calculate a distance to each cluster. The minimum distance (to the nearest cluster) will be used as a cluster-mean-loss. Minimizing this loss should result in the data point moving closer to the nearest cluster mean.\
# Potential Problem: loss functions currently work with y_true (true values) and y_score (predicted values). Calculating the distance would require all features. Calculating only the 1 dimensional distance will result in missing values being put into wrong clusters - depending on the first estimate.

# %%
# define custom loss function: extend L2-loss by cluster-mean-loss

from pytorch_tabnet.metrics import Metric
from sklearn.metrics import mean_squared_error
import astropy.stats

class custom_loss(Metric):

    def __init__(self):
        self._name = "custom_loss"
        self._maximize = False

    def __call__(self, y_true, y_score, cluster_means, y_name, x_val, y_val, cl_weights = [0.5, 1, 0.0001]):
        # reconstruction loss
        rmse = np.sqrt(mean_squared_error(y_true, y_score))
        
        # cluster mean loss
        cml = self.cluster_mean_loss(cluster_means, y_score, y_name, x_val, y_val)
        
        # KL divergence loss
        bins = len(astropy.stats.freedman_bin_width(y_true.reshape(1,-1)[0], return_bins=True)[1])
        distr1, distr2 = self.probability_dist(y_score, y_true, bins)
        KLdl = torch.nn.functional.kl_div(torch.tensor(distr1).log(), torch.tensor(distr2), log_target=False, reduction='sum').item()
        
        # total loss
        custom_loss = cl_weights[0] * rmse + cl_weights[1] * KLdl + cl_weights[2] * cml
        return custom_loss
    
    # calculate sum of distances to the closest cluster mean
    def cluster_mean_loss(self, cluster_means, y_score, y_name, x_val, y_val):
        
        # reorder cluster_means to match x_val columns (predicted feature is last column)
        cols = cluster_means.columns.tolist()
        feature_col = X.columns.get_loc(y_name)
        cols = cols[:feature_col] + cols[feature_col+1:] + [y_name]
        
        # x values extended by predicted values
        x_extended = pd.DataFrame(np.hstack((x_val, y_score)), columns=cols)


        # calculate distances to each cluster and select the closest one
        dist = []
        for cluster in range(cluster_means.shape[0]):
            dist.append(np.linalg.norm((x_extended - cluster_means.iloc[cluster]), axis=1))
            
        dist = pd.DataFrame(dist).T
        min_dist = dist.assign(min_dist=lambda d: d.min(1))["min_dist"]
        
        return sum(min_dist)
    
    # calculate probabilities
    def probability_dist(self, x, y, bins):
        # transforms 2 series into their probability distributions
        # histogram
        hist_xy = np.histogram2d(np.asarray(x)[:,0], np.asarray(y)[:,0], bins=bins)[0]

        # compute marginals
        hist_xy = hist_xy + sys.float_info.min # prevent division with 0
        hist_xy = hist_xy / np.sum(hist_xy)
        hist_x = np.sum(hist_xy, axis=1)
        hist_y = np.sum(hist_xy, axis=0)
        return(hist_x, hist_y)

# %% [markdown]
# ### 2.2. Fill missing values (TabNet).
#
# **Approach 1:**\
# For each feature that contains missing values, use all rows with complete other features as train set and predict missing values of the feature.\
# &rarr; Problem: lots of models, especially for high-dimensional datasets.
# Also problem, if more than one feature is missing values. &rarr; see Approach 2
#
# **Approach 2:**\
# Mask missing values as -1 (or some other value) and fit a model predicting each feature just like in approach 1.\
# &rarr; one model for each feature containing missing values.\
# Possible adaption: use predicted values to predict subsequent values (instead of using -1)

# %%
import time

from pytorch_tabnet.tab_model import TabNetRegressor
from sklearn.model_selection import train_test_split

features_to_predict = X_mv.columns[X_mv.isnull().any()]
X_reconstr = {}
output["costs"] = {}
output["runtimes"] = {}
output["predictions"] = {}

for run in range(config["RQ2"]["runs"]):
    
    print(f"Run {run + 1} / {config['RQ2']['runs']}")
    X_reconstr[run] = []
    output["costs"][f"run_{run}"] = {}
    output["runtimes"][f"run_{run}"] = {}
    output["predictions"][f"run_{run}"] = {}
    
    for i, experiment_value in enumerate(experiment_variable_values):
        
        config[experiment_dict_key][config["general"]["experiment_variable"]] = experiment_value
        
        time_start = time.time()
        X_reconstr[run].append(X_mv.copy())
        output["costs"][f"run_{run}"][str(experiment_value)] = {}
        output["runtimes"][f"run_{run}"][str(experiment_value)] = {}
        output["predictions"][f"run_{run}"][str(experiment_value)] = {}
        
        for feature in features_to_predict:
            
            # select % of features for prediction based on pred_features (e.g. 10% of randomly selected features)
            n_features = math.ceil(config["RQ2"]["pred_features"] * (len(X_mv.columns)) - 1)
            X_mv_masked = X_mv.copy().drop(feature, axis=1).sample(n=n_features, axis='columns')
            other_features = X_mv_masked.columns

            # mask other columns' missing values as defined in config (missing_value_mask)
            X_mv_masked[feature] = X_mv[feature]
            X_mv_masked[other_features] = X_mv_masked[(other_features)].fillna(config["general"]["missing_value_mask"])

            # separate complete rows as train data
            # separate column with missing values as target
            test_data = X_mv_masked[X_mv_masked[feature].isna()].drop(feature, axis=1).to_numpy()
            train_data = X_mv_masked[X_mv_masked[feature].notna()]
            train_features = train_data.drop(columns=feature).to_numpy()
            train_target = train_data[feature].to_numpy().reshape(-1,1)

            x_train, x_val, y_train, y_val = train_test_split(train_features, train_target, train_size=config["training"]["train_val_split"])

            # create & train model
            model = TabNetRegressor(**regressor_param)
            if config["model_param"]["eval_metric"] == ["custom_loss"]:
                model.fit(
                    x_train, y_train,
                    eval_set=[(x_val, y_val)],
                    **config["model_param"],
                    cluster_means=cluster_means,
                    y_name=feature,
                    x_val=x_val,
                    y_val=y_val,
                    cl_weights=config["training"]["cl_weights"]
                )
            else:
                model.fit(
                    x_train, y_train,
                    eval_set=[(x_val, y_val)],
                    **config["model_param"]
                )     

            #track runtime
            time_end = time.time()

            # save costs
            output["costs"][f"run_{run}"][str(experiment_value)][feature] = model.best_cost

            # save predictions
            predictions = [x[0] for x in model.predict(test_data)]
            output["predictions"][f"run_{run}"][str(experiment_value)][feature] = predictions
            
            # fill missing values with model predictions
            X_reconstr[run][i].loc[X_reconstr[run][i][feature].isna(), feature] = predictions

            # save outputs
            if save_models:

                # save model
                torch.save(model, os.path.join(models_path, f"Model_run{run}_{config['general']['experiment_variable']}{experiment_value}_{feature}.pt"))
            
            if save_output:
                # save runtimes
                output["runtimes"][f"run_{run}"][str(experiment_value)][feature] = time_end - time_start
# Out:
# Run 1 / 100
#
# Early stopping occurred at epoch 146 with best_epoch = 96 and best_val_0_custom_loss = 1300000002.97097
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_custom_loss = 1100000019.78254
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 113 with best_epoch = 63 and best_val_0_custom_loss = 2141421359.07736
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 145 with best_epoch = 95 and best_val_0_custom_loss = 4.99902
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 79 with best_epoch = 29 and best_val_0_custom_loss = 21.47636
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.94741
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 89 with best_epoch = 39 and best_val_0_custom_loss = 4.77638
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 107 with best_epoch = 57 and best_val_0_custom_loss = 20.50307
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 247 and best_val_0_custom_loss = 4.18579
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 248 and best_val_0_custom_loss = 4.23887
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 82 with best_epoch = 32 and best_val_0_custom_loss = 28.53014
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 103 with best_epoch = 53 and best_val_0_custom_loss = 4.32983
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 126 with best_epoch = 76 and best_val_0_custom_loss = 5.65785
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 98 with best_epoch = 48 and best_val_0_custom_loss = 19.33334
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 57 with best_epoch = 7 and best_val_0_custom_loss = 7.24454
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 64 with best_epoch = 14 and best_val_0_custom_loss = 4.10493
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 77 with best_epoch = 27 and best_val_0_custom_loss = 28.93966
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 212 and best_val_0_custom_loss = 3.75817
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 124 with best_epoch = 74 and best_val_0_custom_loss = 1.10209
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 74 with best_epoch = 24 and best_val_0_custom_loss = 13.6711
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 118 with best_epoch = 68 and best_val_0_custom_loss = 3.92349
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 83 with best_epoch = 33 and best_val_0_custom_loss = 4.5296
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 108 with best_epoch = 58 and best_val_0_custom_loss = 21.79328
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 243 and best_val_0_custom_loss = 3.87301
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 96 with best_epoch = 46 and best_val_0_custom_loss = 5.20238
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 60 with best_epoch = 10 and best_val_0_custom_loss = 29.83222
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 211 and best_val_0_custom_loss = 4.53065
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 144 with best_epoch = 94 and best_val_0_custom_loss = 1141421359.13881
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 102 with best_epoch = 52 and best_val_0_custom_loss = 841421385.27174
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 145 with best_epoch = 95 and best_val_0_custom_loss = 1282842715.8393
# Best weights from best epoch are automatically used!
# Run 2 / 100
#
# Early stopping occurred at epoch 140 with best_epoch = 90 and best_val_0_custom_loss = 1341421359.71491
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 77 with best_epoch = 27 and best_val_0_custom_loss = 1000000023.04393
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_custom_loss = 1682842715.3901
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 96 with best_epoch = 46 and best_val_0_custom_loss = 4.50581
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 100 with best_epoch = 50 and best_val_0_custom_loss = 28.40129
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 127 with best_epoch = 77 and best_val_0_custom_loss = 5.49114
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 128 with best_epoch = 78 and best_val_0_custom_loss = 4.41233
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 66 with best_epoch = 16 and best_val_0_custom_loss = 29.60565
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 199 with best_epoch = 149 and best_val_0_custom_loss = 5.58782
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 159 with best_epoch = 109 and best_val_0_custom_loss = 3.98946
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 114 with best_epoch = 64 and best_val_0_custom_loss = 36.15595
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 194 with best_epoch = 144 and best_val_0_custom_loss = 4.62143
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 129 with best_epoch = 79 and best_val_0_custom_loss = 4.37898
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_custom_loss = 19.92418
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 135 with best_epoch = 85 and best_val_0_custom_loss = 5.63536
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 65 with best_epoch = 15 and best_val_0_custom_loss = 5.0703
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 57 with best_epoch = 7 and best_val_0_custom_loss = 19.45637
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 124 with best_epoch = 74 and best_val_0_custom_loss = 4.57147
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 106 with best_epoch = 56 and best_val_0_custom_loss = 4.46433
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 59 with best_epoch = 9 and best_val_0_custom_loss = 28.63109
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 113 with best_epoch = 63 and best_val_0_custom_loss = 5.27863
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_custom_loss = 4.91588
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 64 with best_epoch = 14 and best_val_0_custom_loss = 22.15089
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 228 and best_val_0_custom_loss = 4.16269
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 94 with best_epoch = 44 and best_val_0_custom_loss = 5.18721
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 85 with best_epoch = 35 and best_val_0_custom_loss = 20.48393
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 130 with best_epoch = 80 and best_val_0_custom_loss = 2.56709
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 211 and best_val_0_custom_loss = 1224264071.39066
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 85 with best_epoch = 35 and best_val_0_custom_loss = 941421370.10656
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 83 with best_epoch = 33 and best_val_0_custom_loss = 1882842716.27739
# Best weights from best epoch are automatically used!
# Run 3 / 100
#
# Early stopping occurred at epoch 82 with best_epoch = 32 and best_val_0_custom_loss = 941421360.17055
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 74 with best_epoch = 24 and best_val_0_custom_loss = 1000000016.38221
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 201 and best_val_0_custom_loss = 1641421358.94044
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 115 with best_epoch = 65 and best_val_0_custom_loss = 4.61468
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 63 with best_epoch = 13 and best_val_0_custom_loss = 21.05444
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 92 with best_epoch = 42 and best_val_0_custom_loss = 5.23933
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 226 with best_epoch = 176 and best_val_0_custom_loss = 4.21613
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_custom_loss = 30.71021
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 193 with best_epoch = 143 and best_val_0_custom_loss = 4.63313
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 241 with best_epoch = 191 and best_val_0_custom_loss = 4.01215
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 88 with best_epoch = 38 and best_val_0_custom_loss = 10.42206
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 128 with best_epoch = 78 and best_val_0_custom_loss = 4.53686
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 134 with best_epoch = 84 and best_val_0_custom_loss = 4.58143
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 60 with best_epoch = 10 and best_val_0_custom_loss = 12.06052
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 179 with best_epoch = 129 and best_val_0_custom_loss = 4.65578
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 238 with best_epoch = 188 and best_val_0_custom_loss = 4.44607
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 55 with best_epoch = 5 and best_val_0_custom_loss = 23.89767
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 148 with best_epoch = 98 and best_val_0_custom_loss = 4.03112
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 181 with best_epoch = 131 and best_val_0_custom_loss = 4.0045
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 87 with best_epoch = 37 and best_val_0_custom_loss = 21.0461
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 129 with best_epoch = 79 and best_val_0_custom_loss = 4.72432
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 69 with best_epoch = 19 and best_val_0_custom_loss = 4.3768
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 96 with best_epoch = 46 and best_val_0_custom_loss = 25.61526
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 113 with best_epoch = 63 and best_val_0_custom_loss = 4.32327
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 153 with best_epoch = 103 and best_val_0_custom_loss = 4.78591
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 58 with best_epoch = 8 and best_val_0_custom_loss = 27.42479
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 160 with best_epoch = 110 and best_val_0_custom_loss = 5.07654
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 206 with best_epoch = 156 and best_val_0_custom_loss = 841421359.60771
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 88 with best_epoch = 38 and best_val_0_custom_loss = 941421367.68295
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 123 with best_epoch = 73 and best_val_0_custom_loss = 2124264071.37625
# Best weights from best epoch are automatically used!
# Run 4 / 100
#
# Early stopping occurred at epoch 102 with best_epoch = 52 and best_val_0_custom_loss = 1541421358.93602
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 69 with best_epoch = 19 and best_val_0_custom_loss = 1441421374.27729
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 2082842714.87744
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 93 with best_epoch = 43 and best_val_0_custom_loss = 4.48384
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 53 with best_epoch = 3 and best_val_0_custom_loss = 26.38806
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_custom_loss = 6.51624
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_custom_loss = 4.48684
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 150 with best_epoch = 100 and best_val_0_custom_loss = 19.49744
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 59 with best_epoch = 9 and best_val_0_custom_loss = 5.24982
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 134 with best_epoch = 84 and best_val_0_custom_loss = 4.21032
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 67 with best_epoch = 17 and best_val_0_custom_loss = 19.36507
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 93 with best_epoch = 43 and best_val_0_custom_loss = 4.41629
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 135 with best_epoch = 85 and best_val_0_custom_loss = 4.3323
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 66 with best_epoch = 16 and best_val_0_custom_loss = 24.10026
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 247 and best_val_0_custom_loss = 3.94959
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 247 and best_val_0_custom_loss = 3.70105
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 80 with best_epoch = 30 and best_val_0_custom_loss = 24.52124
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 122 with best_epoch = 72 and best_val_0_custom_loss = 4.54443
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 243 and best_val_0_custom_loss = 4.31447
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_custom_loss = 21.25621
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 3.9277
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 163 with best_epoch = 113 and best_val_0_custom_loss = 3.97159
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 97 with best_epoch = 47 and best_val_0_custom_loss = 15.19311
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 232 and best_val_0_custom_loss = 4.41299
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 104 with best_epoch = 54 and best_val_0_custom_loss = 3.31643
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_custom_loss = 25.21585
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 162 with best_epoch = 112 and best_val_0_custom_loss = 5.31937
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 85 with best_epoch = 35 and best_val_0_custom_loss = 1041421363.68399
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_custom_loss = 1300000012.55822
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 239 and best_val_0_custom_loss = 2224264071.07593
# Best weights from best epoch are automatically used!
# Run 5 / 100
#
# Early stopping occurred at epoch 54 with best_epoch = 4 and best_val_0_custom_loss = 900000004.92276
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 80 with best_epoch = 30 and best_val_0_custom_loss = 900000016.88485
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 246 and best_val_0_custom_loss = 1582842713.29501
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 112 with best_epoch = 62 and best_val_0_custom_loss = 4.33879
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 63 with best_epoch = 13 and best_val_0_custom_loss = 19.65116
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 243 with best_epoch = 193 and best_val_0_custom_loss = 5.11613
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 202 with best_epoch = 152 and best_val_0_custom_loss = 4.47929
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 76 with best_epoch = 26 and best_val_0_custom_loss = 20.96998
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 96 with best_epoch = 46 and best_val_0_custom_loss = 4.56107
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 113 with best_epoch = 63 and best_val_0_custom_loss = 4.15376
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 58 with best_epoch = 8 and best_val_0_custom_loss = 25.29759
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 105 with best_epoch = 55 and best_val_0_custom_loss = 4.17609
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 179 with best_epoch = 129 and best_val_0_custom_loss = 4.32963
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 65 with best_epoch = 15 and best_val_0_custom_loss = 21.31256
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 247 and best_val_0_custom_loss = 1.20232
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 153 with best_epoch = 103 and best_val_0_custom_loss = 3.85285
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 99 with best_epoch = 49 and best_val_0_custom_loss = 17.50513
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 234 and best_val_0_custom_loss = 4.25069
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 136 with best_epoch = 86 and best_val_0_custom_loss = 4.34334
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 67 with best_epoch = 17 and best_val_0_custom_loss = 19.36221
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 67 with best_epoch = 17 and best_val_0_custom_loss = 4.69622
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 141 with best_epoch = 91 and best_val_0_custom_loss = 3.94336
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 114 with best_epoch = 64 and best_val_0_custom_loss = 21.01571
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 242 and best_val_0_custom_loss = 4.09811
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 156 with best_epoch = 106 and best_val_0_custom_loss = 4.23647
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 103 with best_epoch = 53 and best_val_0_custom_loss = 28.14024
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 2.35604
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 150 with best_epoch = 100 and best_val_0_custom_loss = 1400000003.65572
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 82 with best_epoch = 32 and best_val_0_custom_loss = 1000000029.53225
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 84 with best_epoch = 34 and best_val_0_custom_loss = 1782842717.00114
# Best weights from best epoch are automatically used!
# Run 6 / 100
#
# Early stopping occurred at epoch 127 with best_epoch = 77 and best_val_0_custom_loss = 1541421357.29891
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 125 with best_epoch = 75 and best_val_0_custom_loss = 1200000018.0559
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 139 with best_epoch = 89 and best_val_0_custom_loss = 1541421358.47106
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 96 with best_epoch = 46 and best_val_0_custom_loss = 4.99074
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 72 with best_epoch = 22 and best_val_0_custom_loss = 27.20963
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 136 with best_epoch = 86 and best_val_0_custom_loss = 4.97264
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 229 and best_val_0_custom_loss = 3.60835
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 69 with best_epoch = 19 and best_val_0_custom_loss = 25.46862
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 185 with best_epoch = 135 and best_val_0_custom_loss = 4.07476
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 138 with best_epoch = 88 and best_val_0_custom_loss = 4.32782
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_custom_loss = 16.77943
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 168 with best_epoch = 118 and best_val_0_custom_loss = 4.57659
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 224 and best_val_0_custom_loss = 4.10969
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 89 with best_epoch = 39 and best_val_0_custom_loss = 21.59643
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 148 with best_epoch = 98 and best_val_0_custom_loss = 4.17535
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_custom_loss = 5.63821
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 64 with best_epoch = 14 and best_val_0_custom_loss = 16.03395
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 90 with best_epoch = 40 and best_val_0_custom_loss = 4.24208
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 139 with best_epoch = 89 and best_val_0_custom_loss = 4.6464
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 71 with best_epoch = 21 and best_val_0_custom_loss = 28.83127
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 225 and best_val_0_custom_loss = 4.03346
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 77 with best_epoch = 27 and best_val_0_custom_loss = 5.018
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 93 with best_epoch = 43 and best_val_0_custom_loss = 19.93264
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.13471
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 136 with best_epoch = 86 and best_val_0_custom_loss = 4.56284
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_custom_loss = 27.21018
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 180 with best_epoch = 130 and best_val_0_custom_loss = 4.91081
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 103 with best_epoch = 53 and best_val_0_custom_loss = 1382842715.6023
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 85 with best_epoch = 35 and best_val_0_custom_loss = 1000000010.92374
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 188 with best_epoch = 138 and best_val_0_custom_loss = 1582842715.2897
# Best weights from best epoch are automatically used!
# Run 7 / 100
#
# Early stopping occurred at epoch 178 with best_epoch = 128 and best_val_0_custom_loss = 741421359.44591
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 85 with best_epoch = 35 and best_val_0_custom_loss = 1100000032.74415
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 79 with best_epoch = 29 and best_val_0_custom_loss = 2165685427.97777
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 130 with best_epoch = 80 and best_val_0_custom_loss = 4.30485
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 74 with best_epoch = 24 and best_val_0_custom_loss = 28.65327
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 52 with best_epoch = 2 and best_val_0_custom_loss = 29.62351
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 60 with best_epoch = 10 and best_val_0_custom_loss = 4.59547
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 79 with best_epoch = 29 and best_val_0_custom_loss = 28.3219
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 180 with best_epoch = 130 and best_val_0_custom_loss = 4.72495
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 165 with best_epoch = 115 and best_val_0_custom_loss = 1.3933
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 55 with best_epoch = 5 and best_val_0_custom_loss = 21.78663
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 243 and best_val_0_custom_loss = 4.04441
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 96 with best_epoch = 46 and best_val_0_custom_loss = 4.08571
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 91 with best_epoch = 41 and best_val_0_custom_loss = 23.0564
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 95 with best_epoch = 45 and best_val_0_custom_loss = 4.72661
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 106 with best_epoch = 56 and best_val_0_custom_loss = 4.35092
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 74 with best_epoch = 24 and best_val_0_custom_loss = 25.912
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 3.76202
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 71 with best_epoch = 21 and best_val_0_custom_loss = 4.78794
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 83 with best_epoch = 33 and best_val_0_custom_loss = 22.62269
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 155 with best_epoch = 105 and best_val_0_custom_loss = 4.70507
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 229 with best_epoch = 179 and best_val_0_custom_loss = 3.72207
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 55 with best_epoch = 5 and best_val_0_custom_loss = 22.7548
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 1.26447
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 146 with best_epoch = 96 and best_val_0_custom_loss = 4.85951
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 110 with best_epoch = 60 and best_val_0_custom_loss = 15.2016
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 148 with best_epoch = 98 and best_val_0_custom_loss = 4.51562
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 65 with best_epoch = 15 and best_val_0_custom_loss = 1341421360.7278
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 78 with best_epoch = 28 and best_val_0_custom_loss = 700000014.24833
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 86 with best_epoch = 36 and best_val_0_custom_loss = 2141421358.86401
# Best weights from best epoch are automatically used!
# Run 8 / 100
#
# Early stopping occurred at epoch 145 with best_epoch = 95 and best_val_0_custom_loss = 1200000002.76199
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 55 with best_epoch = 5 and best_val_0_custom_loss = 1100000022.60104
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 241 and best_val_0_custom_loss = 2224264069.68222
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 198 with best_epoch = 148 and best_val_0_custom_loss = 4.38196
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 53 with best_epoch = 3 and best_val_0_custom_loss = 24.92438
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 136 with best_epoch = 86 and best_val_0_custom_loss = 2.80715
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 118 with best_epoch = 68 and best_val_0_custom_loss = 4.32096
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_custom_loss = 16.92817
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 3.97757
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 57 with best_epoch = 7 and best_val_0_custom_loss = 8.69323
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 77 with best_epoch = 27 and best_val_0_custom_loss = 19.3438
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 109 with best_epoch = 59 and best_val_0_custom_loss = 4.87077
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 138 with best_epoch = 88 and best_val_0_custom_loss = 4.06054
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_custom_loss = 15.0693
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 212 with best_epoch = 162 and best_val_0_custom_loss = 3.86107
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 63 with best_epoch = 13 and best_val_0_custom_loss = 4.73362
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_custom_loss = 18.24165
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 53 with best_epoch = 3 and best_val_0_custom_loss = 5.8203
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 231 and best_val_0_custom_loss = 4.08913
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 61 with best_epoch = 11 and best_val_0_custom_loss = 17.99568
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 3.84882
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 155 with best_epoch = 105 and best_val_0_custom_loss = 4.04173
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 61 with best_epoch = 11 and best_val_0_custom_loss = 28.32392
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 114 with best_epoch = 64 and best_val_0_custom_loss = 4.40625
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 168 with best_epoch = 118 and best_val_0_custom_loss = 4.36872
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 94 with best_epoch = 44 and best_val_0_custom_loss = 21.3307
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 204 and best_val_0_custom_loss = 5.53935
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 244 and best_val_0_custom_loss = 1200000003.10836
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 98 with best_epoch = 48 and best_val_0_custom_loss = 941421378.09664
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 231 and best_val_0_custom_loss = 1824264071.2165
# Best weights from best epoch are automatically used!
# Run 9 / 100
#
# Early stopping occurred at epoch 67 with best_epoch = 17 and best_val_0_custom_loss = 1200000004.75192
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 58 with best_epoch = 8 and best_val_0_custom_loss = 1100000029.25517
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 122 with best_epoch = 72 and best_val_0_custom_loss = 2124264071.65658
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 174 with best_epoch = 124 and best_val_0_custom_loss = 5.09184
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 55 with best_epoch = 5 and best_val_0_custom_loss = 36.60671
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 79 with best_epoch = 29 and best_val_0_custom_loss = 3.66511
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 108 with best_epoch = 58 and best_val_0_custom_loss = 4.19603
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 60 with best_epoch = 10 and best_val_0_custom_loss = 20.49303
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 221 and best_val_0_custom_loss = 4.26272
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 159 with best_epoch = 109 and best_val_0_custom_loss = 4.34145
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_custom_loss = 16.72586
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 140 with best_epoch = 90 and best_val_0_custom_loss = 4.4352
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_custom_loss = 4.67068
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 69 with best_epoch = 19 and best_val_0_custom_loss = 21.2791
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 54 with best_epoch = 4 and best_val_0_custom_loss = 5.3556
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 141 with best_epoch = 91 and best_val_0_custom_loss = 1.45895
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 66 with best_epoch = 16 and best_val_0_custom_loss = 23.75308
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 147 with best_epoch = 97 and best_val_0_custom_loss = 4.20194
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 168 with best_epoch = 118 and best_val_0_custom_loss = 5.10616
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 98 with best_epoch = 48 and best_val_0_custom_loss = 32.43905
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.49562
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 234 and best_val_0_custom_loss = 4.04676
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_custom_loss = 24.67681
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 155 with best_epoch = 105 and best_val_0_custom_loss = 1.41794
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 135 with best_epoch = 85 and best_val_0_custom_loss = 5.2238
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 65 with best_epoch = 15 and best_val_0_custom_loss = 13.91741
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 138 with best_epoch = 88 and best_val_0_custom_loss = 4.84063
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 86 with best_epoch = 36 and best_val_0_custom_loss = 1441421360.21805
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 77 with best_epoch = 27 and best_val_0_custom_loss = 1041421375.6167
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 161 with best_epoch = 111 and best_val_0_custom_loss = 1941421359.08044
# Best weights from best epoch are automatically used!
# Run 10 / 100
# Early stopping occurred at epoch 203 with best_epoch = 153 and best_val_0_custom_loss = 1100000002.90093
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 85 with best_epoch = 35 and best_val_0_custom_loss = 941421369.09112
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 125 with best_epoch = 75 and best_val_0_custom_loss = 1482842715.49194
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 217 and best_val_0_custom_loss = 4.54816
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 94 with best_epoch = 44 and best_val_0_custom_loss = 23.47182
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 243 and best_val_0_custom_loss = 2.40078
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 158 with best_epoch = 108 and best_val_0_custom_loss = 4.35123
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 55 with best_epoch = 5 and best_val_0_custom_loss = 25.16052
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 65 with best_epoch = 15 and best_val_0_custom_loss = 5.04194
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 247 with best_epoch = 197 and best_val_0_custom_loss = 4.11103
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 125 with best_epoch = 75 and best_val_0_custom_loss = 20.31802
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 83 with best_epoch = 33 and best_val_0_custom_loss = 1.44873
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 103 with best_epoch = 53 and best_val_0_custom_loss = 4.56122
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 93 with best_epoch = 43 and best_val_0_custom_loss = 23.31267
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 225 with best_epoch = 175 and best_val_0_custom_loss = 3.74005
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 172 with best_epoch = 122 and best_val_0_custom_loss = 3.9625
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 96 with best_epoch = 46 and best_val_0_custom_loss = 25.65751
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 74 with best_epoch = 24 and best_val_0_custom_loss = 1.59731
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 3.62001
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 137 with best_epoch = 87 and best_val_0_custom_loss = 19.02462
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.11149
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 105 with best_epoch = 55 and best_val_0_custom_loss = 3.88208
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 52 with best_epoch = 2 and best_val_0_custom_loss = 47.42344
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 245 with best_epoch = 195 and best_val_0_custom_loss = 3.85251
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 88 with best_epoch = 38 and best_val_0_custom_loss = 5.24979
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 117 with best_epoch = 67 and best_val_0_custom_loss = 12.85051
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 244 and best_val_0_custom_loss = 4.50871
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 239 and best_val_0_custom_loss = 700000001.21404
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 94 with best_epoch = 44 and best_val_0_custom_loss = 800000015.03938
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 69 with best_epoch = 19 and best_val_0_custom_loss = 1982842715.38902
# Best weights from best epoch are automatically used!
# Run 11 / 100
#
# Early stopping occurred at epoch 116 with best_epoch = 66 and best_val_0_custom_loss = 1041421358.82408
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 105 with best_epoch = 55 and best_val_0_custom_loss = 800000012.29577
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 211 with best_epoch = 161 and best_val_0_custom_loss = 1665685426.93877
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 141 with best_epoch = 91 and best_val_0_custom_loss = 4.24669
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 78 with best_epoch = 28 and best_val_0_custom_loss = 26.43306
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 66 with best_epoch = 16 and best_val_0_custom_loss = 5.82481
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 77 with best_epoch = 27 and best_val_0_custom_loss = 4.47553
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 71 with best_epoch = 21 and best_val_0_custom_loss = 19.17587
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 137 with best_epoch = 87 and best_val_0_custom_loss = 4.7434
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 102 with best_epoch = 52 and best_val_0_custom_loss = 4.59615
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 93 with best_epoch = 43 and best_val_0_custom_loss = 26.53748
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.23505
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 120 with best_epoch = 70 and best_val_0_custom_loss = 4.20769
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 71 with best_epoch = 21 and best_val_0_custom_loss = 16.19325
# ...
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 58 with best_epoch = 8 and best_val_0_custom_loss = 6.74818
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 143 with best_epoch = 93 and best_val_0_custom_loss = 18.26477
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 80 with best_epoch = 30 and best_val_0_custom_loss = 5.38755
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 246 with best_epoch = 196 and best_val_0_custom_loss = 1341421359.40395
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 76 with best_epoch = 26 and best_val_0_custom_loss = 841421380.65177
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 124 with best_epoch = 74 and best_val_0_custom_loss = 1582842715.34757
# Best weights from best epoch are automatically used!
# Run 97 / 100
#
# Early stopping occurred at epoch 135 with best_epoch = 85 and best_val_0_custom_loss = 1000000001.46537
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 57 with best_epoch = 7 and best_val_0_custom_loss = 1000000019.02429
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 198 with best_epoch = 148 and best_val_0_custom_loss = 1524264071.59598
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 119 with best_epoch = 69 and best_val_0_custom_loss = 4.30312
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_custom_loss = 21.50704
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 105 with best_epoch = 55 and best_val_0_custom_loss = 5.5654
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 125 with best_epoch = 75 and best_val_0_custom_loss = 5.92291
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 61 with best_epoch = 11 and best_val_0_custom_loss = 15.59114
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 124 with best_epoch = 74 and best_val_0_custom_loss = 4.76124
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 243 and best_val_0_custom_loss = 3.94495
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 107 with best_epoch = 57 and best_val_0_custom_loss = 25.84799
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 246 and best_val_0_custom_loss = 4.15956
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 76 with best_epoch = 26 and best_val_0_custom_loss = 6.12803
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 164 with best_epoch = 114 and best_val_0_custom_loss = 29.6936
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 173 with best_epoch = 123 and best_val_0_custom_loss = 3.8837
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 196 with best_epoch = 146 and best_val_0_custom_loss = 1.70355
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 87 with best_epoch = 37 and best_val_0_custom_loss = 31.61715
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 141 with best_epoch = 91 and best_val_0_custom_loss = 3.92554
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 226 and best_val_0_custom_loss = 4.20571
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_custom_loss = 21.65455
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 133 with best_epoch = 83 and best_val_0_custom_loss = 4.30903
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_custom_loss = 2.4449
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 89 with best_epoch = 39 and best_val_0_custom_loss = 28.40773
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_custom_loss = 4.24365
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 171 with best_epoch = 121 and best_val_0_custom_loss = 4.71114
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 108 with best_epoch = 58 and best_val_0_custom_loss = 35.5104
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 158 with best_epoch = 108 and best_val_0_custom_loss = 6.13204
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 1000000003.01932
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 54 with best_epoch = 4 and best_val_0_custom_loss = 1500000031.59556
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 248 and best_val_0_custom_loss = 1800000002.71148
# Best weights from best epoch are automatically used!
# Run 98 / 100
#
# Early stopping occurred at epoch 72 with best_epoch = 22 and best_val_0_custom_loss = 1341421359.78695
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 88 with best_epoch = 38 and best_val_0_custom_loss = 1300000019.78933
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 1441421358.93121
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.3339
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 120 with best_epoch = 70 and best_val_0_custom_loss = 22.69346
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 83 with best_epoch = 33 and best_val_0_custom_loss = 8.20079
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_custom_loss = 3.96221
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 71 with best_epoch = 21 and best_val_0_custom_loss = 11.637
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 119 with best_epoch = 69 and best_val_0_custom_loss = 4.04886
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 67 with best_epoch = 17 and best_val_0_custom_loss = 4.59526
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 217 with best_epoch = 167 and best_val_0_custom_loss = 31.89553
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 177 with best_epoch = 127 and best_val_0_custom_loss = 4.39101
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 72 with best_epoch = 22 and best_val_0_custom_loss = 4.71808
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 144 with best_epoch = 94 and best_val_0_custom_loss = 18.44806
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 171 with best_epoch = 121 and best_val_0_custom_loss = 4.09509
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 65 with best_epoch = 15 and best_val_0_custom_loss = 4.2875
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 54 with best_epoch = 4 and best_val_0_custom_loss = 39.95269
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.22627
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 133 with best_epoch = 83 and best_val_0_custom_loss = 4.83646
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_custom_loss = 28.48969
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 240 with best_epoch = 190 and best_val_0_custom_loss = 4.58945
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 58 with best_epoch = 8 and best_val_0_custom_loss = 4.22736
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 58 with best_epoch = 8 and best_val_0_custom_loss = 21.98779
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 123 with best_epoch = 73 and best_val_0_custom_loss = 4.42576
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 211 with best_epoch = 161 and best_val_0_custom_loss = 4.84786
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 100 with best_epoch = 50 and best_val_0_custom_loss = 18.69055
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 236 and best_val_0_custom_loss = 5.08917
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_custom_loss = 1041421360.59901
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 65 with best_epoch = 15 and best_val_0_custom_loss = 941421377.63292
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 78 with best_epoch = 28 and best_val_0_custom_loss = 2165685430.79424
# Best weights from best epoch are automatically used!
# Run 99 / 100
#
# Early stopping occurred at epoch 249 with best_epoch = 199 and best_val_0_custom_loss = 1000000002.9349
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 144 with best_epoch = 94 and best_val_0_custom_loss = 1000000017.57777
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 80 with best_epoch = 30 and best_val_0_custom_loss = 1500000002.88503
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 86 with best_epoch = 36 and best_val_0_custom_loss = 4.81106
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_custom_loss = 15.68601
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 249 with best_epoch = 199 and best_val_0_custom_loss = 4.88768
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 132 with best_epoch = 82 and best_val_0_custom_loss = 4.59015
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 60 with best_epoch = 10 and best_val_0_custom_loss = 26.60331
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 244 and best_val_0_custom_loss = 3.993
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.32137
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 55 with best_epoch = 5 and best_val_0_custom_loss = 18.98117
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 80 with best_epoch = 30 and best_val_0_custom_loss = 4.95011
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_custom_loss = 4.23472
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_custom_loss = 16.74707
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 74 with best_epoch = 24 and best_val_0_custom_loss = 4.81108
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 191 with best_epoch = 141 and best_val_0_custom_loss = 4.10821
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_custom_loss = 22.98082
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 236 with best_epoch = 186 and best_val_0_custom_loss = 4.21057
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 60 with best_epoch = 10 and best_val_0_custom_loss = 5.35307
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 58 with best_epoch = 8 and best_val_0_custom_loss = 27.39238
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 246 with best_epoch = 196 and best_val_0_custom_loss = 4.02407
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 109 with best_epoch = 59 and best_val_0_custom_loss = 4.82504
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_custom_loss = 16.02027
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 235 and best_val_0_custom_loss = 3.78676
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 111 with best_epoch = 61 and best_val_0_custom_loss = 4.88626
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 71 with best_epoch = 21 and best_val_0_custom_loss = 20.51555
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 89 with best_epoch = 39 and best_val_0_custom_loss = 5.60471
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 129 with best_epoch = 79 and best_val_0_custom_loss = 1082842716.06719
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_custom_loss = 700000021.35143
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 234 and best_val_0_custom_loss = 1582842715.31651
# Best weights from best epoch are automatically used!
# Run 100 / 100
# Stop training because you reached max_epochs = 250 with best_epoch = 245 and best_val_0_custom_loss = 1600000002.66912
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_custom_loss = 1300000013.29143
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 2082842714.44469
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 131 with best_epoch = 81 and best_val_0_custom_loss = 4.19988
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_custom_loss = 17.68529
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 82 with best_epoch = 32 and best_val_0_custom_loss = 5.05926
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 136 with best_epoch = 86 and best_val_0_custom_loss = 4.37853
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 66 with best_epoch = 16 and best_val_0_custom_loss = 28.08609
# Best weights from best epoch are automatically used!

# %% [markdown]
# ## 3. Reconstruct Dataset
# choose best model based on min. squared custom loss (punishing large outliers in losses for single features)

# %%
best_per_run = []
best_per_run_index = []
for run in range(config["RQ2"]["runs"]):
    cost_list = list(output["costs"][f"run_{run}"].values())
    cost_totals = [sum(c**2 for c in list(x.values())) for x in cost_list]
    best_per_run.append(min(cost_totals))
    best_per_run_index.append(cost_totals.index(min(cost_totals)))
    
best_run = best_per_run.index(min(best_per_run))
best_model = best_per_run_index[best_run]
print(f"Best model: run {best_run} model {best_model}")

X_best = X_reconstr[best_run][best_model]

# %% [markdown]
# ## 4. Clustering
# Apply k-means (k=3) on reconstructed data. In order to make the clusters comparable, the k-Means labels will be replaced using Munkres / Hungarian algorithm as explained here:\
# https://gist.github.com/siolag161/dc6e42b64e1bde1f263b \
# https://github.com/benchaplin/hungarian-algorithm

# %%
# apply clustering
y_reconstr = []
for run in range(config["RQ2"]["runs"]):
    y_reconstr.append([])
    for i, var in enumerate(experiment_variable_values):
        
        X_reconstr_scaled = pd.DataFrame(StandardScaler().fit_transform(X_reconstr[run][i]))
        k_mean_reconstr = KMeans(n_clusters=3).fit(X_reconstr_scaled)
        
        cost_matrix = make_cost_matrix(k_mean_reconstr.labels_, y)
        indexes = Munkres().compute(cost_matrix)
        mapping = [new for (_, new) in indexes]
        
        y_reconstr[run].append(np.choose(k_mean_reconstr.labels_,mapping).astype(np.int64))

# %% [markdown]
# ## 5. Cluster Performance

# %% [markdown]
# ### 5.1 Feature Distributions
# #### 5.1.1 Distr. Plots based on best model predictions

# %%
# plot distributions
bins = len(astropy.stats.freedman_bin_width(X[feature], return_bins=True)[1])
n_feat = len(features_to_predict) if len(features_to_predict) > 1 else 2

fig, (ax) = plt.subplots(n_feat, 2, figsize=(10,n_feat*3))
fig.suptitle(f"distributions based on best model", fontweight='bold')
for n, feature in enumerate(X_best[features_to_predict]):
    ax[n, 0].hist(X[feature], bins=bins)
    ax[n, 0].set_title(f"{feature}_orig")
    ax[n, 1].hist(X_best[feature], bins=bins)
    ax[n, 1].set_title(f"{feature}_reconstructed")

fig.tight_layout()
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "feature distributions.png"), **config["plots"])

# %% [markdown]
# #### 5.1.1 Predictions out of original min/max range

# %%
data = {}

for feature in features_to_predict:
    data[feature] = {}
    n_predictions = sum(X_mv[feature].isna()) * config["RQ2"]["runs"]
    min_val = X[feature].min()
    max_val = X[feature].max()
    n_inliers = 0
    
    for experiment_value in experiment_variable_values:
        data[feature][str(experiment_value)] = 0  
        
        for run in range(config["RQ2"]["runs"]):
            data[feature][str(experiment_value)] += sum([True if x > min_val and x < max_val else False for x in output["predictions"][f"run_{run}"][str(experiment_value)][feature]])
    
        data[feature][str(experiment_value)] = data[feature][str(experiment_value)] / n_predictions

# %%
n_features = len(features_to_predict) if len(features_to_predict) > 1 else 2
base_height = 5
base_width = 2
fontsize=20

fig, axs = plt.subplots(n_features, figsize=(len(experiment_variable_values)*base_width,n_features*base_height))
fig.suptitle(f"% of predicted values within original range", fontweight='bold',fontsize=fontsize)

for nr, feature in enumerate(features_to_predict):
    axs[nr].plot(data[feature].keys(), data[feature].values())
    axs[nr].set_xlabel(config["general"]["experiment_variable"],fontsize=fontsize)
    axs[nr].set_ylabel(feature, fontweight='bold', fontsize=fontsize)
    axs[nr].set_ylim([0, 1])

plt.tight_layout() 

if save_output:
    plt.savefig(os.path.join(plots_path, "5_prediction_range_rel.png"), **config["plots"])

plt.show()

# %%
data = {}
for feature in features_to_predict:
    data[feature] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        # add all replaced values from all runs to a list
        data[feature][str(experiment_value)] = []
        for run in range(config["RQ2"]["runs"]): 
            data[feature][str(experiment_value)].extend(output["predictions"][f"run_{run}"][str(experiment_value)][feature])

nr_features = len(features_to_predict) if len(features_to_predict) > 1 else 2
base_height = 10
base_width = 3
fontsize=20

fig, axs = plt.subplots(nr_features, figsize=(len(experiment_variable_values)*base_width,nr_features*base_height))
fig.suptitle(f"Predicted values", fontweight='bold',fontsize=fontsize)

for nr, feature in enumerate(features_to_predict):
    axs[nr].boxplot(data[feature].values(), patch_artist = True)
    axs[nr].set_xticklabels(data[feature].keys(),fontsize=fontsize)
    axs[nr].set_xlabel(config["general"]["experiment_variable"],fontsize=fontsize)
    axs[nr].set_ylabel(feature, fontweight='bold', fontsize=fontsize)
    axs[nr].axhline(X[feature].min(),color='red',ls='-')
    axs[nr].axhline(X[feature].max(),color='red',ls='-')
    axs[nr].text(0.9, 0.9, f"min {X[feature].min()}\nmax {X[feature].max()}", horizontalalignment='center', verticalalignment='center', transform=axs[nr].transAxes, fontsize=30)

plt.tight_layout() 

if save_output:
    plt.savefig(os.path.join(plots_path, "5_prediction_range_abs.png"), **config["plots"])

plt.show()

# %% [markdown]
# #### 5.1.2 KL Divergence

# %%
# KL Divergence
def kl_divergence(feature1, feature2):
    
    # calculate probability distributions
    def probability_dist(x, y, bins):
        # transforms 2 series into their probability distributions
        # histogram
        hist_xy = np.histogram2d(x, y, bins=bins)[0]

        # compute marginals
        hist_xy = hist_xy + sys.float_info.min # prevent division with 0
        hist_xy = hist_xy / np.sum(hist_xy)
        hist_x = np.sum(hist_xy, axis=1)
        hist_y = np.sum(hist_xy, axis=0)
        return(hist_x, hist_y)

    # calculate kl divergence
    bins = len(astropy.stats.freedman_bin_width(feature1, return_bins=True)[1])
    distr1, distr2 = probability_dist(feature1, feature2, bins)
    return torch.nn.functional.kl_div(torch.tensor(distr1).log(), torch.tensor(distr2), log_target=False, reduction='sum').item()

# %%
output["kl_divergence"] = {}

# save kl divergence
for run in range(config["RQ2"]["runs"]):
    output["kl_divergence"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        output["kl_divergence"][f"run_{run}"][str(experiment_value)] = {}
        for feature in features_to_predict:
            output["kl_divergence"][f"run_{run}"][str(experiment_value)][feature] = kl_divergence(X[feature], X_reconstr[run][i][feature])

# %%
# plot
data = {}
for feature in features_to_predict:
    data[feature] = {}
    for experiment_value in experiment_variable_values:
        data[feature][str(experiment_value)] = [x[str(experiment_value)][feature] for x in output["kl_divergence"].values()]

nr_features = len(features_to_predict) if len(features_to_predict) > 1 else 2
fig, axs = plt.subplots(nr_features, figsize=(len(experiment_variable_values)*3,nr_features*4))
fig.suptitle(f"KL divergence, {config['RQ2']['runs']} runs", fontweight='bold')

for nr, feature in enumerate(features_to_predict):
    axs[nr].boxplot(data[feature].values(), patch_artist = True) # , showfliers=False
    axs[nr].set_xticklabels(data[feature].keys())
    axs[nr].set_xlabel(config["general"]["experiment_variable"])
    axs[nr].set_ylabel(feature, fontweight='bold')

plt.tight_layout() 

if save_output:
    plt.savefig(os.path.join(plots_path, "5_kl_divergence.png"), **config["plots"])
    
plt.show()

# %% [markdown]
# ### 5.2 Silhouette Score

# %%
from sklearn.metrics import silhouette_score

output["silhouette_scores"] = {}
output["silhouette_scores"]["orig_data"] = float(silhouette_score(X, np.ravel(y)))

for run in range(config["RQ2"]["runs"]):
    output["silhouette_scores"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        if len(np.unique(y_reconstr[run][i])) > 1:
            output["silhouette_scores"][f"run_{run}"][str(experiment_value)] = float(silhouette_score(X_reconstr[run][i], y_reconstr[run][i]))
        else:
            output["silhouette_scores"][f"run_{run}"][str(experiment_value)] = np.nan

# %%
# plot
sil_scores = output["silhouette_scores"].copy()
del(sil_scores["orig_data"])

data = {}
for experiment_value in experiment_variable_values:
    data[str(experiment_value)] = [x[str(experiment_value)] for x in sil_scores.values()]

fig, ax = plt.subplots()
ax.boxplot(data.values(), patch_artist = True)
ax.set_xticklabels(data.keys())
plt.axhline(y=output['silhouette_scores']['orig_data'], color='r', linestyle='-')
plt.xlabel(config["general"]["experiment_variable"])
plt.ylabel("silhouette score")
plt.title(f"silhouette scores, {config['RQ2']['runs']} runs\noriginal data: {round(output['silhouette_scores']['orig_data'], 2)}")

if save_output:
    plt.savefig(os.path.join(plots_path, "5_silhouette_scores.png"), **config["plots"])

plt.show()

# %% [markdown]
# ### 5.3. ARI Score

# %%
from sklearn.metrics.cluster import adjusted_rand_score

output["ARI_score"] = {}
output["ARI_score"]["orig_data"] = adjusted_rand_score(y_orig, y)

for run in range(config["RQ2"]["runs"]):
    output["ARI_score"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        ari = adjusted_rand_score(y_reconstr[run][i], y)
        output["ARI_score"][f"run_{run}"][str(experiment_value)] = ari

# %%
# plot
ari = output["ARI_score"].copy()
del(ari['orig_data'])

data = {}
for experiment_value in experiment_variable_values:
    data[str(experiment_value)] = [x[str(experiment_value)] for x in ari.values()]

fig, ax = plt.subplots()
ax.boxplot(data.values(), patch_artist = True)
ax.set_xticklabels(data.keys())
plt.axhline(y=output['ARI_score']['orig_data'], color='r', linestyle='-')
plt.xlabel(config["general"]["experiment_variable"])
plt.ylabel("ARI Score")
plt.title(f"ARI Score, {config['RQ2']['runs']} runs")

if save_output:
    plt.savefig(os.path.join(plots_path, "5_ARI-score.png"), **config["plots"])

plt.show()

# %% [markdown]
# ### 5.5. Save Output

# %%
if save_output:
    # save output file
    with open(output_path, "w") as f:
                toml.dump(output, f)

    # save notebook
    shutil.copy2(nb_name, experiment_path)
