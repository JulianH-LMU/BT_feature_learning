# %% [markdown]
# ## Change Log
# - Experiments can be setup by using the config parameter "experiment_variable" and assigning the experiment values as a list
# - E.g.
#     - experiment_variable = "train_val_split"
#     - config["training"]["train_val_split"] = [0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]
# - note: only parameters of the category "training" and "model_param" can be used

# %%
# %%javascript
# IPython.notebook.kernel.execute('nb_name = "' + IPython.notebook.notebook_name + '"')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import random
import math

import sys
import os
sys.path.append(os.getcwd() + "/pytorch_tabnet/")

from sklearn.cluster import DBSCAN
from scipy.special import rel_entr

# %% [markdown]
# ## 0. Experiment Setup

# %%
# should an output folder be created to save the experiment data?
save_output = True
save_models = False

# %%
# read config file
import toml
config = toml.load("config.toml")

experiment_variable_values = ""
experiment_dict_key = ""
for category_name, category_values in config.items():
    if config["general"]["experiment_variable"] in category_values:
        experiment_variable_values = category_values[config["general"]["experiment_variable"]]
        experiment_dict_key = category_name
        
# rnd seed to support reproducable results
seed_value =  config["general"]["random_seed"] if config["general"]["random_seed"] else random.randrange(2**32 -1)
random.seed(seed_value)
np.random.seed(seed_value)

# TabNet hyperparameters
experiment_variable = config["general"]["experiment_variable"]
regressor_param = {"optimizer_fn" : torch.optim.Adam,
                   "optimizer_params" : {"lr":0.05},
                   "scheduler_params" : {"step_size": 2, "gamma": 0.9},
                   "scheduler_fn" : torch.optim.lr_scheduler.StepLR,
                   "mask_type" : 'entmax',
                   "device_name" : 'cuda', # only working on NVIDIA GPUs
                   "verbose" : 0
                  }

if save_output:
    # create experiment folder
    from datetime import datetime
    
    experiment_name = config["general"]["experiment_name"]
    experiment_folder = f"{experiment_name} {datetime.now().strftime('%Y_%m_%d %H-%M-%S')}" if experiment_name else f"{config['RQ2']['runs']}_runs_{config['general']['experiment_variable']} {datetime.now().strftime('%Y_%m_%d %H-%M-%S')}"
    
    experiment_path = os.path.join("Experiments", experiment_folder)
    os.mkdir(experiment_path)
    
    plots_path = os.path.join(experiment_path, "plots")
    os.mkdir(plots_path)
    
    models_path = os.path.join(experiment_path, "models")
    os.mkdir(models_path)
    
    # save config file
    import shutil
    shutil.copy2("config.toml", experiment_path)
    
    # save random seed
    if not config["general"]["random_seed"]:
        config["general"]["random_seed"] = seed_value
        config_path = os.path.join(experiment_path, "config.toml")
        with open(config_path, "w") as f:
            toml.dump(config, f)
    
    # save model hyperparameters
    with open(os.path.join(experiment_path, 'config.toml'), 'a') as config_file:
        config_file.write("\n#[regressor_param]\n")
        for key, value in regressor_param.items(): 
            config_file.write('#%s = %s\n' % (key, str(value)))
    
    # save notebook
    shutil.copy2(nb_name, experiment_path)
    
    # create output file
    output_path = os.path.join(experiment_path, "output.toml")
    output_file = open(output_path, "w")
    output = {}

# %% [markdown]
# ## 1. Datasets
#
# Different datasets are to be used for the experiments.
# - toy dataset using make_blobs from sklearn mainly to setup and test the notebook
# - DAMI Benchmark datasets with the respective best practice hyperparameters (https://www.dbs.ifi.lmu.de/research/outlier-evaluation/DAMI/)
#
# ### 1.0. Create toy dataset
# As of now, only a toy dataset is used (n_features features with clusters centered around different points).

# %%
from sklearn.datasets import make_blobs

if config["general"]["use_toy_data"]:
    features_arr, clusters_arr = make_blobs(**config["toy_data"], random_state=seed_value)

    # name feature and cluster (ground truth) columns
    features = pd.DataFrame(features_arr, columns=[f"F{x + 1}" for x in range(features_arr.shape[1])])
    clusters = pd.DataFrame(clusters_arr, columns=["C"])

# %%
# plot dataset
if config["general"]["use_toy_data"]:
    # %matplotlib notebook
    fig = plt.figure(figsize=(8, 8))
    ax = fig.add_subplot(projection='3d')
    ax.scatter(features_arr[:, 0], features_arr[:, 1], features_arr[:, 2], c=clusters_arr)
    plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
    plt.show()
    if save_output:
        plt.savefig(os.path.join(plots_path, "0_ground_truth_clusters.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### 1.1. Use existing datasets

# %%
if not config["general"]["use_toy_data"]:
    features = pd.read_csv(os.path.join('Datasets', 'housing.csv'))

# %% [markdown]
# ### 1.2. Create missing data
# Create a specified amount of missing values in the given feature columns (for complete datasets).

# %%
# create missing values in feature column(s)
mv_config = {feature:mv_ratio for feature,mv_ratio in zip(list(features.columns), config["general"]["missing_percent"])}
features_mv = features.copy()

for f, mv in mv_config.items():
    features_mv[f] = features_mv[f].mask(np.random.random(features.shape[0]) < mv)

# %%
import missingno as msno
# %matplotlib inline

# plot missing values
fig = msno.matrix(features_mv)
plt.show()
if save_output:
    #plt.savefig(os.path.join(plots_path, "missing_values.png"), **config["plots"])
    fig_copy = fig.get_figure()
    fig_copy.savefig(os.path.join(plots_path, "missing_values.png"), **config["plots"], bbox_inches = 'tight')

# %% [markdown]
# ### 1.3. Initial Clustering (without missing values)
# Use the cluster algorithm on dataset without missing values.\
# Get cluster means for loss function input.

# %%
# run DBSCAN on original data
dbscan_orig = DBSCAN(**config["DBSCAN"]).fit(features)
clusters_orig = dbscan_orig.labels_

# %%
# plot clustering
# %matplotlib notebook
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(projection='3d')
ax.scatter(features.iloc[:, 0], features.iloc[:, 1], features.iloc[:, 2], c=clusters_orig)
plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "1_DBSCAN_original_data.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# get cluster means (used to calculate the cluster mean loss)
complete_data = features.copy()
complete_data["C"] = clusters_orig
cluster_means = complete_data.groupby("C").agg("mean")
cluster_means = cluster_means if -1 not in cluster_means.index else cluster_means.drop(-1)

# %% [markdown]
# ## 2. Filling Strategies
#
#
# ### 2.1. Define custom-loss
# The loss function for the model fitting shall be customized to improve cluster perforamnce. The custom loss is divided into 2 separate losses
#
# 1. **Reconstruction Loss**\
# Classic loss function, such as RMSE.
# 2. **Cluster-Mean Loss**\
# The distance to the nearest cluster mean shall be minimized.
# 3. **KL Divergence Loss**\
# Deviation of original distribution shall be minimized \
# (prob distribution based on https://stackoverflow.com/questions/57687458/how-to-calculate-probabilities-using-numpy-histogram-and-then-use-it-for-calcula \
# number of bins: D. Freedman & P. Diaconis (1981) “On the histogram as a density estimator: L2 theory”. Probability Theory and Related Fields 57 (4): 453-476)
#
# The chosen approach to implement the cluster-mean loss is as follows:\
# **Adapt the loss function** to calculate a distance to each cluster. The minimum distance (to the nearest cluster) will be used as a cluster-mean-loss. Minimizing this loss should result in the data point moving closer to the nearest cluster mean.\
# Potential Problem: loss functions currently work with y_true (true values) and y_score (predicted values). Calculating the distance would require all features. Calculating only the 1 dimensional distance will result in missing values being put into wrong clusters - depending on the first estimate.

# %%
# define custom loss function: extend L2-loss by cluster-mean-loss

from pytorch_tabnet.metrics import Metric
from sklearn.metrics import mean_squared_error
import astropy.stats

class custom_loss(Metric):

    def __init__(self):
        self._name = "custom_loss"
        self._maximize = False

    def __call__(self, y_true, y_score, cluster_means, target_feature, x_val, y_val):
        # reconstruction loss
        rmse = np.sqrt(mean_squared_error(y_true, y_score))
        
        # cluster mean loss
        cml = self.cluster_mean_loss(cluster_means, y_score, target_feature, x_val, y_val)
        
        # KL divergence loss
        bins = len(astropy.stats.freedman_bin_width(y_true.reshape(1,-1)[0], return_bins=True)[1])
        distr1, distr2 = self.probability_dist(y_score, y_true, bins)
        KLdl = torch.nn.functional.kl_div(torch.tensor(distr1).log(), torch.tensor(distr2), log_target=False, reduction='sum').item()
        
        # total loss
        custom_loss = rmse + KLdl + cml
        return custom_loss
    
    # calculate sum of distances to the closest cluster mean
    def cluster_mean_loss(self, cluster_means, y_score, target_feature, x_val, y_val):
        
        # reorder cluster_means to match x_val columns (predicted feature is last column)
        cols = cluster_means.columns.tolist()
        feature_col = features.columns.get_loc(target_feature)
        cols = cols[:feature_col] + cols[feature_col+1:] + [target_feature]
        
        # x values extended by predicted values
        x_extended = pd.DataFrame(np.hstack((x_val, y_score)), columns=cols)


        # calculate distances to each cluster and select the closest one
        dist = []
        for cluster in range(cluster_means.shape[0]):
            dist.append(np.linalg.norm((x_extended - cluster_means.iloc[cluster]), axis=1))
            
        dist = pd.DataFrame(dist).T
        min_dist = dist.assign(min_dist=lambda d: d.min(1))["min_dist"]
        
        return sum(min_dist)
    
    # calculate probabilities
    def probability_dist(self, x, y, bins):
        # transforms 2 series into their probability distributions
        # histogram
        hist_xy = np.histogram2d(np.asarray(x)[:,0], np.asarray(y)[:,0], bins=bins)[0]

        # compute marginals
        hist_xy = hist_xy + sys.float_info.min # prevent division with 0
        hist_xy = hist_xy / np.sum(hist_xy)
        hist_x = np.sum(hist_xy, axis=1)
        hist_y = np.sum(hist_xy, axis=0)
        return(hist_x, hist_y)

# %% [markdown]
# ### 2.2. Fill missing values (TabNet).
#
# **Approach 1:**\
# For each feature that contains missing values, use all rows with complete other features as train set and predict missing values of the feature.\
# &rarr; Problem: lots of models, especially for high-dimensional datasets.
# Also problem, if more than one feature is missing values. &rarr; see Approach 2
#
# **Approach 2:**\
# Mask missing values as -1 (or some other value) and fit a model predicting each feature just like in approach 1.\
# &rarr; one model for each feature containing missing values.\
# Possible adaption: use predicted values to predict subsequent values (instead of using -1)

# %%
import time

from pytorch_tabnet.tab_model import TabNetRegressor
from sklearn.model_selection import train_test_split

features_to_predict = features_mv.columns[features_mv.isnull().any()]
features_reconstr = {}
costs = {}
output["runtimes"] = {}

for run in range(config["RQ2"]["runs"]):
    
    print(f"Run {run + 1} / {config['RQ2']['runs']}")
    features_reconstr[run] = []
    costs[run] = {}
    output["runtimes"][f"run_{run}"] = {}
    
    for i, experiment_value in enumerate(experiment_variable_values):
        
        config[experiment_dict_key][config["general"]["experiment_variable"]] = experiment_value
        
        time_start = time.time()
        features_reconstr[run].append(features_mv.copy())
        costs[run][str(experiment_value)] = []

        for feature in features_to_predict:
            
            # select % of features for prediction based on pred_features (e.g. 10% of randomly selected features)
            number_of_features = math.ceil(config["RQ2"]["pred_features"] * (len(features_mv.columns)) - 1)
            features_mv_masked = features_mv.copy().drop(feature, axis=1).sample(n=number_of_features, axis='columns')
            selected_features = features_mv_masked.columns

            # mask other columns' missing values as defined in config (missing_value_mask)
            features_mv_masked[feature] = features_mv[feature]
            features_mv_masked[selected_features] = features_mv_masked[(selected_features)].fillna(config["general"]["missing_value_mask"])

            # separate complete rows as train data
            # separate column with missing values as target
            test_data = features_mv_masked[features_mv_masked[feature].isna()].drop(feature, axis=1).to_numpy()
            train_data = features_mv_masked[features_mv_masked[feature].notna()]
            train_features = train_data.drop(columns=feature).to_numpy()
            train_target = train_data[feature].to_numpy().reshape(-1,1)

            x_train, x_val, y_train, y_val = train_test_split(train_features, train_target, train_size=config["training"]["train_val_split"])

            # create & train model
            model = TabNetRegressor(**regressor_param)
            model.fit(
                x_train, y_train,
                eval_set=[(x_val, y_val)],
                **config["model_param"],
                cluster_means=cluster_means,
                target_feature=feature,
                x_val=x_val,
                y_val=y_val,
            )

            #track runtime
            time_end = time.time()

            # add costs to dict
            costs[run][str(experiment_value)].append(model.best_cost)


            # fill missing values with model predictions
            features_reconstr[run][i].loc[features_reconstr[run][i][feature].isna(), feature] = [x[0] for x in model.predict(test_data)]

            # save outputs
            if save_models:

                # save model
                torch.save(model, os.path.join(models_path, f"Model_run{run}_{config['general']['experiment_variable']}{experiment_value}_{feature}.pt"))
            
            if save_output:
                # save runtimes
                output["runtimes"][f"run_{run}"][f"{config['general']['experiment_variable']}_{feature}"] = time_end - time_start
# Out:
# Run 1 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.45562
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 159 and best_val_0_custom_loss = 2.19975
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.29866
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.38031
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.27466
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.9617
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 4.1598
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.90788
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.18145
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.99106
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 77 with best_epoch = 27 and best_val_0_custom_loss = 4.35038
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.58321
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_custom_loss = 2.9649
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 187 with best_epoch = 137 and best_val_0_custom_loss = 1.21654
# Best weights from best epoch are automatically used!
# Run 2 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.75129
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.30563
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.84984
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 190 and best_val_0_custom_loss = 2.15735
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 174 and best_val_0_custom_loss = 3.71875
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.61421
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 4.22487
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.60795
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 190 and best_val_0_custom_loss = 2.89211
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.41478
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_custom_loss = 5.60193
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 178 and best_val_0_custom_loss = 1.76742
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.49186
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 175 and best_val_0_custom_loss = 1.75104
# Best weights from best epoch are automatically used!
# Run 3 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.35235
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 193 and best_val_0_custom_loss = 1.98447
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.556
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 175 and best_val_0_custom_loss = 2.05673
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 91 with best_epoch = 41 and best_val_0_custom_loss = 4.49728
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.98516
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 60 with best_epoch = 10 and best_val_0_custom_loss = 6.68014
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.24038
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 84 with best_epoch = 34 and best_val_0_custom_loss = 4.47371
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 58 with best_epoch = 8 and best_val_0_custom_loss = 3.70519
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 90 with best_epoch = 40 and best_val_0_custom_loss = 5.71881
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.00495
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.4717
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 183 and best_val_0_custom_loss = 1.19717
# Best weights from best epoch are automatically used!
# Run 4 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 164 and best_val_0_custom_loss = 2.51638
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.17646
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.51296
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.9052
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 181 with best_epoch = 131 and best_val_0_custom_loss = 3.68234
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.30346
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.69863
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.09095
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.23968
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 168 with best_epoch = 118 and best_val_0_custom_loss = 2.82873
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.43376
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 156 and best_val_0_custom_loss = 2.2384
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.00756
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.2186
# Best weights from best epoch are automatically used!
# Run 5 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.70967
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 58 with best_epoch = 8 and best_val_0_custom_loss = 8.59887
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 198 and best_val_0_custom_loss = 2.93572
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.25464
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.76097
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 156 and best_val_0_custom_loss = 1.98921
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 186 and best_val_0_custom_loss = 2.00688
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 184 and best_val_0_custom_loss = 1.98224
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 198 with best_epoch = 148 and best_val_0_custom_loss = 3.49401
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.12516
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.86455
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.09741
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.99308
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.31536
# Best weights from best epoch are automatically used!
# Run 6 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.50142
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.09782
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 59 with best_epoch = 9 and best_val_0_custom_loss = 28.6888
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 183 with best_epoch = 133 and best_val_0_custom_loss = 1.77725
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 179 and best_val_0_custom_loss = 3.18501
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.148
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.09292
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.79309
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.78291
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 178 and best_val_0_custom_loss = 1.75827
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 192 with best_epoch = 142 and best_val_0_custom_loss = 2.91572
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 198 and best_val_0_custom_loss = 1.41639
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.53022
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 177 with best_epoch = 127 and best_val_0_custom_loss = 2.20659
# Best weights from best epoch are automatically used!
# Run 7 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 161 and best_val_0_custom_loss = 4.02325
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.56975
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 174 and best_val_0_custom_loss = 2.13513
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 190 and best_val_0_custom_loss = 2.08079
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 82 with best_epoch = 32 and best_val_0_custom_loss = 5.00541
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.03462
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.50853
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.16977
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 82 with best_epoch = 32 and best_val_0_custom_loss = 4.85903
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.9726
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_custom_loss = 6.0191
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_custom_loss = 4.40613
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_custom_loss = 9.18818
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.64617
# Best weights from best epoch are automatically used!
# Run 8 / 100
#
# Early stopping occurred at epoch 124 with best_epoch = 74 and best_val_0_custom_loss = 2.97937
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.83674
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 149 with best_epoch = 99 and best_val_0_custom_loss = 4.58939
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.14618
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 4.3171
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.55402
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 178 and best_val_0_custom_loss = 3.39368
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.84635
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.18827
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.00305
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.82363
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.03546
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 94 with best_epoch = 44 and best_val_0_custom_loss = 3.66889
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.04614
# Best weights from best epoch are automatically used!
# Run 9 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.15245
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.07787
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 198 with best_epoch = 148 and best_val_0_custom_loss = 2.93793
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.15732
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 4.52819
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 189 and best_val_0_custom_loss = 1.83927
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.85218
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 184 and best_val_0_custom_loss = 1.82857
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 158 and best_val_0_custom_loss = 1.69971
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.04415
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.9298
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 185 and best_val_0_custom_loss = 1.67497
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.58288
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.97262
# Best weights from best epoch are automatically used!
# Run 10 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 4.01049
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.28541
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 157 and best_val_0_custom_loss = 2.77554
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.26897
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 71 with best_epoch = 21 and best_val_0_custom_loss = 6.14683
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.52687
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.48744
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 189 and best_val_0_custom_loss = 1.87017
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.17949
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 172 with best_epoch = 122 and best_val_0_custom_loss = 1.7458
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.70854
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 197 and best_val_0_custom_loss = 2.39785
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 188 and best_val_0_custom_loss = 2.49532
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.88677
# Best weights from best epoch are automatically used!
# Run 11 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.62842
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.07384
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 195 and best_val_0_custom_loss = 2.24439
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.03097
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 197 and best_val_0_custom_loss = 3.53909
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.07545
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 138 with best_epoch = 88 and best_val_0_custom_loss = 3.25536
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.19052
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 191 with best_epoch = 141 and best_val_0_custom_loss = 2.68288
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.86144
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.15905
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.82973
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 83 with best_epoch = 33 and best_val_0_custom_loss = 4.83922
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 163 and best_val_0_custom_loss = 2.42295
# Best weights from best epoch are automatically used!
# Run 12 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.11645
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 199 with best_epoch = 149 and best_val_0_custom_loss = 2.23287
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.91776
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.20947
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 63 with best_epoch = 13 and best_val_0_custom_loss = 8.05637
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.05587
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.13368
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.0828
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.98185
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.1795
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.66384
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.22204
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 4.72182
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.14992
# Best weights from best epoch are automatically used!
# Run 13 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.90605
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.30169
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.75928
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.15498
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 144 with best_epoch = 94 and best_val_0_custom_loss = 3.57283
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.31789
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 187 and best_val_0_custom_loss = 3.29465
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.03061
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 96 with best_epoch = 46 and best_val_0_custom_loss = 3.56084
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.19158
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.64855
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.74537
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 112 with best_epoch = 62 and best_val_0_custom_loss = 4.32736
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.64255
# Best weights from best epoch are automatically used!
# Run 14 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.99547
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 194 with best_epoch = 144 and best_val_0_custom_loss = 2.0759
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 189 with best_epoch = 139 and best_val_0_custom_loss = 3.85401
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.97151
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_custom_loss = 5.68746
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 189 and best_val_0_custom_loss = 2.11495
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.24239
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.81144
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.97405
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 166 and best_val_0_custom_loss = 1.98651
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.79397
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.17617
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.47608
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 63 with best_epoch = 13 and best_val_0_custom_loss = 3.15969
# Best weights from best epoch are automatically used!
# Run 15 / 100
#
# Early stopping occurred at epoch 160 with best_epoch = 110 and best_val_0_custom_loss = 5.21018
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 192 and best_val_0_custom_loss = 2.17616
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_custom_loss = 6.83759
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 196 and best_val_0_custom_loss = 2.0897
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 101 with best_epoch = 51 and best_val_0_custom_loss = 4.83783
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.08522
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.30774
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 185 and best_val_0_custom_loss = 2.12681
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 80 with best_epoch = 30 and best_val_0_custom_loss = 4.2542
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.66873
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.00515
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.28236
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 159 and best_val_0_custom_loss = 2.25172
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.46289
# Best weights from best epoch are automatically used!
# Run 16 / 100
#
# Early stopping occurred at epoch 128 with best_epoch = 78 and best_val_0_custom_loss = 3.79434
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.87247
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 108 with best_epoch = 58 and best_val_0_custom_loss = 4.41311
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 164 and best_val_0_custom_loss = 2.00065
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.14172
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.19799
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.10558
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.17797
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.69665
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.99028
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.09917
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.8946
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 180 and best_val_0_custom_loss = 1.24248
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 64 with best_epoch = 14 and best_val_0_custom_loss = 4.67218
# Best weights from best epoch are automatically used!
# Run 17 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.31196
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 195 with best_epoch = 145 and best_val_0_custom_loss = 2.10262
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.54387
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.28353
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.12429
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.52217
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 4.19157
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 198 and best_val_0_custom_loss = 2.05363
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.9538
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.53481
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.19042
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.14886
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.71873
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 194 and best_val_0_custom_loss = 1.38244
# Best weights from best epoch are automatically used!
# Run 18 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.3562
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 178 with best_epoch = 128 and best_val_0_custom_loss = 2.66712
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.07756
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.92335
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.05797
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.78477
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 157 and best_val_0_custom_loss = 2.51195
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.89199
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 196 and best_val_0_custom_loss = 2.67496
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.08328
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.15202
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.59504
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 194 and best_val_0_custom_loss = 3.40911
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.62245
# Best weights from best epoch are automatically used!
# Run 19 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.83967
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.8745
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.08978
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.18136
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.35656
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.49188
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 185 and best_val_0_custom_loss = 2.22548
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.11949
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.62915
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 198 and best_val_0_custom_loss = 2.1484
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.73676
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.31551
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.33064
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 160 and best_val_0_custom_loss = 1.92892
# Best weights from best epoch are automatically used!
# Run 20 / 100
#
# Early stopping occurred at epoch 90 with best_epoch = 40 and best_val_0_custom_loss = 5.91522
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.32273
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.26097
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.10889
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 180 and best_val_0_custom_loss = 4.1965
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.12257
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.80556
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.8753
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 197 and best_val_0_custom_loss = 3.17596
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.5975
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 179 and best_val_0_custom_loss = 3.03253
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.47981
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.71343
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 177 and best_val_0_custom_loss = 1.90692
# Best weights from best epoch are automatically used!
# Run 21 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.51358
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 183 and best_val_0_custom_loss = 2.28787
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_custom_loss = 9.52946
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.31214
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 64 with best_epoch = 14 and best_val_0_custom_loss = 6.17981
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.09131
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 194 with best_epoch = 144 and best_val_0_custom_loss = 3.61607
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.98715
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.6585
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.88756
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 74 with best_epoch = 24 and best_val_0_custom_loss = 6.01433
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.74562
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 194 and best_val_0_custom_loss = 1.97028
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 96 with best_epoch = 46 and best_val_0_custom_loss = 2.15821
# Best weights from best epoch are automatically used!
# Run 22 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.29286
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.13085
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.28745
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.19978
# ...
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.0931
# Best weights from best epoch are automatically used!
# Run 94 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.62632
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.80441
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 177 and best_val_0_custom_loss = 3.67648
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.29805
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.43281
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.19804
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 125 with best_epoch = 75 and best_val_0_custom_loss = 3.18696
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.87065
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 156 and best_val_0_custom_loss = 2.7833
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.02113
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 67 with best_epoch = 17 and best_val_0_custom_loss = 5.91239
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 170 and best_val_0_custom_loss = 1.78092
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 69 with best_epoch = 19 and best_val_0_custom_loss = 3.84544
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 170 and best_val_0_custom_loss = 1.75833
# Best weights from best epoch are automatically used!
# Run 95 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 170 and best_val_0_custom_loss = 3.29006
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.23246
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.1741
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.95319
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 168 and best_val_0_custom_loss = 2.99224
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 189 and best_val_0_custom_loss = 1.95122
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 183 and best_val_0_custom_loss = 4.58329
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.06229
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.03023
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.5891
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 83 with best_epoch = 33 and best_val_0_custom_loss = 5.71622
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 192 with best_epoch = 142 and best_val_0_custom_loss = 2.08302
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 98 with best_epoch = 48 and best_val_0_custom_loss = 6.43034
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 168 and best_val_0_custom_loss = 1.46153
# Best weights from best epoch are automatically used!
# Run 96 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 180 and best_val_0_custom_loss = 2.96028
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.42013
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 181 and best_val_0_custom_loss = 3.18499
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.99331
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 180 and best_val_0_custom_loss = 3.71251
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.03393
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.23649
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.27769
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.239
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 160 and best_val_0_custom_loss = 2.28773
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 190 and best_val_0_custom_loss = 1.49278
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.453
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_custom_loss = 5.28851
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.86594
# Best weights from best epoch are automatically used!
# Run 97 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.40037
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 196 and best_val_0_custom_loss = 2.99887
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 4.07796
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.72871
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.13093
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.76466
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 184 and best_val_0_custom_loss = 3.16272
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 196 and best_val_0_custom_loss = 2.19164
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.27821
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 179 and best_val_0_custom_loss = 1.61064
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 79 with best_epoch = 29 and best_val_0_custom_loss = 4.16345
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.02757
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 183 and best_val_0_custom_loss = 1.69505
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.17081
# Best weights from best epoch are automatically used!
# Run 98 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.05596
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 166 and best_val_0_custom_loss = 1.93396
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 110 with best_epoch = 60 and best_val_0_custom_loss = 4.97453
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.17339
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 188 with best_epoch = 138 and best_val_0_custom_loss = 3.10302
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 59 with best_epoch = 9 and best_val_0_custom_loss = 9.08907
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 90 with best_epoch = 40 and best_val_0_custom_loss = 4.26563
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 196 with best_epoch = 146 and best_val_0_custom_loss = 1.87854
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 71 with best_epoch = 21 and best_val_0_custom_loss = 6.5162
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.66526
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.67239
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.18686
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.23541
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.3373
# Best weights from best epoch are automatically used!
# Run 99 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.72259
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.32566
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 179 with best_epoch = 129 and best_val_0_custom_loss = 4.12234
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.83376
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 191 and best_val_0_custom_loss = 2.89656
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 194 and best_val_0_custom_loss = 2.07248
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.72903
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.23967
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 197 and best_val_0_custom_loss = 1.80363
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.83503
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 170 and best_val_0_custom_loss = 2.73386
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.19157
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.91619
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.32461
# Best weights from best epoch are automatically used!
# Run 100 / 100
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 3.1576
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.79529
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 170 and best_val_0_custom_loss = 3.8999
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.29579
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 153 and best_val_0_custom_loss = 2.90155
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.92934
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 186 and best_val_0_custom_loss = 2.73071
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.9842
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 194 and best_val_0_custom_loss = 3.51784
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 1.89458
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 199 and best_val_0_custom_loss = 2.47821
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 185 and best_val_0_custom_loss = 2.15242
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 193 with best_epoch = 143 and best_val_0_custom_loss = 2.97993
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 200 with best_epoch = 189 and best_val_0_custom_loss = 1.85588
# Best weights from best epoch are automatically used!

# %% [markdown]
# ## 3. Complete Dataset
# Costs for each run

# %%
costs
# Out:
# {0: {'0.6': [3.455624148371224, 2.199753165934193],
#   '0.65': [3.2986592321448334, 2.380305551545218],
#   '0.7': [3.274657203456031, 1.9616963517378179],
#   '0.75': [4.159802812434567, 1.907876160007651],
#   '0.8': [3.1814507059146337, 1.9910558564304757],
#   '0.85': [4.350383091452642, 1.5832145140623597],
#   '0.9': [2.9649028920164775, 1.2165368032898778]},
#  1: {'0.6': [3.751293361026593, 2.3056267526393426],
#   '0.65': [3.849839576487291, 2.1573518626862644],
#   '0.7': [3.718751937743381, 2.614206218096825],
#   '0.75': [4.224871598580385, 2.6079507646314384],
#   '0.8': [2.8921056498065316, 2.414778223932681],
#  99: {'0.6': [3.1576034861245725, 2.795289569696186],
#   '0.65': [3.8999012479659716, 2.295793713732752],
#   '0.7': [2.9015455804621033, 1.9293382633349867],
#   '0.75': [2.730712830388567, 1.9842044532409717],
#   '0.8': [3.5178414030448724, 1.8945751427084585],
#   '0.85': [2.478206305616449, 2.152421337007041],
#   '0.9': [2.9799323532340036, 1.8558817261778031]}}

# %% [markdown]
# ### 3.1 Reconstruct Dataset
# choose best model based on min. squared custom loss (punishing large outliers in losses for single features)

# %%
best_per_run = []
best_per_run_index = []
for run in range(config["RQ2"]["runs"]):
    cost_totals = [sum([x**2 for x in c]) for _, c in costs[run].items()]
    best_per_run.append(min(cost_totals))
    best_per_run_index.append(cost_totals.index(min(cost_totals)))
    
best_run = best_per_run.index(min(best_per_run))
best_model = best_per_run_index[best_run]
print(f"Best model: run {best_run} model {best_model}")

features_best = features_reconstr[best_run][best_model]
# Out:
# Best model: run 95 model 5

# %% [markdown]
# ### 3.2 Plot changes (comp. to original data)

# %%
# scatter plot with combined data
orig_data = features.copy()
orig_data["change"] = 0
changed_data = features_best[features_mv.isna().any(axis=1)]
comp_data = pd.concat([orig_data, changed_data]).reset_index(drop=True).fillna(1)

# line plot connecting filled data to true data points
reconstr_data = features_best[features_mv.isna().any(axis=1)]
true_data = features[features_mv.isna().any(axis=1)]

# plot
fig = plt.figure(figsize=(8,8))
ax  = fig.add_subplot(projection = '3d')
ax.scatter(comp_data["F1"], comp_data["F2"], comp_data["F3"], c=[comp_data["change"]])

for i in range(len(reconstr_data)):
    ax.plot([reconstr_data["F1"].iloc[i], true_data["F1"].iloc[i]],[reconstr_data["F2"].iloc[i], true_data["F2"].iloc[i]],[reconstr_data["F3"].iloc[i], true_data["F3"].iloc[i]], color="black", linewidth=.5)


plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
plt.show
if save_output:
    plt.savefig(os.path.join(plots_path, "4_imputation_differences.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## 4. Clustering

# %%
# apply clustering
clusters_reconstr = []
for run in range(config["RQ2"]["runs"]):
    clusters_reconstr.append([])
    for i, var in enumerate(experiment_variable_values):
        dbscan_reconstr = DBSCAN(**config["DBSCAN"]).fit(features_reconstr[run][i])
        clusters_reconstr[run].append(dbscan_reconstr.labels_)

# %% [markdown]
# ### 4.1. Plot of clustering based on best model predictions

# %%
# plot new clustering
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(projection='3d')
ax.scatter(features_reconstr[best_run][best_model].iloc[:, 0], features_reconstr[best_run][best_model].iloc[:, 1], features_reconstr[best_run][best_model].iloc[:, 2], c=clusters_reconstr[best_run][best_model])
plt.gca().update(dict(title='DBSCAN with reconstructed data', xlabel='F1', ylabel='F2', zlabel='F3'))
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "3_DBSCAN_imputed_data.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## 5. Cluster Performance

# %% [markdown]
# ### 5.1 Feature Distributions
# #### 5.1.1 Distr. Plots based on best model predictions

# %%
# plot distributions
bins = len(astropy.stats.freedman_bin_width(features[feature], return_bins=True)[1])
n_feat = len(features_best.columns)

fig, (ax) = plt.subplots(n_feat, 2, figsize=(n_feat*2,6))
for n, feature in enumerate(features_best.columns):
    ax[n, 0].hist(features[feature], bins=bins)
    ax[n, 0].set_title(f"{feature}_orig")
    ax[n, 1].hist(features_best[feature], bins=bins)
    ax[n, 1].set_title(f"{feature}_filled")

fig.tight_layout()
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "feature distributions.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# #### 5.1.2 KL Divergence

# %%
# KL Divergence
def kl_divergence(feature1, feature2):
    
    # calculate probability distributions
    def probability_dist(x, y, bins):
        # transforms 2 series into their probability distributions
        # histogram
        hist_xy = np.histogram2d(x, y, bins=bins)[0]

        # compute marginals
        hist_xy = hist_xy + sys.float_info.min # prevent division with 0
        hist_xy = hist_xy / np.sum(hist_xy)
        hist_x = np.sum(hist_xy, axis=1)
        hist_y = np.sum(hist_xy, axis=0)
        return(hist_x, hist_y)

    # calculate kl divergence
    bins = len(astropy.stats.freedman_bin_width(feature1, return_bins=True)[1])
    distr1, distr2 = probability_dist(feature1, feature2, bins)
    return torch.nn.functional.kl_div(torch.tensor(distr1).log(), torch.tensor(distr2), log_target=False, reduction='sum').item()

# %%
output["kl_divergence"] = {}

# save kl divergence
for run in range(config["RQ2"]["runs"]):
    output["kl_divergence"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        output["kl_divergence"][f"run_{run}"][str(experiment_value)] = {}
        for feature in features_to_predict:
            output["kl_divergence"][f"run_{run}"][str(experiment_value)][feature] = kl_divergence(features[feature], features_reconstr[run][i][feature])

# %%
# plot
data = {}
for feature in features_to_predict:
    data[feature] = {}
    for experiment_value in experiment_variable_values:
        data[feature][str(experiment_value)] = [x[str(experiment_value)][feature] for x in output["kl_divergence"].values()]

nr_features = len(features_to_predict)
fig, axs = plt.subplots(nr_features)
fig.suptitle(f"KL divergence, {config['RQ2']['runs']} runs", fontweight='bold')

for nr, feature in enumerate(features_to_predict):
    axs[nr].boxplot(data[feature].values(), patch_artist = True) # , showfliers=False
    axs[nr].set_xticklabels(data[feature].keys())
    axs[nr].set_xlabel(config["general"]["experiment_variable"])
    axs[nr].set_ylabel(feature, fontweight='bold')

plt.tight_layout() 
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "5_kl_divergence.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 5.2 Silhouette Score

# %%
from sklearn.metrics import silhouette_score

output["silhouette_scores"] = {}
output["silhouette_scores"]["orig_data"] = float(silhouette_score(features, np.ravel(clusters)))

for run in range(config["RQ2"]["runs"]):
    output["silhouette_scores"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        if len(np.unique(clusters_reconstr[run][i])) > 1:
            output["silhouette_scores"][f"run_{run}"][str(experiment_value)] = float(silhouette_score(features_reconstr[run][i], clusters_reconstr[run][i]))
        else:
            output["silhouette_scores"][f"run_{run}"][str(experiment_value)] = np.nan

# %%
# plot
sil_scores = output["silhouette_scores"].copy()
del(sil_scores["orig_data"])

data = {}
for experiment_value in experiment_variable_values:
    data[str(experiment_value)] = [x[str(experiment_value)] for x in sil_scores.values()]

fig, ax = plt.subplots()
ax.boxplot(data.values(), patch_artist = True)
ax.set_xticklabels(data.keys())
plt.axhline(y=output['silhouette_scores']['orig_data'], color='r', linestyle='-')
plt.xlabel(config["general"]["experiment_variable"])
plt.ylabel("silhouette score")
plt.title(f"silhouette scores, {config['RQ2']['runs']} runs\noriginal data: {round(output['silhouette_scores']['orig_data'], 2)}")
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "5_silhouette_scores.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 5.3. Outlierness
# #### 5.3.1 Global outliers (considering all features)

# %%
# Outliers detected as noise by DBSCAN
output["cluster_noise"] = {}
output["cluster_noise"][f"orig_data"] = sum(clusters_orig == -1)

for run in range(config["RQ2"]["runs"]):
    output["cluster_noise"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        output["cluster_noise"][f"run_{run}"][str(experiment_value)] = sum(clusters_reconstr[run][i] == -1)

# %%
# plot
noise = output["cluster_noise"].copy()
del(noise["orig_data"])

data = {}
for experiment_value in experiment_variable_values:
    data[str(experiment_value)] = [x[str(experiment_value)] for x in noise.values()]

fig, ax = plt.subplots()
ax.boxplot(data.values(), patch_artist = True)
ax.set_xticklabels(data.keys())
plt.axhline(y=output["cluster_noise"]['orig_data'], color='r', linestyle='-')
plt.xlabel(config["general"]["experiment_variable"])
plt.ylabel("number of noise data points")
plt.title(f"DBSCAN noise, {config['RQ2']['runs']} runs\noriginal data: {output['cluster_noise']['orig_data']}")
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "5_DBSCAN-noise.png"), **config["plots"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 5.4. Save Output

# %%
with open(output_path, "w") as f:
            toml.dump(output, f)
