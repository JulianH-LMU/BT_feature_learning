# %% [markdown]
# ## Change Log
# - Experiments can be setup by using the config parameter "experiment_variable" and assigning the experiment values as a list
# - E.g.
#     - experiment_variable = "train_val_split"
#     - config["training"]["train_val_split"] = [0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]
# - note: only parameters of the category "training" and "model_param" can be used

# %%
# %%javascript
# IPython.notebook.kernel.execute('nb_name = "' + IPython.notebook.notebook_name + '"')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import random
import math

import sys
import os
sys.path.append(os.getcwd() + "/pytorch_tabnet/")

from sklearn.cluster import DBSCAN
from scipy.special import rel_entr

# %% [markdown]
# ## 0. Experiment Setup

# %%
# should an output folder be created to save the experiment data?
save_output = True
save_models = False

# %%
# read config file
import toml
config = toml.load("config.toml")

experiment_variable_values = ""
experiment_dict_key = ""
for category_name, category_values in config.items():
    if config["general"]["experiment_variable"] in category_values:
        experiment_variable_values = category_values[config["general"]["experiment_variable"]]
        experiment_dict_key = category_name
        
# rnd seed to support reproducable results
seed_value =  config["general"]["random_seed"] if config["general"]["random_seed"] else random.randrange(2**32 -1)
random.seed(seed_value)
np.random.seed(seed_value)

# TabNet hyperparameters
experiment_variable = config["general"]["experiment_variable"]
regressor_param = {"optimizer_fn" : torch.optim.Adam,
                   "optimizer_params" : {"lr":0.05},
                   "scheduler_params" : {"step_size": 2, "gamma": 0.9},
                   "scheduler_fn" : torch.optim.lr_scheduler.StepLR,
                   "mask_type" : 'entmax',
                   "device_name" : 'cuda', # only working on NVIDIA GPUs
                   "verbose" : 0
                  }

if save_output or save_models:
    # create experiment folder
    from datetime import datetime
    
    experiment_name = config["general"]["experiment_name"]
    experiment_folder = f"{experiment_name} {datetime.now().strftime('%Y_%m_%d %H-%M-%S')}" if experiment_name else f"{config['RQ2']['runs']}_runs_{config['general']['experiment_variable']} {datetime.now().strftime('%Y_%m_%d %H-%M-%S')}"
    
    experiment_path = os.path.join("Experiments", experiment_folder)
    os.mkdir(experiment_path)
    
    plots_path = os.path.join(experiment_path, "plots")
    os.mkdir(plots_path)
    
    models_path = os.path.join(experiment_path, "models")
    os.mkdir(models_path)
    
    # save config file
    import shutil
    shutil.copy2("config.toml", experiment_path)
    
    # save random seed
    if not config["general"]["random_seed"]:
        config["general"]["random_seed"] = seed_value
        config_path = os.path.join(experiment_path, "config.toml")
        with open(config_path, "w") as f:
            toml.dump(config, f)
    
    # save model hyperparameters
    with open(os.path.join(experiment_path, 'config.toml'), 'a') as config_file:
        config_file.write("\n#[regressor_param]\n")
        for key, value in regressor_param.items(): 
            config_file.write('#%s = %s\n' % (key, str(value)))
    
    # save notebook
    shutil.copy2(nb_name, experiment_path)
    
    # create output file
    output_path = os.path.join(experiment_path, "output.toml")
    output_file = open(output_path, "w")

output = {}

# %% [markdown]
# ## 1. Datasets
#
# ### 1.0. Use wine dataset

# %%
if not config["general"]["use_toy_data"]:
    
    from sklearn.datasets import load_wine
    from sklearn.preprocessing import scale, StandardScaler
    
    wine = load_wine()
    features_unscaled, clusters= pd.DataFrame(wine.data, columns=wine['feature_names']), wine.target
    features = pd.DataFrame(StandardScaler().fit_transform(features_unscaled), columns=wine['feature_names'])

# %% [markdown]
# ### 1.1. Create missing data
# Create a specified amount of missing values in the given feature columns (for complete datasets).

# %%
# create missing values in feature column(s)
mv_config = {feature:mv_ratio for feature,mv_ratio in zip(list(features_unscaled.columns), config["general"]["missing_percent"])}
features_mv = features_unscaled.copy()

for f, mv in mv_config.items():
    features_mv[f] = features_mv[f].mask(np.random.random(features_unscaled.shape[0]) < mv)

# %%
import missingno as msno
# %matplotlib inline

# plot missing values
fig = msno.matrix(features_mv)
plt.show()
if save_output:
    #plt.savefig(os.path.join(plots_path, "missing_values.png"), **config["plots"])
    fig_copy = fig.get_figure()
    fig_copy.savefig(os.path.join(plots_path, "missing_values.png"), **config["plots"], bbox_inches = 'tight')

# %% [markdown]
# ### 1.3. Initial Clustering (without missing values)
# Automatically determine DBSCAN hyperparameters min_samples and eps.\
# min_samples results in 26 for the wine dataset (dimensionality 13).\
# for eps we choose 2 (elbow of the graph).

# %%
from sklearn.neighbors import NearestNeighbors

min_samples = 2 * len(features.columns)

neighbors = NearestNeighbors(n_neighbors=min_samples)
neighbors_fit = neighbors.fit(features)
distances, indices = neighbors_fit.kneighbors(features)
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)

# %% [markdown]
# Use the cluster algorithm on dataset without missing values shows, that DBSCAN is not performaing well with 13 dimensional dataset (empty space problem leads to either 1 or 0 clusters).

# %%
# run DBSCAN on original data
config["DBSCAN"]["eps"] = 2
config["DBSCAN"]["min_samples"] = min_samples
if save_output or save_models:
    with open(config_path, "w") as f:
        toml.dump(config, f)

dbscan_orig = DBSCAN(**config["DBSCAN"]).fit(features)
clusters_orig = dbscan_orig.labels_
print(f"DBSCAN noise: {(sum(abs(clusters_orig[clusters_orig == -1]))*100) / len(clusters_orig)}%")
# Out:
# DBSCAN noise: 100.0%

# %% [markdown]
# As an alternative, we use k-means for the initial clustering (k=3). This does clearly work better with a more than 96% correct labeling of data.

# %%
from sklearn.cluster import KMeans
k_mean_orig = KMeans(n_clusters=3, random_state=seed_value).fit(features)
clusters_orig = k_mean_orig.labels_

# %%
from munkres import Munkres
from sklearn.metrics import confusion_matrix

# use Munkres / Hungarian algorithm to relabel clusters in order to match original label names
def make_cost_matrix(c1, c2):
    """
    """
    uc1 = np.unique(c1)
    uc2 = np.unique(c2)
    l1 = uc1.size
    l2 = uc2.size
    assert(l1 == l2 and np.all(uc1 == uc2))

    m = np.ones([l1, l2])
    for i in range(l1):
        it_i = np.nonzero(c1 == uc1[i])[0]
        for j in range(l2):
            it_j = np.nonzero(c2 == uc2[j])[0]
            m_ij = np.intersect1d(it_j, it_i)
            m[i,j] =  -m_ij.size
    return m

# %%
cost_matrix = make_cost_matrix(clusters_orig, clusters)
indexes = Munkres().compute(cost_matrix)
mapping = [new for (_, new) in indexes]
clusters_orig_renamed = np.choose(clusters_orig,mapping).astype(np.int64)

mislabeled = clusters - clusters_orig_renamed
mislabeled[mislabeled != 0] = 1
mislabeled_orig = sum(mislabeled) / len(mislabeled)
print(f"{round(mislabeled_orig * 100, 2)}% mislabeled")
# Out:
# 3.37% mislabeled

# %% [markdown]
# Get cluster means for loss function input.

# %%
# get cluster means (used to calculate the cluster mean loss)
complete_data = features_unscaled.copy()
complete_data["C"] = clusters_orig
cluster_means = complete_data.groupby("C").agg("mean")
cluster_means = cluster_means if -1 not in cluster_means.index else cluster_means.drop(-1)

# %% [markdown]
# ## 2. Filling Strategies
#
#
# ### 2.1. Define custom-loss
# The loss function for the model fitting shall be customized to improve cluster perforamnce. The custom loss is divided into 2 separate losses
#
# 1. **Reconstruction Loss**\
# Classic loss function, such as RMSE.
# 2. **Cluster-Mean Loss**\
# The distance to the nearest cluster mean shall be minimized.
# 3. **KL Divergence Loss**\
# Deviation of original distribution shall be minimized \
# (prob distribution based on https://stackoverflow.com/questions/57687458/how-to-calculate-probabilities-using-numpy-histogram-and-then-use-it-for-calcula \
# number of bins: D. Freedman & P. Diaconis (1981) “On the histogram as a density estimator: L2 theory”. Probability Theory and Related Fields 57 (4): 453-476)
#
# The chosen approach to implement the cluster-mean loss is as follows:\
# **Adapt the loss function** to calculate a distance to each cluster. The minimum distance (to the nearest cluster) will be used as a cluster-mean-loss. Minimizing this loss should result in the data point moving closer to the nearest cluster mean.\
# Potential Problem: loss functions currently work with y_true (true values) and y_score (predicted values). Calculating the distance would require all features. Calculating only the 1 dimensional distance will result in missing values being put into wrong clusters - depending on the first estimate.

# %%
# define custom loss function: extend L2-loss by cluster-mean-loss

from pytorch_tabnet.metrics import Metric
from sklearn.metrics import mean_squared_error
import astropy.stats

class custom_loss(Metric):

    def __init__(self):
        self._name = "custom_loss"
        self._maximize = False

    def __call__(self, y_true, y_score, cluster_means, target_feature, x_val, y_val):
        # reconstruction loss
        rmse = np.sqrt(mean_squared_error(y_true, y_score))
        
        # cluster mean loss
        cml = self.cluster_mean_loss(cluster_means, y_score, target_feature, x_val, y_val)
        
        # KL divergence loss
        bins = len(astropy.stats.freedman_bin_width(y_true.reshape(1,-1)[0], return_bins=True)[1])
        distr1, distr2 = self.probability_dist(y_score, y_true, bins)
        KLdl = torch.nn.functional.kl_div(torch.tensor(distr1).log(), torch.tensor(distr2), log_target=False, reduction='sum').item()
        
        # total loss
        custom_loss = 0.5 * rmse + KLdl + (1/10000) * cml
        return custom_loss
    
    # calculate sum of distances to the closest cluster mean
    def cluster_mean_loss(self, cluster_means, y_score, target_feature, x_val, y_val):
        
        # reorder cluster_means to match x_val columns (predicted feature is last column)
        cols = cluster_means.columns.tolist()
        feature_col = features.columns.get_loc(target_feature)
        cols = cols[:feature_col] + cols[feature_col+1:] + [target_feature]
        
        # x values extended by predicted values
        x_extended = pd.DataFrame(np.hstack((x_val, y_score)), columns=cols)


        # calculate distances to each cluster and select the closest one
        dist = []
        for cluster in range(cluster_means.shape[0]):
            dist.append(np.linalg.norm((x_extended - cluster_means.iloc[cluster]), axis=1))
            
        dist = pd.DataFrame(dist).T
        min_dist = dist.assign(min_dist=lambda d: d.min(1))["min_dist"]
        
        return sum(min_dist)
    
    # calculate probabilities
    def probability_dist(self, x, y, bins):
        # transforms 2 series into their probability distributions
        # histogram
        hist_xy = np.histogram2d(np.asarray(x)[:,0], np.asarray(y)[:,0], bins=bins)[0]

        # compute marginals
        hist_xy = hist_xy + sys.float_info.min # prevent division with 0
        hist_xy = hist_xy / np.sum(hist_xy)
        hist_x = np.sum(hist_xy, axis=1)
        hist_y = np.sum(hist_xy, axis=0)
        return(hist_x, hist_y)

# %% [markdown]
# ### 2.2. Fill missing values (TabNet).
#
# **Approach 1:**\
# For each feature that contains missing values, use all rows with complete other features as train set and predict missing values of the feature.\
# &rarr; Problem: lots of models, especially for high-dimensional datasets.
# Also problem, if more than one feature is missing values. &rarr; see Approach 2
#
# **Approach 2:**\
# Mask missing values as -1 (or some other value) and fit a model predicting each feature just like in approach 1.\
# &rarr; one model for each feature containing missing values.\
# Possible adaption: use predicted values to predict subsequent values (instead of using -1)

# %%
import time

from pytorch_tabnet.tab_model import TabNetRegressor
from sklearn.model_selection import train_test_split

features_to_predict = features_mv.columns[features_mv.isnull().any()]
features_reconstr = {}
output["costs"] = {}
output["runtimes"] = {}

for run in range(config["RQ2"]["runs"]):
    
    print(f"Run {run + 1} / {config['RQ2']['runs']}")
    features_reconstr[run] = []
    output["costs"][f"run_{run}"] = {}
    output["runtimes"][f"run_{run}"] = {}
    
    for i, experiment_value in enumerate(experiment_variable_values):
        
        config[experiment_dict_key][config["general"]["experiment_variable"]] = experiment_value
        
        time_start = time.time()
        features_reconstr[run].append(features_mv.copy())
        output["costs"][f"run_{run}"][str(experiment_value)] = {}
        output["runtimes"][f"run_{run}"][str(experiment_value)] = {}
        
        for feature in features_to_predict:
            
            # select % of features for prediction based on pred_features (e.g. 10% of randomly selected features)
            number_of_features = math.ceil(config["RQ2"]["pred_features"] * (len(features_mv.columns)) - 1)
            features_mv_masked = features_mv.copy().drop(feature, axis=1).sample(n=number_of_features, axis='columns')
            selected_features = features_mv_masked.columns

            # mask other columns' missing values as defined in config (missing_value_mask)
            features_mv_masked[feature] = features_mv[feature]
            features_mv_masked[selected_features] = features_mv_masked[(selected_features)].fillna(config["general"]["missing_value_mask"])

            # separate complete rows as train data
            # separate column with missing values as target
            test_data = features_mv_masked[features_mv_masked[feature].isna()].drop(feature, axis=1).to_numpy()
            train_data = features_mv_masked[features_mv_masked[feature].notna()]
            train_features = train_data.drop(columns=feature).to_numpy()
            train_target = train_data[feature].to_numpy().reshape(-1,1)

            x_train, x_val, y_train, y_val = train_test_split(train_features, train_target, train_size=config["training"]["train_val_split"])

            # create & train model
            model = TabNetRegressor(**regressor_param)
            if config["model_param"]["eval_metric"] == ["custom_loss"]:
                model.fit(
                    x_train, y_train,
                    eval_set=[(x_val, y_val)],
                    **config["model_param"],
                    cluster_means=cluster_means,
                    target_feature=feature,
                    x_val=x_val,
                    y_val=y_val,
                )
            else:
                model.fit(
                    x_train, y_train,
                    eval_set=[(x_val, y_val)],
                    **config["model_param"]
                )     

            #track runtime
            time_end = time.time()

            # add costs to dict
            output["costs"][f"run_{run}"][str(experiment_value)][feature] = model.best_cost


            # fill missing values with model predictions
            features_reconstr[run][i].loc[features_reconstr[run][i][feature].isna(), feature] = [x[0] for x in model.predict(test_data)]

            # save outputs
            if save_models:

                # save model
                torch.save(model, os.path.join(models_path, f"Model_run{run}_{config['general']['experiment_variable']}{experiment_value}_{feature}.pt"))
            
            if save_output:
                # save runtimes
                output["runtimes"][f"run_{run}"][str(experiment_value)][feature] = time_end - time_start
# Out:
# Run 1 / 100
#
# Early stopping occurred at epoch 226 with best_epoch = 176 and best_val_0_custom_loss = 7.0991
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 202 and best_val_0_custom_loss = 8.23916
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 226 and best_val_0_custom_loss = 5.3654
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_custom_loss = 6.97874
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_custom_loss = 15.17439
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 82 with best_epoch = 32 and best_val_0_custom_loss = 5.55589
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 99 with best_epoch = 49 and best_val_0_custom_loss = 1.85354
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 53 with best_epoch = 3 and best_val_0_custom_loss = 12.48822
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 246 and best_val_0_custom_loss = 4.25393
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 125 with best_epoch = 75 and best_val_0_custom_loss = 5.09413
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 82 with best_epoch = 32 and best_val_0_custom_loss = 7.16629
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 164 with best_epoch = 114 and best_val_0_custom_loss = 3.36522
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 233 with best_epoch = 183 and best_val_0_custom_loss = 3.86019
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 171 with best_epoch = 121 and best_val_0_custom_loss = 5.00203
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 197 with best_epoch = 147 and best_val_0_custom_loss = 2.80262
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_custom_loss = 3.31473
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 180 with best_epoch = 130 and best_val_0_custom_loss = 4.08351
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 131 with best_epoch = 81 and best_val_0_custom_loss = 2.29566
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 95 with best_epoch = 45 and best_val_0_custom_loss = 2.16539
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 3.44968
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 57 with best_epoch = 7 and best_val_0_custom_loss = 2.68716
# Best weights from best epoch are automatically used!
# Run 2 / 100
#
# Early stopping occurred at epoch 180 with best_epoch = 130 and best_val_0_custom_loss = 7.15561
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 213 and best_val_0_custom_loss = 3.70945
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 5.72886
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 99 with best_epoch = 49 and best_val_0_custom_loss = 5.82631
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 132 with best_epoch = 82 and best_val_0_custom_loss = 14.55022
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 92 with best_epoch = 42 and best_val_0_custom_loss = 4.98859
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 134 with best_epoch = 84 and best_val_0_custom_loss = 5.38697
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 98 with best_epoch = 48 and best_val_0_custom_loss = 7.54089
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 110 with best_epoch = 60 and best_val_0_custom_loss = 1.26519
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 173 with best_epoch = 123 and best_val_0_custom_loss = 4.00457
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 107 with best_epoch = 57 and best_val_0_custom_loss = 5.87967
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 69 with best_epoch = 19 and best_val_0_custom_loss = 4.8579
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 84 with best_epoch = 34 and best_val_0_custom_loss = 3.89953
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 112 with best_epoch = 62 and best_val_0_custom_loss = 2.3753
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 184 with best_epoch = 134 and best_val_0_custom_loss = 4.08882
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 212 with best_epoch = 162 and best_val_0_custom_loss = 2.61617
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 78 with best_epoch = 28 and best_val_0_custom_loss = 6.31787
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 139 with best_epoch = 89 and best_val_0_custom_loss = 2.25407
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 155 with best_epoch = 105 and best_val_0_custom_loss = 2.26301
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 247 with best_epoch = 197 and best_val_0_custom_loss = 3.58953
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 135 with best_epoch = 85 and best_val_0_custom_loss = 1.91398
# Best weights from best epoch are automatically used!
# Run 3 / 100
#
# Early stopping occurred at epoch 83 with best_epoch = 33 and best_val_0_custom_loss = 7.12831
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 105 with best_epoch = 55 and best_val_0_custom_loss = 9.23059
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 237 and best_val_0_custom_loss = 5.08286
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 157 with best_epoch = 107 and best_val_0_custom_loss = 6.27035
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 7.83647
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 78 with best_epoch = 28 and best_val_0_custom_loss = 5.22007
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 94 with best_epoch = 44 and best_val_0_custom_loss = 5.06702
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 50 with best_epoch = 0 and best_val_0_custom_loss = 17.38849
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 107 with best_epoch = 57 and best_val_0_custom_loss = 1.40701
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 243 and best_val_0_custom_loss = 3.66622
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 248 and best_val_0_custom_loss = 7.67204
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 227 and best_val_0_custom_loss = 3.46342
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_custom_loss = 4.71426
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 98 with best_epoch = 48 and best_val_0_custom_loss = 5.11337
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 163 with best_epoch = 113 and best_val_0_custom_loss = 2.9837
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 241 and best_val_0_custom_loss = 2.74294
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 245 with best_epoch = 195 and best_val_0_custom_loss = 3.59776
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 221 and best_val_0_custom_loss = 2.3575
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 94 with best_epoch = 44 and best_val_0_custom_loss = 2.19388
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 3.25617
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 91 with best_epoch = 41 and best_val_0_custom_loss = 1.68674
# Best weights from best epoch are automatically used!
# Run 4 / 100
#
# Early stopping occurred at epoch 95 with best_epoch = 45 and best_val_0_custom_loss = 7.46079
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 59 with best_epoch = 9 and best_val_0_custom_loss = 12.93385
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 235 and best_val_0_custom_loss = 5.04699
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 59 with best_epoch = 9 and best_val_0_custom_loss = 6.85182
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 171 with best_epoch = 121 and best_val_0_custom_loss = 6.99936
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 79 with best_epoch = 29 and best_val_0_custom_loss = 6.33456
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_custom_loss = 6.66403
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 61 with best_epoch = 11 and best_val_0_custom_loss = 11.60351
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 98 with best_epoch = 48 and best_val_0_custom_loss = 1.48386
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 118 with best_epoch = 68 and best_val_0_custom_loss = 5.6309
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 50 with best_epoch = 0 and best_val_0_custom_loss = 32.37567
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 80 with best_epoch = 30 and best_val_0_custom_loss = 3.96237
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 107 with best_epoch = 57 and best_val_0_custom_loss = 3.39381
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 91 with best_epoch = 41 and best_val_0_custom_loss = 4.70277
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 2.7638
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 82 with best_epoch = 32 and best_val_0_custom_loss = 1.23565
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 104 with best_epoch = 54 and best_val_0_custom_loss = 4.56039
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 52 with best_epoch = 2 and best_val_0_custom_loss = 2.5142
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 91 with best_epoch = 41 and best_val_0_custom_loss = 2.07561
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 236 and best_val_0_custom_loss = 2.73612
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 132 with best_epoch = 82 and best_val_0_custom_loss = 1.74145
# Best weights from best epoch are automatically used!
# Run 5 / 100
#
# Early stopping occurred at epoch 59 with best_epoch = 9 and best_val_0_custom_loss = 7.29564
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 123 with best_epoch = 73 and best_val_0_custom_loss = 4.59172
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 102 with best_epoch = 52 and best_val_0_custom_loss = 6.32261
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 61 with best_epoch = 11 and best_val_0_custom_loss = 7.63072
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 126 with best_epoch = 76 and best_val_0_custom_loss = 16.90891
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 237 and best_val_0_custom_loss = 4.80371
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 100 with best_epoch = 50 and best_val_0_custom_loss = 5.38049
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 211 and best_val_0_custom_loss = 6.53244
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 119 with best_epoch = 69 and best_val_0_custom_loss = 3.96256
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 66 with best_epoch = 16 and best_val_0_custom_loss = 5.66346
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 218 with best_epoch = 168 and best_val_0_custom_loss = 5.74167
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 163 with best_epoch = 113 and best_val_0_custom_loss = 5.15188
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 204 with best_epoch = 154 and best_val_0_custom_loss = 3.67183
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 99 with best_epoch = 49 and best_val_0_custom_loss = 6.21192
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 200 with best_epoch = 150 and best_val_0_custom_loss = 2.78955
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 111 with best_epoch = 61 and best_val_0_custom_loss = 3.17872
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 67 with best_epoch = 17 and best_val_0_custom_loss = 3.31961
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 60 with best_epoch = 10 and best_val_0_custom_loss = 3.65614
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 187 with best_epoch = 137 and best_val_0_custom_loss = 1.18505
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 240 and best_val_0_custom_loss = 2.88516
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 224 and best_val_0_custom_loss = 1.60508
# Best weights from best epoch are automatically used!
# Run 6 / 100
#
# Early stopping occurred at epoch 151 with best_epoch = 101 and best_val_0_custom_loss = 6.03816
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.02085
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 160 with best_epoch = 110 and best_val_0_custom_loss = 5.03435
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 146 with best_epoch = 96 and best_val_0_custom_loss = 6.29016
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 239 and best_val_0_custom_loss = 6.92436
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 134 with best_epoch = 84 and best_val_0_custom_loss = 5.00536
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 129 with best_epoch = 79 and best_val_0_custom_loss = 5.34811
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 245 with best_epoch = 195 and best_val_0_custom_loss = 6.54165
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 106 with best_epoch = 56 and best_val_0_custom_loss = 4.35602
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 161 with best_epoch = 111 and best_val_0_custom_loss = 3.92049
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 51 with best_epoch = 1 and best_val_0_custom_loss = 8.24467
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 63 with best_epoch = 13 and best_val_0_custom_loss = 2.12964
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 141 with best_epoch = 91 and best_val_0_custom_loss = 3.69783
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 119 with best_epoch = 69 and best_val_0_custom_loss = 4.78159
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 111 with best_epoch = 61 and best_val_0_custom_loss = 3.16798
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 181 with best_epoch = 131 and best_val_0_custom_loss = 2.69246
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 127 with best_epoch = 77 and best_val_0_custom_loss = 4.76543
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 191 with best_epoch = 141 and best_val_0_custom_loss = 2.45067
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 130 with best_epoch = 80 and best_val_0_custom_loss = 2.66641
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_custom_loss = 6.86686
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 214 and best_val_0_custom_loss = 1.47451
# Best weights from best epoch are automatically used!
# Run 7 / 100
#
# Early stopping occurred at epoch 107 with best_epoch = 57 and best_val_0_custom_loss = 2.75955
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 165 with best_epoch = 115 and best_val_0_custom_loss = 11.70194
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 246 and best_val_0_custom_loss = 5.35784
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 150 with best_epoch = 100 and best_val_0_custom_loss = 7.73277
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 192 with best_epoch = 142 and best_val_0_custom_loss = 7.80748
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 65 with best_epoch = 15 and best_val_0_custom_loss = 6.18442
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 61 with best_epoch = 11 and best_val_0_custom_loss = 6.90563
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 142 with best_epoch = 92 and best_val_0_custom_loss = 9.81836
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_custom_loss = 4.55743
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 172 with best_epoch = 122 and best_val_0_custom_loss = 4.25345
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 220 and best_val_0_custom_loss = 6.58339
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 74 with best_epoch = 24 and best_val_0_custom_loss = 4.17055
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 214 with best_epoch = 164 and best_val_0_custom_loss = 3.90839
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.48847
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 132 with best_epoch = 82 and best_val_0_custom_loss = 3.56236
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 134 with best_epoch = 84 and best_val_0_custom_loss = 2.83047
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 137 with best_epoch = 87 and best_val_0_custom_loss = 3.97453
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 176 with best_epoch = 126 and best_val_0_custom_loss = 2.43361
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 110 with best_epoch = 60 and best_val_0_custom_loss = 2.60028
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 219 and best_val_0_custom_loss = 3.34543
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 234 with best_epoch = 184 and best_val_0_custom_loss = 1.76525
# Best weights from best epoch are automatically used!
# Run 8 / 100
#
# Early stopping occurred at epoch 63 with best_epoch = 13 and best_val_0_custom_loss = 9.54422
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 215 and best_val_0_custom_loss = 8.47104
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 189 with best_epoch = 139 and best_val_0_custom_loss = 5.35175
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 93 with best_epoch = 43 and best_val_0_custom_loss = 6.26937
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 213 and best_val_0_custom_loss = 7.09617
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 243 with best_epoch = 193 and best_val_0_custom_loss = 4.77637
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 127 with best_epoch = 77 and best_val_0_custom_loss = 5.29451
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 211 with best_epoch = 161 and best_val_0_custom_loss = 6.67655
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 107 with best_epoch = 57 and best_val_0_custom_loss = 4.19852
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 202 with best_epoch = 152 and best_val_0_custom_loss = 3.98815
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 137 with best_epoch = 87 and best_val_0_custom_loss = 6.81697
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 119 with best_epoch = 69 and best_val_0_custom_loss = 3.28749
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 102 with best_epoch = 52 and best_val_0_custom_loss = 4.30195
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 99 with best_epoch = 49 and best_val_0_custom_loss = 5.15884
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_custom_loss = 2.94622
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 241 with best_epoch = 191 and best_val_0_custom_loss = 3.52598
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 133 with best_epoch = 83 and best_val_0_custom_loss = 4.25737
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 2.0544
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_custom_loss = 3.12902
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 51 with best_epoch = 1 and best_val_0_custom_loss = 13.31748
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 97 with best_epoch = 47 and best_val_0_custom_loss = 2.12935
# Best weights from best epoch are automatically used!
# Run 9 / 100
# Stop training because you reached max_epochs = 250 with best_epoch = 231 and best_val_0_custom_loss = 1.81627
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 166 with best_epoch = 116 and best_val_0_custom_loss = 4.26964
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 88 with best_epoch = 38 and best_val_0_custom_loss = 5.49263
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 101 with best_epoch = 51 and best_val_0_custom_loss = 6.07244
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_custom_loss = 10.53597
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 213 with best_epoch = 163 and best_val_0_custom_loss = 4.61947
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 207 and best_val_0_custom_loss = 1.51225
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 54 with best_epoch = 4 and best_val_0_custom_loss = 9.86761
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 119 with best_epoch = 69 and best_val_0_custom_loss = 4.04025
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 246 and best_val_0_custom_loss = 4.44774
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_custom_loss = 9.58218
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 102 with best_epoch = 52 and best_val_0_custom_loss = 3.54818
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 117 with best_epoch = 67 and best_val_0_custom_loss = 3.89669
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 207 with best_epoch = 157 and best_val_0_custom_loss = 4.9045
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 65 with best_epoch = 15 and best_val_0_custom_loss = 3.14854
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_custom_loss = 1.32468
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 224 with best_epoch = 174 and best_val_0_custom_loss = 3.71459
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 59 with best_epoch = 9 and best_val_0_custom_loss = 0.94515
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 194 with best_epoch = 144 and best_val_0_custom_loss = 2.09195
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 238 and best_val_0_custom_loss = 3.58744
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 219 with best_epoch = 169 and best_val_0_custom_loss = 0.56895
# Best weights from best epoch are automatically used!
# Run 10 / 100
#
# Early stopping occurred at epoch 128 with best_epoch = 78 and best_val_0_custom_loss = 8.13274
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 53 with best_epoch = 3 and best_val_0_custom_loss = 9.51605
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 164 with best_epoch = 114 and best_val_0_custom_loss = 5.25096
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 242 and best_val_0_custom_loss = 5.6908
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 149 with best_epoch = 99 and best_val_0_custom_loss = 8.10461
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 86 with best_epoch = 36 and best_val_0_custom_loss = 6.05239
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 142 with best_epoch = 92 and best_val_0_custom_loss = 9.44634
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 54 with best_epoch = 4 and best_val_0_custom_loss = 10.16028
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 190 with best_epoch = 140 and best_val_0_custom_loss = 4.34076
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 110 with best_epoch = 60 and best_val_0_custom_loss = 4.42675
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 142 with best_epoch = 92 and best_val_0_custom_loss = 6.16208
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 224 and best_val_0_custom_loss = 3.37323
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 134 with best_epoch = 84 and best_val_0_custom_loss = 4.61605
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 141 with best_epoch = 91 and best_val_0_custom_loss = 5.59338
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 188 with best_epoch = 138 and best_val_0_custom_loss = 2.89298
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 83 with best_epoch = 33 and best_val_0_custom_loss = 2.83241
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 137 with best_epoch = 87 and best_val_0_custom_loss = 4.33836
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 205 with best_epoch = 155 and best_val_0_custom_loss = 2.17199
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 182 with best_epoch = 132 and best_val_0_custom_loss = 3.11207
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 94 with best_epoch = 44 and best_val_0_custom_loss = 8.90098
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 213 with best_epoch = 163 and best_val_0_custom_loss = 1.66424
# Best weights from best epoch are automatically used!
# Run 11 / 100
#
# Early stopping occurred at epoch 95 with best_epoch = 45 and best_val_0_custom_loss = 6.48929
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 187 with best_epoch = 137 and best_val_0_custom_loss = 9.40563
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 138 with best_epoch = 88 and best_val_0_custom_loss = 5.79922
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 64 with best_epoch = 14 and best_val_0_custom_loss = 3.30017
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 193 with best_epoch = 143 and best_val_0_custom_loss = 6.16201
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 195 with best_epoch = 145 and best_val_0_custom_loss = 4.98317
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 210 with best_epoch = 160 and best_val_0_custom_loss = 5.18786
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 177 with best_epoch = 127 and best_val_0_custom_loss = 6.7713
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 201 with best_epoch = 151 and best_val_0_custom_loss = 3.40682
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 53 with best_epoch = 3 and best_val_0_custom_loss = 12.39881
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 215 with best_epoch = 165 and best_val_0_custom_loss = 6.42353
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 3.44093
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 83 with best_epoch = 33 and best_val_0_custom_loss = 6.12843
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 85 with best_epoch = 35 and best_val_0_custom_loss = 5.90825
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_custom_loss = 3.20264
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 213 with best_epoch = 163 and best_val_0_custom_loss = 3.38972
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 243 and best_val_0_custom_loss = 4.39152
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 122 with best_epoch = 72 and best_val_0_custom_loss = 2.35343
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 63 with best_epoch = 13 and best_val_0_custom_loss = 2.73279
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 3.77768
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 93 with best_epoch = 43 and best_val_0_custom_loss = 2.2823
# Best weights from best epoch are automatically used!
# Run 12 / 100
#
# Early stopping occurred at epoch 104 with best_epoch = 54 and best_val_0_custom_loss = 6.83288
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_custom_loss = 9.16237
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 76 with best_epoch = 26 and best_val_0_custom_loss = 5.99824
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 57 with best_epoch = 7 and best_val_0_custom_loss = 6.74626
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 148 with best_epoch = 98 and best_val_0_custom_loss = 3.4678
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 211 with best_epoch = 161 and best_val_0_custom_loss = 4.63967
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 228 and best_val_0_custom_loss = 4.91152
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 83 with best_epoch = 33 and best_val_0_custom_loss = 7.89722
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 143 with best_epoch = 93 and best_val_0_custom_loss = 4.18329
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 194 with best_epoch = 144 and best_val_0_custom_loss = 4.30347
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 132 with best_epoch = 82 and best_val_0_custom_loss = 7.05504
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 138 with best_epoch = 88 and best_val_0_custom_loss = 4.00528
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 157 with best_epoch = 107 and best_val_0_custom_loss = 4.5731
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 142 with best_epoch = 92 and best_val_0_custom_loss = 5.98385
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 106 with best_epoch = 56 and best_val_0_custom_loss = 3.28608
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 223 and best_val_0_custom_loss = 2.92868
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 134 with best_epoch = 84 and best_val_0_custom_loss = 4.86969
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 121 with best_epoch = 71 and best_val_0_custom_loss = 3.28866
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 69 with best_epoch = 19 and best_val_0_custom_loss = 3.68928
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 135 with best_epoch = 85 and best_val_0_custom_loss = 3.9481
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 225 and best_val_0_custom_loss = 1.39913
# Best weights from best epoch are automatically used!
# Run 13 / 100
# Stop training because you reached max_epochs = 250 with best_epoch = 246 and best_val_0_custom_loss = 6.26688
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 51 with best_epoch = 1 and best_val_0_custom_loss = 17.14957
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 66 with best_epoch = 16 and best_val_0_custom_loss = 7.62715
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 76 with best_epoch = 26 and best_val_0_custom_loss = 8.07808
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 116 with best_epoch = 66 and best_val_0_custom_loss = 8.31368
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 139 with best_epoch = 89 and best_val_0_custom_loss = 4.95864
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 144 with best_epoch = 94 and best_val_0_custom_loss = 1.66668
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_custom_loss = 8.74165
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 130 with best_epoch = 80 and best_val_0_custom_loss = 4.25123
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 110 with best_epoch = 60 and best_val_0_custom_loss = 5.22256
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 74 with best_epoch = 24 and best_val_0_custom_loss = 7.87088
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 191 with best_epoch = 141 and best_val_0_custom_loss = 3.65846
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 152 with best_epoch = 102 and best_val_0_custom_loss = 3.78133
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 60 with best_epoch = 10 and best_val_0_custom_loss = 10.23049
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 248 and best_val_0_custom_loss = 2.93523
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 116 with best_epoch = 66 and best_val_0_custom_loss = 3.20797
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 210 and best_val_0_custom_loss = 3.00802
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 198 with best_epoch = 148 and best_val_0_custom_loss = 2.31778
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_custom_loss = 2.98748
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 55 with best_epoch = 5 and best_val_0_custom_loss = 9.10032
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 188 with best_epoch = 138 and best_val_0_custom_loss = 1.81356
# Best weights from best epoch are automatically used!
# Run 14 / 100
# Early stopping occurred at epoch 134 with best_epoch = 84 and best_val_0_custom_loss = 6.57701
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 8.04767
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 114 with best_epoch = 64 and best_val_0_custom_loss = 6.08898
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 126 with best_epoch = 76 and best_val_0_custom_loss = 5.9119
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 94 with best_epoch = 44 and best_val_0_custom_loss = 8.34421
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_custom_loss = 5.05226
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 221 with best_epoch = 171 and best_val_0_custom_loss = 5.12316
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 53 with best_epoch = 3 and best_val_0_custom_loss = 13.36472
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 76 with best_epoch = 26 and best_val_0_custom_loss = 4.66684
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 222 with best_epoch = 172 and best_val_0_custom_loss = 4.4187
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 227 and best_val_0_custom_loss = 5.70651
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 240 with best_epoch = 190 and best_val_0_custom_loss = 3.06052
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_custom_loss = 3.74233
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 54 with best_epoch = 4 and best_val_0_custom_loss = 7.18319
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 215 with best_epoch = 165 and best_val_0_custom_loss = 2.75955
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_custom_loss = 1.22541
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 239 and best_val_0_custom_loss = 4.82672
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 91 with best_epoch = 41 and best_val_0_custom_loss = 2.94233
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 95 with best_epoch = 45 and best_val_0_custom_loss = 2.43968
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 238 with best_epoch = 188 and best_val_0_custom_loss = 3.76289
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 151 with best_epoch = 101 and best_val_0_custom_loss = 1.64699
# Best weights from best epoch are automatically used!
# Run 15 / 100
# Stop training because you reached max_epochs = 250 with best_epoch = 206 and best_val_0_custom_loss = 6.2056
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_custom_loss = 9.13671
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 248 and best_val_0_custom_loss = 5.47642
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 100 with best_epoch = 50 and best_val_0_custom_loss = 5.9256
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 52 with best_epoch = 2 and best_val_0_custom_loss = 13.74827
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 190 with best_epoch = 140 and best_val_0_custom_loss = 2.37727
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 141 with best_epoch = 91 and best_val_0_custom_loss = 5.31038
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 209 and best_val_0_custom_loss = 8.32027
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 244 and best_val_0_custom_loss = 3.86137
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 140 with best_epoch = 90 and best_val_0_custom_loss = 4.35171
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 52 with best_epoch = 2 and best_val_0_custom_loss = 10.28243
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 69 with best_epoch = 19 and best_val_0_custom_loss = 3.74387
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 104 with best_epoch = 54 and best_val_0_custom_loss = 3.80672
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 129 with best_epoch = 79 and best_val_0_custom_loss = 5.9056
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 170 with best_epoch = 120 and best_val_0_custom_loss = 3.08217
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 243 with best_epoch = 193 and best_val_0_custom_loss = 2.71844
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 151 with best_epoch = 101 and best_val_0_custom_loss = 4.64918
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 63 with best_epoch = 13 and best_val_0_custom_loss = 2.83276
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 203 with best_epoch = 153 and best_val_0_custom_loss = 2.20236
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 234 and best_val_0_custom_loss = 3.72537
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 218 and best_val_0_custom_loss = 1.44946
# Best weights from best epoch are automatically used!
# Run 16 / 100
#
# Early stopping occurred at epoch 113 with best_epoch = 63 and best_val_0_custom_loss = 7.85646
# Best weights from best epoch are automatically used!
#
# ...
# Best weights from best epoch are automatically used!
# Run 96 / 100
#
# Early stopping occurred at epoch 128 with best_epoch = 78 and best_val_0_custom_loss = 6.41023
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 113 with best_epoch = 63 and best_val_0_custom_loss = 3.76992
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 226 with best_epoch = 176 and best_val_0_custom_loss = 5.37448
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 130 with best_epoch = 80 and best_val_0_custom_loss = 6.59232
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 192 with best_epoch = 142 and best_val_0_custom_loss = 10.39671
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 101 with best_epoch = 51 and best_val_0_custom_loss = 4.76246
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 130 with best_epoch = 80 and best_val_0_custom_loss = 1.63734
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 51 with best_epoch = 1 and best_val_0_custom_loss = 10.36583
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 242 and best_val_0_custom_loss = 3.83277
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 230 and best_val_0_custom_loss = 4.21321
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 219 with best_epoch = 169 and best_val_0_custom_loss = 7.50314
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 147 with best_epoch = 97 and best_val_0_custom_loss = 3.66975
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 207 with best_epoch = 157 and best_val_0_custom_loss = 3.73842
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 223 and best_val_0_custom_loss = 5.32302
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 124 with best_epoch = 74 and best_val_0_custom_loss = 2.67752
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 64 with best_epoch = 14 and best_val_0_custom_loss = 3.47197
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 150 with best_epoch = 100 and best_val_0_custom_loss = 4.69804
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 163 with best_epoch = 113 and best_val_0_custom_loss = 2.26271
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 136 with best_epoch = 86 and best_val_0_custom_loss = 2.07924
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 248 and best_val_0_custom_loss = 3.42682
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 113 with best_epoch = 63 and best_val_0_custom_loss = 2.68491
# Best weights from best epoch are automatically used!
# Run 97 / 100
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 7.2038
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 58 with best_epoch = 8 and best_val_0_custom_loss = 16.52007
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 231 with best_epoch = 181 and best_val_0_custom_loss = 5.15867
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_custom_loss = 8.62569
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 155 with best_epoch = 105 and best_val_0_custom_loss = 8.63575
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 246 with best_epoch = 196 and best_val_0_custom_loss = 4.85655
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 111 with best_epoch = 61 and best_val_0_custom_loss = 5.86405
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 53 with best_epoch = 3 and best_val_0_custom_loss = 11.47916
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 136 with best_epoch = 86 and best_val_0_custom_loss = 4.38524
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 138 with best_epoch = 88 and best_val_0_custom_loss = 4.52399
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 212 and best_val_0_custom_loss = 5.17431
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 161 with best_epoch = 111 and best_val_0_custom_loss = 3.29278
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 246 with best_epoch = 196 and best_val_0_custom_loss = 3.77625
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 53 with best_epoch = 3 and best_val_0_custom_loss = 6.34621
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 231 and best_val_0_custom_loss = 2.60399
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_custom_loss = 1.79681
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 54 with best_epoch = 4 and best_val_0_custom_loss = 5.00711
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 63 with best_epoch = 13 and best_val_0_custom_loss = 2.78492
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 122 with best_epoch = 72 and best_val_0_custom_loss = 2.0111
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 95 with best_epoch = 45 and best_val_0_custom_loss = 3.72165
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 111 with best_epoch = 61 and best_val_0_custom_loss = 2.0385
# Best weights from best epoch are automatically used!
# Run 98 / 100
#
# Early stopping occurred at epoch 153 with best_epoch = 103 and best_val_0_custom_loss = 6.54954
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 210 and best_val_0_custom_loss = 8.42924
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 138 with best_epoch = 88 and best_val_0_custom_loss = 5.53949
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 158 with best_epoch = 108 and best_val_0_custom_loss = 5.81072
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 61 with best_epoch = 11 and best_val_0_custom_loss = 7.37622
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_custom_loss = 5.27846
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 88 with best_epoch = 38 and best_val_0_custom_loss = 4.99009
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 148 with best_epoch = 98 and best_val_0_custom_loss = 7.72529
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 158 with best_epoch = 108 and best_val_0_custom_loss = 4.33352
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 78 with best_epoch = 28 and best_val_0_custom_loss = 4.60644
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 61 with best_epoch = 11 and best_val_0_custom_loss = 23.45061
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 231 and best_val_0_custom_loss = 3.37222
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 192 with best_epoch = 142 and best_val_0_custom_loss = 3.5627
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 205 and best_val_0_custom_loss = 5.06878
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 113 with best_epoch = 63 and best_val_0_custom_loss = 2.86304
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 115 with best_epoch = 65 and best_val_0_custom_loss = 3.44999
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 105 with best_epoch = 55 and best_val_0_custom_loss = 6.56954
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 187 with best_epoch = 137 and best_val_0_custom_loss = 2.42832
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 59 with best_epoch = 9 and best_val_0_custom_loss = 2.69363
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 89 with best_epoch = 39 and best_val_0_custom_loss = 5.31824
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 86 with best_epoch = 36 and best_val_0_custom_loss = 0.76095
# Best weights from best epoch are automatically used!
# Run 99 / 100
#
# Early stopping occurred at epoch 127 with best_epoch = 77 and best_val_0_custom_loss = 6.71547
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 102 with best_epoch = 52 and best_val_0_custom_loss = 8.1122
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 79 with best_epoch = 29 and best_val_0_custom_loss = 1.86334
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 57 with best_epoch = 7 and best_val_0_custom_loss = 6.08751
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 238 and best_val_0_custom_loss = 8.43599
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 133 with best_epoch = 83 and best_val_0_custom_loss = 4.70208
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_custom_loss = 4.72506
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 52 with best_epoch = 2 and best_val_0_custom_loss = 11.45011
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 106 with best_epoch = 56 and best_val_0_custom_loss = 4.85365
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 63 with best_epoch = 13 and best_val_0_custom_loss = 6.19969
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 51 with best_epoch = 1 and best_val_0_custom_loss = 26.84694
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 163 with best_epoch = 113 and best_val_0_custom_loss = 3.28246
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 142 with best_epoch = 92 and best_val_0_custom_loss = 3.6294
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 225 with best_epoch = 175 and best_val_0_custom_loss = 6.94297
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 99 with best_epoch = 49 and best_val_0_custom_loss = 3.06871
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 123 with best_epoch = 73 and best_val_0_custom_loss = 2.98795
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 89 with best_epoch = 39 and best_val_0_custom_loss = 6.11535
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 242 and best_val_0_custom_loss = 2.01094
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 72 with best_epoch = 22 and best_val_0_custom_loss = 3.16288
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 107 with best_epoch = 57 and best_val_0_custom_loss = 2.42326
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 127 with best_epoch = 77 and best_val_0_custom_loss = 1.55636
# Best weights from best epoch are automatically used!
# Run 100 / 100
#
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_custom_loss = 7.08351
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 88 with best_epoch = 38 and best_val_0_custom_loss = 15.05247
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 244 and best_val_0_custom_loss = 5.29034
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 83 with best_epoch = 33 and best_val_0_custom_loss = 6.14298
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 7.7689
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 206 and best_val_0_custom_loss = 4.66083
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 119 with best_epoch = 69 and best_val_0_custom_loss = 6.05482
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 53 with best_epoch = 3 and best_val_0_custom_loss = 12.66888
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 91 with best_epoch = 41 and best_val_0_custom_loss = 4.73158
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 204 with best_epoch = 154 and best_val_0_custom_loss = 4.41474
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 85 with best_epoch = 35 and best_val_0_custom_loss = 7.39844
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 111 with best_epoch = 61 and best_val_0_custom_loss = 3.58295
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 57 with best_epoch = 7 and best_val_0_custom_loss = 4.43975
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 91 with best_epoch = 41 and best_val_0_custom_loss = 3.62536
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 136 with best_epoch = 86 and best_val_0_custom_loss = 2.97482
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 65 with best_epoch = 15 and best_val_0_custom_loss = 3.16366
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 63 with best_epoch = 13 and best_val_0_custom_loss = 10.64441
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 113 with best_epoch = 63 and best_val_0_custom_loss = 2.6168
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 133 with best_epoch = 83 and best_val_0_custom_loss = 2.2786
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 53 with best_epoch = 3 and best_val_0_custom_loss = 10.2688
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 77 with best_epoch = 27 and best_val_0_custom_loss = 2.14358
# Best weights from best epoch are automatically used!

# %% [markdown]
# ## 3. Reconstruct Dataset
# choose best model based on min. squared custom loss (punishing large outliers in losses for single features)

# %%
best_per_run = []
best_per_run_index = []
for run in range(config["RQ2"]["runs"]):
    cost_list = list(output["costs"][f"run_{run}"].values())
    cost_totals = [sum(c**2 for c in list(x.values())) for x in cost_list]
    best_per_run.append(min(cost_totals))
    best_per_run_index.append(cost_totals.index(min(cost_totals)))
    
best_run = best_per_run.index(min(best_per_run))
best_model = best_per_run_index[best_run]
print(f"Best model: run {best_run} model {best_model}")

features_best = features_reconstr[best_run][best_model]
# Out:
# Best model: run 32 model 6

# %% [markdown]
# ## 4. Clustering
# Apply k-means (k=3) on reconstructed data. In order to make the clusters comparable, the k-Means labels will be replaced using Munkres / Hungarian algorithm as explained here:\
# https://gist.github.com/siolag161/dc6e42b64e1bde1f263b \
# https://github.com/benchaplin/hungarian-algorithm

# %%
# apply clustering
clusters_reconstr = []
for run in range(config["RQ2"]["runs"]):
    clusters_reconstr.append([])
    for i, var in enumerate(experiment_variable_values):
        
        features_scaled = pd.DataFrame(StandardScaler().fit_transform(features_reconstr[run][i]))
        k_mean_reconstr = KMeans(n_clusters=3).fit(features_scaled)
        
        cost_matrix = make_cost_matrix(k_mean_reconstr.labels_, clusters)
        indexes = Munkres().compute(cost_matrix)
        mapping = [new for (_, new) in indexes]
        
        clusters_reconstr[run].append(np.choose(k_mean_reconstr.labels_,mapping).astype(np.int64))

# %% [markdown]
# ## 5. Cluster Performance

# %% [markdown]
# ### 5.1 Feature Distributions
# #### 5.1.1 Distr. Plots based on best model predictions

# %%
# plot distributions
bins = len(astropy.stats.freedman_bin_width(features[feature], return_bins=True)[1])
n_feat = len(features_to_predict) if len(features_to_predict) > 1 else 2

fig, (ax) = plt.subplots(n_feat, 2, figsize=(10,n_feat*3))
for n, feature in enumerate(features_best[features_to_predict]):
    ax[n, 0].hist(features_unscaled[feature], bins=bins)
    ax[n, 0].set_title(f"{feature}_orig")
    ax[n, 1].hist(features_best[feature], bins=bins)
    ax[n, 1].set_title(f"{feature}_filled")

fig.tight_layout()
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "feature distributions.png"), **config["plots"])

# %% [markdown]
# #### 5.1.2 KL Divergence

# %%
# KL Divergence
def kl_divergence(feature1, feature2):
    
    # calculate probability distributions
    def probability_dist(x, y, bins):
        # transforms 2 series into their probability distributions
        # histogram
        hist_xy = np.histogram2d(x, y, bins=bins)[0]

        # compute marginals
        hist_xy = hist_xy + sys.float_info.min # prevent division with 0
        hist_xy = hist_xy / np.sum(hist_xy)
        hist_x = np.sum(hist_xy, axis=1)
        hist_y = np.sum(hist_xy, axis=0)
        return(hist_x, hist_y)

    # calculate kl divergence
    bins = len(astropy.stats.freedman_bin_width(feature1, return_bins=True)[1])
    distr1, distr2 = probability_dist(feature1, feature2, bins)
    return torch.nn.functional.kl_div(torch.tensor(distr1).log(), torch.tensor(distr2), log_target=False, reduction='sum').item()

# %%
output["kl_divergence"] = {}

# save kl divergence
for run in range(config["RQ2"]["runs"]):
    output["kl_divergence"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        output["kl_divergence"][f"run_{run}"][str(experiment_value)] = {}
        for feature in features_to_predict:
            output["kl_divergence"][f"run_{run}"][str(experiment_value)][feature] = kl_divergence(features_unscaled[feature], features_reconstr[run][i][feature])

# %%
# plot
data = {}
for feature in features_to_predict:
    data[feature] = {}
    for experiment_value in experiment_variable_values:
        data[feature][str(experiment_value)] = [x[str(experiment_value)][feature] for x in output["kl_divergence"].values()]

nr_features = len(features_to_predict) if len(features_to_predict) > 1 else 2
fig, axs = plt.subplots(nr_features, figsize=(len(experiment_variable_values)*3,nr_features*4))
fig.suptitle(f"KL divergence, {config['RQ2']['runs']} runs", fontweight='bold')

for nr, feature in enumerate(features_to_predict):
    axs[nr].boxplot(data[feature].values(), patch_artist = True) # , showfliers=False
    axs[nr].set_xticklabels(data[feature].keys())
    axs[nr].set_xlabel(config["general"]["experiment_variable"])
    axs[nr].set_ylabel(feature, fontweight='bold')

plt.tight_layout() 
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "5_kl_divergence.png"), **config["plots"])

# %% [markdown]
# ### 5.2 Silhouette Score

# %%
from sklearn.metrics import silhouette_score

output["silhouette_scores"] = {}
output["silhouette_scores"]["orig_data"] = float(silhouette_score(features_unscaled, np.ravel(clusters)))

for run in range(config["RQ2"]["runs"]):
    output["silhouette_scores"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        if len(np.unique(clusters_reconstr[run][i])) > 1:
            output["silhouette_scores"][f"run_{run}"][str(experiment_value)] = float(silhouette_score(features_reconstr[run][i], clusters_reconstr[run][i]))
        else:
            output["silhouette_scores"][f"run_{run}"][str(experiment_value)] = np.nan

# %%
# plot
sil_scores = output["silhouette_scores"].copy()
del(sil_scores["orig_data"])

data = {}
for experiment_value in experiment_variable_values:
    data[str(experiment_value)] = [x[str(experiment_value)] for x in sil_scores.values()]

fig, ax = plt.subplots()
ax.boxplot(data.values(), patch_artist = True)
ax.set_xticklabels(data.keys())
plt.axhline(y=output['silhouette_scores']['orig_data'], color='r', linestyle='-')
plt.xlabel(config["general"]["experiment_variable"])
plt.ylabel("silhouette score")
plt.title(f"silhouette scores, {config['RQ2']['runs']} runs\noriginal data: {round(output['silhouette_scores']['orig_data'], 2)}")
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "5_silhouette_scores.png"), **config["plots"])

# %% [markdown]
# ### 5.3. ARI Score

# %%
from sklearn.metrics.cluster import adjusted_rand_score

output["ARI_score"] = {}
output["ARI_score"]["orig_data"] = adjusted_rand_score(clusters_orig, clusters)

for run in range(config["RQ2"]["runs"]):
    output["ARI_score"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        ari = adjusted_rand_score(clusters_reconstr[run][i], clusters)
        output["ARI_score"][f"run_{run}"][str(experiment_value)] = ari

# %%
# plot
ari = output["ARI_score"].copy()
del(ari['orig_data'])

data = {}
for experiment_value in experiment_variable_values:
    data[str(experiment_value)] = [x[str(experiment_value)] for x in ari.values()]

fig, ax = plt.subplots()
ax.boxplot(data.values(), patch_artist = True)
ax.set_xticklabels(data.keys())
plt.axhline(y=output['ARI_score']['orig_data'], color='r', linestyle='-')
plt.xlabel(config["general"]["experiment_variable"])
plt.ylabel("ARI Score")
plt.title(f"ARI Score, {config['RQ2']['runs']} runs")
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "5_DBSCAN-noise.png"), **config["plots"])

# %% [markdown]
# ### 5.5. Save Output

# %%
if save_output:
    with open(output_path, "w") as f:
                toml.dump(output, f)
