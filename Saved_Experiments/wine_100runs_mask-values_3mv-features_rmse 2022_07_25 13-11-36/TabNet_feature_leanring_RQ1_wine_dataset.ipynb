# %% [markdown]
# ## Change Log
# - Experiments can be setup by using the config parameter "experiment_variable" and assigning the experiment values as a list
# - E.g.
#     - experiment_variable = "train_val_split"
#     - config["training"]["train_val_split"] = [0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]
# - note: only parameters of the category "training" and "model_param" can be used

# %%
# %%javascript
# IPython.notebook.kernel.execute('nb_name = "' + IPython.notebook.notebook_name + '"')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import random
import math

import sys
import os
sys.path.append(os.getcwd() + "/pytorch_tabnet/")

from sklearn.cluster import DBSCAN

# %% [markdown]
# ## 0. Experiment Setup

# %%
# should an output folder be created to save the experiment data?
save_output = True
save_models = False

# %%
# read config file
import toml
config = toml.load("config.toml")

# determine experimental parameter from config
experiment_variable_values = ""
experiment_dict_key = ""
for category_name, category_values in config.items():
    if config["general"]["experiment_variable"] in category_values:
        experiment_variable_values = category_values[config["general"]["experiment_variable"]]
        experiment_dict_key = category_name
        
# rnd seed to support reproducable results
seed_value =  config["general"]["random_seed"] if config["general"]["random_seed"] else random.randrange(2**32 -1)
random.seed(seed_value)
np.random.seed(seed_value)

# TabNet hyperparameters
experiment_variable = config["general"]["experiment_variable"]
regressor_param = {"optimizer_fn" : torch.optim.Adam,
                   "optimizer_params" : {"lr":0.05},
                   "scheduler_params" : {"step_size": 2, "gamma": 0.9},
                   "scheduler_fn" : torch.optim.lr_scheduler.StepLR,
                   "mask_type" : 'entmax',
                   "device_name" : 'cuda', # only working on NVIDIA GPUs
                   "verbose" : 0
                  }

# create experiment folder structure
if save_output or save_models:  
    from datetime import datetime
    
    experiment_name = config["general"]["experiment_name"]
    experiment_folder = f"{experiment_name} {datetime.now().strftime('%Y_%m_%d %H-%M-%S')}" if experiment_name else f"{config['RQ2']['runs']}_runs_{config['general']['experiment_variable']} {datetime.now().strftime('%Y_%m_%d %H-%M-%S')}"
    
    experiment_path = os.path.join("Experiments", experiment_folder)
    os.mkdir(experiment_path)
    
    plots_path = os.path.join(experiment_path, "plots")
    os.mkdir(plots_path)
    
    models_path = os.path.join(experiment_path, "models")
    os.mkdir(models_path)
    
    # save config file
    import shutil
    shutil.copy2("config.toml", experiment_path)
    
    # save random seed
    if not config["general"]["random_seed"]:
        config["general"]["random_seed"] = seed_value
        config_path = os.path.join(experiment_path, "config.toml")
        with open(config_path, "w") as f:
            toml.dump(config, f)
    
    # save model hyperparameters
    with open(os.path.join(experiment_path, 'config.toml'), 'a') as config_file:
        config_file.write("\n#[regressor_param]\n")
        for key, value in regressor_param.items(): 
            config_file.write('#%s = %s\n' % (key, str(value)))
    
    # create output file
    output_path = os.path.join(experiment_path, "output.toml")
    output_file = open(output_path, "w")

output = {}

# %% [markdown]
# ## 1. Datasets
#
# ### 1.0. Use wine dataset

# %%
from sklearn.datasets import load_wine
from sklearn.preprocessing import scale, StandardScaler

wine = load_wine()
X, y = pd.DataFrame(wine.data, columns=wine['feature_names']), wine.target
X_scaled = pd.DataFrame(StandardScaler().fit_transform(X), columns=wine['feature_names'])

# %% [markdown]
# ### 1.1. Create missing data
# Create a specified amount of missing values in the given feature columns (for complete datasets).

# %%
# create missing values in feature column(s)
mv_config = {feature:mv_ratio for feature,mv_ratio in zip(list(X.columns), config["general"]["missing_percent"])}
X_mv = X.copy()

for f, mv in mv_config.items():
    X_mv[f] = X_mv[f].mask(np.random.random(X.shape[0]) < mv)

# %%
import missingno as msno
# %matplotlib inline

# plot missing values
fig = msno.matrix(X_mv)
plt.show()
if save_output:
    #plt.savefig(os.path.join(plots_path, "missing_values.png"), **config["plots"])
    fig_copy = fig.get_figure()
    fig_copy.savefig(os.path.join(plots_path, "missing_values.png"), **config["plots"], bbox_inches = 'tight')

# %% [markdown]
# ### 1.3. Initial Clustering (without missing values)
# Automatically determine DBSCAN hyperparameters min_samples and eps.\
# min_samples results in 26 for the wine dataset (dimensionality 13).\
# for eps we choose 2 (elbow of the graph).

# %%
from sklearn.neighbors import NearestNeighbors

min_samples = 2 * len(X_scaled.columns)

neighbors = NearestNeighbors(n_neighbors=min_samples)
neighbors_fit = neighbors.fit(X_scaled)
distances, indices = neighbors_fit.kneighbors(X_scaled)
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)

# %% [markdown]
# Use the cluster algorithm on dataset without missing values shows, that DBSCAN is not performaing well with 13 dimensional dataset (empty space problem leads to either 1 or 0 clusters).

# %%
# run DBSCAN on original data
config["DBSCAN"]["eps"] = 2
config["DBSCAN"]["min_samples"] = min_samples
if save_output or save_models:
    with open(config_path, "w") as f:
        toml.dump(config, f)

dbscan_orig = DBSCAN(**config["DBSCAN"]).fit(X_scaled)
y_orig = dbscan_orig.labels_
print(f"DBSCAN noise: {(sum(abs(y_orig[y_orig == -1]))*100) / len(y)}%")
# Out:
# DBSCAN noise: 100.0%

# %% [markdown]
# As an alternative, we use k-means for the initial clustering (k=3). This does clearly work better with a more than 96% correct labeling of data.

# %%
from sklearn.cluster import KMeans
k_mean_orig = KMeans(n_clusters=3, random_state=seed_value).fit(X_scaled)
y_orig = k_mean_orig.labels_

# %%
from munkres import Munkres
from sklearn.metrics import confusion_matrix

# use Munkres / Hungarian algorithm to relabel clusters in order to match original label names
def make_cost_matrix(c1, c2):
    """
    """
    uc1 = np.unique(c1)
    uc2 = np.unique(c2)
    l1 = uc1.size
    l2 = uc2.size
    assert(l1 == l2 and np.all(uc1 == uc2))

    m = np.ones([l1, l2])
    for i in range(l1):
        it_i = np.nonzero(c1 == uc1[i])[0]
        for j in range(l2):
            it_j = np.nonzero(c2 == uc2[j])[0]
            m_ij = np.intersect1d(it_j, it_i)
            m[i,j] =  -m_ij.size
    return m

# %%
cost_matrix = make_cost_matrix(y_orig, y)
indexes = Munkres().compute(cost_matrix)
mapping = [new for (_, new) in indexes]
y_orig_renamed = np.choose(y_orig, mapping).astype(np.int64)

mislabeled = y - y_orig_renamed
mislabeled[mislabeled != 0] = 1
mislabeled_orig = sum(mislabeled) / len(mislabeled)
print(f"{round(mislabeled_orig * 100, 2)}% mislabeled")
# Out:
# 3.37% mislabeled

# %% [markdown]
# Get cluster means for loss function input.

# %%
# get cluster means (used to calculate the cluster mean loss)
complete_data = X.copy()
complete_data["C"] = y_orig
cluster_means = complete_data.groupby("C").agg("mean")
cluster_means = cluster_means if -1 not in cluster_means.index else cluster_means.drop(-1)

# %% [markdown]
# ## 2. Filling Strategies
#
#
# ### 2.1. Define custom-loss
# The loss function for the model fitting shall be customized to improve cluster perforamnce. The custom loss is divided into 2 separate losses
#
# 1. **Reconstruction Loss**\
# Classic loss function, such as RMSE.
# 2. **Cluster-Mean Loss**\
# The distance to the nearest cluster mean shall be minimized.
# 3. **KL Divergence Loss**\
# Deviation of original distribution shall be minimized \
# (prob distribution based on https://stackoverflow.com/questions/57687458/how-to-calculate-probabilities-using-numpy-histogram-and-then-use-it-for-calcula \
# number of bins: D. Freedman & P. Diaconis (1981) “On the histogram as a density estimator: L2 theory”. Probability Theory and Related Fields 57 (4): 453-476)
#
# The chosen approach to implement the cluster-mean loss is as follows:\
# **Adapt the loss function** to calculate a distance to each cluster. The minimum distance (to the nearest cluster) will be used as a cluster-mean-loss. Minimizing this loss should result in the data point moving closer to the nearest cluster mean.\
# Potential Problem: loss functions currently work with y_true (true values) and y_score (predicted values). Calculating the distance would require all features. Calculating only the 1 dimensional distance will result in missing values being put into wrong clusters - depending on the first estimate.

# %%
# define custom loss function: extend L2-loss by cluster-mean-loss

from pytorch_tabnet.metrics import Metric
from sklearn.metrics import mean_squared_error
import astropy.stats

class custom_loss(Metric):

    def __init__(self):
        self._name = "custom_loss"
        self._maximize = False

    def __call__(self, y_true, y_score, cluster_means, y_name, x_val, y_val, cl_weights = [0.5, 1, 0.0001]):
        # reconstruction loss
        rmse = np.sqrt(mean_squared_error(y_true, y_score))
        
        # cluster mean loss
        cml = self.cluster_mean_loss(cluster_means, y_score, y_name, x_val, y_val)
        
        # KL divergence loss
        bins = len(astropy.stats.freedman_bin_width(y_true.reshape(1,-1)[0], return_bins=True)[1])
        distr1, distr2 = self.probability_dist(y_score, y_true, bins)
        KLdl = torch.nn.functional.kl_div(torch.tensor(distr1).log(), torch.tensor(distr2), log_target=False, reduction='sum').item()
        
        # total loss
        custom_loss = cl_weights[0] * rmse + cl_weights[1] * KLdl + cl_weights[2] * cml
        return custom_loss
    
    # calculate sum of distances to the closest cluster mean
    def cluster_mean_loss(self, cluster_means, y_score, y_name, x_val, y_val):
        
        # reorder cluster_means to match x_val columns (predicted feature is last column)
        cols = cluster_means.columns.tolist()
        feature_col = X.columns.get_loc(y_name)
        cols = cols[:feature_col] + cols[feature_col+1:] + [y_name]
        
        # x values extended by predicted values
        x_extended = pd.DataFrame(np.hstack((x_val, y_score)), columns=cols)


        # calculate distances to each cluster and select the closest one
        dist = []
        for cluster in range(cluster_means.shape[0]):
            dist.append(np.linalg.norm((x_extended - cluster_means.iloc[cluster]), axis=1))
            
        dist = pd.DataFrame(dist).T
        min_dist = dist.assign(min_dist=lambda d: d.min(1))["min_dist"]
        
        return sum(min_dist)
    
    # calculate probabilities
    def probability_dist(self, x, y, bins):
        # transforms 2 series into their probability distributions
        # histogram
        hist_xy = np.histogram2d(np.asarray(x)[:,0], np.asarray(y)[:,0], bins=bins)[0]

        # compute marginals
        hist_xy = hist_xy + sys.float_info.min # prevent division with 0
        hist_xy = hist_xy / np.sum(hist_xy)
        hist_x = np.sum(hist_xy, axis=1)
        hist_y = np.sum(hist_xy, axis=0)
        return(hist_x, hist_y)

# %% [markdown]
# ### 2.2. Fill missing values (TabNet).
#
# **Approach 1:**\
# For each feature that contains missing values, use all rows with complete other features as train set and predict missing values of the feature.\
# &rarr; Problem: lots of models, especially for high-dimensional datasets.
# Also problem, if more than one feature is missing values. &rarr; see Approach 2
#
# **Approach 2:**\
# Mask missing values as -1 (or some other value) and fit a model predicting each feature just like in approach 1.\
# &rarr; one model for each feature containing missing values.\
# Possible adaption: use predicted values to predict subsequent values (instead of using -1)

# %%
import time

from pytorch_tabnet.tab_model import TabNetRegressor
from sklearn.model_selection import train_test_split

features_to_predict = X_mv.columns[X_mv.isnull().any()]
X_reconstr = {}
output["costs"] = {}
output["runtimes"] = {}
output["predictions"] = {}

for run in range(config["RQ2"]["runs"]):
    
    print(f"Run {run + 1} / {config['RQ2']['runs']}")
    X_reconstr[run] = []
    output["costs"][f"run_{run}"] = {}
    output["runtimes"][f"run_{run}"] = {}
    output["predictions"][f"run_{run}"] = {}
    
    for i, experiment_value in enumerate(experiment_variable_values):
        
        config[experiment_dict_key][config["general"]["experiment_variable"]] = experiment_value
        
        time_start = time.time()
        X_reconstr[run].append(X_mv.copy())
        output["costs"][f"run_{run}"][str(experiment_value)] = {}
        output["runtimes"][f"run_{run}"][str(experiment_value)] = {}
        output["predictions"][f"run_{run}"][str(experiment_value)] = {}
        
        for feature in features_to_predict:
            
            # select % of features for prediction based on pred_features (e.g. 10% of randomly selected features)
            n_features = math.ceil(config["RQ2"]["pred_features"] * (len(X_mv.columns)) - 1)
            X_mv_masked = X_mv.copy().drop(feature, axis=1).sample(n=n_features, axis='columns')
            other_features = X_mv_masked.columns

            # mask other columns' missing values as defined in config (missing_value_mask)
            X_mv_masked[feature] = X_mv[feature]
            X_mv_masked[other_features] = X_mv_masked[(other_features)].fillna(config["general"]["missing_value_mask"])

            # separate complete rows as train data
            # separate column with missing values as target
            test_data = X_mv_masked[X_mv_masked[feature].isna()].drop(feature, axis=1).to_numpy()
            train_data = X_mv_masked[X_mv_masked[feature].notna()]
            train_features = train_data.drop(columns=feature).to_numpy()
            train_target = train_data[feature].to_numpy().reshape(-1,1)

            x_train, x_val, y_train, y_val = train_test_split(train_features, train_target, train_size=config["training"]["train_val_split"])

            # create & train model
            model = TabNetRegressor(**regressor_param)
            if config["model_param"]["eval_metric"] == ["custom_loss"]:
                model.fit(
                    x_train, y_train,
                    eval_set=[(x_val, y_val)],
                    **config["model_param"],
                    cluster_means=cluster_means,
                    y_name=feature,
                    x_val=x_val,
                    y_val=y_val,
                    cl_weights=config["training"]["cl_weights"]
                )
            else:
                model.fit(
                    x_train, y_train,
                    eval_set=[(x_val, y_val)],
                    **config["model_param"]
                )     

            #track runtime
            time_end = time.time()

            # save costs
            output["costs"][f"run_{run}"][str(experiment_value)][feature] = model.best_cost

            # save predictions
            predictions = [x[0] for x in model.predict(test_data)]
            output["predictions"][f"run_{run}"][str(experiment_value)][feature] = predictions
            
            # fill missing values with model predictions
            X_reconstr[run][i].loc[X_reconstr[run][i][feature].isna(), feature] = predictions

            # save outputs
            if save_models:

                # save model
                torch.save(model, os.path.join(models_path, f"Model_run{run}_{config['general']['experiment_variable']}{experiment_value}_{feature}.pt"))
            
            if save_output:
                # save runtimes
                output["runtimes"][f"run_{run}"][str(experiment_value)][feature] = time_end - time_start
# Out:
# Run 1 / 100
#
# Early stopping occurred at epoch 115 with best_epoch = 65 and best_val_0_rmse = 1.67362
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 63 with best_epoch = 13 and best_val_0_rmse = 39.09413
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.74476
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 98 with best_epoch = 48 and best_val_0_rmse = 1.00893
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 58 with best_epoch = 8 and best_val_0_rmse = 57.86913
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.68164
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 242 with best_epoch = 192 and best_val_0_rmse = 1.12754
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_rmse = 34.38217
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.79007
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 205 with best_epoch = 155 and best_val_0_rmse = 1.2659
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 72 with best_epoch = 22 and best_val_0_rmse = 37.92239
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 140 with best_epoch = 90 and best_val_0_rmse = 0.83
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.01601
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_rmse = 44.63973
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 225 and best_val_0_rmse = 0.59244
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 222 and best_val_0_rmse = 1.29446
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 63 with best_epoch = 13 and best_val_0_rmse = 35.06661
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_rmse = 4.62135
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 242 with best_epoch = 192 and best_val_0_rmse = 0.89531
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 113 with best_epoch = 63 and best_val_0_rmse = 39.21637
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.6797
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 2.58651
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 91 with best_epoch = 41 and best_val_0_rmse = 28.31934
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.54366
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 65 with best_epoch = 15 and best_val_0_rmse = 1.71356
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 95 with best_epoch = 45 and best_val_0_rmse = 39.99427
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 229 and best_val_0_rmse = 0.4996
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 108 with best_epoch = 58 and best_val_0_rmse = 1.59342
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 69 with best_epoch = 19 and best_val_0_rmse = 45.29068
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 65 with best_epoch = 15 and best_val_0_rmse = 2.21478
# Best weights from best epoch are automatically used!
# Run 2 / 100
# Stop training because you reached max_epochs = 250 with best_epoch = 212 and best_val_0_rmse = 1.44919
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 86 with best_epoch = 36 and best_val_0_rmse = 32.64606
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 121 with best_epoch = 71 and best_val_0_rmse = 0.93719
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.1109
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 114 with best_epoch = 64 and best_val_0_rmse = 31.98213
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.70611
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_rmse = 5.31113
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_rmse = 27.82647
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 236 with best_epoch = 186 and best_val_0_rmse = 0.66316
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 83 with best_epoch = 33 and best_val_0_rmse = 1.11453
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 76 with best_epoch = 26 and best_val_0_rmse = 25.66708
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_rmse = 1.64338
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 92 with best_epoch = 42 and best_val_0_rmse = 1.66901
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 98 with best_epoch = 48 and best_val_0_rmse = 33.44724
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 216 and best_val_0_rmse = 0.51297
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_rmse = 2.10683
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 157 with best_epoch = 107 and best_val_0_rmse = 45.94612
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 222 and best_val_0_rmse = 0.49889
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.42248
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 83 with best_epoch = 33 and best_val_0_rmse = 27.84782
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.79177
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 210 and best_val_0_rmse = 1.15361
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 67 with best_epoch = 17 and best_val_0_rmse = 32.33314
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.59052
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.01929
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_rmse = 31.62822
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 222 and best_val_0_rmse = 0.82984
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 168 with best_epoch = 118 and best_val_0_rmse = 1.10219
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_rmse = 42.35831
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.66829
# Best weights from best epoch are automatically used!
# Run 3 / 100
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.28674
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 106 with best_epoch = 56 and best_val_0_rmse = 22.78756
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.51763
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 233 with best_epoch = 183 and best_val_0_rmse = 1.37933
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 94 with best_epoch = 44 and best_val_0_rmse = 31.30378
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.77119
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 214 and best_val_0_rmse = 1.20287
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_rmse = 66.69456
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_rmse = 1.48045
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 197 with best_epoch = 147 and best_val_0_rmse = 1.05135
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 58 with best_epoch = 8 and best_val_0_rmse = 25.63631
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 122 with best_epoch = 72 and best_val_0_rmse = 1.38781
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 145 with best_epoch = 95 and best_val_0_rmse = 1.11636
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 61 with best_epoch = 11 and best_val_0_rmse = 38.29925
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.56933
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 77 with best_epoch = 27 and best_val_0_rmse = 1.16027
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 115 with best_epoch = 65 and best_val_0_rmse = 53.41334
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.729
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 160 with best_epoch = 110 and best_val_0_rmse = 2.08496
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 111 with best_epoch = 61 and best_val_0_rmse = 32.21148
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.67079
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 174 with best_epoch = 124 and best_val_0_rmse = 1.3426
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 88 with best_epoch = 38 and best_val_0_rmse = 27.27652
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.6876
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.38871
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_rmse = 36.07841
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 96 with best_epoch = 46 and best_val_0_rmse = 0.9742
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 159 with best_epoch = 109 and best_val_0_rmse = 0.96916
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 67 with best_epoch = 17 and best_val_0_rmse = 26.04027
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 165 with best_epoch = 115 and best_val_0_rmse = 0.64483
# Best weights from best epoch are automatically used!
# Run 4 / 100
# Stop training because you reached max_epochs = 250 with best_epoch = 221 and best_val_0_rmse = 1.11382
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 59 with best_epoch = 9 and best_val_0_rmse = 59.74316
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.63015
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 69 with best_epoch = 19 and best_val_0_rmse = 2.39327
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_rmse = 39.64259
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.67107
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 104 with best_epoch = 54 and best_val_0_rmse = 2.59735
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 65 with best_epoch = 15 and best_val_0_rmse = 41.69341
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_rmse = 0.80722
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 174 with best_epoch = 124 and best_val_0_rmse = 1.60935
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 74 with best_epoch = 24 and best_val_0_rmse = 32.7582
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.4899
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 226 with best_epoch = 176 and best_val_0_rmse = 0.92693
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 117 with best_epoch = 67 and best_val_0_rmse = 35.30074
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.48251
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 229 with best_epoch = 179 and best_val_0_rmse = 0.72748
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 57 with best_epoch = 7 and best_val_0_rmse = 41.38117
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.45475
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 121 with best_epoch = 71 and best_val_0_rmse = 1.20706
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 69 with best_epoch = 19 and best_val_0_rmse = 21.74977
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.60984
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 240 and best_val_0_rmse = 1.57332
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_rmse = 48.76971
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 79 with best_epoch = 29 and best_val_0_rmse = 0.78902
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.24466
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 78 with best_epoch = 28 and best_val_0_rmse = 53.48395
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 74 with best_epoch = 24 and best_val_0_rmse = 2.16247
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 96 with best_epoch = 46 and best_val_0_rmse = 1.3252
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 107 with best_epoch = 57 and best_val_0_rmse = 36.95594
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 99 with best_epoch = 49 and best_val_0_rmse = 0.73199
# Best weights from best epoch are automatically used!
# Run 5 / 100
#
# Early stopping occurred at epoch 57 with best_epoch = 7 and best_val_0_rmse = 2.92411
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 69 with best_epoch = 19 and best_val_0_rmse = 47.11368
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.57601
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 117 with best_epoch = 67 and best_val_0_rmse = 1.33827
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 59 with best_epoch = 9 and best_val_0_rmse = 47.96561
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 239 and best_val_0_rmse = 0.4783
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 198 with best_epoch = 148 and best_val_0_rmse = 0.70271
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 79 with best_epoch = 29 and best_val_0_rmse = 26.74037
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 59 with best_epoch = 9 and best_val_0_rmse = 2.27176
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 152 with best_epoch = 102 and best_val_0_rmse = 1.32933
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 146 with best_epoch = 96 and best_val_0_rmse = 33.71228
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.59275
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 181 with best_epoch = 131 and best_val_0_rmse = 1.07342
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 59 with best_epoch = 9 and best_val_0_rmse = 42.38393
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.51427
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 238 with best_epoch = 188 and best_val_0_rmse = 0.94112
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 80 with best_epoch = 30 and best_val_0_rmse = 33.38768
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 165 with best_epoch = 115 and best_val_0_rmse = 0.83992
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 191 with best_epoch = 141 and best_val_0_rmse = 1.11265
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 71 with best_epoch = 21 and best_val_0_rmse = 56.63989
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_rmse = 1.1098
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 161 with best_epoch = 111 and best_val_0_rmse = 1.40076
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 101 with best_epoch = 51 and best_val_0_rmse = 23.78802
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.53421
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 63 with best_epoch = 13 and best_val_0_rmse = 2.52116
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 83 with best_epoch = 33 and best_val_0_rmse = 21.2791
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 156 with best_epoch = 106 and best_val_0_rmse = 1.04205
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 93 with best_epoch = 43 and best_val_0_rmse = 1.40803
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 57 with best_epoch = 7 and best_val_0_rmse = 40.74964
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 60 with best_epoch = 10 and best_val_0_rmse = 2.19554
# Best weights from best epoch are automatically used!
# Run 6 / 100
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_rmse = 2.50982
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 80 with best_epoch = 30 and best_val_0_rmse = 39.31985
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.49766
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 64 with best_epoch = 14 and best_val_0_rmse = 4.41362
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 86 with best_epoch = 36 and best_val_0_rmse = 51.42951
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.57777
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 218 with best_epoch = 168 and best_val_0_rmse = 0.9337
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_rmse = 26.2021
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.64086
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.55412
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 77 with best_epoch = 27 and best_val_0_rmse = 49.97726
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.59764
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 242 with best_epoch = 192 and best_val_0_rmse = 1.47929
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 114 with best_epoch = 64 and best_val_0_rmse = 43.56923
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_rmse = 3.57381
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 180 with best_epoch = 130 and best_val_0_rmse = 1.66823
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 58 with best_epoch = 8 and best_val_0_rmse = 44.66322
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_rmse = 1.1507
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 208 with best_epoch = 158 and best_val_0_rmse = 1.04065
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 102 with best_epoch = 52 and best_val_0_rmse = 32.7085
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.77298
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 242 with best_epoch = 192 and best_val_0_rmse = 1.18813
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 103 with best_epoch = 53 and best_val_0_rmse = 31.21633
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.58118
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.25527
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 54 with best_epoch = 4 and best_val_0_rmse = 27.89027
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.66459
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 213 and best_val_0_rmse = 1.00578
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 90 with best_epoch = 40 and best_val_0_rmse = 33.75735
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 205 with best_epoch = 155 and best_val_0_rmse = 0.91238
# Best weights from best epoch are automatically used!
# Run 7 / 100
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.27581
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 83 with best_epoch = 33 and best_val_0_rmse = 38.49773
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 86 with best_epoch = 36 and best_val_0_rmse = 0.89629
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 82 with best_epoch = 32 and best_val_0_rmse = 2.43943
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 93 with best_epoch = 43 and best_val_0_rmse = 32.81455
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 67 with best_epoch = 17 and best_val_0_rmse = 1.69386
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 66 with best_epoch = 16 and best_val_0_rmse = 2.35522
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 72 with best_epoch = 22 and best_val_0_rmse = 43.34446
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 237 and best_val_0_rmse = 0.58768
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 96 with best_epoch = 46 and best_val_0_rmse = 1.63221
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 71 with best_epoch = 21 and best_val_0_rmse = 28.81205
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 99 with best_epoch = 49 and best_val_0_rmse = 1.109
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 106 with best_epoch = 56 and best_val_0_rmse = 1.01398
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 66 with best_epoch = 16 and best_val_0_rmse = 33.03963
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.58913
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 64 with best_epoch = 14 and best_val_0_rmse = 5.39522
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 55 with best_epoch = 5 and best_val_0_rmse = 24.74116
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 104 with best_epoch = 54 and best_val_0_rmse = 1.17754
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 67 with best_epoch = 17 and best_val_0_rmse = 1.61094
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 87 with best_epoch = 37 and best_val_0_rmse = 29.29216
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 85 with best_epoch = 35 and best_val_0_rmse = 2.81677
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 79 with best_epoch = 29 and best_val_0_rmse = 5.84539
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 57 with best_epoch = 7 and best_val_0_rmse = 44.45247
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.51103
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_rmse = 5.51591
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 118 with best_epoch = 68 and best_val_0_rmse = 37.39363
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.06776
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 125 with best_epoch = 75 and best_val_0_rmse = 1.23675
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 69 with best_epoch = 19 and best_val_0_rmse = 23.03842
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.64474
# Best weights from best epoch are automatically used!
# Run 8 / 100
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.63965
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 100 with best_epoch = 50 and best_val_0_rmse = 16.63077
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 190 with best_epoch = 140 and best_val_0_rmse = 0.84532
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 208 and best_val_0_rmse = 0.99092
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 131 with best_epoch = 81 and best_val_0_rmse = 29.11294
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.77935
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 71 with best_epoch = 21 and best_val_0_rmse = 1.37749
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 177 with best_epoch = 127 and best_val_0_rmse = 61.52668
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.62361
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 65 with best_epoch = 15 and best_val_0_rmse = 2.76712
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_rmse = 27.67792
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.68881
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 231 and best_val_0_rmse = 1.23803
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 52 with best_epoch = 2 and best_val_0_rmse = 40.89081
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.52814
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_rmse = 1.87084
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 88 with best_epoch = 38 and best_val_0_rmse = 32.20355
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.3202
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 230 and best_val_0_rmse = 0.81066
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_rmse = 44.69388
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 88 with best_epoch = 38 and best_val_0_rmse = 1.90766
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 220 and best_val_0_rmse = 1.08564
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 85 with best_epoch = 35 and best_val_0_rmse = 29.70785
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.61084
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 202 with best_epoch = 152 and best_val_0_rmse = 1.10359
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 114 with best_epoch = 64 and best_val_0_rmse = 67.2382
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 105 with best_epoch = 55 and best_val_0_rmse = 1.4521
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 219 and best_val_0_rmse = 1.32234
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 138 with best_epoch = 88 and best_val_0_rmse = 47.52503
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 222 and best_val_0_rmse = 0.77919
# Best weights from best epoch are automatically used!
# Run 9 / 100
#
# Early stopping occurred at epoch 77 with best_epoch = 27 and best_val_0_rmse = 1.51654
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 65 with best_epoch = 15 and best_val_0_rmse = 45.92321
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 71 with best_epoch = 21 and best_val_0_rmse = 2.84192
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.45493
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_rmse = 21.1725
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 67 with best_epoch = 17 and best_val_0_rmse = 1.88922
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 165 with best_epoch = 115 and best_val_0_rmse = 1.15668
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 58 with best_epoch = 8 and best_val_0_rmse = 46.05764
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 77 with best_epoch = 27 and best_val_0_rmse = 1.16281
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 63 with best_epoch = 13 and best_val_0_rmse = 2.37608
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 83 with best_epoch = 33 and best_val_0_rmse = 26.45376
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 84 with best_epoch = 34 and best_val_0_rmse = 0.94651
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 76 with best_epoch = 26 and best_val_0_rmse = 1.3208
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 64 with best_epoch = 14 and best_val_0_rmse = 43.67095
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 244 and best_val_0_rmse = 0.71569
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 115 with best_epoch = 65 and best_val_0_rmse = 1.68659
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_rmse = 33.14458
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.61809
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 58 with best_epoch = 8 and best_val_0_rmse = 6.80163
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 111 with best_epoch = 61 and best_val_0_rmse = 69.6813
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 196 with best_epoch = 146 and best_val_0_rmse = 0.8403
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 148 with best_epoch = 98 and best_val_0_rmse = 1.70164
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 111 with best_epoch = 61 and best_val_0_rmse = 26.53182
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 144 with best_epoch = 94 and best_val_0_rmse = 1.07542
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 74 with best_epoch = 24 and best_val_0_rmse = 1.55439
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 91 with best_epoch = 41 and best_val_0_rmse = 46.25047
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 212 and best_val_0_rmse = 0.62466
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 99 with best_epoch = 49 and best_val_0_rmse = 1.42255
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 84 with best_epoch = 34 and best_val_0_rmse = 28.41821
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.65228
# Best weights from best epoch are automatically used!
# Run 10 / 100
#
# Early stopping occurred at epoch 228 with best_epoch = 178 and best_val_0_rmse = 1.31878
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 59 with best_epoch = 9 and best_val_0_rmse = 52.12422
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 67 with best_epoch = 17 and best_val_0_rmse = 1.39165
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 224 with best_epoch = 174 and best_val_0_rmse = 0.92684
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 158 with best_epoch = 108 and best_val_0_rmse = 49.57342
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.55017
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 218 with best_epoch = 168 and best_val_0_rmse = 1.42314
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 64 with best_epoch = 14 and best_val_0_rmse = 45.50482
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.91586
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 53 with best_epoch = 3 and best_val_0_rmse = 3.15985
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 120 with best_epoch = 70 and best_val_0_rmse = 35.9693
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.50572
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 112 with best_epoch = 62 and best_val_0_rmse = 1.73899
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 89 with best_epoch = 39 and best_val_0_rmse = 28.09228
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.65046
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_rmse = 5.7391
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 67 with best_epoch = 17 and best_val_0_rmse = 38.70232
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.81393
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 248 with best_epoch = 198 and best_val_0_rmse = 1.31949
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 100 with best_epoch = 50 and best_val_0_rmse = 26.55699
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 57 with best_epoch = 7 and best_val_0_rmse = 4.18904
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.09368
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 80 with best_epoch = 30 and best_val_0_rmse = 15.18587
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 102 with best_epoch = 52 and best_val_0_rmse = 1.32488
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 55 with best_epoch = 5 and best_val_0_rmse = 2.64445
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 94 with best_epoch = 44 and best_val_0_rmse = 16.70318
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.62954
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 235 with best_epoch = 185 and best_val_0_rmse = 1.16468
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_rmse = 28.71638
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.56146
# Best weights from best epoch are automatically used!
# Run 11 / 100
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.96424
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 138 with best_epoch = 88 and best_val_0_rmse = 41.18642
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 190 with best_epoch = 140 and best_val_0_rmse = 0.76608
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 205 with best_epoch = 155 and best_val_0_rmse = 1.4438
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 54 with best_epoch = 4 and best_val_0_rmse = 52.85824
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.57082
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 161 with best_epoch = 111 and best_val_0_rmse = 1.57468
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_rmse = 17.57725
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 77 with best_epoch = 27 and best_val_0_rmse = 4.63029
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.30095
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 67 with best_epoch = 17 and best_val_0_rmse = 52.53783
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 132 with best_epoch = 82 and best_val_0_rmse = 0.93696
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 58 with best_epoch = 8 and best_val_0_rmse = 8.95558
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 104 with best_epoch = 54 and best_val_0_rmse = 21.43776
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 98 with best_epoch = 48 and best_val_0_rmse = 1.35432
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.02175
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 55 with best_epoch = 5 and best_val_0_rmse = 51.68933
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 51 with best_epoch = 1 and best_val_0_rmse = 5.93146
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 203 and best_val_0_rmse = 1.12029
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 76 with best_epoch = 26 and best_val_0_rmse = 32.60746
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.57401
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 106 with best_epoch = 56 and best_val_0_rmse = 1.74538
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 52 with best_epoch = 2 and best_val_0_rmse = 48.78297
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 127 with best_epoch = 77 and best_val_0_rmse = 0.8099
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.35187
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 79 with best_epoch = 29 and best_val_0_rmse = 45.02662
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 102 with best_epoch = 52 and best_val_0_rmse = 2.12874
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.42479
# Best weights from best epoch are automatically used!
#
# ...
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.67986
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 181 with best_epoch = 131 and best_val_0_rmse = 0.90776
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 88 with best_epoch = 38 and best_val_0_rmse = 27.59166
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 219 and best_val_0_rmse = 0.77543
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 60 with best_epoch = 10 and best_val_0_rmse = 2.8502
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_rmse = 41.09784
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.46569
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 123 with best_epoch = 73 and best_val_0_rmse = 1.26148
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 86 with best_epoch = 36 and best_val_0_rmse = 40.464
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 242 and best_val_0_rmse = 0.59825
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 240 with best_epoch = 190 and best_val_0_rmse = 1.18089
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 53 with best_epoch = 3 and best_val_0_rmse = 30.56895
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.82083
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 128 with best_epoch = 78 and best_val_0_rmse = 0.98962
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 135 with best_epoch = 85 and best_val_0_rmse = 29.65818
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 248 and best_val_0_rmse = 0.59826
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_rmse = 2.3048
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_rmse = 44.38336
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.18672
# Best weights from best epoch are automatically used!
# Run 98 / 100
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_rmse = 8.53391
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 156 with best_epoch = 106 and best_val_0_rmse = 56.15848
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 129 with best_epoch = 79 and best_val_0_rmse = 1.00056
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 177 with best_epoch = 127 and best_val_0_rmse = 1.0952
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 99 with best_epoch = 49 and best_val_0_rmse = 51.20157
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.76054
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 57 with best_epoch = 7 and best_val_0_rmse = 2.3822
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 59 with best_epoch = 9 and best_val_0_rmse = 39.16386
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 71 with best_epoch = 21 and best_val_0_rmse = 0.75073
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 61 with best_epoch = 11 and best_val_0_rmse = 3.73398
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 57 with best_epoch = 7 and best_val_0_rmse = 37.7999
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.54432
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 224 and best_val_0_rmse = 1.27425
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 116 with best_epoch = 66 and best_val_0_rmse = 25.18349
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.62991
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 132 with best_epoch = 82 and best_val_0_rmse = 2.87097
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 165 with best_epoch = 115 and best_val_0_rmse = 48.45651
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.7173
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 65 with best_epoch = 15 and best_val_0_rmse = 1.71832
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 55 with best_epoch = 5 and best_val_0_rmse = 48.78303
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 122 with best_epoch = 72 and best_val_0_rmse = 1.35248
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 246 with best_epoch = 196 and best_val_0_rmse = 1.3436
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 79 with best_epoch = 29 and best_val_0_rmse = 42.83381
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 223 and best_val_0_rmse = 0.83344
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 136 with best_epoch = 86 and best_val_0_rmse = 1.16197
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 58 with best_epoch = 8 and best_val_0_rmse = 27.10569
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 147 with best_epoch = 97 and best_val_0_rmse = 0.65168
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 134 with best_epoch = 84 and best_val_0_rmse = 1.52937
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 98 with best_epoch = 48 and best_val_0_rmse = 34.0409
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 55 with best_epoch = 5 and best_val_0_rmse = 3.75455
# Best weights from best epoch are automatically used!
# Run 99 / 100
#
# Early stopping occurred at epoch 154 with best_epoch = 104 and best_val_0_rmse = 1.39927
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 120 with best_epoch = 70 and best_val_0_rmse = 25.32713
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.56335
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 207 and best_val_0_rmse = 0.91396
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 117 with best_epoch = 67 and best_val_0_rmse = 43.49967
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 162 with best_epoch = 112 and best_val_0_rmse = 0.76191
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 199 with best_epoch = 149 and best_val_0_rmse = 1.90087
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 128 with best_epoch = 78 and best_val_0_rmse = 17.04798
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 60 with best_epoch = 10 and best_val_0_rmse = 1.50372
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 245 with best_epoch = 195 and best_val_0_rmse = 1.51546
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_rmse = 23.98766
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.67327
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 192 with best_epoch = 142 and best_val_0_rmse = 1.15459
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 97 with best_epoch = 47 and best_val_0_rmse = 49.13391
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.77779
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 114 with best_epoch = 64 and best_val_0_rmse = 1.91326
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_rmse = 13.5193
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.7272
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 194 with best_epoch = 144 and best_val_0_rmse = 1.39199
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 90 with best_epoch = 40 and best_val_0_rmse = 30.04226
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 54 with best_epoch = 4 and best_val_0_rmse = 1.38127
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 60 with best_epoch = 10 and best_val_0_rmse = 4.28825
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 57 with best_epoch = 7 and best_val_0_rmse = 29.79339
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.96394
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_rmse = 2.11185
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 105 with best_epoch = 55 and best_val_0_rmse = 49.51029
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.87221
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 213 and best_val_0_rmse = 1.24801
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_rmse = 51.28283
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.54908
# Best weights from best epoch are automatically used!
# Run 100 / 100
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.10642
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 104 with best_epoch = 54 and best_val_0_rmse = 36.55119
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 236 with best_epoch = 186 and best_val_0_rmse = 0.61646
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 188 with best_epoch = 138 and best_val_0_rmse = 1.19585
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_rmse = 39.83214
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.58068
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 222 and best_val_0_rmse = 1.69572
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 55 with best_epoch = 5 and best_val_0_rmse = 20.85622
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.4842
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 57 with best_epoch = 7 and best_val_0_rmse = 2.74146
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 133 with best_epoch = 83 and best_val_0_rmse = 40.94697
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 94 with best_epoch = 44 and best_val_0_rmse = 1.23387
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 66 with best_epoch = 16 and best_val_0_rmse = 3.17555
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 80 with best_epoch = 30 and best_val_0_rmse = 41.46057
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 115 with best_epoch = 65 and best_val_0_rmse = 0.60723
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 64 with best_epoch = 14 and best_val_0_rmse = 1.50554
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 93 with best_epoch = 43 and best_val_0_rmse = 40.18006
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 239 and best_val_0_rmse = 0.69078
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 1.28956
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_rmse = 34.36624
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.78732
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 239 and best_val_0_rmse = 1.29149
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 51 with best_epoch = 1 and best_val_0_rmse = 37.31098
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_rmse = 1.64785
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 90 with best_epoch = 40 and best_val_0_rmse = 0.93339
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 86 with best_epoch = 36 and best_val_0_rmse = 57.78867
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 64 with best_epoch = 14 and best_val_0_rmse = 1.31557
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_rmse = 0.95607
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 55 with best_epoch = 5 and best_val_0_rmse = 41.44243
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 80 with best_epoch = 30 and best_val_0_rmse = 1.28093
# Best weights from best epoch are automatically used!

# %% [markdown]
# ## 3. Reconstruct Dataset
# choose best model based on min. squared custom loss (punishing large outliers in losses for single features)

# %%
best_per_run = []
best_per_run_index = []
for run in range(config["RQ2"]["runs"]):
    cost_list = list(output["costs"][f"run_{run}"].values())
    cost_totals = [sum(c**2 for c in list(x.values())) for x in cost_list]
    best_per_run.append(min(cost_totals))
    best_per_run_index.append(cost_totals.index(min(cost_totals)))
    
best_run = best_per_run.index(min(best_per_run))
best_model = best_per_run_index[best_run]
print(f"Best model: run {best_run} model {best_model}")

X_best = X_reconstr[best_run][best_model]
# Out:
# Best model: run 36 model 3

# %% [markdown]
# ## 4. Clustering
# Apply k-means (k=3) on reconstructed data. In order to make the clusters comparable, the k-Means labels will be replaced using Munkres / Hungarian algorithm as explained here:\
# https://gist.github.com/siolag161/dc6e42b64e1bde1f263b \
# https://github.com/benchaplin/hungarian-algorithm

# %%
# apply clustering
y_reconstr = []
for run in range(config["RQ2"]["runs"]):
    y_reconstr.append([])
    for i, var in enumerate(experiment_variable_values):
        
        X_reconstr_scaled = pd.DataFrame(StandardScaler().fit_transform(X_reconstr[run][i]))
        k_mean_reconstr = KMeans(n_clusters=3).fit(X_reconstr_scaled)
        
        cost_matrix = make_cost_matrix(k_mean_reconstr.labels_, y)
        indexes = Munkres().compute(cost_matrix)
        mapping = [new for (_, new) in indexes]
        
        y_reconstr[run].append(np.choose(k_mean_reconstr.labels_,mapping).astype(np.int64))

# %% [markdown]
# ## 5. Cluster Performance

# %% [markdown]
# ### 5.1 Feature Distributions
# #### 5.1.1 Distr. Plots based on best model predictions

# %%
# plot distributions
bins = len(astropy.stats.freedman_bin_width(X[feature], return_bins=True)[1])
n_feat = len(features_to_predict) if len(features_to_predict) > 1 else 2

fig, (ax) = plt.subplots(n_feat, 2, figsize=(10,n_feat*3))
fig.suptitle(f"distributions based on best model", fontweight='bold')
for n, feature in enumerate(X_best[features_to_predict]):
    ax[n, 0].hist(X[feature], bins=bins)
    ax[n, 0].set_title(f"{feature}_orig")
    ax[n, 1].hist(X_best[feature], bins=bins)
    ax[n, 1].set_title(f"{feature}_reconstructed")

fig.tight_layout()
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "feature distributions.png"), **config["plots"])

# %% [markdown]
# #### 5.1.1 Predictions out of original min/max range

# %%
data = {}

for feature in features_to_predict:
    data[feature] = {}
    n_predictions = sum(X_mv[feature].isna()) * config["RQ2"]["runs"]
    min_val = X[feature].min()
    max_val = X[feature].max()
    n_inliers = 0
    
    for experiment_value in experiment_variable_values:
        data[feature][str(experiment_value)] = 0  
        
        for run in range(config["RQ2"]["runs"]):
            data[feature][str(experiment_value)] += sum([True if x > min_val and x < max_val else False for x in output["predictions"][f"run_{run}"][str(experiment_value)][feature]])
    
        data[feature][str(experiment_value)] = data[feature][str(experiment_value)] / n_predictions

n_features = len(features_to_predict) if len(features_to_predict) > 1 else 2
base_height = 5
base_width = 2
fontsize=20

fig, axs = plt.subplots(n_features, figsize=(len(experiment_variable_values)*base_width,n_features*base_height))
fig.suptitle(f"% of predicted values within original range", fontweight='bold',fontsize=fontsize)

for nr, feature in enumerate(features_to_predict):
    axs[nr].plot(data[feature].keys(), data[feature].values())
    axs[nr].set_xlabel(config["general"]["experiment_variable"],fontsize=fontsize)
    axs[nr].set_ylabel(feature, fontweight='bold', fontsize=fontsize)
    axs[nr].set_ylim([0, 1])
    axs[nr].text(0.9, 0.9, f"{[x for x in config['general']['missing_percent'] if x != 0][nr]}% missing", horizontalalignment='center', verticalalignment='center', transform=axs[nr].transAxes, fontsize=30)

plt.tight_layout() 

if save_output:
    plt.savefig(os.path.join(plots_path, "5_prediction_range_rel.png"), **config["plots"])

plt.show()

# %%
data = {}
for feature in features_to_predict:
    data[feature] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        # add all replaced values from all runs to a list
        data[feature][str(experiment_value)] = []
        for run in range(config["RQ2"]["runs"]): 
            data[feature][str(experiment_value)].extend(output["predictions"][f"run_{run}"][str(experiment_value)][feature])

nr_features = len(features_to_predict) if len(features_to_predict) > 1 else 2
base_height = 10
base_width = 3
fontsize=20

fig, axs = plt.subplots(nr_features, figsize=(len(experiment_variable_values)*base_width,nr_features*base_height))
fig.suptitle(f"Predicted values", fontweight='bold',fontsize=fontsize)

for nr, feature in enumerate(features_to_predict):
    axs[nr].boxplot(data[feature].values(), patch_artist = True)
    axs[nr].set_xticklabels(data[feature].keys(),fontsize=fontsize)
    axs[nr].set_xlabel(config["general"]["experiment_variable"],fontsize=fontsize)
    axs[nr].set_ylabel(feature, fontweight='bold', fontsize=fontsize)
    axs[nr].axhline(X[feature].min(),color='red',ls='-')
    axs[nr].axhline(X[feature].max(),color='red',ls='-')
    axs[nr].text(0.9, 0.9, f"min {X[feature].min()}\nmax {X[feature].max()}", horizontalalignment='center', verticalalignment='center', transform=axs[nr].transAxes, fontsize=30)

plt.tight_layout() 

if save_output:
    plt.savefig(os.path.join(plots_path, "5_prediction_range_abs.png"), **config["plots"])

plt.show()

# %% [markdown]
# #### 5.1.2 KL Divergence

# %%
# KL Divergence
def kl_divergence(feature1, feature2):
    
    # calculate probability distributions
    def probability_dist(x, y, bins):
        # transforms 2 series into their probability distributions
        # histogram
        hist_xy = np.histogram2d(x, y, bins=bins)[0]

        # compute marginals
        hist_xy = hist_xy + sys.float_info.min # prevent division with 0
        hist_xy = hist_xy / np.sum(hist_xy)
        hist_x = np.sum(hist_xy, axis=1)
        hist_y = np.sum(hist_xy, axis=0)
        return(hist_x, hist_y)

    # calculate kl divergence
    bins = len(astropy.stats.freedman_bin_width(feature1, return_bins=True)[1])
    distr1, distr2 = probability_dist(feature1, feature2, bins)
    return torch.nn.functional.kl_div(torch.tensor(distr1).log(), torch.tensor(distr2), log_target=False, reduction='sum').item()

# %%
output["kl_divergence"] = {}

# save kl divergence
for run in range(config["RQ2"]["runs"]):
    output["kl_divergence"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        output["kl_divergence"][f"run_{run}"][str(experiment_value)] = {}
        for feature in features_to_predict:
            output["kl_divergence"][f"run_{run}"][str(experiment_value)][feature] = kl_divergence(X[feature], X_reconstr[run][i][feature])

# %%
# plot
data = {}
for feature in features_to_predict:
    data[feature] = {}
    for experiment_value in experiment_variable_values:
        data[feature][str(experiment_value)] = [x[str(experiment_value)][feature] for x in output["kl_divergence"].values()]

nr_features = len(features_to_predict) if len(features_to_predict) > 1 else 2
fig, axs = plt.subplots(nr_features, figsize=(len(experiment_variable_values)*3,nr_features*4))
fig.suptitle(f"KL divergence, {config['RQ2']['runs']} runs", fontweight='bold')

for nr, feature in enumerate(features_to_predict):
    axs[nr].boxplot(data[feature].values(), patch_artist = True) # , showfliers=False
    axs[nr].set_xticklabels(data[feature].keys())
    axs[nr].set_xlabel(config["general"]["experiment_variable"])
    axs[nr].set_ylabel(feature, fontweight='bold')

plt.tight_layout() 

if save_output:
    plt.savefig(os.path.join(plots_path, "5_kl_divergence.png"), **config["plots"])
    
plt.show()

# %% [markdown]
# ### 5.2 Silhouette Score

# %%
from sklearn.metrics import silhouette_score

output["silhouette_scores"] = {}
output["silhouette_scores"]["orig_data"] = float(silhouette_score(X, np.ravel(y)))

for run in range(config["RQ2"]["runs"]):
    output["silhouette_scores"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        if len(np.unique(y_reconstr[run][i])) > 1:
            output["silhouette_scores"][f"run_{run}"][str(experiment_value)] = float(silhouette_score(X_reconstr[run][i], y_reconstr[run][i]))
        else:
            output["silhouette_scores"][f"run_{run}"][str(experiment_value)] = np.nan

# %%
# plot
sil_scores = output["silhouette_scores"].copy()
del(sil_scores["orig_data"])

data = {}
for experiment_value in experiment_variable_values:
    data[str(experiment_value)] = [x[str(experiment_value)] for x in sil_scores.values()]

fig, ax = plt.subplots()
ax.boxplot(data.values(), patch_artist = True)
ax.set_xticklabels(data.keys())
plt.axhline(y=output['silhouette_scores']['orig_data'], color='r', linestyle='-')
plt.xlabel(config["general"]["experiment_variable"])
plt.ylabel("silhouette score")
plt.title(f"silhouette scores, {config['RQ2']['runs']} runs\noriginal data: {round(output['silhouette_scores']['orig_data'], 2)}")

if save_output:
    plt.savefig(os.path.join(plots_path, "5_silhouette_scores.png"), **config["plots"])

plt.show()

# %% [markdown]
# ### 5.3. ARI Score

# %%
from sklearn.metrics.cluster import adjusted_rand_score

output["ARI_score"] = {}
output["ARI_score"]["orig_data"] = adjusted_rand_score(y_orig, y)

for run in range(config["RQ2"]["runs"]):
    output["ARI_score"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        ari = adjusted_rand_score(y_reconstr[run][i], y)
        output["ARI_score"][f"run_{run}"][str(experiment_value)] = ari

# %%
# plot
ari = output["ARI_score"].copy()
del(ari['orig_data'])

data = {}
for experiment_value in experiment_variable_values:
    data[str(experiment_value)] = [x[str(experiment_value)] for x in ari.values()]

fig, ax = plt.subplots()
ax.boxplot(data.values(), patch_artist = True)
ax.set_xticklabels(data.keys())
plt.axhline(y=output['ARI_score']['orig_data'], color='r', linestyle='-')
plt.xlabel(config["general"]["experiment_variable"])
plt.ylabel("ARI Score")
plt.title(f"ARI Score, {config['RQ2']['runs']} runs")

if save_output:
    plt.savefig(os.path.join(plots_path, "5_ARI-score.png"), **config["plots"])

plt.show()

# %% [markdown]
# ### 5.5. Save Output

# %%
if save_output:
    # save output file
    with open(output_path, "w") as f:
                toml.dump(output, f)

    # save notebook
    shutil.copy2(nb_name, experiment_path)
