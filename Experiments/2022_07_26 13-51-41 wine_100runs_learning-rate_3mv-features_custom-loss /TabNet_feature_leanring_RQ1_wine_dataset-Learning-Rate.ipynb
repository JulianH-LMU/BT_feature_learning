# %% [markdown]
# ## Change Log
# - Experiments can be setup by using the config parameter "experiment_variable" and assigning the experiment values as a list
# - E.g.
#     - experiment_variable = "train_val_split"
#     - config["training"]["train_val_split"] = [0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]
# - note: only parameters of the category "training" and "model_param" can be used

# %%
# %%javascript
# IPython.notebook.kernel.execute('nb_name = "' + IPython.notebook.notebook_name + '"')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import random
import math

import sys
import os
sys.path.append(os.getcwd() + "/pytorch_tabnet/")

from sklearn.cluster import DBSCAN

# %% [markdown]
# ## 0. Experiment Setup

# %%
# should an output folder be created to save the experiment data?
save_output = True
save_models = True

# %%
# read config file
import toml
config = toml.load("config.toml")

# determine experimental parameter from config
experiment_variable_values = ""
experiment_dict_key = ""
for category_name, category_values in config.items():
    if config["general"]["experiment_variable"] in category_values:
        experiment_variable_values = category_values[config["general"]["experiment_variable"]]
        experiment_dict_key = category_name        

# rnd seed to support reproducable results
seed_value =  config["general"]["random_seed"] if config["general"]["random_seed"] else random.randrange(2**32 -1)
random.seed(seed_value)
np.random.seed(seed_value)

# TabNet hyperparameters
experiment_variable = config["general"]["experiment_variable"]
regressor_param = {"optimizer_fn" : torch.optim.Adam,
                   "optimizer_params" : {"lr":0.05},
                   "scheduler_params" : {"step_size": 2, "gamma": 0.9},
                   "scheduler_fn" : torch.optim.lr_scheduler.StepLR,
                   "mask_type" : 'entmax',
                   "device_name" : 'cuda', # only working on NVIDIA GPUs
                   "verbose" : 0
                  }

# create experiment folder structure
if save_output or save_models:  
    from datetime import datetime
    
    experiment_name = config["general"]["experiment_name"]
    experiment_folder = f"{datetime.now().strftime('%Y_%m_%d %H-%M-%S')} {experiment_name} " if experiment_name else f"{datetime.now().strftime('%Y_%m_%d %H-%M-%S')} {config['RQ2']['runs']}_runs_{config['general']['experiment_variable']}"
    
    experiment_path = os.path.join("Experiments", experiment_folder)
    os.mkdir(experiment_path)
    
    plots_path = os.path.join(experiment_path, "plots")
    os.mkdir(plots_path)
    
    models_path = os.path.join(experiment_path, "models")
    os.mkdir(models_path)
    
    # save config file
    import shutil
    shutil.copy2("config.toml", experiment_path)
    
    # save random seed
    if not config["general"]["random_seed"]:
        config["general"]["random_seed"] = seed_value
        config_path = os.path.join(experiment_path, "config.toml")
        with open(config_path, "w") as f:
            toml.dump(config, f)
    
    # save model hyperparameters
    with open(os.path.join(experiment_path, 'config.toml'), 'a') as config_file:
        config_file.write("\n#[regressor_param]\n")
        for key, value in regressor_param.items(): 
            config_file.write('#%s = %s\n' % (key, str(value)))
    
    # create output file
    output_path = os.path.join(experiment_path, "output.toml")
    output_file = open(output_path, "w")

output = {}

# %% [markdown]
# ## 1. Datasets
#
# ### 1.0. Use wine dataset

# %%
from sklearn.datasets import load_wine
from sklearn.preprocessing import scale, StandardScaler

wine = load_wine()
X, labels_true = pd.DataFrame(wine.data, columns=wine['feature_names']), wine.target
X_scaled = pd.DataFrame(StandardScaler().fit_transform(X), columns=wine['feature_names'])

# %% [markdown]
# ### 1.1. Create missing data
# Create a specified amount of missing values in the given feature columns (for complete datasets).

# %%
# create missing values in feature column(s)
mv_config = {feature:mv_ratio for feature,mv_ratio in zip(list(X.columns), config["general"]["missing_percent"])}
X_mv = X.copy()

for f, mv in mv_config.items():
    X_mv[f] = X_mv[f].mask(np.random.random(X.shape[0]) < mv)

# %%
import missingno as msno
# %matplotlib inline

# plot missing values
fig = msno.matrix(X_mv)
plt.show()
if save_output:
    #plt.savefig(os.path.join(plots_path, "missing_values.png"), **config["plots"])
    fig_copy = fig.get_figure()
    fig_copy.savefig(os.path.join(plots_path, "missing_values.png"), **config["plots"], bbox_inches = 'tight')

# %% [markdown]
# ### 1.3. Initial Clustering (without missing values)
# Automatically determine DBSCAN hyperparameters min_samples and eps.\
# min_samples results in 26 for the wine dataset (dimensionality 13).\
# for eps we choose 2 (elbow of the graph).

# %%
from sklearn.neighbors import NearestNeighbors

min_samples = 2 * len(X_scaled.columns)

neighbors = NearestNeighbors(n_neighbors=min_samples)
neighbors_fit = neighbors.fit(X_scaled)
distances, indices = neighbors_fit.kneighbors(X_scaled)
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)

# %% [markdown]
# Use the cluster algorithm on dataset without missing values shows, that DBSCAN is not performaing well with 13 dimensional dataset (empty space problem leads to either 1 or 0 clusters).

# %%
# run DBSCAN on original data
config["DBSCAN"]["eps"] = 2
config["DBSCAN"]["min_samples"] = min_samples
if save_output or save_models:
    with open(config_path, "w") as f:
        toml.dump(config, f)

dbscan_orig = DBSCAN(**config["DBSCAN"]).fit(X_scaled)
labels_orig = dbscan_orig.labels_
print(f"DBSCAN noise: {(sum(abs(labels_orig[labels_orig == -1]))*100) / len(labels_true)}%")
# Out:
# DBSCAN noise: 100.0%

# %% [markdown]
# As an alternative, we use k-means for the initial clustering (k=3). This does clearly work better with a more than 96% correct labeling of data.

# %%
from sklearn.cluster import KMeans
k_mean_orig = KMeans(n_clusters=3, random_state=seed_value).fit(X_scaled)
labels_orig = k_mean_orig.labels_

# %%
from munkres import Munkres
from sklearn.metrics import confusion_matrix

# use Munkres / Hungarian algorithm to relabel clusters in order to match original label names
def make_cost_matrix(c1, c2):
    """
    """
    uc1 = np.unique(c1)
    uc2 = np.unique(c2)
    l1 = uc1.size
    l2 = uc2.size
    assert(l1 == l2 and np.all(uc1 == uc2))

    m = np.ones([l1, l2])
    for i in range(l1):
        it_i = np.nonzero(c1 == uc1[i])[0]
        for j in range(l2):
            it_j = np.nonzero(c2 == uc2[j])[0]
            m_ij = np.intersect1d(it_j, it_i)
            m[i,j] =  -m_ij.size
    return m

# %%
cost_matrix = make_cost_matrix(labels_orig, labels_true)
indexes = Munkres().compute(cost_matrix)
mapping = [new for (_, new) in indexes]
labels_orig_renamed = np.choose(labels_orig, mapping).astype(np.int64)

mislabeled = labels_true - labels_orig_renamed
mislabeled[mislabeled != 0] = 1
mislabeled_orig = sum(mislabeled) / len(mislabeled)
print(f"{round(mislabeled_orig * 100, 2)}% mislabeled")
# Out:
# 3.37% mislabeled

# %% [markdown]
# Get cluster means for loss function input.

# %%
# get cluster means (used to calculate the cluster mean loss)
complete_data = X.copy()
complete_data["C"] = labels_orig
cluster_means = complete_data.groupby("C").agg("mean")
cluster_means = cluster_means if -1 not in cluster_means.index else cluster_means.drop(-1)

# %% [markdown]
# ## 2. Filling Strategies
#
#
# ### 2.1. Define custom-loss
# The loss function for the model fitting shall be customized to improve cluster perforamnce. The custom loss is divided into 2 separate losses
#
# 1. **Reconstruction Loss**\
# Classic loss function, such as RMSE.
# 2. **Cluster-Mean Loss**\
# The distance to the nearest cluster mean shall be minimized.
# 3. **KL Divergence Loss**\
# Deviation of original distribution shall be minimized \
# (prob distribution based on https://stackoverflow.com/questions/57687458/how-to-calculate-probabilities-using-numpy-histogram-and-then-use-it-for-calcula \
# number of bins: D. Freedman & P. Diaconis (1981) “On the histogram as a density estimator: L2 theory”. Probability Theory and Related Fields 57 (4): 453-476)
#
# The chosen approach to implement the cluster-mean loss is as follows:\
# **Adapt the loss function** to calculate a distance to each cluster. The minimum distance (to the nearest cluster) will be used as a cluster-mean-loss. Minimizing this loss should result in the data point moving closer to the nearest cluster mean.\
# Potential Problem: loss functions currently work with y_true (true values) and y_score (predicted values). Calculating the distance would require all features. Calculating only the 1 dimensional distance will result in missing values being put into wrong clusters - depending on the first estimate.

# %%
# define custom loss function: extend L2-loss by cluster-mean-loss

from pytorch_tabnet.metrics import Metric
from sklearn.metrics import mean_squared_error
import astropy.stats

class custom_loss(Metric):

    def __init__(self):
        self._name = "custom_loss"
        self._maximize = False

    def __call__(self, y_true, y_score, cluster_means, y_name, x_val, y_val, cl_weights = [0.5, 1, 0.0001]):
        # reconstruction loss
        rmse = np.sqrt(mean_squared_error(y_true, y_score))
        
        # cluster mean loss
        cml = self.cluster_mean_loss(cluster_means, y_score, y_name, x_val, y_val)
        
        # KL divergence loss
        bins = len(astropy.stats.freedman_bin_width(y_true.reshape(1,-1)[0], return_bins=True)[1])
        distr1, distr2 = self.probability_dist(y_score, y_true, bins)
        KLdl = torch.nn.functional.kl_div(torch.tensor(distr1).log(), torch.tensor(distr2), log_target=False, reduction='sum').item()
        
        # total loss
        custom_loss = cl_weights[0] * rmse + cl_weights[1] * KLdl + cl_weights[2] * cml
        return custom_loss
    
    # calculate sum of distances to the closest cluster mean
    def cluster_mean_loss(self, cluster_means, y_score, y_name, x_val, y_val):
        
        # reorder cluster_means to match x_val columns (predicted feature is last column)
        cols = cluster_means.columns.tolist()
        feature_col = X.columns.get_loc(y_name)
        cols = cols[:feature_col] + cols[feature_col+1:] + [y_name]
        
        # x values extended by predicted values
        x_extended = pd.DataFrame(np.hstack((x_val, y_score)), columns=cols)


        # calculate distances to each cluster and select the closest one
        dist = []
        for cluster in range(cluster_means.shape[0]):
            dist.append(np.linalg.norm((x_extended - cluster_means.iloc[cluster]), axis=1))
            
        dist = pd.DataFrame(dist).T
        min_dist = dist.assign(min_dist=lambda d: d.min(1))["min_dist"]
        
        return sum(min_dist)
    
    # calculate probabilities
    def probability_dist(self, x, y, bins):
        # transforms 2 series into their probability distributions
        # histogram
        hist_xy = np.histogram2d(np.asarray(x)[:,0], np.asarray(y)[:,0], bins=bins)[0]

        # compute marginals
        hist_xy = hist_xy + sys.float_info.min # prevent division with 0
        hist_xy = hist_xy / np.sum(hist_xy)
        hist_x = np.sum(hist_xy, axis=1)
        hist_y = np.sum(hist_xy, axis=0)
        return(hist_x, hist_y)

# %% [markdown]
# ### 2.2. Fill missing values (TabNet).
#
# **Approach 1:**\
# For each feature that contains missing values, use all rows with complete other features as train set and predict missing values of the feature.\
# &rarr; Problem: lots of models, especially for high-dimensional datasets.
# Also problem, if more than one feature is missing values. &rarr; see Approach 2
#
# **Approach 2:**\
# Mask missing values as -1 (or some other value) and fit a model predicting each feature just like in approach 1.\
# &rarr; one model for each feature containing missing values.\
# Possible adaption: use predicted values to predict subsequent values (instead of using -1)

# %%
import time

from pytorch_tabnet.tab_model import TabNetRegressor
from sklearn.model_selection import train_test_split

features_to_predict = X_mv.columns[X_mv.isnull().any()]
X_reconstr = {}
output["costs"] = {}
output["runtimes"] = {}
output["predictions"] = {}

for run in range(config["RQ2"]["runs"]):
    
    print(f"Run {run + 1} / {config['RQ2']['runs']}")
    X_reconstr[run] = []
    output["costs"][f"run_{run}"] = {}
    output["runtimes"][f"run_{run}"] = {}
    output["predictions"][f"run_{run}"] = {}
    
    for i, experiment_value in enumerate(experiment_variable_values):
        
        #config[experiment_dict_key][config["general"]["experiment_variable"]] = experiment_value
        regressor_param["optimizer_params"] = {"lr":config["regressor_param"]["optimizer_params"][i]}
        
        time_start = time.time()
        X_reconstr[run].append(X_mv.copy())
        output["costs"][f"run_{run}"][str(experiment_value)] = {}
        output["runtimes"][f"run_{run}"][str(experiment_value)] = {}
        output["predictions"][f"run_{run}"][str(experiment_value)] = {}
        
        for feature in features_to_predict:
            
            # select % of features for prediction based on pred_features (e.g. 10% of randomly selected features)
            n_features = math.ceil(config["RQ2"]["pred_features"] * (len(X_mv.columns)) - 1)
            X_mv_masked = X_mv.copy().drop(feature, axis=1).sample(n=n_features, axis='columns')
            other_features = X_mv_masked.columns

            # mask other columns' missing values as defined in config (missing_value_mask)
            X_mv_masked[feature] = X_mv[feature]
            X_mv_masked[other_features] = X_mv_masked[(other_features)].fillna(config["general"]["missing_value_mask"])

            # separate complete rows as train data
            # separate column with missing values as target
            test_data = X_mv_masked[X_mv_masked[feature].isna()].drop(feature, axis=1).to_numpy()
            train_data = X_mv_masked[X_mv_masked[feature].notna()]
            train_features = train_data.drop(columns=feature).to_numpy()
            train_target = train_data[feature].to_numpy().reshape(-1,1)

            x_train, x_val, y_train, y_val = train_test_split(train_features, train_target, train_size=config["training"]["train_val_split"])

            # create & train model
            model = TabNetRegressor(**regressor_param)
            if config["model_param"]["eval_metric"] == ["custom_loss"]:
                model.fit(
                    x_train, y_train,
                    eval_set=[(x_val, y_val)],
                    **config["model_param"],
                    cluster_means=cluster_means,
                    y_name=feature,
                    x_val=x_val,
                    y_val=y_val,
                    cl_weights=config["training"]["cl_weights"]
                )
            else:
                model.fit(
                    x_train, y_train,
                    eval_set=[(x_val, y_val)],
                    **config["model_param"]
                )     

            #track runtime
            time_end = time.time()

            # save costs
            output["costs"][f"run_{run}"][str(experiment_value)][feature] = model.best_cost

            # save predictions
            predictions = [x[0] for x in model.predict(test_data)]
            output["predictions"][f"run_{run}"][str(experiment_value)][feature] = predictions
            
            # fill missing values with model predictions
            X_reconstr[run][i].loc[X_reconstr[run][i][feature].isna(), feature] = predictions

            # save outputs
            if save_models:

                # save model
                torch.save(model, os.path.join(models_path, f"Model_run{run}_{config['general']['experiment_variable']}{experiment_value}_{feature}.pt"))
            
            if save_output:
                # save runtimes
                output["runtimes"][f"run_{run}"][str(experiment_value)][feature] = time_end - time_start
# Out:
# Run 1 / 100
#
# Early stopping occurred at epoch 191 with best_epoch = 141 and best_val_0_custom_loss = 5.06088
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 74 with best_epoch = 24 and best_val_0_custom_loss = 38.49842
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 175 with best_epoch = 125 and best_val_0_custom_loss = 4.91055
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 181 with best_epoch = 131 and best_val_0_custom_loss = 4.28889
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_custom_loss = 33.06808
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 239 with best_epoch = 189 and best_val_0_custom_loss = 4.22593
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 150 with best_epoch = 100 and best_val_0_custom_loss = 3.95652
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_custom_loss = 17.02372
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 238 with best_epoch = 188 and best_val_0_custom_loss = 4.03414
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 71 with best_epoch = 21 and best_val_0_custom_loss = 4.27611
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 55 with best_epoch = 5 and best_val_0_custom_loss = 12.64669
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 214 and best_val_0_custom_loss = 4.27385
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 175 with best_epoch = 125 and best_val_0_custom_loss = 4.19563
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 87 with best_epoch = 37 and best_val_0_custom_loss = 24.62152
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 242 and best_val_0_custom_loss = 4.00031
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 203 and best_val_0_custom_loss = 3.94074
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 100 with best_epoch = 50 and best_val_0_custom_loss = 9.70637
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 246 and best_val_0_custom_loss = 4.05085
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 245 and best_val_0_custom_loss = 4.60018
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 82 with best_epoch = 32 and best_val_0_custom_loss = 16.84403
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 224 and best_val_0_custom_loss = 4.54686
# Best weights from best epoch are automatically used!
# Run 2 / 100
#
# Early stopping occurred at epoch 112 with best_epoch = 62 and best_val_0_custom_loss = 6.11917
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_custom_loss = 51.96997
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 147 with best_epoch = 97 and best_val_0_custom_loss = 4.78793
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_custom_loss = 8.08682
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 58 with best_epoch = 8 and best_val_0_custom_loss = 43.15509
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 177 with best_epoch = 127 and best_val_0_custom_loss = 4.82833
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 80 with best_epoch = 30 and best_val_0_custom_loss = 4.58059
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_custom_loss = 18.61222
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 240 and best_val_0_custom_loss = 3.93261
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 124 with best_epoch = 74 and best_val_0_custom_loss = 3.93826
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 50 with best_epoch = 0 and best_val_0_custom_loss = 24.6738
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 120 with best_epoch = 70 and best_val_0_custom_loss = 4.53596
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 150 with best_epoch = 100 and best_val_0_custom_loss = 6.29168
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 224 with best_epoch = 174 and best_val_0_custom_loss = 12.68954
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 87 with best_epoch = 37 and best_val_0_custom_loss = 4.17669
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 189 with best_epoch = 139 and best_val_0_custom_loss = 3.89758
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 50 with best_epoch = 0 and best_val_0_custom_loss = 27.0873
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 222 and best_val_0_custom_loss = 4.11017
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 138 with best_epoch = 88 and best_val_0_custom_loss = 4.29941
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 172 with best_epoch = 122 and best_val_0_custom_loss = 11.51082
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 240 with best_epoch = 190 and best_val_0_custom_loss = 4.72639
# Best weights from best epoch are automatically used!
# Run 3 / 100
#
# Early stopping occurred at epoch 52 with best_epoch = 2 and best_val_0_custom_loss = 7.81319
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_custom_loss = 45.4004
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 169 with best_epoch = 119 and best_val_0_custom_loss = 5.00841
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 105 with best_epoch = 55 and best_val_0_custom_loss = 4.6338
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 76 with best_epoch = 26 and best_val_0_custom_loss = 38.76866
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 88 with best_epoch = 38 and best_val_0_custom_loss = 6.00529
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 97 with best_epoch = 47 and best_val_0_custom_loss = 4.3665
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 66 with best_epoch = 16 and best_val_0_custom_loss = 17.17216
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 186 with best_epoch = 136 and best_val_0_custom_loss = 4.94271
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 65 with best_epoch = 15 and best_val_0_custom_loss = 5.41724
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 51 with best_epoch = 1 and best_val_0_custom_loss = 39.01082
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 217 with best_epoch = 167 and best_val_0_custom_loss = 3.98531
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_custom_loss = 4.68166
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 228 and best_val_0_custom_loss = 11.19433
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_custom_loss = 4.38082
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 100 with best_epoch = 50 and best_val_0_custom_loss = 5.90528
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 94 with best_epoch = 44 and best_val_0_custom_loss = 15.40411
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 3.7705
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 109 with best_epoch = 59 and best_val_0_custom_loss = 3.83711
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 246 and best_val_0_custom_loss = 12.64741
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 131 with best_epoch = 81 and best_val_0_custom_loss = 4.15812
# Best weights from best epoch are automatically used!
# Run 4 / 100
#
# Early stopping occurred at epoch 247 with best_epoch = 197 and best_val_0_custom_loss = 3.92846
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 65 with best_epoch = 15 and best_val_0_custom_loss = 46.87086
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 137 with best_epoch = 87 and best_val_0_custom_loss = 4.9249
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 150 with best_epoch = 100 and best_val_0_custom_loss = 1.5045
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 64 with best_epoch = 14 and best_val_0_custom_loss = 29.84765
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 208 with best_epoch = 158 and best_val_0_custom_loss = 4.31401
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 133 with best_epoch = 83 and best_val_0_custom_loss = 4.39691
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_custom_loss = 14.57918
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 149 with best_epoch = 99 and best_val_0_custom_loss = 3.8558
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 69 with best_epoch = 19 and best_val_0_custom_loss = 4.34269
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 54 with best_epoch = 4 and best_val_0_custom_loss = 25.05368
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 58 with best_epoch = 8 and best_val_0_custom_loss = 5.44547
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 123 with best_epoch = 73 and best_val_0_custom_loss = 3.98486
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 245 and best_val_0_custom_loss = 10.43991
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 53 with best_epoch = 3 and best_val_0_custom_loss = 18.8813
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 116 with best_epoch = 66 and best_val_0_custom_loss = 4.65799
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 50 with best_epoch = 0 and best_val_0_custom_loss = 20.26756
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 105 with best_epoch = 55 and best_val_0_custom_loss = 4.66963
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 114 with best_epoch = 64 and best_val_0_custom_loss = 3.89368
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 245 and best_val_0_custom_loss = 16.81763
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 113 with best_epoch = 63 and best_val_0_custom_loss = 6.12307
# Best weights from best epoch are automatically used!
# Run 5 / 100
# Stop training because you reached max_epochs = 250 with best_epoch = 247 and best_val_0_custom_loss = 4.15787
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 82 with best_epoch = 32 and best_val_0_custom_loss = 39.01062
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 185 with best_epoch = 135 and best_val_0_custom_loss = 4.48143
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 224 and best_val_0_custom_loss = 4.24363
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 54 with best_epoch = 4 and best_val_0_custom_loss = 37.15069
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 90 with best_epoch = 40 and best_val_0_custom_loss = 4.9296
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 142 with best_epoch = 92 and best_val_0_custom_loss = 4.16692
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 78 with best_epoch = 28 and best_val_0_custom_loss = 30.50607
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 89 with best_epoch = 39 and best_val_0_custom_loss = 5.49582
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 57 with best_epoch = 7 and best_val_0_custom_loss = 9.26406
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 61 with best_epoch = 11 and best_val_0_custom_loss = 21.09425
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 240 and best_val_0_custom_loss = 3.98503
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 111 with best_epoch = 61 and best_val_0_custom_loss = 3.94589
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 51 with best_epoch = 1 and best_val_0_custom_loss = 24.51676
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.02255
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 84 with best_epoch = 34 and best_val_0_custom_loss = 4.64995
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 230 and best_val_0_custom_loss = 9.85619
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 111 with best_epoch = 61 and best_val_0_custom_loss = 4.01387
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 102 with best_epoch = 52 and best_val_0_custom_loss = 4.19723
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 200 with best_epoch = 150 and best_val_0_custom_loss = 10.43243
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 203 with best_epoch = 153 and best_val_0_custom_loss = 4.16506
# Best weights from best epoch are automatically used!
# Run 6 / 100
#
# Early stopping occurred at epoch 132 with best_epoch = 82 and best_val_0_custom_loss = 4.00115
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 80 with best_epoch = 30 and best_val_0_custom_loss = 49.04708
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 165 with best_epoch = 115 and best_val_0_custom_loss = 5.10754
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 66 with best_epoch = 16 and best_val_0_custom_loss = 7.32882
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 93 with best_epoch = 43 and best_val_0_custom_loss = 40.84725
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.26609
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_custom_loss = 4.89693
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 72 with best_epoch = 22 and best_val_0_custom_loss = 33.44593
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 248 and best_val_0_custom_loss = 4.11196
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 161 with best_epoch = 111 and best_val_0_custom_loss = 3.74765
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 51 with best_epoch = 1 and best_val_0_custom_loss = 42.32461
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 206 and best_val_0_custom_loss = 3.82059
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 61 with best_epoch = 11 and best_val_0_custom_loss = 5.28037
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_custom_loss = 29.47783
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 155 with best_epoch = 105 and best_val_0_custom_loss = 3.80936
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 167 with best_epoch = 117 and best_val_0_custom_loss = 3.90012
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 10.43696
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 97 with best_epoch = 47 and best_val_0_custom_loss = 1.588
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 208 with best_epoch = 158 and best_val_0_custom_loss = 3.92795
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 225 and best_val_0_custom_loss = 9.55024
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 111 with best_epoch = 61 and best_val_0_custom_loss = 6.40727
# Best weights from best epoch are automatically used!
# Run 7 / 100
#
# Early stopping occurred at epoch 108 with best_epoch = 58 and best_val_0_custom_loss = 6.93827
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 107 with best_epoch = 57 and best_val_0_custom_loss = 44.59626
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 207 with best_epoch = 157 and best_val_0_custom_loss = 4.65262
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 126 with best_epoch = 76 and best_val_0_custom_loss = 6.42972
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_custom_loss = 41.20252
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 246 and best_val_0_custom_loss = 4.21146
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 118 with best_epoch = 68 and best_val_0_custom_loss = 4.13108
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 103 with best_epoch = 53 and best_val_0_custom_loss = 21.24722
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 214 with best_epoch = 164 and best_val_0_custom_loss = 4.22445
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 243 and best_val_0_custom_loss = 1.43017
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 237 and best_val_0_custom_loss = 12.66733
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 1.17398
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 247 with best_epoch = 197 and best_val_0_custom_loss = 4.40766
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 50 with best_epoch = 0 and best_val_0_custom_loss = 28.65
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 80 with best_epoch = 30 and best_val_0_custom_loss = 5.00853
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 208 with best_epoch = 158 and best_val_0_custom_loss = 4.01138
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 118 with best_epoch = 68 and best_val_0_custom_loss = 11.52844
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.2259
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 125 with best_epoch = 75 and best_val_0_custom_loss = 5.4474
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 227 with best_epoch = 177 and best_val_0_custom_loss = 13.8208
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 216 with best_epoch = 166 and best_val_0_custom_loss = 5.50832
# Best weights from best epoch are automatically used!
# Run 8 / 100
#
# Early stopping occurred at epoch 91 with best_epoch = 41 and best_val_0_custom_loss = 5.14993
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 133 with best_epoch = 83 and best_val_0_custom_loss = 51.49398
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 135 with best_epoch = 85 and best_val_0_custom_loss = 5.83304
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 243 with best_epoch = 193 and best_val_0_custom_loss = 4.60239
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 59 with best_epoch = 9 and best_val_0_custom_loss = 40.61678
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 107 with best_epoch = 57 and best_val_0_custom_loss = 4.59806
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 175 with best_epoch = 125 and best_val_0_custom_loss = 1.49868
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 94 with best_epoch = 44 and best_val_0_custom_loss = 19.4498
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 152 with best_epoch = 102 and best_val_0_custom_loss = 4.03577
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 200 with best_epoch = 150 and best_val_0_custom_loss = 4.27588
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 54 with best_epoch = 4 and best_val_0_custom_loss = 30.13267
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 230 with best_epoch = 180 and best_val_0_custom_loss = 4.58702
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 199 with best_epoch = 149 and best_val_0_custom_loss = 1.13622
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 215 and best_val_0_custom_loss = 14.07216
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 115 with best_epoch = 65 and best_val_0_custom_loss = 4.73753
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 158 with best_epoch = 108 and best_val_0_custom_loss = 4.27288
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 11.71782
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 216 with best_epoch = 166 and best_val_0_custom_loss = 4.18318
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 122 with best_epoch = 72 and best_val_0_custom_loss = 4.67793
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 186 with best_epoch = 136 and best_val_0_custom_loss = 12.9148
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 113 with best_epoch = 63 and best_val_0_custom_loss = 1.64015
# Best weights from best epoch are automatically used!
# Run 9 / 100
#
# Early stopping occurred at epoch 135 with best_epoch = 85 and best_val_0_custom_loss = 5.05664
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 77 with best_epoch = 27 and best_val_0_custom_loss = 44.90554
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.66844
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 163 with best_epoch = 113 and best_val_0_custom_loss = 3.79404
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 72 with best_epoch = 22 and best_val_0_custom_loss = 31.03468
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_custom_loss = 5.86484
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 82 with best_epoch = 32 and best_val_0_custom_loss = 5.76413
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 67 with best_epoch = 17 and best_val_0_custom_loss = 23.702
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 61 with best_epoch = 11 and best_val_0_custom_loss = 7.43485
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 144 with best_epoch = 94 and best_val_0_custom_loss = 4.34155
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 55 with best_epoch = 5 and best_val_0_custom_loss = 18.86367
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 114 with best_epoch = 64 and best_val_0_custom_loss = 4.16779
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 61 with best_epoch = 11 and best_val_0_custom_loss = 6.33714
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 91 with best_epoch = 41 and best_val_0_custom_loss = 13.701
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 86 with best_epoch = 36 and best_val_0_custom_loss = 4.66794
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 156 with best_epoch = 106 and best_val_0_custom_loss = 4.00146
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 50 with best_epoch = 0 and best_val_0_custom_loss = 25.00745
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 205 with best_epoch = 155 and best_val_0_custom_loss = 3.96457
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 194 with best_epoch = 144 and best_val_0_custom_loss = 4.61657
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 224 and best_val_0_custom_loss = 13.21263
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 87 with best_epoch = 37 and best_val_0_custom_loss = 6.09391
# Best weights from best epoch are automatically used!
# Run 10 / 100
#
# Early stopping occurred at epoch 98 with best_epoch = 48 and best_val_0_custom_loss = 4.98646
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_custom_loss = 48.6964
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 112 with best_epoch = 62 and best_val_0_custom_loss = 5.92928
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 228 with best_epoch = 178 and best_val_0_custom_loss = 4.20485
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 69 with best_epoch = 19 and best_val_0_custom_loss = 41.12233
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 184 with best_epoch = 134 and best_val_0_custom_loss = 4.25194
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 140 with best_epoch = 90 and best_val_0_custom_loss = 4.577
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 130 with best_epoch = 80 and best_val_0_custom_loss = 33.14873
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 246 and best_val_0_custom_loss = 4.03307
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 138 with best_epoch = 88 and best_val_0_custom_loss = 1.3136
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_custom_loss = 21.02334
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 77 with best_epoch = 27 and best_val_0_custom_loss = 4.85165
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_custom_loss = 4.33095
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 79 with best_epoch = 29 and best_val_0_custom_loss = 9.63578
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 115 with best_epoch = 65 and best_val_0_custom_loss = 4.21042
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 95 with best_epoch = 45 and best_val_0_custom_loss = 5.47984
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 196 with best_epoch = 146 and best_val_0_custom_loss = 9.83558
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 232 and best_val_0_custom_loss = 4.35932
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 125 with best_epoch = 75 and best_val_0_custom_loss = 5.38324
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 243 and best_val_0_custom_loss = 12.95435
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 145 with best_epoch = 95 and best_val_0_custom_loss = 4.20505
# Best weights from best epoch are automatically used!
# Run 11 / 100
#
# Early stopping occurred at epoch 149 with best_epoch = 99 and best_val_0_custom_loss = 5.14603
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 94 with best_epoch = 44 and best_val_0_custom_loss = 38.64582
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 144 with best_epoch = 94 and best_val_0_custom_loss = 4.48918
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 218 with best_epoch = 168 and best_val_0_custom_loss = 4.97297
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 95 with best_epoch = 45 and best_val_0_custom_loss = 41.17421
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.65745
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 61 with best_epoch = 11 and best_val_0_custom_loss = 4.54544
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 59 with best_epoch = 9 and best_val_0_custom_loss = 23.50485
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_custom_loss = 5.79658
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 108 with best_epoch = 58 and best_val_0_custom_loss = 3.98179
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 54 with best_epoch = 4 and best_val_0_custom_loss = 40.33533
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 208 and best_val_0_custom_loss = 1.12079
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 77 with best_epoch = 27 and best_val_0_custom_loss = 4.0655
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 122 with best_epoch = 72 and best_val_0_custom_loss = 12.02351
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.0924
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 135 with best_epoch = 85 and best_val_0_custom_loss = 4.00887
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 74 with best_epoch = 24 and best_val_0_custom_loss = 18.0765
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 121 with best_epoch = 71 and best_val_0_custom_loss = 5.07922
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 200 with best_epoch = 150 and best_val_0_custom_loss = 4.46987
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 224 and best_val_0_custom_loss = 9.91536
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 224 with best_epoch = 174 and best_val_0_custom_loss = 4.39185
# Best weights from best epoch are automatically used!
# Run 12 / 100
#
# Early stopping occurred at epoch 124 with best_epoch = 74 and best_val_0_custom_loss = 4.98108
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 82 with best_epoch = 32 and best_val_0_custom_loss = 47.76116
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 96 with best_epoch = 46 and best_val_0_custom_loss = 1.84614
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 51 with best_epoch = 1 and best_val_0_custom_loss = 9.04617
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 60 with best_epoch = 10 and best_val_0_custom_loss = 38.18039
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 73 with best_epoch = 23 and best_val_0_custom_loss = 5.07371
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 143 with best_epoch = 93 and best_val_0_custom_loss = 3.94925
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 89 with best_epoch = 39 and best_val_0_custom_loss = 22.76406
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 208 and best_val_0_custom_loss = 3.53252
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 52 with best_epoch = 2 and best_val_0_custom_loss = 5.97517
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 51 with best_epoch = 1 and best_val_0_custom_loss = 54.82418
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 151 with best_epoch = 101 and best_val_0_custom_loss = 4.33733
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 80 with best_epoch = 30 and best_val_0_custom_loss = 4.01327
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 216 with best_epoch = 166 and best_val_0_custom_loss = 9.92085
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 139 with best_epoch = 89 and best_val_0_custom_loss = 4.20129
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 204 with best_epoch = 154 and best_val_0_custom_loss = 4.26777
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 147 with best_epoch = 97 and best_val_0_custom_loss = 13.51762
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 184 with best_epoch = 134 and best_val_0_custom_loss = 4.35675
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 142 with best_epoch = 92 and best_val_0_custom_loss = 4.40414
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 201 and best_val_0_custom_loss = 11.64126
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 126 with best_epoch = 76 and best_val_0_custom_loss = 4.68075
# Best weights from best epoch are automatically used!
# Run 13 / 100
#
# Early stopping occurred at epoch 85 with best_epoch = 35 and best_val_0_custom_loss = 6.33767
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 118 with best_epoch = 68 and best_val_0_custom_loss = 48.34663
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 100 with best_epoch = 50 and best_val_0_custom_loss = 5.78775
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 69 with best_epoch = 19 and best_val_0_custom_loss = 5.61042
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_custom_loss = 31.62165
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 137 with best_epoch = 87 and best_val_0_custom_loss = 1.36689
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 88 with best_epoch = 38 and best_val_0_custom_loss = 4.08171
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 85 with best_epoch = 35 and best_val_0_custom_loss = 18.11912
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 115 with best_epoch = 65 and best_val_0_custom_loss = 4.79189
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 77 with best_epoch = 27 and best_val_0_custom_loss = 4.14934
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 54 with best_epoch = 4 and best_val_0_custom_loss = 46.70334
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 107 with best_epoch = 57 and best_val_0_custom_loss = 4.33109
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 60 with best_epoch = 10 and best_val_0_custom_loss = 4.41076
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 50 with best_epoch = 0 and best_val_0_custom_loss = 40.36027
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 53 with best_epoch = 3 and best_val_0_custom_loss = 8.74006
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_custom_loss = 4.0036
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 126 with best_epoch = 76 and best_val_0_custom_loss = 8.23287
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 93 with best_epoch = 43 and best_val_0_custom_loss = 4.70773
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 152 with best_epoch = 102 and best_val_0_custom_loss = 4.29373
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 113 with best_epoch = 63 and best_val_0_custom_loss = 76.40857
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 248 and best_val_0_custom_loss = 4.18729
# Best weights from best epoch are automatically used!
# Run 14 / 100
# Early stopping occurred at epoch 114 with best_epoch = 64 and best_val_0_custom_loss = 4.72461
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 69 with best_epoch = 19 and best_val_0_custom_loss = 48.2146
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 181 with best_epoch = 131 and best_val_0_custom_loss = 4.36039
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 66 with best_epoch = 16 and best_val_0_custom_loss = 5.79669
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 59 with best_epoch = 9 and best_val_0_custom_loss = 33.72078
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 166 with best_epoch = 116 and best_val_0_custom_loss = 4.65348
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 152 with best_epoch = 102 and best_val_0_custom_loss = 4.2852
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 113 with best_epoch = 63 and best_val_0_custom_loss = 17.69807
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 1.08648
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 54 with best_epoch = 4 and best_val_0_custom_loss = 11.15324
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 12.52952
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 92 with best_epoch = 42 and best_val_0_custom_loss = 4.65334
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 80 with best_epoch = 30 and best_val_0_custom_loss = 4.34359
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 128 with best_epoch = 78 and best_val_0_custom_loss = 20.28504
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.02001
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 116 with best_epoch = 66 and best_val_0_custom_loss = 4.31485
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 176 with best_epoch = 126 and best_val_0_custom_loss = 13.77171
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.38149
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 162 with best_epoch = 112 and best_val_0_custom_loss = 4.82205
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 241 with best_epoch = 191 and best_val_0_custom_loss = 11.89164
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 219 with best_epoch = 169 and best_val_0_custom_loss = 4.61761
# Best weights from best epoch are automatically used!
# Run 15 / 100
#
# Early stopping occurred at epoch 60 with best_epoch = 10 and best_val_0_custom_loss = 10.51967
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 141 with best_epoch = 91 and best_val_0_custom_loss = 48.91308
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 84 with best_epoch = 34 and best_val_0_custom_loss = 2.33235
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 62 with best_epoch = 12 and best_val_0_custom_loss = 4.5093
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 84 with best_epoch = 34 and best_val_0_custom_loss = 23.58257
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.09977
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_custom_loss = 4.55658
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 80 with best_epoch = 30 and best_val_0_custom_loss = 21.1258
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 3.98537
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 76 with best_epoch = 26 and best_val_0_custom_loss = 4.11774
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 53 with best_epoch = 3 and best_val_0_custom_loss = 20.1558
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 153 with best_epoch = 103 and best_val_0_custom_loss = 4.60449
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 143 with best_epoch = 93 and best_val_0_custom_loss = 4.19566
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 168 with best_epoch = 118 and best_val_0_custom_loss = 11.04821
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.2999
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 241 with best_epoch = 191 and best_val_0_custom_loss = 3.74501
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 179 with best_epoch = 129 and best_val_0_custom_loss = 12.04138
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 234 and best_val_0_custom_loss = 4.37833
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 190 with best_epoch = 140 and best_val_0_custom_loss = 3.79056
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 202 with best_epoch = 152 and best_val_0_custom_loss = 15.05538
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 218 and best_val_0_custom_loss = 4.27698
# Best weights from best epoch are automatically used!
# Run 16 / 100
#
# Early stopping occurred at epoch 112 with best_epoch = 62 and best_val_0_custom_loss = 5.15659
# Best weights from best epoch are automatically used!
#
# ...
#
# Early stopping occurred at epoch 65 with best_epoch = 15 and best_val_0_custom_loss = 7.44354
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 126 with best_epoch = 76 and best_val_0_custom_loss = 1.95896
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 68 with best_epoch = 18 and best_val_0_custom_loss = 23.41906
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 210 with best_epoch = 160 and best_val_0_custom_loss = 4.29889
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 139 with best_epoch = 89 and best_val_0_custom_loss = 3.90328
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 54 with best_epoch = 4 and best_val_0_custom_loss = 28.95462
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.1409
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 179 with best_epoch = 129 and best_val_0_custom_loss = 4.33849
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 130 with best_epoch = 80 and best_val_0_custom_loss = 13.11053
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 149 with best_epoch = 99 and best_val_0_custom_loss = 4.79374
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 139 with best_epoch = 89 and best_val_0_custom_loss = 5.75136
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 235 with best_epoch = 185 and best_val_0_custom_loss = 10.51968
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 156 with best_epoch = 106 and best_val_0_custom_loss = 7.14115
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 191 with best_epoch = 141 and best_val_0_custom_loss = 3.80022
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 180 with best_epoch = 130 and best_val_0_custom_loss = 11.19511
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 243 and best_val_0_custom_loss = 4.04404
# Best weights from best epoch are automatically used!
# Run 96 / 100
#
# Early stopping occurred at epoch 171 with best_epoch = 121 and best_val_0_custom_loss = 4.21121
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 75 with best_epoch = 25 and best_val_0_custom_loss = 42.40586
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 85 with best_epoch = 35 and best_val_0_custom_loss = 5.8189
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 239 with best_epoch = 189 and best_val_0_custom_loss = 4.60519
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_custom_loss = 26.4251
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 98 with best_epoch = 48 and best_val_0_custom_loss = 4.46562
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 153 with best_epoch = 103 and best_val_0_custom_loss = 4.14921
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 157 with best_epoch = 107 and best_val_0_custom_loss = 22.89812
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 223 with best_epoch = 173 and best_val_0_custom_loss = 4.38319
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 93 with best_epoch = 43 and best_val_0_custom_loss = 4.43361
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 185 with best_epoch = 135 and best_val_0_custom_loss = 12.60669
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 230 with best_epoch = 180 and best_val_0_custom_loss = 4.27981
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 127 with best_epoch = 77 and best_val_0_custom_loss = 4.03054
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 203 with best_epoch = 153 and best_val_0_custom_loss = 16.03583
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 222 with best_epoch = 172 and best_val_0_custom_loss = 4.66255
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 116 with best_epoch = 66 and best_val_0_custom_loss = 4.39807
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 205 with best_epoch = 155 and best_val_0_custom_loss = 10.47371
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 231 and best_val_0_custom_loss = 4.40262
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 103 with best_epoch = 53 and best_val_0_custom_loss = 4.08748
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 103 with best_epoch = 53 and best_val_0_custom_loss = 23.66755
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 206 and best_val_0_custom_loss = 4.02143
# Best weights from best epoch are automatically used!
# Run 97 / 100
#
# Early stopping occurred at epoch 126 with best_epoch = 76 and best_val_0_custom_loss = 1.99213
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 70 with best_epoch = 20 and best_val_0_custom_loss = 48.23298
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 197 with best_epoch = 147 and best_val_0_custom_loss = 5.42933
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 161 with best_epoch = 111 and best_val_0_custom_loss = 1.51439
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_custom_loss = 43.37403
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 205 with best_epoch = 155 and best_val_0_custom_loss = 4.79999
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 166 with best_epoch = 116 and best_val_0_custom_loss = 4.12123
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 105 with best_epoch = 55 and best_val_0_custom_loss = 24.25772
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 155 with best_epoch = 105 and best_val_0_custom_loss = 4.40734
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 119 with best_epoch = 69 and best_val_0_custom_loss = 3.82768
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 100 with best_epoch = 50 and best_val_0_custom_loss = 14.36907
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 64 with best_epoch = 14 and best_val_0_custom_loss = 1.50973
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 53 with best_epoch = 3 and best_val_0_custom_loss = 2.52149
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 122 with best_epoch = 72 and best_val_0_custom_loss = 14.62626
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 87 with best_epoch = 37 and best_val_0_custom_loss = 5.10384
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 241 with best_epoch = 191 and best_val_0_custom_loss = 1.13579
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 222 and best_val_0_custom_loss = 12.17427
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 246 and best_val_0_custom_loss = 4.1108
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 129 with best_epoch = 79 and best_val_0_custom_loss = 4.16648
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 220 and best_val_0_custom_loss = 13.20604
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 136 with best_epoch = 86 and best_val_0_custom_loss = 4.65028
# Best weights from best epoch are automatically used!
# Run 98 / 100
#
# Early stopping occurred at epoch 209 with best_epoch = 159 and best_val_0_custom_loss = 4.4887
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 57 with best_epoch = 7 and best_val_0_custom_loss = 35.44506
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 66 with best_epoch = 16 and best_val_0_custom_loss = 5.88523
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 3.78204
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 78 with best_epoch = 28 and best_val_0_custom_loss = 35.12853
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 81 with best_epoch = 31 and best_val_0_custom_loss = 2.38186
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 111 with best_epoch = 61 and best_val_0_custom_loss = 4.22581
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 86 with best_epoch = 36 and best_val_0_custom_loss = 27.27077
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 129 with best_epoch = 79 and best_val_0_custom_loss = 4.39635
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 94 with best_epoch = 44 and best_val_0_custom_loss = 5.77588
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 56 with best_epoch = 6 and best_val_0_custom_loss = 26.89477
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 247 and best_val_0_custom_loss = 0.9156
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 93 with best_epoch = 43 and best_val_0_custom_loss = 4.1045
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 199 with best_epoch = 149 and best_val_0_custom_loss = 12.92338
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 111 with best_epoch = 61 and best_val_0_custom_loss = 4.62076
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 135 with best_epoch = 85 and best_val_0_custom_loss = 4.0072
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 146 with best_epoch = 96 and best_val_0_custom_loss = 7.17666
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 106 with best_epoch = 56 and best_val_0_custom_loss = 4.39073
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 202 and best_val_0_custom_loss = 1.63477
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 221 and best_val_0_custom_loss = 6.89154
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 225 and best_val_0_custom_loss = 4.45859
# Best weights from best epoch are automatically used!
# Run 99 / 100
# Stop training because you reached max_epochs = 250 with best_epoch = 237 and best_val_0_custom_loss = 3.9478
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 92 with best_epoch = 42 and best_val_0_custom_loss = 41.25103
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 66 with best_epoch = 16 and best_val_0_custom_loss = 7.35191
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 158 with best_epoch = 108 and best_val_0_custom_loss = 4.19023
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 55 with best_epoch = 5 and best_val_0_custom_loss = 33.52482
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 249 and best_val_0_custom_loss = 4.16159
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 112 with best_epoch = 62 and best_val_0_custom_loss = 4.76569
# Best weights from best epoch are automatically used!
# Early stopping occurred at epoch 64 with best_epoch = 14 and best_val_0_custom_loss = 22.10687
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 89 with best_epoch = 39 and best_val_0_custom_loss = 4.51795
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 140 with best_epoch = 90 and best_val_0_custom_loss = 4.15338
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 244 with best_epoch = 194 and best_val_0_custom_loss = 17.95366
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 108 with best_epoch = 58 and best_val_0_custom_loss = 4.88572
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 67 with best_epoch = 17 and best_val_0_custom_loss = 4.26458
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 79 with best_epoch = 29 and best_val_0_custom_loss = 24.18401
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 209 and best_val_0_custom_loss = 4.16154
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 140 with best_epoch = 90 and best_val_0_custom_loss = 4.28838
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 229 and best_val_0_custom_loss = 13.4463
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 153 with best_epoch = 103 and best_val_0_custom_loss = 4.28235
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 111 with best_epoch = 61 and best_val_0_custom_loss = 7.04974
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 236 with best_epoch = 186 and best_val_0_custom_loss = 9.01652
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 140 with best_epoch = 90 and best_val_0_custom_loss = 4.21419
# Best weights from best epoch are automatically used!
# Run 100 / 100
#
# Early stopping occurred at epoch 202 with best_epoch = 152 and best_val_0_custom_loss = 4.09898
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 64 with best_epoch = 14 and best_val_0_custom_loss = 43.68129
# Best weights from best epoch are automatically used!
# Stop training because you reached max_epochs = 250 with best_epoch = 216 and best_val_0_custom_loss = 4.22964
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 128 with best_epoch = 78 and best_val_0_custom_loss = 28.30472
# Best weights from best epoch are automatically used!
#
# Early stopping occurred at epoch 79 with best_epoch = 29 and best_val_0_custom_loss = 31.31878
# Best weights from best epoch are automatically used!

# %% [markdown]
# ## 3. Reconstruct Dataset
# choose best model based on min. squared custom loss (punishing large outliers in losses for single features)

# %%
best_per_run = []
best_per_run_index = []
for run in range(config["RQ2"]["runs"]):
    cost_list = list(output["costs"][f"run_{run}"].values())
    cost_totals = [sum(c**2 for c in list(x.values())) for x in cost_list]
    best_per_run.append(min(cost_totals))
    best_per_run_index.append(cost_totals.index(min(cost_totals)))
    
best_run = best_per_run.index(min(best_per_run))
best_model = best_per_run_index[best_run]
print(f"Best model: run {best_run} model {best_model}")

X_best = X_reconstr[best_run][best_model]

# %% [markdown]
# ## 4. Clustering
# Apply k-means (k=3) on reconstructed data. In order to make the clusters comparable, the k-Means labels will be replaced using Munkres / Hungarian algorithm as explained here:\
# https://gist.github.com/siolag161/dc6e42b64e1bde1f263b \
# https://github.com/benchaplin/hungarian-algorithm

# %%
# apply clustering
labels_reconstr = []
for run in range(config["RQ2"]["runs"]):
    labels_reconstr.append([])
    for i, var in enumerate(experiment_variable_values):
        
        X_reconstr_scaled = pd.DataFrame(StandardScaler().fit_transform(X_reconstr[run][i]))
        k_mean_reconstr = KMeans(n_clusters=3).fit(X_reconstr_scaled)
        
        cost_matrix = make_cost_matrix(k_mean_reconstr.labels_, labels_true)
        indexes = Munkres().compute(cost_matrix)
        mapping = [new for (_, new) in indexes]
        
        labels_reconstr[run].append(np.choose(k_mean_reconstr.labels_,mapping).astype(np.int64))

# %% [markdown]
# ## 5. Cluster Performance

# %% [markdown]
# ### 5.1 Feature Distributions
# #### 5.1.1 Distr. Plots based on best model predictions

# %%
# plot distributions
bins = len(astropy.stats.freedman_bin_width(X[feature], return_bins=True)[1])
n_feat = len(features_to_predict) if len(features_to_predict) > 1 else 2

fig, (ax) = plt.subplots(n_feat, 2, figsize=(10,n_feat*3))
fig.suptitle(f"distributions based on best model", fontweight='bold')
for n, feature in enumerate(X_best[features_to_predict]):
    ax[n, 0].hist(X[feature], bins=bins)
    ax[n, 0].set_title(f"{feature}_orig")
    ax[n, 1].hist(X_best[feature], bins=bins)
    ax[n, 1].set_title(f"{feature}_reconstructed")

fig.tight_layout()
plt.show()
if save_output:
    plt.savefig(os.path.join(plots_path, "feature distributions.png"), **config["plots"])

# %% [markdown]
# #### 5.1.1 Predictions out of original min/max range

# %%
data = {}

for feature in features_to_predict:
    data[feature] = {}
    n_predictions = sum(X_mv[feature].isna()) * config["RQ2"]["runs"]
    min_val = X[feature].min()
    max_val = X[feature].max()
    n_inliers = 0
    
    for experiment_value in experiment_variable_values:
        data[feature][str(experiment_value)] = 0  
        
        for run in range(config["RQ2"]["runs"]):
            data[feature][str(experiment_value)] += sum([True if x > min_val and x < max_val else False for x in output["predictions"][f"run_{run}"][str(experiment_value)][feature]])
    
        data[feature][str(experiment_value)] = data[feature][str(experiment_value)] / n_predictions

n_features = len(features_to_predict) if len(features_to_predict) > 1 else 2
base_height = 5
base_width = 2
fontsize=20

fig, axs = plt.subplots(n_features, figsize=(len(experiment_variable_values)*base_width,n_features*base_height))
fig.suptitle(f"% of predicted values within original range", fontweight='bold',fontsize=fontsize)

for nr, feature in enumerate(features_to_predict):
    axs[nr].plot(data[feature].keys(), data[feature].values())
    axs[nr].set_xlabel(config["general"]["experiment_variable"],fontsize=fontsize)
    axs[nr].set_ylabel(feature, fontweight='bold', fontsize=fontsize)
    axs[nr].set_ylim([0, 1])
    axs[nr].text(0.9, 0.9, f"{[x for x in config['general']['missing_percent'] if x != 0][nr]}% missing", horizontalalignment='center', verticalalignment='center', transform=axs[nr].transAxes, fontsize=30)

plt.tight_layout() 

if save_output:
    plt.savefig(os.path.join(plots_path, "5_prediction_range_rel.png"), **config["plots"])

plt.show()

# %%
data = {}
for feature in features_to_predict:
    data[feature] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        # add all replaced values from all runs to a list
        data[feature][str(experiment_value)] = []
        for run in range(config["RQ2"]["runs"]): 
            data[feature][str(experiment_value)].extend(output["predictions"][f"run_{run}"][str(experiment_value)][feature])

nr_features = len(features_to_predict) if len(features_to_predict) > 1 else 2
base_height = 5
base_width = 3
fontsize=10

fig, axs = plt.subplots(nr_features, figsize=(len(experiment_variable_values)*base_width,nr_features*base_height))
fig.suptitle(f"Predicted values", fontweight='bold',fontsize=fontsize)

for nr, feature in enumerate(features_to_predict):
    axs[nr].boxplot(data[feature].values(), patch_artist = True)
    axs[nr].set_xticklabels(data[feature].keys(),fontsize=fontsize)
    axs[nr].set_xlabel(config["general"]["experiment_variable"],fontsize=fontsize)
    axs[nr].set_ylabel(feature, fontweight='bold', fontsize=fontsize)
    axs[nr].axhline(X[feature].min(),color='red',ls='-')
    axs[nr].axhline(X[feature].max(),color='red',ls='-')
    axs[nr].text(0.9, 0.9, f"min {X[feature].min()}\nmax {X[feature].max()}", horizontalalignment='center', verticalalignment='center', transform=axs[nr].transAxes, fontsize=fontsize*1.5)

plt.tight_layout() 

if save_output:
    plt.savefig(os.path.join(plots_path, "5_prediction_range_abs.png"), **config["plots"])

plt.show()

# %% [markdown]
# #### 5.1.2 KL Divergence

# %%
# KL Divergence
def kl_divergence(feature1, feature2):
    
    # calculate probability distributions
    def probability_dist(x, y, bins):
        # transforms 2 series into their probability distributions
        # histogram
        hist_xy = np.histogram2d(x, y, bins=bins)[0]

        # compute marginals
        hist_xy = hist_xy + sys.float_info.min # prevent division with 0
        hist_xy = hist_xy / np.sum(hist_xy)
        hist_x = np.sum(hist_xy, axis=1)
        hist_y = np.sum(hist_xy, axis=0)
        return(hist_x, hist_y)

    # calculate kl divergence
    bins = len(astropy.stats.freedman_bin_width(feature1, return_bins=True)[1])
    distr1, distr2 = probability_dist(feature1, feature2, bins)
    return torch.nn.functional.kl_div(torch.tensor(distr1).log(), torch.tensor(distr2), log_target=False, reduction='sum').item()

# %%
output["kl_divergence"] = {}

# save kl divergence
for run in range(config["RQ2"]["runs"]):
    output["kl_divergence"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        output["kl_divergence"][f"run_{run}"][str(experiment_value)] = {}
        for feature in features_to_predict:
            output["kl_divergence"][f"run_{run}"][str(experiment_value)][feature] = kl_divergence(X[feature], X_reconstr[run][i][feature])

# %%
# plot
data = {}
for feature in features_to_predict:
    data[feature] = {}
    for experiment_value in experiment_variable_values:
        data[feature][str(experiment_value)] = [x[str(experiment_value)][feature] for x in output["kl_divergence"].values()]

nr_features = len(features_to_predict) if len(features_to_predict) > 1 else 2
fig, axs = plt.subplots(nr_features, figsize=(len(experiment_variable_values)*3,nr_features*4))
fig.suptitle(f"KL divergence, {config['RQ2']['runs']} runs", fontweight='bold')

for nr, feature in enumerate(features_to_predict):
    axs[nr].boxplot(data[feature].values(), patch_artist = True) # , showfliers=False
    axs[nr].set_xticklabels(data[feature].keys())
    axs[nr].set_xlabel(config["general"]["experiment_variable"])
    axs[nr].set_ylabel(feature, fontweight='bold')

plt.tight_layout() 

if save_output:
    plt.savefig(os.path.join(plots_path, "5_kl_divergence.png"), **config["plots"])
    
plt.show()

# %% [markdown]
# ### 5.2 Silhouette Score

# %%
from sklearn.metrics import silhouette_score

output["silhouette_scores"] = {}
output["silhouette_scores"]["orig_data"] = float(silhouette_score(X, np.ravel(labels_true)))

for run in range(config["RQ2"]["runs"]):
    output["silhouette_scores"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        if len(np.unique(labels_reconstr[run][i])) > 1:
            output["silhouette_scores"][f"run_{run}"][str(experiment_value)] = float(silhouette_score(X_reconstr[run][i], labels_reconstr[run][i]))
        else:
            output["silhouette_scores"][f"run_{run}"][str(experiment_value)] = np.nan

# %%
# plot
sil_scores = output["silhouette_scores"].copy()
del(sil_scores["orig_data"])

data = {}
for experiment_value in experiment_variable_values:
    data[str(experiment_value)] = [x[str(experiment_value)] for x in sil_scores.values()]

fig, ax = plt.subplots()
ax.boxplot(data.values(), patch_artist = True)
ax.set_xticklabels(data.keys())
plt.axhline(y=output['silhouette_scores']['orig_data'], color='r', linestyle='-')
plt.xlabel(config["general"]["experiment_variable"])
plt.ylabel("silhouette score")
plt.title(f"silhouette scores, {config['RQ2']['runs']} runs\noriginal data: {round(output['silhouette_scores']['orig_data'], 2)}")

if save_output:
    plt.savefig(os.path.join(plots_path, "5_silhouette_scores.png"), **config["plots"])

plt.show()

# %% [markdown]
# ### 5.3. ARI Score

# %%
from sklearn.metrics.cluster import adjusted_rand_score

output["ARI_score"] = {}
output["ARI_score"]["orig_data"] = adjusted_rand_score(labels_orig, labels_true)

for run in range(config["RQ2"]["runs"]):
    output["ARI_score"][f"run_{run}"] = {}
    for i, experiment_value in enumerate(experiment_variable_values):
        ari = adjusted_rand_score(labels_reconstr[run][i], labels_true)
        output["ARI_score"][f"run_{run}"][str(experiment_value)] = ari

# %%
# plot
ari = output["ARI_score"].copy()
del(ari['orig_data'])

data = {}
for experiment_value in experiment_variable_values:
    data[str(experiment_value)] = [x[str(experiment_value)] for x in ari.values()]

fig, ax = plt.subplots()
ax.boxplot(data.values(), patch_artist = True)
ax.set_xticklabels(data.keys())
plt.axhline(y=output['ARI_score']['orig_data'], color='r', linestyle='-')
plt.xlabel(config["general"]["experiment_variable"])
plt.ylabel("ARI Score")
plt.title(f"ARI Score, {config['RQ2']['runs']} runs")

if save_output:
    plt.savefig(os.path.join(plots_path, "5_ARI-score.png"), **config["plots"])

plt.show()

# %% [markdown]
# ### 5.5. Save Output

# %%
if save_output:
    # save output file
    with open(output_path, "w") as f:
                toml.dump(output, f)

    # save notebook
    shutil.copy2(nb_name, experiment_path)
